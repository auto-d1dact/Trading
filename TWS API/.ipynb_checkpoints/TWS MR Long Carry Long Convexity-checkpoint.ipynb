# %%
import warnings
warnings.filterwarnings('ignore')
import os

import tws_data 
import statsmodels.tsa.stattools as ts
import statsmodels.api as sm
from ib_insync import *
import numpy as np
import pandas as pd
import datetime as dt
import time
pd.options.display.float_format = '{:,.4f}'.format
# %matplotlib inline
from scipy.stats import norm as norm
import matplotlib.pyplot as plt
import requests as req
from bs4 import BeautifulSoup as bs
import plotly.plotly as py
import plotly.graph_objs as go
from plotly.offline import download_plotlyjs, init_notebook_mode, plot, iplot
init_notebook_mode(connected=True)
import math
# Out:
# <script>requirejs.config({paths: { 'plotly': ['https://cdn.plot.ly/plotly-latest.min']},});if(!window.Plotly) {{require(['plotly'],function(plotly) {window.Plotly=plotly;});}}</script>

# %%
os.chdir('D:\Options Data\IB Intraday')

def create_dfrow(curr_option):
    df_row = pd.DataFrame({'Symbol': curr_option.contract.localSymbol, 
                           'Type':curr_option.contract.right, 
                           'Bid': curr_option.bid, 
                           'Ask': curr_option.ask, 
                           'Volume': curr_option.volume, 
                           'Strike': curr_option.contract.strike,
                           'Expiry': dt.datetime.strptime(curr_option.contract.lastTradeDateOrContractMonth, '%Y%m%d'),
                           'bidIV': curr_option.bidGreeks.impliedVol, 
                           'bidDelta': curr_option.bidGreeks.delta,
                           'bidGamma': curr_option.bidGreeks.gamma, 
                           'bidVega': curr_option.bidGreeks.vega,
                           'bidTheta': curr_option.bidGreeks.theta, 
                           'askIV': curr_option.askGreeks.impliedVol, 
                           'askDelta': curr_option.askGreeks.delta,
                           'askGamma': curr_option.askGreeks.gamma, 
                           'askVega': curr_option.askGreeks.vega,
                           'askTheta': curr_option.askGreeks.theta,
                           'modelIV': curr_option.modelGreeks.impliedVol, 
                           'modelDelta': curr_option.modelGreeks.delta,
                           'modelGamma': curr_option.modelGreeks.gamma, 
                           'modelVega': curr_option.modelGreeks.vega,
                           'modelTheta': curr_option.modelGreeks.theta}, index = [0])
    return df_row

def get_movers():

    indexarb_url = 'http://www.indexarb.com/stockVsIndexesMiddleColumn.html#djIndexAnalysis'
    indexarb_soup = bs(req.get(indexarb_url).text,'lxml')
    indexarb_tables = indexarb_soup.select('table[align="LEFT"]')

    movers = []

    for i, table_html in enumerate(indexarb_tables):
        curr_table = pd.read_html(str(table_html))[2]
        curr_table.columns = curr_table.loc[1,:].tolist()

        if i == 0:
            curr_table = curr_table.iloc[2:,:4].set_index('Index').apply(pd.to_numeric)
        else:
            curr_table = curr_table.iloc[2:,[1,3,4,5,6]].dropna().set_index('Sym').apply(pd.to_numeric)

        curr_table.columns = [x.split(' ')[0] for x in curr_table.columns.tolist()]
        movers.append(curr_table)

    index = movers[0]
    movers = pd.concat(movers[1:], axis = 0)
    movers = movers.sort_values('OneMonth')
    
    return index, movers

def time_remaining(weekly_options, curr_spx):
    typ = weekly_options.reset_index().loc[0,'Type']

    try:
        interest_rate = bs(req.get('https://www.marketwatch.com/investing/bond/tmubmusd01m?countrycode=bx','lxml').text, 'lxml')
        interest_rate = float(interest_rate.select_one('h3[class*="intraday__price"]').select_one('bg-quote').text)/100
    except:
        interest_rate = 0.02422

    weekly_options['a'] = interest_rate - (weekly_options['modelIV']**2)/2

    if typ == 'P':
        weekly_options['b'] = weekly_options['modelIV']*norm.ppf(-weekly_options['modelDelta'])
    if typ == 'C':
        weekly_options['b'] = -weekly_options['modelIV']*norm.ppf(weekly_options['modelDelta'])
    weekly_options['c'] = np.log(curr_spx/weekly_options['Strike'])

    weekly_options_otm = weekly_options[abs(weekly_options.modelDelta) <= 0.5]
    weekly_options_itm = weekly_options[abs(weekly_options.modelDelta) > 0.5]

    if typ == 'P':
        weekly_options_otm['time_remaining'] = ((-weekly_options_otm.b - 
                                                 np.sqrt(weekly_options_otm.b**2 - 
                                                         4*weekly_options_otm.a*weekly_options_otm.c))/(2*weekly_options_otm.a))**2
        weekly_options_itm['time_remaining'] = ((-weekly_options_itm.b + 
                                                 np.sqrt(weekly_options_itm.b**2 - 
                                                         4*weekly_options_itm.a*weekly_options_itm.c))/(2*weekly_options_itm.a))**2
    if typ == 'C':
        weekly_options_otm['time_remaining'] = ((-weekly_options_otm.b + 
                                                 np.sqrt(weekly_options_otm.b**2 - 
                                                         4*weekly_options_otm.a*weekly_options_otm.c))/(2*weekly_options_otm.a))**2
        weekly_options_itm['time_remaining'] = ((-weekly_options_itm.b - 
                                                 np.sqrt(weekly_options_itm.b**2 - 
                                                         4*weekly_options_itm.a*weekly_options_itm.c))/(2*weekly_options_itm.a))**2
    weekly_times = pd.concat([weekly_options_otm, 
                              weekly_options_itm], axis = 0)[['Expiry','time_remaining']].dropna().groupby('Expiry').mean()

    del weekly_options['a'], weekly_options['b'], weekly_options['c'], weekly_options_itm, weekly_options_otm

    return weekly_options.merge(weekly_times.reset_index(), on = 'Expiry')


def get_options(ticker, exchange, contractType, earliest_date, latest_date, curr_iv, stdevs, save_csv = False):
    if contractType == 'Stock':
        security = Stock(ticker,exchange)
    else:
        security = Index(ticker, exchange)

    ib.qualifyContracts(security)

    chains = ib.reqSecDefOptParams(security.symbol, '', security.secType, security.conId)

    chains_df = util.df(chains)
    chain = next(c for c in chains if c.tradingClass == ticker and c.exchange == 'SMART')

    all_expirations = sorted(exp for exp in chain.expirations)
    expirations_dates = [dt.datetime.strptime(x, '%Y%m%d') for x in all_expirations]

    expirations = list(filter(lambda x: x[0] >= earliest_date and x[0] <= latest_date, list(zip(expirations_dates,all_expirations))))
    dte_expirations = [(expir[0] - dt.datetime.today()).days for expir in expirations]
    expirations = [expir[1] for expir in expirations]

    ib.reqHeadTimeStamp(security, whatToShow='TRADES', useRTH=True)

    end_date = '' #'20100506 13:00:00 PST'
    duration = '1 D'

    sec_bars = ib.reqHistoricalData(
            security,
            endDateTime=end_date,
            durationStr=duration,
            barSizeSetting='1 min',
            whatToShow='TRADES',
            useRTH=True,
            formatDate=1)


    sec_df = util.df(sec_bars).set_index('date')
    sec_df.index = pd.to_datetime(sec_df.index)

    curr_sec_price = sec_df.reset_index().loc[len(sec_df) - 1, 'close']
    bounds_lst = [curr_sec_price*(stdevs*stdevs/(100*np.sqrt(365.25/dte))) for dte in dte_expirations]


    contracts_list = []

    for bounds, expiration in zip(bounds_lst, expirations):
#         strikes = [strike for strike in chain.strikes
#                    if strike % 5 == 0
#                    and curr_sec_price - bounds < strike < curr_sec_price + bounds]
        strikes = [strike for strike in chain.strikes
                   if curr_sec_price - bounds < strike < curr_sec_price + bounds]

        rights = ['P', 'C']

        curr_contracts = [Option(ticker, expiration, strike, right, 'SMART')
                          for right in rights
                          for strike in strikes]
        contracts_list += [curr_contracts]

    puts_list = []
    calls_list = []

    for contracts in contracts_list:
        ib.qualifyContracts(*contracts)
        sec_options = ib.reqTickers(*contracts)

        puts_rows = []
        calls_rows = []

        for curr_option in sec_options:
            try:
                curr_row = create_dfrow(curr_option)
                if curr_option.contract.right == 'P':
                    puts_rows.append(curr_row)
                elif curr_option.contract.right == 'C':
                    calls_rows.append(curr_row)
            except:
                continue

        puts = pd.concat(puts_rows).reset_index(drop = True).sort_values(['Expiry','Strike'])
        calls = pd.concat(calls_rows).reset_index(drop = True).sort_values(['Expiry','Strike'])
        puts = time_remaining(puts, curr_sec_price)
        calls = time_remaining(calls, curr_sec_price)
        puts_list.append(puts)
        calls_list.append(calls)
        time.sleep(5)

    puts_df = pd.concat(puts_list,axis = 0).reset_index(drop = True)
    calls_df = pd.concat(calls_list,axis = 0).reset_index(drop = True)

    if save_csv:
        curr_time = dt.datetime.now().strftime('%Y%m%d-%H-%M')
        puts_df.to_csv('ib_puts' + curr_time + '.csv')
        calls_df.to_csv('ib_calls' + curr_time + '.csv')
        
    return puts_df, calls_df, curr_sec_price


def get_spreads(weekly_options, curr_spx, expiry_index = 0, rowshift = 1, commissions = 0.0266):

    expirations_dates = weekly_options.Expiry.drop_duplicates().tolist()

    weekly_options = weekly_options[weekly_options.Expiry == expirations_dates[expiry_index]]

    typ = weekly_options.reset_index().loc[0,'Type']

    if typ == 'P':
        weekly_options = weekly_options.sort_values('Strike', ascending = False).reset_index(drop = True)
    if typ == 'C':
        weekly_options = weekly_options.sort_values('Strike', ascending = True).reset_index(drop = True)

    time_remaining = weekly_options.reset_index(drop = True).loc[0,'time_remaining']

    weekly_options['Mid'] = (weekly_options.Ask + weekly_options.Bid)/2
    shorts = weekly_options[['Mid', 'Strike', 'bidDelta', 'bidGamma', 'bidTheta', 'bidVega']]
    shorts.columns = ['Price','Strike','Delta','Gamma','Theta','Vega']
    longs = weekly_options[['Mid','Strike', 'askDelta', 'askGamma','askTheta', 'askVega']]
    longs.columns = ['Price','Strike','Delta','Gamma','Theta','Vega']

    spreads = shorts - longs.shift(-rowshift)
    spreads['Short_Strike'] = shorts.Strike
    spreads['Short_Delta'] = shorts.Delta
    spreads['Long_Strike'] = longs.Strike.shift(-rowshift)
    spreads = spreads[['Short_Strike', 'Long_Strike', 'Short_Delta', 'Price',
                       'Strike', 'Delta', 'Gamma', 'Theta', 'Vega']]

    spreads['Credit'] = spreads.Price - commissions

    if typ == 'P':
        spreads['MaxLoss'] = (-spreads.Strike + spreads.Credit)*100
        spreads['BreakEven'] = spreads['Short_Strike'] - spreads.Credit
    if typ == 'C':
        spreads['MaxLoss'] = (spreads.Strike + spreads.Credit)*100
        spreads['BreakEven'] = spreads['Short_Strike'] + spreads.Credit

    del spreads['Price'], spreads['Strike']

    spreads = spreads[spreads.Credit > 0].dropna().reset_index(drop = True)
    spreads['Expiry'] = expirations_dates[expiry_index]

    return spreads

def art_hedges(curr_calls, curr_puts, curr_price, expiry_index, bias = 'upside',
               maxshift = 6, commissions = 0.0266):
    
    hedge = []
    for rowshift in range(1,maxshift):

        if bias == 'upside':
            spreads = get_spreads(curr_puts, curr_price, expiry_index, rowshift, commissions = 0.0266)
        else:
            spreads = get_spreads(curr_calls, curr_price, expiry_index, rowshift, commissions = 0.0266)
        spreads = spreads[(spreads.Credit > 0.5)]
        hedge.append(spreads)

    hedge = pd.concat(hedge, axis = 0).reset_index(drop = True)

    if bias == 'upside':
        expirations_dates = curr_calls.Expiry.drop_duplicates().tolist()

        long_hedge = curr_calls[(curr_calls.Expiry == expirations_dates[expiry_index])][['Ask', 'Bid', 'Expiry', 'Strike',
                                                                             'modelDelta', 'modelGamma',
                                                                             'modelTheta', 'modelVega', 'time_remaining']].reset_index(drop = True)
    else:
        expirations_dates = curr_puts.Expiry.drop_duplicates().tolist()

        long_hedge = curr_puts[(curr_puts.Expiry == expirations_dates[expiry_index])][['Ask', 'Bid', 'Expiry', 'Strike',
                                                                             'modelDelta', 'modelGamma',
                                                                             'modelTheta', 'modelVega', 'time_remaining']].reset_index(drop = True)

    long_hedge['Mid'] = (long_hedge['Ask'] + long_hedge['Bid'])/2
    long_hedge.columns = [x.replace('model','') for x in long_hedge.columns.tolist()]

    hedges_lst = []

    for idx, row in hedge.iterrows():

        curr_hedge = long_hedge[long_hedge.Mid < row.Credit][['Mid','Expiry', 'Strike',
                                                              'Delta', 'Gamma',
                                                              'Theta', 'Vega', 'time_remaining']]
        curr_hedge['Gamma'] = curr_hedge['Gamma'] - row.Gamma
        curr_hedge['Delta'] = curr_hedge['Delta'] - row.Delta
        curr_hedge['Theta'] = curr_hedge['Theta'] - row.Theta
        curr_hedge['Vega'] = curr_hedge['Vega'] - row.Vega
        if bias == 'upside':
            curr_hedge = curr_hedge[(curr_hedge.Delta > 0) &
                                    (curr_hedge.Gamma > 0) &
                                    (curr_hedge.Theta > 0) &
                                    (curr_hedge.Vega > 0)]
        else:
            curr_hedge = curr_hedge[(curr_hedge.Delta < 0) &
                                (curr_hedge.Gamma > 0) &
                                (curr_hedge.Theta > 0) &
                                (curr_hedge.Vega > 0)]
        curr_hedge['Credit'] = -curr_hedge.Mid + row.Credit - 0.0133

        if bias == 'upside':
            curr_hedge['MaxLoss'] = (row.Long_Strike - row.Short_Strike + curr_hedge.Credit)*100
            curr_hedge['BreakEven'] = row.Short_Strike - curr_hedge['Credit']
        else:
            curr_hedge['MaxLoss'] = (row.Short_Strike - row.Long_Strike + curr_hedge.Credit)*100
            curr_hedge['BreakEven'] = row.Short_Strike + curr_hedge['Credit']
        curr_hedge['Maturity'] = curr_hedge['Expiry']
        curr_hedge['Mid'] = row.Short_Strike
        curr_hedge['Expiry'] = row.Long_Strike

        if bias == 'upside':
            curr_hedge.columns = ['Short_Put_Strike','Long_Put_Strike','Long_Call_Strike'] + curr_hedge.columns.tolist()[3:]
        else:
            curr_hedge.columns = ['Short_Call_Strike','Long_Call_Strike','Long_Put_Strike'] + curr_hedge.columns.tolist()[3:]

        hedges_lst.append(curr_hedge)

    hedges_df = pd.concat(hedges_lst, axis = 0)
    
    return hedges_df

# %%
index, movers = get_movers()

# %%
losers = movers.head()
winners = movers.tail().sort_values('OneMonth', ascending = False)

# %%
client_id = 11

ib = IB()
ib.connect('127.0.0.1', 7496, clientId=client_id)
# Out:
# <IB connected to 127.0.0.1:7496 clientId=11>

# %%
exchange = 'NYSE'
contractType = 'Stock'
earliest_date = dt.datetime(2019,4,6)
latest_date = dt.datetime(2019,6,30)
curr_iv = 40
stdevs = 9

stock_prices = {}
stock_puts = {}
stock_calls = {}

for ticker in losers.index:

    curr_puts, curr_calls, curr_price = get_options(ticker, exchange, contractType, earliest_date, latest_date, curr_iv, stdevs, save_csv = False)
    
    stock_prices[ticker] = curr_price
    stock_puts[ticker] = curr_puts
    stock_calls[ticker] = curr_calls
    break

# %%
exchange = 'NYSE'
contractType = 'Stock'
earliest_date = dt.datetime(2019,5,1)
latest_date = dt.datetime(2019,5,31)

ticker = 'GOOGL'
curr_iv = 30
stdevs = 9
curr_puts, curr_calls, curr_price = get_options(ticker, exchange, contractType, earliest_date, latest_date, curr_iv, stdevs, save_csv = False)
# Out:
# Started to throttle requests
# Error 200, reqId 10: No security definition has been found for the request, contract: Option(symbol='GOOGL', lastTradeDateOrContractMonth='20190503', strike=1045.0, right='P', exchange='SMART')
# Error 200, reqId 12: No security definition has been found for the request, contract: Option(symbol='GOOGL', lastTradeDateOrContractMonth='20190503', strike=1055.0, right='P', exchange='SMART')
# Error 200, reqId 16: No security definition has been found for the request, contract: Option(symbol='GOOGL', lastTradeDateOrContractMonth='20190503', strike=1075.0, right='P', exchange='SMART')
# Error 200, reqId 14: No security definition has been found for the request, contract: Option(symbol='GOOGL', lastTradeDateOrContractMonth='20190503', strike=1065.0, right='P', exchange='SMART')
# Error 200, reqId 18: No security definition has been found for the request, contract: Option(symbol='GOOGL', lastTradeDateOrContractMonth='20190503', strike=1085.0, right='P', exchange='SMART')
# Error 200, reqId 20: No security definition has been found for the request, contract: Option(symbol='GOOGL', lastTradeDateOrContractMonth='20190503', strike=1095.0, right='P', exchange='SMART')
# Error 200, reqId 64: No security definition has been found for the request, contract: Option(symbol='GOOGL', lastTradeDateOrContractMonth='20190503', strike=1315.0, right='P', exchange='SMART')
# Error 200, reqId 66: No security definition has been found for the request, contract: Option(symbol='GOOGL', lastTradeDateOrContractMonth='20190503', strike=1325.0, right='P', exchange='SMART')
# Error 200, reqId 62: No security definition has been found for the request, contract: Option(symbol='GOOGL', lastTradeDateOrContractMonth='20190503', strike=1305.0, right='P', exchange='SMART')
# Error 200, reqId 68: No security definition has been found for the request, contract: Option(symbol='GOOGL', lastTradeDateOrContractMonth='20190503', strike=1335.0, right='P', exchange='SMART')
# Error 200, reqId 70: No security definition has been found for the request, contract: Option(symbol='GOOGL', lastTradeDateOrContractMonth='20190503', strike=1345.0, right='P', exchange='SMART')
# Error 200, reqId 72: No security definition has been found for the request, contract: Option(symbol='GOOGL', lastTradeDateOrContractMonth='20190503', strike=1355.0, right='P', exchange='SMART')
# Error 200, reqId 76: No security definition has been found for the request, contract: Option(symbol='GOOGL', lastTradeDateOrContractMonth='20190503', strike=1375.0, right='P', exchange='SMART')
# Error 200, reqId 78: No security definition has been found for the request, contract: Option(symbol='GOOGL', lastTradeDateOrContractMonth='20190503', strike=1385.0, right='P', exchange='SMART')
# Error 200, reqId 74: No security definition has been found for the request, contract: Option(symbol='GOOGL', lastTradeDateOrContractMonth='20190503', strike=1365.0, right='P', exchange='SMART')
# Error 200, reqId 80: No security definition has been found for the request, contract: Option(symbol='GOOGL', lastTradeDateOrContractMonth='20190503', strike=1395.0, right='P', exchange='SMART')
# Error 200, reqId 82: No security definition has been found for the request, contract: Option(symbol='GOOGL', lastTradeDateOrContractMonth='20190503', strike=1405.0, right='P', exchange='SMART')
# Error 200, reqId 87: No security definition has been found for the request, contract: Option(symbol='GOOGL', lastTradeDateOrContractMonth='20190503', strike=1045.0, right='C', exchange='SMART')
# Error 200, reqId 89: No security definition has been found for the request, contract: Option(symbol='GOOGL', lastTradeDateOrContractMonth='20190503', strike=1055.0, right='C', exchange='SMART')
# Error 200, reqId 91: No security definition has been found for the request, contract: Option(symbol='GOOGL', lastTradeDateOrContractMonth='20190503', strike=1065.0, right='C', exchange='SMART')
# Error 200, reqId 93: No security definition has been found for the request, contract: Option(symbol='GOOGL', lastTradeDateOrContractMonth='20190503', strike=1075.0, right='C', exchange='SMART')
# Error 200, reqId 95: No security definition has been found for the request, contract: Option(symbol='GOOGL', lastTradeDateOrContractMonth='20190503', strike=1085.0, right='C', exchange='SMART')
# Error 200, reqId 97: No security definition has been found for the request, contract: Option(symbol='GOOGL', lastTradeDateOrContractMonth='20190503', strike=1095.0, right='C', exchange='SMART')
# Stopped to throttle requests
# Error 200, reqId 139: No security definition has been found for the request, contract: Option(symbol='GOOGL', lastTradeDateOrContractMonth='20190503', strike=1305.0, right='C', exchange='SMART')
# Error 200, reqId 141: No security definition has been found for the request, contract: Option(symbol='GOOGL', lastTradeDateOrContractMonth='20190503', strike=1315.0, right='C', exchange='SMART')
# Error 200, reqId 143: No security definition has been found for the request, contract: Option(symbol='GOOGL', lastTradeDateOrContractMonth='20190503', strike=1325.0, right='C', exchange='SMART')
# Error 200, reqId 145: No security definition has been found for the request, contract: Option(symbol='GOOGL', lastTradeDateOrContractMonth='20190503', strike=1335.0, right='C', exchange='SMART')
# Error 200, reqId 149: No security definition has been found for the request, contract: Option(symbol='GOOGL', lastTradeDateOrContractMonth='20190503', strike=1355.0, right='C', exchange='SMART')
# Error 200, reqId 147: No security definition has been found for the request, contract: Option(symbol='GOOGL', lastTradeDateOrContractMonth='20190503', strike=1345.0, right='C', exchange='SMART')
# Error 200, reqId 151: No security definition has been found for the request, contract: Option(symbol='GOOGL', lastTradeDateOrContractMonth='20190503', strike=1365.0, right='C', exchange='SMART')
# Error 200, reqId 153: No security definition has been found for the request, contract: Option(symbol='GOOGL', lastTradeDateOrContractMonth='20190503', strike=1375.0, right='C', exchange='SMART')
# Error 200, reqId 155: No security definition has been found for the request, contract: Option(symbol='GOOGL', lastTradeDateOrContractMonth='20190503', strike=1385.0, right='C', exchange='SMART')
# Error 200, reqId 157: No security definition has been found for the request, contract: Option(symbol='GOOGL', lastTradeDateOrContractMonth='20190503', strike=1395.0, right='C', exchange='SMART')
# Error 200, reqId 159: No security definition has been found for the request, contract: Option(symbol='GOOGL', lastTradeDateOrContractMonth='20190503', strike=1405.0, right='C', exchange='SMART')
# Unknown contract: Option(symbol='GOOGL', lastTradeDateOrContractMonth='20190503', strike=1045.0, right='P', exchange='SMART')
# Unknown contract: Option(symbol='GOOGL', lastTradeDateOrContractMonth='20190503', strike=1055.0, right='P', exchange='SMART')
# Unknown contract: Option(symbol='GOOGL', lastTradeDateOrContractMonth='20190503', strike=1065.0, right='P', exchange='SMART')
# Unknown contract: Option(symbol='GOOGL', lastTradeDateOrContractMonth='20190503', strike=1075.0, right='P', exchange='SMART')
# Unknown contract: Option(symbol='GOOGL', lastTradeDateOrContractMonth='20190503', strike=1085.0, right='P', exchange='SMART')
# Unknown contract: Option(symbol='GOOGL', lastTradeDateOrContractMonth='20190503', strike=1095.0, right='P', exchange='SMART')
# Unknown contract: Option(symbol='GOOGL', lastTradeDateOrContractMonth='20190503', strike=1305.0, right='P', exchange='SMART')
# Unknown contract: Option(symbol='GOOGL', lastTradeDateOrContractMonth='20190503', strike=1315.0, right='P', exchange='SMART')
# Unknown contract: Option(symbol='GOOGL', lastTradeDateOrContractMonth='20190503', strike=1325.0, right='P', exchange='SMART')
# Unknown contract: Option(symbol='GOOGL', lastTradeDateOrContractMonth='20190503', strike=1335.0, right='P', exchange='SMART')
# Unknown contract: Option(symbol='GOOGL', lastTradeDateOrContractMonth='20190503', strike=1345.0, right='P', exchange='SMART')
# Unknown contract: Option(symbol='GOOGL', lastTradeDateOrContractMonth='20190503', strike=1355.0, right='P', exchange='SMART')
# Unknown contract: Option(symbol='GOOGL', lastTradeDateOrContractMonth='20190503', strike=1365.0, right='P', exchange='SMART')
# Unknown contract: Option(symbol='GOOGL', lastTradeDateOrContractMonth='20190503', strike=1375.0, right='P', exchange='SMART')
# Unknown contract: Option(symbol='GOOGL', lastTradeDateOrContractMonth='20190503', strike=1385.0, right='P', exchange='SMART')
# Unknown contract: Option(symbol='GOOGL', lastTradeDateOrContractMonth='20190503', strike=1395.0, right='P', exchange='SMART')
# Unknown contract: Option(symbol='GOOGL', lastTradeDateOrContractMonth='20190503', strike=1405.0, right='P', exchange='SMART')
# Unknown contract: Option(symbol='GOOGL', lastTradeDateOrContractMonth='20190503', strike=1045.0, right='C', exchange='SMART')
# Unknown contract: Option(symbol='GOOGL', lastTradeDateOrContractMonth='20190503', strike=1055.0, right='C', exchange='SMART')
# Unknown contract: Option(symbol='GOOGL', lastTradeDateOrContractMonth='20190503', strike=1065.0, right='C', exchange='SMART')
# Unknown contract: Option(symbol='GOOGL', lastTradeDateOrContractMonth='20190503', strike=1075.0, right='C', exchange='SMART')
# Unknown contract: Option(symbol='GOOGL', lastTradeDateOrContractMonth='20190503', strike=1085.0, right='C', exchange='SMART')
# Unknown contract: Option(symbol='GOOGL', lastTradeDateOrContractMonth='20190503', strike=1095.0, right='C', exchange='SMART')
# Unknown contract: Option(symbol='GOOGL', lastTradeDateOrContractMonth='20190503', strike=1305.0, right='C', exchange='SMART')
# Unknown contract: Option(symbol='GOOGL', lastTradeDateOrContractMonth='20190503', strike=1315.0, right='C', exchange='SMART')
# Unknown contract: Option(symbol='GOOGL', lastTradeDateOrContractMonth='20190503', strike=1325.0, right='C', exchange='SMART')
# Unknown contract: Option(symbol='GOOGL', lastTradeDateOrContractMonth='20190503', strike=1335.0, right='C', exchange='SMART')
# Unknown contract: Option(symbol='GOOGL', lastTradeDateOrContractMonth='20190503', strike=1345.0, right='C', exchange='SMART')
# Unknown contract: Option(symbol='GOOGL', lastTradeDateOrContractMonth='20190503', strike=1355.0, right='C', exchange='SMART')
# Unknown contract: Option(symbol='GOOGL', lastTradeDateOrContractMonth='20190503', strike=1365.0, right='C', exchange='SMART')
# Unknown contract: Option(symbol='GOOGL', lastTradeDateOrContractMonth='20190503', strike=1375.0, right='C', exchange='SMART')
# Unknown contract: Option(symbol='GOOGL', lastTradeDateOrContractMonth='20190503', strike=1385.0, right='C', exchange='SMART')
# Unknown contract: Option(symbol='GOOGL', lastTradeDateOrContractMonth='20190503', strike=1395.0, right='C', exchange='SMART')
# Unknown contract: Option(symbol='GOOGL', lastTradeDateOrContractMonth='20190503', strike=1405.0, right='C', exchange='SMART')
# Started to throttle requests
# Error 200, reqId 164: No security definition has been found for the request, contract: Option(symbol='GOOGL', lastTradeDateOrContractMonth='20190503', strike=1045.0, right='P', exchange='SMART')
# Error 200, reqId 166: No security definition has been found for the request, contract: Option(symbol='GOOGL', lastTradeDateOrContractMonth='20190503', strike=1055.0, right='P', exchange='SMART')
# Error 200, reqId 168: No security definition has been found for the request, contract: Option(symbol='GOOGL', lastTradeDateOrContractMonth='20190503', strike=1065.0, right='P', exchange='SMART')
# Error 200, reqId 170: No security definition has been found for the request, contract: Option(symbol='GOOGL', lastTradeDateOrContractMonth='20190503', strike=1075.0, right='P', exchange='SMART')
# Error 200, reqId 172: No security definition has been found for the request, contract: Option(symbol='GOOGL', lastTradeDateOrContractMonth='20190503', strike=1085.0, right='P', exchange='SMART')
# Error 200, reqId 174: No security definition has been found for the request, contract: Option(symbol='GOOGL', lastTradeDateOrContractMonth='20190503', strike=1095.0, right='P', exchange='SMART')
# Error 200, reqId 216: No security definition has been found for the request, contract: Option(symbol='GOOGL', lastTradeDateOrContractMonth='20190503', strike=1305.0, right='P', exchange='SMART')
# Error 200, reqId 218: No security definition has been found for the request, contract: Option(symbol='GOOGL', lastTradeDateOrContractMonth='20190503', strike=1315.0, right='P', exchange='SMART')
# Error 200, reqId 220: No security definition has been found for the request, contract: Option(symbol='GOOGL', lastTradeDateOrContractMonth='20190503', strike=1325.0, right='P', exchange='SMART')
# Error 200, reqId 222: No security definition has been found for the request, contract: Option(symbol='GOOGL', lastTradeDateOrContractMonth='20190503', strike=1335.0, right='P', exchange='SMART')
# Error 200, reqId 224: No security definition has been found for the request, contract: Option(symbol='GOOGL', lastTradeDateOrContractMonth='20190503', strike=1345.0, right='P', exchange='SMART')
# Error 200, reqId 226: No security definition has been found for the request, contract: Option(symbol='GOOGL', lastTradeDateOrContractMonth='20190503', strike=1355.0, right='P', exchange='SMART')
# Error 200, reqId 228: No security definition has been found for the request, contract: Option(symbol='GOOGL', lastTradeDateOrContractMonth='20190503', strike=1365.0, right='P', exchange='SMART')
# Error 200, reqId 230: No security definition has been found for the request, contract: Option(symbol='GOOGL', lastTradeDateOrContractMonth='20190503', strike=1375.0, right='P', exchange='SMART')
# Error 200, reqId 232: No security definition has been found for the request, contract: Option(symbol='GOOGL', lastTradeDateOrContractMonth='20190503', strike=1385.0, right='P', exchange='SMART')
# Error 200, reqId 234: No security definition has been found for the request, contract: Option(symbol='GOOGL', lastTradeDateOrContractMonth='20190503', strike=1395.0, right='P', exchange='SMART')
# Error 200, reqId 236: No security definition has been found for the request, contract: Option(symbol='GOOGL', lastTradeDateOrContractMonth='20190503', strike=1405.0, right='P', exchange='SMART')
# Error 200, reqId 241: No security definition has been found for the request, contract: Option(symbol='GOOGL', lastTradeDateOrContractMonth='20190503', strike=1045.0, right='C', exchange='SMART')
# Error 200, reqId 243: No security definition has been found for the request, contract: Option(symbol='GOOGL', lastTradeDateOrContractMonth='20190503', strike=1055.0, right='C', exchange='SMART')
# Error 200, reqId 245: No security definition has been found for the request, contract: Option(symbol='GOOGL', lastTradeDateOrContractMonth='20190503', strike=1065.0, right='C', exchange='SMART')
# Error 200, reqId 247: No security definition has been found for the request, contract: Option(symbol='GOOGL', lastTradeDateOrContractMonth='20190503', strike=1075.0, right='C', exchange='SMART')
# Error 200, reqId 249: No security definition has been found for the request, contract: Option(symbol='GOOGL', lastTradeDateOrContractMonth='20190503', strike=1085.0, right='C', exchange='SMART')
# Error 200, reqId 251: No security definition has been found for the request, contract: Option(symbol='GOOGL', lastTradeDateOrContractMonth='20190503', strike=1095.0, right='C', exchange='SMART')
# Error 200, reqId 293: No security definition has been found for the request, contract: Option(symbol='GOOGL', lastTradeDateOrContractMonth='20190503', strike=1305.0, right='C', exchange='SMART')
# Stopped to throttle requests
# Error 200, reqId 295: No security definition has been found for the request, contract: Option(symbol='GOOGL', lastTradeDateOrContractMonth='20190503', strike=1315.0, right='C', exchange='SMART')
# Error 200, reqId 297: No security definition has been found for the request, contract: Option(symbol='GOOGL', lastTradeDateOrContractMonth='20190503', strike=1325.0, right='C', exchange='SMART')
# Error 200, reqId 299: No security definition has been found for the request, contract: Option(symbol='GOOGL', lastTradeDateOrContractMonth='20190503', strike=1335.0, right='C', exchange='SMART')
# Error 200, reqId 301: No security definition has been found for the request, contract: Option(symbol='GOOGL', lastTradeDateOrContractMonth='20190503', strike=1345.0, right='C', exchange='SMART')
# Error 200, reqId 303: No security definition has been found for the request, contract: Option(symbol='GOOGL', lastTradeDateOrContractMonth='20190503', strike=1355.0, right='C', exchange='SMART')
# Error 200, reqId 305: No security definition has been found for the request, contract: Option(symbol='GOOGL', lastTradeDateOrContractMonth='20190503', strike=1365.0, right='C', exchange='SMART')
# Error 200, reqId 307: No security definition has been found for the request, contract: Option(symbol='GOOGL', lastTradeDateOrContractMonth='20190503', strike=1375.0, right='C', exchange='SMART')
# Error 200, reqId 309: No security definition has been found for the request, contract: Option(symbol='GOOGL', lastTradeDateOrContractMonth='20190503', strike=1385.0, right='C', exchange='SMART')
# Error 200, reqId 311: No security definition has been found for the request, contract: Option(symbol='GOOGL', lastTradeDateOrContractMonth='20190503', strike=1395.0, right='C', exchange='SMART')
# Error 200, reqId 313: No security definition has been found for the request, contract: Option(symbol='GOOGL', lastTradeDateOrContractMonth='20190503', strike=1405.0, right='C', exchange='SMART')
# Started to throttle requests
# Error 200, reqId 317: No security definition has been found for the request, contract: Option(symbol='GOOGL', lastTradeDateOrContractMonth='20190510', strike=1025.0, right='P', exchange='SMART')
# Error 200, reqId 319: No security definition has been found for the request, contract: Option(symbol='GOOGL', lastTradeDateOrContractMonth='20190510', strike=1035.0, right='P', exchange='SMART')
# Error 200, reqId 321: No security definition has been found for the request, contract: Option(symbol='GOOGL', lastTradeDateOrContractMonth='20190510', strike=1045.0, right='P', exchange='SMART')
# Error 200, reqId 323: No security definition has been found for the request, contract: Option(symbol='GOOGL', lastTradeDateOrContractMonth='20190510', strike=1055.0, right='P', exchange='SMART')
# Error 200, reqId 325: No security definition has been found for the request, contract: Option(symbol='GOOGL', lastTradeDateOrContractMonth='20190510', strike=1065.0, right='P', exchange='SMART')
# Error 200, reqId 327: No security definition has been found for the request, contract: Option(symbol='GOOGL', lastTradeDateOrContractMonth='20190510', strike=1075.0, right='P', exchange='SMART')
# Error 200, reqId 329: No security definition has been found for the request, contract: Option(symbol='GOOGL', lastTradeDateOrContractMonth='20190510', strike=1085.0, right='P', exchange='SMART')
# Error 200, reqId 331: No security definition has been found for the request, contract: Option(symbol='GOOGL', lastTradeDateOrContractMonth='20190510', strike=1095.0, right='P', exchange='SMART')
# Error 200, reqId 373: No security definition has been found for the request, contract: Option(symbol='GOOGL', lastTradeDateOrContractMonth='20190510', strike=1305.0, right='P', exchange='SMART')
# Error 200, reqId 375: No security definition has been found for the request, contract: Option(symbol='GOOGL', lastTradeDateOrContractMonth='20190510', strike=1315.0, right='P', exchange='SMART')
# Error 200, reqId 377: No security definition has been found for the request, contract: Option(symbol='GOOGL', lastTradeDateOrContractMonth='20190510', strike=1325.0, right='P', exchange='SMART')
# Error 200, reqId 379: No security definition has been found for the request, contract: Option(symbol='GOOGL', lastTradeDateOrContractMonth='20190510', strike=1335.0, right='P', exchange='SMART')
# Error 200, reqId 381: No security definition has been found for the request, contract: Option(symbol='GOOGL', lastTradeDateOrContractMonth='20190510', strike=1345.0, right='P', exchange='SMART')
# Error 200, reqId 383: No security definition has been found for the request, contract: Option(symbol='GOOGL', lastTradeDateOrContractMonth='20190510', strike=1355.0, right='P', exchange='SMART')
# Error 200, reqId 385: No security definition has been found for the request, contract: Option(symbol='GOOGL', lastTradeDateOrContractMonth='20190510', strike=1365.0, right='P', exchange='SMART')
# Error 200, reqId 387: No security definition has been found for the request, contract: Option(symbol='GOOGL', lastTradeDateOrContractMonth='20190510', strike=1375.0, right='P', exchange='SMART')
# Error 200, reqId 389: No security definition has been found for the request, contract: Option(symbol='GOOGL', lastTradeDateOrContractMonth='20190510', strike=1385.0, right='P', exchange='SMART')
# Error 200, reqId 391: No security definition has been found for the request, contract: Option(symbol='GOOGL', lastTradeDateOrContractMonth='20190510', strike=1395.0, right='P', exchange='SMART')
# Error 200, reqId 393: No security definition has been found for the request, contract: Option(symbol='GOOGL', lastTradeDateOrContractMonth='20190510', strike=1405.0, right='P', exchange='SMART')
# Error 200, reqId 401: No security definition has been found for the request, contract: Option(symbol='GOOGL', lastTradeDateOrContractMonth='20190510', strike=1005.0, right='P', exchange='SMART')
# Error 200, reqId 403: No security definition has been found for the request, contract: Option(symbol='GOOGL', lastTradeDateOrContractMonth='20190510', strike=1015.0, right='P', exchange='SMART')
# Error 200, reqId 407: No security definition has been found for the request, contract: Option(symbol='GOOGL', lastTradeDateOrContractMonth='20190510', strike=1035.0, right='C', exchange='SMART')
# Error 200, reqId 405: No security definition has been found for the request, contract: Option(symbol='GOOGL', lastTradeDateOrContractMonth='20190510', strike=1025.0, right='C', exchange='SMART')
# Error 200, reqId 399: No security definition has been found for the request, contract: Option(symbol='GOOGL', lastTradeDateOrContractMonth='20190510', strike=995.0, right='P', exchange='SMART')
# Error 200, reqId 409: No security definition has been found for the request, contract: Option(symbol='GOOGL', lastTradeDateOrContractMonth='20190510', strike=1045.0, right='C', exchange='SMART')
# Error 200, reqId 411: No security definition has been found for the request, contract: Option(symbol='GOOGL', lastTradeDateOrContractMonth='20190510', strike=1055.0, right='C', exchange='SMART')
# Stopped to throttle requests
# Error 200, reqId 415: No security definition has been found for the request, contract: Option(symbol='GOOGL', lastTradeDateOrContractMonth='20190510', strike=1075.0, right='C', exchange='SMART')
# Error 200, reqId 413: No security definition has been found for the request, contract: Option(symbol='GOOGL', lastTradeDateOrContractMonth='20190510', strike=1065.0, right='C', exchange='SMART')
# Error 200, reqId 419: No security definition has been found for the request, contract: Option(symbol='GOOGL', lastTradeDateOrContractMonth='20190510', strike=1095.0, right='C', exchange='SMART')
# Error 200, reqId 417: No security definition has been found for the request, contract: Option(symbol='GOOGL', lastTradeDateOrContractMonth='20190510', strike=1085.0, right='C', exchange='SMART')
# Error 200, reqId 461: No security definition has been found for the request, contract: Option(symbol='GOOGL', lastTradeDateOrContractMonth='20190510', strike=1305.0, right='C', exchange='SMART')
# Error 200, reqId 463: No security definition has been found for the request, contract: Option(symbol='GOOGL', lastTradeDateOrContractMonth='20190510', strike=1315.0, right='C', exchange='SMART')
# Error 200, reqId 465: No security definition has been found for the request, contract: Option(symbol='GOOGL', lastTradeDateOrContractMonth='20190510', strike=1325.0, right='C', exchange='SMART')
# Error 200, reqId 467: No security definition has been found for the request, contract: Option(symbol='GOOGL', lastTradeDateOrContractMonth='20190510', strike=1335.0, right='C', exchange='SMART')
# Error 200, reqId 469: No security definition has been found for the request, contract: Option(symbol='GOOGL', lastTradeDateOrContractMonth='20190510', strike=1345.0, right='C', exchange='SMART')
# Error 200, reqId 475: No security definition has been found for the request, contract: Option(symbol='GOOGL', lastTradeDateOrContractMonth='20190510', strike=1375.0, right='C', exchange='SMART')
# Error 200, reqId 471: No security definition has been found for the request, contract: Option(symbol='GOOGL', lastTradeDateOrContractMonth='20190510', strike=1355.0, right='C', exchange='SMART')
# Error 200, reqId 473: No security definition has been found for the request, contract: Option(symbol='GOOGL', lastTradeDateOrContractMonth='20190510', strike=1365.0, right='C', exchange='SMART')
# Error 200, reqId 477: No security definition has been found for the request, contract: Option(symbol='GOOGL', lastTradeDateOrContractMonth='20190510', strike=1385.0, right='C', exchange='SMART')
# Error 200, reqId 481: No security definition has been found for the request, contract: Option(symbol='GOOGL', lastTradeDateOrContractMonth='20190510', strike=1405.0, right='C', exchange='SMART')
# Error 200, reqId 479: No security definition has been found for the request, contract: Option(symbol='GOOGL', lastTradeDateOrContractMonth='20190510', strike=1395.0, right='C', exchange='SMART')
# Error 200, reqId 487: No security definition has been found for the request, contract: Option(symbol='GOOGL', lastTradeDateOrContractMonth='20190510', strike=995.0, right='C', exchange='SMART')
# Error 200, reqId 489: No security definition has been found for the request, contract: Option(symbol='GOOGL', lastTradeDateOrContractMonth='20190510', strike=1005.0, right='C', exchange='SMART')
# Error 200, reqId 491: No security definition has been found for the request, contract: Option(symbol='GOOGL', lastTradeDateOrContractMonth='20190510', strike=1015.0, right='C', exchange='SMART')
# Unknown contract: Option(symbol='GOOGL', lastTradeDateOrContractMonth='20190510', strike=1025.0, right='P', exchange='SMART')
# Unknown contract: Option(symbol='GOOGL', lastTradeDateOrContractMonth='20190510', strike=1035.0, right='P', exchange='SMART')
# Unknown contract: Option(symbol='GOOGL', lastTradeDateOrContractMonth='20190510', strike=1045.0, right='P', exchange='SMART')
# Unknown contract: Option(symbol='GOOGL', lastTradeDateOrContractMonth='20190510', strike=1055.0, right='P', exchange='SMART')
# Unknown contract: Option(symbol='GOOGL', lastTradeDateOrContractMonth='20190510', strike=1065.0, right='P', exchange='SMART')
# Unknown contract: Option(symbol='GOOGL', lastTradeDateOrContractMonth='20190510', strike=1075.0, right='P', exchange='SMART')
# Unknown contract: Option(symbol='GOOGL', lastTradeDateOrContractMonth='20190510', strike=1085.0, right='P', exchange='SMART')
# Unknown contract: Option(symbol='GOOGL', lastTradeDateOrContractMonth='20190510', strike=1095.0, right='P', exchange='SMART')
# Unknown contract: Option(symbol='GOOGL', lastTradeDateOrContractMonth='20190510', strike=1305.0, right='P', exchange='SMART')
# Unknown contract: Option(symbol='GOOGL', lastTradeDateOrContractMonth='20190510', strike=1315.0, right='P', exchange='SMART')
# Unknown contract: Option(symbol='GOOGL', lastTradeDateOrContractMonth='20190510', strike=1325.0, right='P', exchange='SMART')
# Unknown contract: Option(symbol='GOOGL', lastTradeDateOrContractMonth='20190510', strike=1335.0, right='P', exchange='SMART')
# Unknown contract: Option(symbol='GOOGL', lastTradeDateOrContractMonth='20190510', strike=1345.0, right='P', exchange='SMART')
# Unknown contract: Option(symbol='GOOGL', lastTradeDateOrContractMonth='20190510', strike=1355.0, right='P', exchange='SMART')
# Unknown contract: Option(symbol='GOOGL', lastTradeDateOrContractMonth='20190510', strike=1365.0, right='P', exchange='SMART')
# Unknown contract: Option(symbol='GOOGL', lastTradeDateOrContractMonth='20190510', strike=1375.0, right='P', exchange='SMART')
# Unknown contract: Option(symbol='GOOGL', lastTradeDateOrContractMonth='20190510', strike=1385.0, right='P', exchange='SMART')
# Unknown contract: Option(symbol='GOOGL', lastTradeDateOrContractMonth='20190510', strike=1395.0, right='P', exchange='SMART')
# Unknown contract: Option(symbol='GOOGL', lastTradeDateOrContractMonth='20190510', strike=1405.0, right='P', exchange='SMART')
# Unknown contract: Option(symbol='GOOGL', lastTradeDateOrContractMonth='20190510', strike=995.0, right='P', exchange='SMART')
# Unknown contract: Option(symbol='GOOGL', lastTradeDateOrContractMonth='20190510', strike=1005.0, right='P', exchange='SMART')
# Unknown contract: Option(symbol='GOOGL', lastTradeDateOrContractMonth='20190510', strike=1015.0, right='P', exchange='SMART')
# Unknown contract: Option(symbol='GOOGL', lastTradeDateOrContractMonth='20190510', strike=1025.0, right='C', exchange='SMART')
# Unknown contract: Option(symbol='GOOGL', lastTradeDateOrContractMonth='20190510', strike=1035.0, right='C', exchange='SMART')
# Unknown contract: Option(symbol='GOOGL', lastTradeDateOrContractMonth='20190510', strike=1045.0, right='C', exchange='SMART')
# Unknown contract: Option(symbol='GOOGL', lastTradeDateOrContractMonth='20190510', strike=1055.0, right='C', exchange='SMART')
# Unknown contract: Option(symbol='GOOGL', lastTradeDateOrContractMonth='20190510', strike=1065.0, right='C', exchange='SMART')
# Unknown contract: Option(symbol='GOOGL', lastTradeDateOrContractMonth='20190510', strike=1075.0, right='C', exchange='SMART')
# Unknown contract: Option(symbol='GOOGL', lastTradeDateOrContractMonth='20190510', strike=1085.0, right='C', exchange='SMART')
# Unknown contract: Option(symbol='GOOGL', lastTradeDateOrContractMonth='20190510', strike=1095.0, right='C', exchange='SMART')
# Unknown contract: Option(symbol='GOOGL', lastTradeDateOrContractMonth='20190510', strike=1305.0, right='C', exchange='SMART')
# Unknown contract: Option(symbol='GOOGL', lastTradeDateOrContractMonth='20190510', strike=1315.0, right='C', exchange='SMART')
# Unknown contract: Option(symbol='GOOGL', lastTradeDateOrContractMonth='20190510', strike=1325.0, right='C', exchange='SMART')
# Unknown contract: Option(symbol='GOOGL', lastTradeDateOrContractMonth='20190510', strike=1335.0, right='C', exchange='SMART')
# Unknown contract: Option(symbol='GOOGL', lastTradeDateOrContractMonth='20190510', strike=1345.0, right='C', exchange='SMART')
# Unknown contract: Option(symbol='GOOGL', lastTradeDateOrContractMonth='20190510', strike=1355.0, right='C', exchange='SMART')
# Unknown contract: Option(symbol='GOOGL', lastTradeDateOrContractMonth='20190510', strike=1365.0, right='C', exchange='SMART')
# Unknown contract: Option(symbol='GOOGL', lastTradeDateOrContractMonth='20190510', strike=1375.0, right='C', exchange='SMART')
# Unknown contract: Option(symbol='GOOGL', lastTradeDateOrContractMonth='20190510', strike=1385.0, right='C', exchange='SMART')
# Unknown contract: Option(symbol='GOOGL', lastTradeDateOrContractMonth='20190510', strike=1395.0, right='C', exchange='SMART')
# Unknown contract: Option(symbol='GOOGL', lastTradeDateOrContractMonth='20190510', strike=1405.0, right='C', exchange='SMART')
# Unknown contract: Option(symbol='GOOGL', lastTradeDateOrContractMonth='20190510', strike=995.0, right='C', exchange='SMART')
# Unknown contract: Option(symbol='GOOGL', lastTradeDateOrContractMonth='20190510', strike=1005.0, right='C', exchange='SMART')
# Unknown contract: Option(symbol='GOOGL', lastTradeDateOrContractMonth='20190510', strike=1015.0, right='C', exchange='SMART')
# Started to throttle requests
# Error 200, reqId 493: No security definition has been found for the request, contract: Option(symbol='GOOGL', lastTradeDateOrContractMonth='20190510', strike=1025.0, right='P', exchange='SMART')
# Error 200, reqId 495: No security definition has been found for the request, contract: Option(symbol='GOOGL', lastTradeDateOrContractMonth='20190510', strike=1035.0, right='P', exchange='SMART')
# Error 200, reqId 497: No security definition has been found for the request, contract: Option(symbol='GOOGL', lastTradeDateOrContractMonth='20190510', strike=1045.0, right='P', exchange='SMART')
# Error 200, reqId 499: No security definition has been found for the request, contract: Option(symbol='GOOGL', lastTradeDateOrContractMonth='20190510', strike=1055.0, right='P', exchange='SMART')
# Error 200, reqId 501: No security definition has been found for the request, contract: Option(symbol='GOOGL', lastTradeDateOrContractMonth='20190510', strike=1065.0, right='P', exchange='SMART')
# Error 200, reqId 503: No security definition has been found for the request, contract: Option(symbol='GOOGL', lastTradeDateOrContractMonth='20190510', strike=1075.0, right='P', exchange='SMART')
# Error 200, reqId 505: No security definition has been found for the request, contract: Option(symbol='GOOGL', lastTradeDateOrContractMonth='20190510', strike=1085.0, right='P', exchange='SMART')
# Error 200, reqId 507: No security definition has been found for the request, contract: Option(symbol='GOOGL', lastTradeDateOrContractMonth='20190510', strike=1095.0, right='P', exchange='SMART')
# Error 200, reqId 549: No security definition has been found for the request, contract: Option(symbol='GOOGL', lastTradeDateOrContractMonth='20190510', strike=1305.0, right='P', exchange='SMART')
# Error 200, reqId 551: No security definition has been found for the request, contract: Option(symbol='GOOGL', lastTradeDateOrContractMonth='20190510', strike=1315.0, right='P', exchange='SMART')
# Error 200, reqId 553: No security definition has been found for the request, contract: Option(symbol='GOOGL', lastTradeDateOrContractMonth='20190510', strike=1325.0, right='P', exchange='SMART')
# Error 200, reqId 555: No security definition has been found for the request, contract: Option(symbol='GOOGL', lastTradeDateOrContractMonth='20190510', strike=1335.0, right='P', exchange='SMART')
# Error 200, reqId 557: No security definition has been found for the request, contract: Option(symbol='GOOGL', lastTradeDateOrContractMonth='20190510', strike=1345.0, right='P', exchange='SMART')
# Error 200, reqId 559: No security definition has been found for the request, contract: Option(symbol='GOOGL', lastTradeDateOrContractMonth='20190510', strike=1355.0, right='P', exchange='SMART')
# Error 200, reqId 561: No security definition has been found for the request, contract: Option(symbol='GOOGL', lastTradeDateOrContractMonth='20190510', strike=1365.0, right='P', exchange='SMART')
# Error 200, reqId 563: No security definition has been found for the request, contract: Option(symbol='GOOGL', lastTradeDateOrContractMonth='20190510', strike=1375.0, right='P', exchange='SMART')
# Error 200, reqId 565: No security definition has been found for the request, contract: Option(symbol='GOOGL', lastTradeDateOrContractMonth='20190510', strike=1385.0, right='P', exchange='SMART')
# Error 200, reqId 567: No security definition has been found for the request, contract: Option(symbol='GOOGL', lastTradeDateOrContractMonth='20190510', strike=1395.0, right='P', exchange='SMART')
# Error 200, reqId 569: No security definition has been found for the request, contract: Option(symbol='GOOGL', lastTradeDateOrContractMonth='20190510', strike=1405.0, right='P', exchange='SMART')
# Error 200, reqId 575: No security definition has been found for the request, contract: Option(symbol='GOOGL', lastTradeDateOrContractMonth='20190510', strike=995.0, right='P', exchange='SMART')
# Error 200, reqId 577: No security definition has been found for the request, contract: Option(symbol='GOOGL', lastTradeDateOrContractMonth='20190510', strike=1005.0, right='P', exchange='SMART')
# Error 200, reqId 579: No security definition has been found for the request, contract: Option(symbol='GOOGL', lastTradeDateOrContractMonth='20190510', strike=1015.0, right='P', exchange='SMART')
# Error 200, reqId 581: No security definition has been found for the request, contract: Option(symbol='GOOGL', lastTradeDateOrContractMonth='20190510', strike=1025.0, right='C', exchange='SMART')
# Error 200, reqId 583: No security definition has been found for the request, contract: Option(symbol='GOOGL', lastTradeDateOrContractMonth='20190510', strike=1035.0, right='C', exchange='SMART')
# Error 200, reqId 585: No security definition has been found for the request, contract: Option(symbol='GOOGL', lastTradeDateOrContractMonth='20190510', strike=1045.0, right='C', exchange='SMART')
# Error 200, reqId 587: No security definition has been found for the request, contract: Option(symbol='GOOGL', lastTradeDateOrContractMonth='20190510', strike=1055.0, right='C', exchange='SMART')
# Error 200, reqId 589: No security definition has been found for the request, contract: Option(symbol='GOOGL', lastTradeDateOrContractMonth='20190510', strike=1065.0, right='C', exchange='SMART')
# Error 200, reqId 591: No security definition has been found for the request, contract: Option(symbol='GOOGL', lastTradeDateOrContractMonth='20190510', strike=1075.0, right='C', exchange='SMART')
# Error 200, reqId 593: No security definition has been found for the request, contract: Option(symbol='GOOGL', lastTradeDateOrContractMonth='20190510', strike=1085.0, right='C', exchange='SMART')
# Error 200, reqId 595: No security definition has been found for the request, contract: Option(symbol='GOOGL', lastTradeDateOrContractMonth='20190510', strike=1095.0, right='C', exchange='SMART')
# Stopped to throttle requests
# Error 200, reqId 637: No security definition has been found for the request, contract: Option(symbol='GOOGL', lastTradeDateOrContractMonth='20190510', strike=1305.0, right='C', exchange='SMART')
# Error 200, reqId 639: No security definition has been found for the request, contract: Option(symbol='GOOGL', lastTradeDateOrContractMonth='20190510', strike=1315.0, right='C', exchange='SMART')
# Error 200, reqId 641: No security definition has been found for the request, contract: Option(symbol='GOOGL', lastTradeDateOrContractMonth='20190510', strike=1325.0, right='C', exchange='SMART')
# Error 200, reqId 643: No security definition has been found for the request, contract: Option(symbol='GOOGL', lastTradeDateOrContractMonth='20190510', strike=1335.0, right='C', exchange='SMART')
# Error 200, reqId 645: No security definition has been found for the request, contract: Option(symbol='GOOGL', lastTradeDateOrContractMonth='20190510', strike=1345.0, right='C', exchange='SMART')
# Error 200, reqId 647: No security definition has been found for the request, contract: Option(symbol='GOOGL', lastTradeDateOrContractMonth='20190510', strike=1355.0, right='C', exchange='SMART')
# Error 200, reqId 649: No security definition has been found for the request, contract: Option(symbol='GOOGL', lastTradeDateOrContractMonth='20190510', strike=1365.0, right='C', exchange='SMART')
# Error 200, reqId 651: No security definition has been found for the request, contract: Option(symbol='GOOGL', lastTradeDateOrContractMonth='20190510', strike=1375.0, right='C', exchange='SMART')
# Error 200, reqId 653: No security definition has been found for the request, contract: Option(symbol='GOOGL', lastTradeDateOrContractMonth='20190510', strike=1385.0, right='C', exchange='SMART')
# Error 200, reqId 655: No security definition has been found for the request, contract: Option(symbol='GOOGL', lastTradeDateOrContractMonth='20190510', strike=1395.0, right='C', exchange='SMART')
# Error 200, reqId 657: No security definition has been found for the request, contract: Option(symbol='GOOGL', lastTradeDateOrContractMonth='20190510', strike=1405.0, right='C', exchange='SMART')
# Error 200, reqId 663: No security definition has been found for the request, contract: Option(symbol='GOOGL', lastTradeDateOrContractMonth='20190510', strike=995.0, right='C', exchange='SMART')
# Error 200, reqId 665: No security definition has been found for the request, contract: Option(symbol='GOOGL', lastTradeDateOrContractMonth='20190510', strike=1005.0, right='C', exchange='SMART')
# Error 200, reqId 667: No security definition has been found for the request, contract: Option(symbol='GOOGL', lastTradeDateOrContractMonth='20190510', strike=1015.0, right='C', exchange='SMART')
# Started to throttle requests
# commissionReport: No execution found for CommissionReport(execId='0001417f.5cb73bb0.02.01', commission=44.7768, currency='USD', realizedPNL=-855.839314)
# commissionReport: No execution found for CommissionReport(execId='0001417f.5cb73bb0.03.01', commission=44.7768, currency='USD', realizedPNL=1316.812114)
# Error 200, reqId 669: No security definition has been found for the request, contract: Option(symbol='GOOGL', lastTradeDateOrContractMonth='20190517', strike=1025.0, right='P', exchange='SMART')
# Error 200, reqId 671: No security definition has been found for the request, contract: Option(symbol='GOOGL', lastTradeDateOrContractMonth='20190517', strike=1035.0, right='P', exchange='SMART')
# Error 200, reqId 673: No security definition has been found for the request, contract: Option(symbol='GOOGL', lastTradeDateOrContractMonth='20190517', strike=1045.0, right='P', exchange='SMART')
# Error 200, reqId 675: No security definition has been found for the request, contract: Option(symbol='GOOGL', lastTradeDateOrContractMonth='20190517', strike=1055.0, right='P', exchange='SMART')
# Error 200, reqId 725: No security definition has been found for the request, contract: Option(symbol='GOOGL', lastTradeDateOrContractMonth='20190517', strike=1305.0, right='P', exchange='SMART')
# Error 200, reqId 727: No security definition has been found for the request, contract: Option(symbol='GOOGL', lastTradeDateOrContractMonth='20190517', strike=1315.0, right='P', exchange='SMART')
# Error 200, reqId 729: No security definition has been found for the request, contract: Option(symbol='GOOGL', lastTradeDateOrContractMonth='20190517', strike=1325.0, right='P', exchange='SMART')
# Error 200, reqId 731: No security definition has been found for the request, contract: Option(symbol='GOOGL', lastTradeDateOrContractMonth='20190517', strike=1335.0, right='P', exchange='SMART')
# Error 200, reqId 733: No security definition has been found for the request, contract: Option(symbol='GOOGL', lastTradeDateOrContractMonth='20190517', strike=1345.0, right='P', exchange='SMART')
# Error 200, reqId 735: No security definition has been found for the request, contract: Option(symbol='GOOGL', lastTradeDateOrContractMonth='20190517', strike=1355.0, right='P', exchange='SMART')
# Error 200, reqId 737: No security definition has been found for the request, contract: Option(symbol='GOOGL', lastTradeDateOrContractMonth='20190517', strike=1365.0, right='P', exchange='SMART')
# Error 200, reqId 739: No security definition has been found for the request, contract: Option(symbol='GOOGL', lastTradeDateOrContractMonth='20190517', strike=1375.0, right='P', exchange='SMART')
# Error 200, reqId 741: No security definition has been found for the request, contract: Option(symbol='GOOGL', lastTradeDateOrContractMonth='20190517', strike=1385.0, right='P', exchange='SMART')
# Error 200, reqId 743: No security definition has been found for the request, contract: Option(symbol='GOOGL', lastTradeDateOrContractMonth='20190517', strike=1395.0, right='P', exchange='SMART')
# Error 200, reqId 745: No security definition has been found for the request, contract: Option(symbol='GOOGL', lastTradeDateOrContractMonth='20190517', strike=1405.0, right='P', exchange='SMART')
# Error 200, reqId 761: No security definition has been found for the request, contract: Option(symbol='GOOGL', lastTradeDateOrContractMonth='20190517', strike=1005.0, right='P', exchange='SMART')
# Error 200, reqId 766: No security definition has been found for the request, contract: Option(symbol='GOOGL', lastTradeDateOrContractMonth='20190517', strike=1025.0, right='C', exchange='SMART')
# Error 200, reqId 764: No security definition has been found for the request, contract: Option(symbol='GOOGL', lastTradeDateOrContractMonth='20190517', strike=1015.0, right='P', exchange='SMART')
# Error 200, reqId 768: No security definition has been found for the request, contract: Option(symbol='GOOGL', lastTradeDateOrContractMonth='20190517', strike=1035.0, right='C', exchange='SMART')
# Error 200, reqId 770: No security definition has been found for the request, contract: Option(symbol='GOOGL', lastTradeDateOrContractMonth='20190517', strike=1045.0, right='C', exchange='SMART')
# Error 200, reqId 772: No security definition has been found for the request, contract: Option(symbol='GOOGL', lastTradeDateOrContractMonth='20190517', strike=1055.0, right='C', exchange='SMART')
# Error 200, reqId 822: No security definition has been found for the request, contract: Option(symbol='GOOGL', lastTradeDateOrContractMonth='20190517', strike=1305.0, right='C', exchange='SMART')
# Error 200, reqId 824: No security definition has been found for the request, contract: Option(symbol='GOOGL', lastTradeDateOrContractMonth='20190517', strike=1315.0, right='C', exchange='SMART')
# Error 200, reqId 826: No security definition has been found for the request, contract: Option(symbol='GOOGL', lastTradeDateOrContractMonth='20190517', strike=1325.0, right='C', exchange='SMART')
# Error 200, reqId 828: No security definition has been found for the request, contract: Option(symbol='GOOGL', lastTradeDateOrContractMonth='20190517', strike=1335.0, right='C', exchange='SMART')
# Error 200, reqId 830: No security definition has been found for the request, contract: Option(symbol='GOOGL', lastTradeDateOrContractMonth='20190517', strike=1345.0, right='C', exchange='SMART')
# Error 200, reqId 832: No security definition has been found for the request, contract: Option(symbol='GOOGL', lastTradeDateOrContractMonth='20190517', strike=1355.0, right='C', exchange='SMART')
# Error 200, reqId 834: No security definition has been found for the request, contract: Option(symbol='GOOGL', lastTradeDateOrContractMonth='20190517', strike=1365.0, right='C', exchange='SMART')
# Error 200, reqId 838: No security definition has been found for the request, contract: Option(symbol='GOOGL', lastTradeDateOrContractMonth='20190517', strike=1385.0, right='C', exchange='SMART')
# Error 200, reqId 836: No security definition has been found for the request, contract: Option(symbol='GOOGL', lastTradeDateOrContractMonth='20190517', strike=1375.0, right='C', exchange='SMART')
# Error 200, reqId 840: No security definition has been found for the request, contract: Option(symbol='GOOGL', lastTradeDateOrContractMonth='20190517', strike=1395.0, right='C', exchange='SMART')
# Error 200, reqId 842: No security definition has been found for the request, contract: Option(symbol='GOOGL', lastTradeDateOrContractMonth='20190517', strike=1405.0, right='C', exchange='SMART')
# Error 200, reqId 858: No security definition has been found for the request, contract: Option(symbol='GOOGL', lastTradeDateOrContractMonth='20190517', strike=1005.0, right='C', exchange='SMART')
# Stopped to throttle requests
# Error 200, reqId 861: No security definition has been found for the request, contract: Option(symbol='GOOGL', lastTradeDateOrContractMonth='20190517', strike=1015.0, right='C', exchange='SMART')
# Unknown contract: Option(symbol='GOOGL', lastTradeDateOrContractMonth='20190517', strike=1025.0, right='P', exchange='SMART')
# Unknown contract: Option(symbol='GOOGL', lastTradeDateOrContractMonth='20190517', strike=1035.0, right='P', exchange='SMART')
# Unknown contract: Option(symbol='GOOGL', lastTradeDateOrContractMonth='20190517', strike=1045.0, right='P', exchange='SMART')
# Unknown contract: Option(symbol='GOOGL', lastTradeDateOrContractMonth='20190517', strike=1055.0, right='P', exchange='SMART')
# ...
# Error 200, reqId 1714: No security definition has been found for the request, contract: Option(symbol='GOOGL', lastTradeDateOrContractMonth='20190531', strike=1580.0, right='P', exchange='SMART')
# Error 200, reqId 1716: No security definition has been found for the request, contract: Option(symbol='GOOGL', lastTradeDateOrContractMonth='20190531', strike=1075.0, right='P', exchange='SMART')
# Error 200, reqId 1718: No security definition has been found for the request, contract: Option(symbol='GOOGL', lastTradeDateOrContractMonth='20190531', strike=1085.0, right='P', exchange='SMART')
# Error 200, reqId 1720: No security definition has been found for the request, contract: Option(symbol='GOOGL', lastTradeDateOrContractMonth='20190531', strike=1095.0, right='P', exchange='SMART')
# Error 200, reqId 1762: No security definition has been found for the request, contract: Option(symbol='GOOGL', lastTradeDateOrContractMonth='20190531', strike=1305.0, right='P', exchange='SMART')
# Error 200, reqId 1764: No security definition has been found for the request, contract: Option(symbol='GOOGL', lastTradeDateOrContractMonth='20190531', strike=1315.0, right='P', exchange='SMART')
# Error 200, reqId 1766: No security definition has been found for the request, contract: Option(symbol='GOOGL', lastTradeDateOrContractMonth='20190531', strike=1325.0, right='P', exchange='SMART')
# Error 200, reqId 1768: No security definition has been found for the request, contract: Option(symbol='GOOGL', lastTradeDateOrContractMonth='20190531', strike=1335.0, right='P', exchange='SMART')
# Error 200, reqId 1770: No security definition has been found for the request, contract: Option(symbol='GOOGL', lastTradeDateOrContractMonth='20190531', strike=1345.0, right='P', exchange='SMART')
# Error 200, reqId 1772: No security definition has been found for the request, contract: Option(symbol='GOOGL', lastTradeDateOrContractMonth='20190531', strike=1355.0, right='P', exchange='SMART')
# Error 200, reqId 1774: No security definition has been found for the request, contract: Option(symbol='GOOGL', lastTradeDateOrContractMonth='20190531', strike=1365.0, right='P', exchange='SMART')
# Error 200, reqId 1776: No security definition has been found for the request, contract: Option(symbol='GOOGL', lastTradeDateOrContractMonth='20190531', strike=1375.0, right='P', exchange='SMART')
# Error 200, reqId 1778: No security definition has been found for the request, contract: Option(symbol='GOOGL', lastTradeDateOrContractMonth='20190531', strike=1385.0, right='P', exchange='SMART')
# Error 200, reqId 1780: No security definition has been found for the request, contract: Option(symbol='GOOGL', lastTradeDateOrContractMonth='20190531', strike=1395.0, right='P', exchange='SMART')
# Error 200, reqId 1782: No security definition has been found for the request, contract: Option(symbol='GOOGL', lastTradeDateOrContractMonth='20190531', strike=1405.0, right='P', exchange='SMART')
# Error 200, reqId 1783: No security definition has been found for the request, contract: Option(symbol='GOOGL', lastTradeDateOrContractMonth='20190531', strike=895.0, right='P', exchange='SMART')
# Error 200, reqId 1785: No security definition has been found for the request, contract: Option(symbol='GOOGL', lastTradeDateOrContractMonth='20190531', strike=900.0, right='P', exchange='SMART')
# Error 200, reqId 1786: No security definition has been found for the request, contract: Option(symbol='GOOGL', lastTradeDateOrContractMonth='20190531', strike=905.0, right='P', exchange='SMART')
# Error 200, reqId 1788: No security definition has been found for the request, contract: Option(symbol='GOOGL', lastTradeDateOrContractMonth='20190531', strike=910.0, right='P', exchange='SMART')
# Error 200, reqId 1789: No security definition has been found for the request, contract: Option(symbol='GOOGL', lastTradeDateOrContractMonth='20190531', strike=915.0, right='P', exchange='SMART')
# Error 200, reqId 1790: No security definition has been found for the request, contract: Option(symbol='GOOGL', lastTradeDateOrContractMonth='20190531', strike=920.0, right='P', exchange='SMART')
# Error 200, reqId 1791: No security definition has been found for the request, contract: Option(symbol='GOOGL', lastTradeDateOrContractMonth='20190531', strike=925.0, right='P', exchange='SMART')
# Error 200, reqId 1792: No security definition has been found for the request, contract: Option(symbol='GOOGL', lastTradeDateOrContractMonth='20190531', strike=1440.0, right='P', exchange='SMART')
# Error 200, reqId 1793: No security definition has been found for the request, contract: Option(symbol='GOOGL', lastTradeDateOrContractMonth='20190531', strike=930.0, right='P', exchange='SMART')
# Error 200, reqId 1794: No security definition has been found for the request, contract: Option(symbol='GOOGL', lastTradeDateOrContractMonth='20190531', strike=935.0, right='P', exchange='SMART')
# Error 200, reqId 1796: No security definition has been found for the request, contract: Option(symbol='GOOGL', lastTradeDateOrContractMonth='20190531', strike=945.0, right='P', exchange='SMART')
# Error 200, reqId 1797: No security definition has been found for the request, contract: Option(symbol='GOOGL', lastTradeDateOrContractMonth='20190531', strike=1460.0, right='P', exchange='SMART')
# Error 200, reqId 1799: No security definition has been found for the request, contract: Option(symbol='GOOGL', lastTradeDateOrContractMonth='20190531', strike=955.0, right='P', exchange='SMART')
# Error 200, reqId 1801: No security definition has been found for the request, contract: Option(symbol='GOOGL', lastTradeDateOrContractMonth='20190531', strike=965.0, right='P', exchange='SMART')
# Error 200, reqId 1802: No security definition has been found for the request, contract: Option(symbol='GOOGL', lastTradeDateOrContractMonth='20190531', strike=1480.0, right='P', exchange='SMART')
# Error 200, reqId 1804: No security definition has been found for the request, contract: Option(symbol='GOOGL', lastTradeDateOrContractMonth='20190531', strike=975.0, right='P', exchange='SMART')
# Error 200, reqId 1806: No security definition has been found for the request, contract: Option(symbol='GOOGL', lastTradeDateOrContractMonth='20190531', strike=985.0, right='P', exchange='SMART')
# Error 200, reqId 1807: No security definition has been found for the request, contract: Option(symbol='GOOGL', lastTradeDateOrContractMonth='20190531', strike=1500.0, right='P', exchange='SMART')
# Error 200, reqId 1809: No security definition has been found for the request, contract: Option(symbol='GOOGL', lastTradeDateOrContractMonth='20190531', strike=995.0, right='P', exchange='SMART')
# Error 200, reqId 1811: No security definition has been found for the request, contract: Option(symbol='GOOGL', lastTradeDateOrContractMonth='20190531', strike=1005.0, right='P', exchange='SMART')
# Error 200, reqId 1812: No security definition has been found for the request, contract: Option(symbol='GOOGL', lastTradeDateOrContractMonth='20190531', strike=1520.0, right='P', exchange='SMART')
# Error 200, reqId 1814: No security definition has been found for the request, contract: Option(symbol='GOOGL', lastTradeDateOrContractMonth='20190531', strike=1015.0, right='P', exchange='SMART')
# Error 200, reqId 1816: No security definition has been found for the request, contract: Option(symbol='GOOGL', lastTradeDateOrContractMonth='20190531', strike=1025.0, right='C', exchange='SMART')
# Error 200, reqId 1817: No security definition has been found for the request, contract: Option(symbol='GOOGL', lastTradeDateOrContractMonth='20190531', strike=1540.0, right='C', exchange='SMART')
# Error 200, reqId 1819: No security definition has been found for the request, contract: Option(symbol='GOOGL', lastTradeDateOrContractMonth='20190531', strike=1035.0, right='C', exchange='SMART')
# Error 200, reqId 1821: No security definition has been found for the request, contract: Option(symbol='GOOGL', lastTradeDateOrContractMonth='20190531', strike=1045.0, right='C', exchange='SMART')
# Error 200, reqId 1822: No security definition has been found for the request, contract: Option(symbol='GOOGL', lastTradeDateOrContractMonth='20190531', strike=1560.0, right='C', exchange='SMART')
# Error 200, reqId 1824: No security definition has been found for the request, contract: Option(symbol='GOOGL', lastTradeDateOrContractMonth='20190531', strike=1055.0, right='C', exchange='SMART')
# Error 200, reqId 1826: No security definition has been found for the request, contract: Option(symbol='GOOGL', lastTradeDateOrContractMonth='20190531', strike=1065.0, right='C', exchange='SMART')
# Error 200, reqId 1827: No security definition has been found for the request, contract: Option(symbol='GOOGL', lastTradeDateOrContractMonth='20190531', strike=1580.0, right='C', exchange='SMART')
# Error 200, reqId 1829: No security definition has been found for the request, contract: Option(symbol='GOOGL', lastTradeDateOrContractMonth='20190531', strike=1075.0, right='C', exchange='SMART')
# Error 200, reqId 1831: No security definition has been found for the request, contract: Option(symbol='GOOGL', lastTradeDateOrContractMonth='20190531', strike=1085.0, right='C', exchange='SMART')
# Error 200, reqId 1833: No security definition has been found for the request, contract: Option(symbol='GOOGL', lastTradeDateOrContractMonth='20190531', strike=1095.0, right='C', exchange='SMART')
# Error 200, reqId 1875: No security definition has been found for the request, contract: Option(symbol='GOOGL', lastTradeDateOrContractMonth='20190531', strike=1305.0, right='C', exchange='SMART')
# Error 200, reqId 1877: No security definition has been found for the request, contract: Option(symbol='GOOGL', lastTradeDateOrContractMonth='20190531', strike=1315.0, right='C', exchange='SMART')
# Error 200, reqId 1879: No security definition has been found for the request, contract: Option(symbol='GOOGL', lastTradeDateOrContractMonth='20190531', strike=1325.0, right='C', exchange='SMART')
# Error 200, reqId 1881: No security definition has been found for the request, contract: Option(symbol='GOOGL', lastTradeDateOrContractMonth='20190531', strike=1335.0, right='C', exchange='SMART')
# Error 200, reqId 1883: No security definition has been found for the request, contract: Option(symbol='GOOGL', lastTradeDateOrContractMonth='20190531', strike=1345.0, right='C', exchange='SMART')
# Error 200, reqId 1885: No security definition has been found for the request, contract: Option(symbol='GOOGL', lastTradeDateOrContractMonth='20190531', strike=1355.0, right='C', exchange='SMART')
# Error 200, reqId 1887: No security definition has been found for the request, contract: Option(symbol='GOOGL', lastTradeDateOrContractMonth='20190531', strike=1365.0, right='C', exchange='SMART')
# Error 200, reqId 1889: No security definition has been found for the request, contract: Option(symbol='GOOGL', lastTradeDateOrContractMonth='20190531', strike=1375.0, right='C', exchange='SMART')
# Error 200, reqId 1891: No security definition has been found for the request, contract: Option(symbol='GOOGL', lastTradeDateOrContractMonth='20190531', strike=1385.0, right='C', exchange='SMART')
# Stopped to throttle requests
# Error 200, reqId 1893: No security definition has been found for the request, contract: Option(symbol='GOOGL', lastTradeDateOrContractMonth='20190531', strike=1395.0, right='C', exchange='SMART')
# Error 200, reqId 1895: No security definition has been found for the request, contract: Option(symbol='GOOGL', lastTradeDateOrContractMonth='20190531', strike=1405.0, right='C', exchange='SMART')
# Error 200, reqId 1896: No security definition has been found for the request, contract: Option(symbol='GOOGL', lastTradeDateOrContractMonth='20190531', strike=895.0, right='C', exchange='SMART')
# Error 200, reqId 1898: No security definition has been found for the request, contract: Option(symbol='GOOGL', lastTradeDateOrContractMonth='20190531', strike=900.0, right='C', exchange='SMART')
# Error 200, reqId 1899: No security definition has been found for the request, contract: Option(symbol='GOOGL', lastTradeDateOrContractMonth='20190531', strike=905.0, right='C', exchange='SMART')
# Error 200, reqId 1901: No security definition has been found for the request, contract: Option(symbol='GOOGL', lastTradeDateOrContractMonth='20190531', strike=910.0, right='C', exchange='SMART')
# Error 200, reqId 1902: No security definition has been found for the request, contract: Option(symbol='GOOGL', lastTradeDateOrContractMonth='20190531', strike=915.0, right='C', exchange='SMART')
# Error 200, reqId 1903: No security definition has been found for the request, contract: Option(symbol='GOOGL', lastTradeDateOrContractMonth='20190531', strike=920.0, right='C', exchange='SMART')
# Error 200, reqId 1904: No security definition has been found for the request, contract: Option(symbol='GOOGL', lastTradeDateOrContractMonth='20190531', strike=925.0, right='C', exchange='SMART')
# Error 200, reqId 1905: No security definition has been found for the request, contract: Option(symbol='GOOGL', lastTradeDateOrContractMonth='20190531', strike=1440.0, right='C', exchange='SMART')
# Error 200, reqId 1906: No security definition has been found for the request, contract: Option(symbol='GOOGL', lastTradeDateOrContractMonth='20190531', strike=930.0, right='C', exchange='SMART')
# Error 200, reqId 1907: No security definition has been found for the request, contract: Option(symbol='GOOGL', lastTradeDateOrContractMonth='20190531', strike=935.0, right='C', exchange='SMART')
# Error 200, reqId 1909: No security definition has been found for the request, contract: Option(symbol='GOOGL', lastTradeDateOrContractMonth='20190531', strike=945.0, right='C', exchange='SMART')
# Error 200, reqId 1910: No security definition has been found for the request, contract: Option(symbol='GOOGL', lastTradeDateOrContractMonth='20190531', strike=1460.0, right='C', exchange='SMART')
# Error 200, reqId 1912: No security definition has been found for the request, contract: Option(symbol='GOOGL', lastTradeDateOrContractMonth='20190531', strike=955.0, right='C', exchange='SMART')
# Error 200, reqId 1914: No security definition has been found for the request, contract: Option(symbol='GOOGL', lastTradeDateOrContractMonth='20190531', strike=965.0, right='C', exchange='SMART')
# Error 200, reqId 1915: No security definition has been found for the request, contract: Option(symbol='GOOGL', lastTradeDateOrContractMonth='20190531', strike=1480.0, right='C', exchange='SMART')
# Error 200, reqId 1917: No security definition has been found for the request, contract: Option(symbol='GOOGL', lastTradeDateOrContractMonth='20190531', strike=975.0, right='C', exchange='SMART')
# Error 200, reqId 1919: No security definition has been found for the request, contract: Option(symbol='GOOGL', lastTradeDateOrContractMonth='20190531', strike=985.0, right='C', exchange='SMART')
# Error 200, reqId 1920: No security definition has been found for the request, contract: Option(symbol='GOOGL', lastTradeDateOrContractMonth='20190531', strike=1500.0, right='C', exchange='SMART')
# Error 200, reqId 1922: No security definition has been found for the request, contract: Option(symbol='GOOGL', lastTradeDateOrContractMonth='20190531', strike=995.0, right='C', exchange='SMART')
# Error 200, reqId 1924: No security definition has been found for the request, contract: Option(symbol='GOOGL', lastTradeDateOrContractMonth='20190531', strike=1005.0, right='C', exchange='SMART')
# Error 200, reqId 1925: No security definition has been found for the request, contract: Option(symbol='GOOGL', lastTradeDateOrContractMonth='20190531', strike=1520.0, right='C', exchange='SMART')
# Error 200, reqId 1927: No security definition has been found for the request, contract: Option(symbol='GOOGL', lastTradeDateOrContractMonth='20190531', strike=1015.0, right='C', exchange='SMART')

# %%
maxshift = 10

arteHedges_upside = []
for expiry_index in range(len(curr_calls.Expiry.drop_duplicates())):
    bias = 'upside'
    possible_pos = art_hedges(curr_calls, curr_puts, curr_price, expiry_index, bias,
                              maxshift = maxshift, commissions = 0.0266)
    arteHedges_upside.append(possible_pos)

arteHedges_upside = pd.concat(arteHedges_upside,axis = 0)

# %%
arteHedges_downside = []
for expiry_index in range(len(curr_calls.Expiry.drop_duplicates())):
    bias = 'downside'
    possible_pos = art_hedges(curr_calls, curr_puts, curr_price, expiry_index, bias,
                              maxshift = maxshift, commissions = 0.0266)
    arteHedges_downside.append(possible_pos)
arteHedges_downside = pd.concat(arteHedges_downside,axis = 0)

arteHedges_upside['ReturnOnRisk'] = abs(arteHedges_upside.Credit/arteHedges_upside.MaxLoss)
arteHedges_downside['ReturnOnRisk'] = abs(arteHedges_downside.Credit/arteHedges_downside.MaxLoss)

# %%
arteHedges_upside[(arteHedges_upside.Short_Put_Strike < curr_price) &
                  (arteHedges_upside.Short_Put_Strike > 0.001)].sort_values(['Maturity', 
                                                                             'ReturnOnRisk'], ascending = False)
# Out:
#     Short_Put_Strike  Long_Put_Strike  Long_Call_Strike  Delta  Gamma  Theta  \
# 68        1,105.0000       1,020.0000        1,420.0000 0.1001 0.0000 0.0008
# 68        1,110.0000       1,030.0000        1,410.0000 0.0985 0.0000 0.0029
# 69        1,090.0000       1,000.0000        1,420.0000 0.0795 0.0001 0.0064
# 72        1,060.0000         990.0000        1,460.0000 0.0375 0.0000 0.0026
# 72        1,050.0000         970.0000        1,460.0000 0.0361 0.0000 0.0048
# 61        1,100.0000       1,030.0000        1,410.0000 0.0695 0.0001 0.0003
# 60        1,105.0000       1,020.0000        1,400.0000 0.0827 0.0000 0.0099
# 60        1,100.0000       1,010.0000        1,400.0000 0.0801 0.0001 0.0062
# 62        1,090.0000       1,020.0000        1,420.0000 0.0582 0.0000 0.0014
# 62        1,080.0000       1,000.0000        1,420.0000 0.0561 0.0001 0.0062
# 63        1,070.0000       1,000.0000        1,440.0000 0.0437 0.0000 0.0019
# 54        1,130.0000       1,070.0000        1,380.0000 0.0879 0.0000 0.0024
# 55        1,115.0000       1,050.0000        1,390.0000 0.0712 0.0000 0.0130
# 55        1,110.0000       1,040.0000        1,390.0000 0.0690 0.0001 0.0114
# 56        1,105.0000       1,040.0000        1,400.0000 0.0587 0.0000 0.0156
# 54        1,115.0000       1,040.0000        1,380.0000 0.0811 0.0001 0.0085
#
#      Vega  time_remaining  Credit     MaxLoss  BreakEven   Maturity  \
# 68 0.1266          0.1799  2.0101 -8,298.9900 1,102.9899 2019-05-31
# 68 0.1086          0.0997  1.9101 -7,808.9900 1,108.0899 2019-05-24
# 69 0.0055          0.0997  1.3601 -8,863.9900 1,088.6399 2019-05-24
# 72 0.0135          0.0816  0.6101 -6,938.9900 1,059.3899 2019-05-17
# 72 0.0063          0.0816  0.5601 -7,943.9900 1,049.4399 2019-05-17
# 61 0.0358          0.0773  1.0351 -6,896.4900 1,098.9649 2019-05-10
# 60 0.0369          0.0773  1.2351 -8,376.4900 1,103.7649 2019-05-10
# 60 0.0076          0.0773  1.1601 -8,883.9900 1,098.8399 2019-05-10
# 62 0.0381          0.0773  0.8601 -6,913.9900 1,089.1399 2019-05-10
# 62 0.0352          0.0773  0.7601 -7,923.9900 1,079.2399 2019-05-10
# 63 0.0070          0.0773  0.6101 -6,938.9900 1,069.3899 2019-05-10
# 54 0.0172          0.0461  1.3351 -5,866.4900 1,128.6649 2019-05-03
# 55 0.0252          0.0461  1.0351 -6,396.4900 1,113.9649 2019-05-03
# 55 0.0254          0.0461  0.9601 -6,903.9900 1,109.0399 2019-05-03
# 56 0.0178          0.0461  0.8601 -6,413.9900 1,104.1399 2019-05-03
# 54 0.0523          0.0461  0.9851 -7,401.4900 1,114.0149 2019-05-03
#
#     ReturnOnRisk
# 68        0.0002
# 68        0.0002
# 69        0.0002
# 72        0.0001
# 72        0.0001
# 61        0.0002
# 60        0.0001
# 60        0.0001
# 62        0.0001
# 62        0.0001
# 63        0.0001
# 54        0.0002
# 55        0.0002
# 55        0.0001
# 56        0.0001
# 54        0.0001

# %%
arteHedges_downside[(arteHedges_downside.Short_Call_Strike > curr_price)].sort_values(['Maturity', 
                                                                               'Long_Put_Strike'], ascending = False)
# Out:
#    Short_Call_Strike  Long_Call_Strike  Long_Put_Strike   Delta  Gamma  Theta  \
# 8         1,240.0000        1,285.0000       1,020.0000 -0.2231 0.0001 0.0031
# 7         1,240.0000        1,285.0000       1,010.0000 -0.2205 0.0000 0.0128
# 6         1,240.0000        1,280.0000       1,000.0000 -0.1968 0.0001 0.0058
# 5         1,245.0000        1,280.0000         995.0000 -0.1726 0.0000 0.0004
# 5         1,240.0000        1,280.0000         995.0000 -0.1957 0.0000 0.0103
# 4         1,240.0000        1,280.0000         990.0000 -0.1946 0.0000 0.0145
# 3         1,240.0000        1,280.0000         985.0000 -0.1936 0.0000 0.0188
# 2         1,240.0000        1,275.0000         970.0000 -0.1690 0.0000 0.0050
# 1         1,240.0000        1,275.0000         965.0000 -0.1683 0.0000 0.0077
# 0         1,240.0000        1,275.0000         960.0000 -0.1677 0.0000 0.0103
#
#     Vega  time_remaining  Credit     MaxLoss  BreakEven   Maturity  \
# 8 0.0838          0.0835 18.3101 -2,668.9900 1,258.3101 2019-05-17
# 7 0.0211          0.0835 18.4601 -2,653.9900 1,258.4601 2019-05-17
# 6 0.0104          0.0835 16.9101 -2,308.9900 1,256.9101 2019-05-17
# 5 0.0048          0.0835 14.3601 -2,063.9900 1,259.3601 2019-05-17
# 5 0.0100          0.0835 16.9601 -2,303.9900 1,256.9601 2019-05-17
# 4 0.0097          0.0835 17.0101 -2,298.9900 1,257.0101 2019-05-17
# 3 0.0070          0.0835 17.0601 -2,293.9900 1,257.0601 2019-05-17
# 2 0.0246          0.0835 15.4101 -1,958.9900 1,255.4101 2019-05-17
# 1 0.0243          0.0835 15.4351 -1,956.4900 1,255.4351 2019-05-17
# 0 0.0241          0.0835 15.4601 -1,953.9900 1,255.4601 2019-05-17
#
#    ReturnOnRisk
# 8        0.0069
# 7        0.0070
# 6        0.0073
# 5        0.0070
# 5        0.0074
# 4        0.0074
# 3        0.0074
# 2        0.0079
# 1        0.0079
# 0        0.0079

# %%
ib.disconnect()
