# %%
import warnings
warnings.filterwarnings('ignore')
import os

import tws_data 
import statsmodels.tsa.stattools as ts
import statsmodels.api as sm
from ib_insync import *
import numpy as np
import pandas as pd
import datetime as dt
import time
pd.options.display.float_format = '{:,.4f}'.format
# %matplotlib inline
from scipy.stats import norm as norm
import matplotlib.pyplot as plt
import requests as req
from bs4 import BeautifulSoup as bs
import plotly.plotly as py
import plotly.graph_objs as go
from plotly.offline import download_plotlyjs, init_notebook_mode, plot, iplot
init_notebook_mode(connected=True)
import math
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-latest.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %%
os.chdir('D:\Options Data\IB Intraday')

def create_dfrow(curr_option):
    df_row = pd.DataFrame({'Symbol': curr_option.contract.localSymbol, 
                           'Type':curr_option.contract.right, 
                           'Bid': curr_option.bid, 
                           'Ask': curr_option.ask, 
                           'Volume': curr_option.volume, 
                           'Strike': curr_option.contract.strike,
                           'Expiry': dt.datetime.strptime(curr_option.contract.lastTradeDateOrContractMonth, '%Y%m%d'),
                           'bidIV': curr_option.bidGreeks.impliedVol, 
                           'bidDelta': curr_option.bidGreeks.delta,
                           'bidGamma': curr_option.bidGreeks.gamma, 
                           'bidVega': curr_option.bidGreeks.vega,
                           'bidTheta': curr_option.bidGreeks.theta, 
                           'askIV': curr_option.askGreeks.impliedVol, 
                           'askDelta': curr_option.askGreeks.delta,
                           'askGamma': curr_option.askGreeks.gamma, 
                           'askVega': curr_option.askGreeks.vega,
                           'askTheta': curr_option.askGreeks.theta,
                           'modelIV': curr_option.modelGreeks.impliedVol, 
                           'modelDelta': curr_option.modelGreeks.delta,
                           'modelGamma': curr_option.modelGreeks.gamma, 
                           'modelVega': curr_option.modelGreeks.vega,
                           'modelTheta': curr_option.modelGreeks.theta}, index = [0])
    return df_row

def get_movers():

    indexarb_url = 'http://www.indexarb.com/stockVsIndexesMiddleColumn.html#djIndexAnalysis'
    indexarb_soup = bs(req.get(indexarb_url).text,'lxml')
    indexarb_tables = indexarb_soup.select('table[align="LEFT"]')

    movers = []

    for i, table_html in enumerate(indexarb_tables):
        curr_table = pd.read_html(str(table_html))[2]
        curr_table.columns = curr_table.loc[1,:].tolist()

        if i == 0:
            curr_table = curr_table.iloc[2:,:4].set_index('Index').apply(pd.to_numeric)
        else:
            curr_table = curr_table.iloc[2:,[1,3,4,5,6]].dropna().set_index('Sym').apply(pd.to_numeric)

        curr_table.columns = [x.split(' ')[0] for x in curr_table.columns.tolist()]
        movers.append(curr_table)

    index = movers[0]
    movers = pd.concat(movers[1:], axis = 0)
    movers = movers.sort_values('OneMonth')
    
    return index, movers

def time_remaining(weekly_options, curr_spx):
    typ = weekly_options.reset_index().loc[0,'Type']

    try:
        interest_rate = bs(req.get('https://www.marketwatch.com/investing/bond/tmubmusd01m?countrycode=bx','lxml').text, 'lxml')
        interest_rate = float(interest_rate.select_one('h3[class*="intraday__price"]').select_one('bg-quote').text)/100
    except:
        interest_rate = 0.02422

    weekly_options['a'] = interest_rate - (weekly_options['modelIV']**2)/2

    if typ == 'P':
        weekly_options['b'] = weekly_options['modelIV']*norm.ppf(-weekly_options['modelDelta'])
    if typ == 'C':
        weekly_options['b'] = -weekly_options['modelIV']*norm.ppf(weekly_options['modelDelta'])
    weekly_options['c'] = np.log(curr_spx/weekly_options['Strike'])

    weekly_options_otm = weekly_options[abs(weekly_options.modelDelta) <= 0.5]
    weekly_options_itm = weekly_options[abs(weekly_options.modelDelta) > 0.5]

    if typ == 'P':
        weekly_options_otm['time_remaining'] = ((-weekly_options_otm.b - 
                                                 np.sqrt(weekly_options_otm.b**2 - 
                                                         4*weekly_options_otm.a*weekly_options_otm.c))/(2*weekly_options_otm.a))**2
        weekly_options_itm['time_remaining'] = ((-weekly_options_itm.b + 
                                                 np.sqrt(weekly_options_itm.b**2 - 
                                                         4*weekly_options_itm.a*weekly_options_itm.c))/(2*weekly_options_itm.a))**2
    if typ == 'C':
        weekly_options_otm['time_remaining'] = ((-weekly_options_otm.b + 
                                                 np.sqrt(weekly_options_otm.b**2 - 
                                                         4*weekly_options_otm.a*weekly_options_otm.c))/(2*weekly_options_otm.a))**2
        weekly_options_itm['time_remaining'] = ((-weekly_options_itm.b - 
                                                 np.sqrt(weekly_options_itm.b**2 - 
                                                         4*weekly_options_itm.a*weekly_options_itm.c))/(2*weekly_options_itm.a))**2
    weekly_times = pd.concat([weekly_options_otm, 
                              weekly_options_itm], axis = 0)[['Expiry','time_remaining']].dropna().groupby('Expiry').mean()

    del weekly_options['a'], weekly_options['b'], weekly_options['c'], weekly_options_itm, weekly_options_otm

    return weekly_options.merge(weekly_times.reset_index(), on = 'Expiry')


def get_options(ticker, exchange, contractType, earliest_date, latest_date, curr_iv, stdevs, save_csv = False):
    if contractType == 'Stock':
        security = Stock(ticker,exchange)
    else:
        security = Index(ticker, exchange)

    ib.qualifyContracts(security)

    chains = ib.reqSecDefOptParams(security.symbol, '', security.secType, security.conId)

    chains_df = util.df(chains)
    chain = next(c for c in chains if c.tradingClass == ticker and c.exchange == 'SMART')

    all_expirations = sorted(exp for exp in chain.expirations)
    expirations_dates = [dt.datetime.strptime(x, '%Y%m%d') for x in all_expirations]

    expirations = list(filter(lambda x: x[0] >= earliest_date and x[0] <= latest_date, list(zip(expirations_dates,all_expirations))))
    dte_expirations = [(expir[0] - dt.datetime.today()).days for expir in expirations]
    expirations = [expir[1] for expir in expirations]

    ib.reqHeadTimeStamp(security, whatToShow='TRADES', useRTH=True)

    end_date = '' #'20100506 13:00:00 PST'
    duration = '1 D'

    sec_bars = ib.reqHistoricalData(
            security,
            endDateTime=end_date,
            durationStr=duration,
            barSizeSetting='1 min',
            whatToShow='TRADES',
            useRTH=True,
            formatDate=1)


    sec_df = util.df(sec_bars).set_index('date')
    sec_df.index = pd.to_datetime(sec_df.index)

    curr_sec_price = sec_df.reset_index().loc[len(sec_df) - 1, 'close']
    bounds_lst = [curr_sec_price*(stdevs*stdevs/(100*np.sqrt(365.25/dte))) for dte in dte_expirations]


    contracts_list = []

    for bounds, expiration in zip(bounds_lst, expirations):
#         strikes = [strike for strike in chain.strikes
#                    if strike % 5 == 0
#                    and curr_sec_price - bounds < strike < curr_sec_price + bounds]
        strikes = [strike for strike in chain.strikes
                   if curr_sec_price - bounds < strike < curr_sec_price + bounds]

        rights = ['P', 'C']

        curr_contracts = [Option(ticker, expiration, strike, right, 'SMART')
                          for right in rights
                          for strike in strikes]
        contracts_list += [curr_contracts]

    puts_list = []
    calls_list = []

    for contracts in contracts_list:
        ib.qualifyContracts(*contracts)
        sec_options = ib.reqTickers(*contracts)

        puts_rows = []
        calls_rows = []

        for curr_option in sec_options:
            try:
                curr_row = create_dfrow(curr_option)
                if curr_option.contract.right == 'P':
                    puts_rows.append(curr_row)
                elif curr_option.contract.right == 'C':
                    calls_rows.append(curr_row)
            except:
                continue

        puts = pd.concat(puts_rows).reset_index(drop = True).sort_values(['Expiry','Strike'])
        calls = pd.concat(calls_rows).reset_index(drop = True).sort_values(['Expiry','Strike'])
        puts = time_remaining(puts, curr_sec_price)
        calls = time_remaining(calls, curr_sec_price)
        puts_list.append(puts)
        calls_list.append(calls)
        time.sleep(5)

    puts_df = pd.concat(puts_list,axis = 0).reset_index(drop = True)
    calls_df = pd.concat(calls_list,axis = 0).reset_index(drop = True)

    if save_csv:
        curr_time = dt.datetime.now().strftime('%Y%m%d-%H-%M')
        puts_df.to_csv('ib_puts' + curr_time + '.csv')
        calls_df.to_csv('ib_calls' + curr_time + '.csv')
        
    return puts_df, calls_df, curr_sec_price


def get_spreads(weekly_options, curr_spx, expiry_index = 0, rowshift = 1, commissions = 0.0266):

    expirations_dates = weekly_options.Expiry.drop_duplicates().tolist()

    weekly_options = weekly_options[weekly_options.Expiry == expirations_dates[expiry_index]]

    typ = weekly_options.reset_index().loc[0,'Type']

    if typ == 'P':
        weekly_options = weekly_options.sort_values('Strike', ascending = False).reset_index(drop = True)
    if typ == 'C':
        weekly_options = weekly_options.sort_values('Strike', ascending = True).reset_index(drop = True)

    time_remaining = weekly_options.reset_index(drop = True).loc[0,'time_remaining']

    weekly_options['Mid'] = (weekly_options.Ask + weekly_options.Bid)/2
    shorts = weekly_options[['Mid', 'Strike', 'bidDelta', 'bidGamma', 'bidTheta', 'bidVega']]
    shorts.columns = ['Price','Strike','Delta','Gamma','Theta','Vega']
    longs = weekly_options[['Mid','Strike', 'askDelta', 'askGamma','askTheta', 'askVega']]
    longs.columns = ['Price','Strike','Delta','Gamma','Theta','Vega']

    spreads = shorts - longs.shift(-rowshift)
    spreads['Short_Strike'] = shorts.Strike
    spreads['Short_Delta'] = shorts.Delta
    spreads['Long_Strike'] = longs.Strike.shift(-rowshift)
    spreads = spreads[['Short_Strike', 'Long_Strike', 'Short_Delta', 'Price',
                       'Strike', 'Delta', 'Gamma', 'Theta', 'Vega']]

    spreads['Credit'] = spreads.Price - commissions

    if typ == 'P':
        spreads['MaxLoss'] = (-spreads.Strike + spreads.Credit)*100
        spreads['BreakEven'] = spreads['Short_Strike'] - spreads.Credit
    if typ == 'C':
        spreads['MaxLoss'] = (spreads.Strike + spreads.Credit)*100
        spreads['BreakEven'] = spreads['Short_Strike'] + spreads.Credit

    del spreads['Price'], spreads['Strike']

    spreads = spreads[spreads.Credit > 0].dropna().reset_index(drop = True)
    spreads['Expiry'] = expirations_dates[expiry_index]

    return spreads

def art_hedges(curr_calls, curr_puts, curr_price, expiry_index, bias = 'upside',
               maxshift = 6, commissions = 0.0266):
    
    hedge = []
    for rowshift in range(1,maxshift):

        if bias == 'upside':
            spreads = get_spreads(curr_puts, curr_price, expiry_index, rowshift, commissions = 0.0266)
        else:
            spreads = get_spreads(curr_calls, curr_price, expiry_index, rowshift, commissions = 0.0266)
        spreads = spreads[(spreads.Credit > 0.5)]
        hedge.append(spreads)

    hedge = pd.concat(hedge, axis = 0).reset_index(drop = True)

    if bias == 'upside':
        expirations_dates = curr_calls.Expiry.drop_duplicates().tolist()

        long_hedge = curr_calls[(curr_calls.Expiry == expirations_dates[expiry_index])][['Ask', 'Bid', 'Expiry', 'Strike',
                                                                             'modelDelta', 'modelGamma',
                                                                             'modelTheta', 'modelVega', 'time_remaining']].reset_index(drop = True)
    else:
        expirations_dates = curr_puts.Expiry.drop_duplicates().tolist()

        long_hedge = curr_puts[(curr_puts.Expiry == expirations_dates[expiry_index])][['Ask', 'Bid', 'Expiry', 'Strike',
                                                                             'modelDelta', 'modelGamma',
                                                                             'modelTheta', 'modelVega', 'time_remaining']].reset_index(drop = True)

    long_hedge['Mid'] = (long_hedge['Ask'] + long_hedge['Bid'])/2
    long_hedge.columns = [x.replace('model','') for x in long_hedge.columns.tolist()]

    hedges_lst = []

    for idx, row in hedge.iterrows():

        curr_hedge = long_hedge[long_hedge.Mid < row.Credit][['Mid','Expiry', 'Strike',
                                                              'Delta', 'Gamma',
                                                              'Theta', 'Vega', 'time_remaining']]
        curr_hedge['Gamma'] = curr_hedge['Gamma'] - row.Gamma
        curr_hedge['Delta'] = curr_hedge['Delta'] - row.Delta
        curr_hedge['Theta'] = curr_hedge['Theta'] - row.Theta
        curr_hedge['Vega'] = curr_hedge['Vega'] - row.Vega
        if bias == 'upside':
            curr_hedge = curr_hedge[(curr_hedge.Delta > 0) &
                                    (curr_hedge.Gamma > 0) &
                                    (curr_hedge.Theta > 0) &
                                    (curr_hedge.Vega > 0)]
        else:
            curr_hedge = curr_hedge[(curr_hedge.Delta < 0) &
                                (curr_hedge.Gamma > 0) &
                                (curr_hedge.Theta > 0) &
                                (curr_hedge.Vega > 0)]
        curr_hedge['Credit'] = -curr_hedge.Mid + row.Credit - 0.0133

        if bias == 'upside':
            curr_hedge['MaxLoss'] = (row.Long_Strike - row.Short_Strike + curr_hedge.Credit)*100
            curr_hedge['BreakEven'] = row.Short_Strike - curr_hedge['Credit']
        else:
            curr_hedge['MaxLoss'] = (row.Short_Strike - row.Long_Strike + curr_hedge.Credit)*100
            curr_hedge['BreakEven'] = row.Short_Strike + curr_hedge['Credit']
        curr_hedge['Maturity'] = curr_hedge['Expiry']
        curr_hedge['Mid'] = row.Short_Strike
        curr_hedge['Expiry'] = row.Long_Strike

        if bias == 'upside':
            curr_hedge.columns = ['Short_Put_Strike','Long_Put_Strike','Long_Call_Strike'] + curr_hedge.columns.tolist()[3:]
        else:
            curr_hedge.columns = ['Short_Call_Strike','Long_Call_Strike','Long_Put_Strike'] + curr_hedge.columns.tolist()[3:]

        hedges_lst.append(curr_hedge)

    hedges_df = pd.concat(hedges_lst, axis = 0)
    
    return hedges_df

# %%
index, movers = get_movers()

# %%
losers = movers.head()
winners = movers.tail().sort_values('OneMonth', ascending = False)

# %%
client_id = 12

ib = IB()
ib.connect('127.0.0.1', 7496, clientId=client_id)
# Out:
# <IB connected to 127.0.0.1:7496 clientId=12>

# %%
# exchange = 'NYSE'
# contractType = 'Stock'
# earliest_date = dt.datetime(2019,4,6)
# latest_date = dt.datetime(2019,6,30)
# curr_iv = 40
# stdevs = 9

# stock_prices = {}
# stock_puts = {}
# stock_calls = {}

# for ticker in losers.index:

#     curr_puts, curr_calls, curr_price = get_options(ticker, exchange, contractType, earliest_date, latest_date, curr_iv, stdevs, save_csv = False)
    
#     stock_prices[ticker] = curr_price
#     stock_puts[ticker] = curr_puts
#     stock_calls[ticker] = curr_calls
#     break

# %%
exchange = 'NYSE'
contractType = 'Stock'
earliest_date = dt.datetime(2021,1,3)
latest_date = dt.datetime(2021,1,30)

ticker = 'TSLA'
curr_iv = 50
stdevs = 15
curr_puts, curr_calls, curr_price = get_options(ticker, exchange, contractType, earliest_date, latest_date, curr_iv, stdevs, save_csv = False)
# Out:
# commissionReport: No execution found for CommissionReport(execId='0001417f.5d22dd7e.02.01', commission=6.669, currency='USD')
# commissionReport: No execution found for CommissionReport(execId='0001417f.5d22dd7e.03.01', commission=6.669, currency='USD')
# commissionReport: No execution found for CommissionReport(execId='0001417f.5d22dd81.02.01', commission=6.669, currency='USD')
# commissionReport: No execution found for CommissionReport(execId='0001417f.5d22dd81.03.01', commission=6.669, currency='USD')
# Started to throttle requests
# Error 200, reqId 597: No security definition has been found for the request, contract: Option(symbol='TSLA', lastTradeDateOrContractMonth='20210115', strike=515.0, right='P', exchange='SMART')
# Error 200, reqId 598: No security definition has been found for the request, contract: Option(symbol='TSLA', lastTradeDateOrContractMonth='20210115', strike=5.0, right='P', exchange='SMART')
# Error 200, reqId 601: No security definition has been found for the request, contract: Option(symbol='TSLA', lastTradeDateOrContractMonth='20210115', strike=525.0, right='P', exchange='SMART')
# Error 200, reqId 605: No security definition has been found for the request, contract: Option(symbol='TSLA', lastTradeDateOrContractMonth='20210115', strike=535.0, right='P', exchange='SMART')
# Error 200, reqId 648: No security definition has been found for the request, contract: Option(symbol='TSLA', lastTradeDateOrContractMonth='20210115', strike=162.5, right='P', exchange='SMART')
# Error 200, reqId 650: No security definition has been found for the request, contract: Option(symbol='TSLA', lastTradeDateOrContractMonth='20210115', strike=167.5, right='P', exchange='SMART')
# Error 200, reqId 653: No security definition has been found for the request, contract: Option(symbol='TSLA', lastTradeDateOrContractMonth='20210115', strike=172.5, right='P', exchange='SMART')
# Error 200, reqId 655: No security definition has been found for the request, contract: Option(symbol='TSLA', lastTradeDateOrContractMonth='20210115', strike=177.5, right='P', exchange='SMART')
# Error 200, reqId 658: No security definition has been found for the request, contract: Option(symbol='TSLA', lastTradeDateOrContractMonth='20210115', strike=182.5, right='P', exchange='SMART')
# Error 200, reqId 660: No security definition has been found for the request, contract: Option(symbol='TSLA', lastTradeDateOrContractMonth='20210115', strike=187.5, right='P', exchange='SMART')
# Error 200, reqId 661: No security definition has been found for the request, contract: Option(symbol='TSLA', lastTradeDateOrContractMonth='20210115', strike=700.0, right='P', exchange='SMART')
# Error 200, reqId 663: No security definition has been found for the request, contract: Option(symbol='TSLA', lastTradeDateOrContractMonth='20210115', strike=192.5, right='P', exchange='SMART')
# Error 200, reqId 665: No security definition has been found for the request, contract: Option(symbol='TSLA', lastTradeDateOrContractMonth='20210115', strike=197.5, right='P', exchange='SMART')
# Error 200, reqId 667: No security definition has been found for the request, contract: Option(symbol='TSLA', lastTradeDateOrContractMonth='20210115', strike=202.5, right='P', exchange='SMART')
# Error 200, reqId 668: No security definition has been found for the request, contract: Option(symbol='TSLA', lastTradeDateOrContractMonth='20210115', strike=205.0, right='P', exchange='SMART')
# Error 200, reqId 669: No security definition has been found for the request, contract: Option(symbol='TSLA', lastTradeDateOrContractMonth='20210115', strike=207.5, right='P', exchange='SMART')
# Error 200, reqId 671: No security definition has been found for the request, contract: Option(symbol='TSLA', lastTradeDateOrContractMonth='20210115', strike=212.5, right='P', exchange='SMART')
# Error 200, reqId 672: No security definition has been found for the request, contract: Option(symbol='TSLA', lastTradeDateOrContractMonth='20210115', strike=215.0, right='P', exchange='SMART')
# Error 200, reqId 673: No security definition has been found for the request, contract: Option(symbol='TSLA', lastTradeDateOrContractMonth='20210115', strike=217.5, right='P', exchange='SMART')
# Error 200, reqId 675: No security definition has been found for the request, contract: Option(symbol='TSLA', lastTradeDateOrContractMonth='20210115', strike=222.5, right='P', exchange='SMART')
# Error 200, reqId 676: No security definition has been found for the request, contract: Option(symbol='TSLA', lastTradeDateOrContractMonth='20210115', strike=225.0, right='P', exchange='SMART')
# Error 200, reqId 677: No security definition has been found for the request, contract: Option(symbol='TSLA', lastTradeDateOrContractMonth='20210115', strike=227.5, right='P', exchange='SMART')
# Error 200, reqId 679: No security definition has been found for the request, contract: Option(symbol='TSLA', lastTradeDateOrContractMonth='20210115', strike=232.5, right='P', exchange='SMART')
# Error 200, reqId 680: No security definition has been found for the request, contract: Option(symbol='TSLA', lastTradeDateOrContractMonth='20210115', strike=235.0, right='P', exchange='SMART')
# Error 200, reqId 681: No security definition has been found for the request, contract: Option(symbol='TSLA', lastTradeDateOrContractMonth='20210115', strike=237.5, right='P', exchange='SMART')
# Error 200, reqId 683: No security definition has been found for the request, contract: Option(symbol='TSLA', lastTradeDateOrContractMonth='20210115', strike=242.5, right='P', exchange='SMART')
# Error 200, reqId 685: No security definition has been found for the request, contract: Option(symbol='TSLA', lastTradeDateOrContractMonth='20210115', strike=247.5, right='P', exchange='SMART')
# Error 200, reqId 687: No security definition has been found for the request, contract: Option(symbol='TSLA', lastTradeDateOrContractMonth='20210115', strike=252.5, right='P', exchange='SMART')
# Error 200, reqId 689: No security definition has been found for the request, contract: Option(symbol='TSLA', lastTradeDateOrContractMonth='20210115', strike=257.5, right='P', exchange='SMART')
# Error 200, reqId 691: No security definition has been found for the request, contract: Option(symbol='TSLA', lastTradeDateOrContractMonth='20210115', strike=262.5, right='P', exchange='SMART')
# Error 200, reqId 709: No security definition has been found for the request, contract: Option(symbol='TSLA', lastTradeDateOrContractMonth='20210115', strike=345.0, right='P', exchange='SMART')
# Error 200, reqId 711: No security definition has been found for the request, contract: Option(symbol='TSLA', lastTradeDateOrContractMonth='20210115', strike=355.0, right='P', exchange='SMART')
# Error 200, reqId 693: No security definition has been found for the request, contract: Option(symbol='TSLA', lastTradeDateOrContractMonth='20210115', strike=267.5, right='P', exchange='SMART')
# Error 200, reqId 713: No security definition has been found for the request, contract: Option(symbol='TSLA', lastTradeDateOrContractMonth='20210115', strike=365.0, right='P', exchange='SMART')
# Error 200, reqId 715: No security definition has been found for the request, contract: Option(symbol='TSLA', lastTradeDateOrContractMonth='20210115', strike=375.0, right='P', exchange='SMART')
# Error 200, reqId 717: No security definition has been found for the request, contract: Option(symbol='TSLA', lastTradeDateOrContractMonth='20210115', strike=385.0, right='P', exchange='SMART')
# Error 200, reqId 719: No security definition has been found for the request, contract: Option(symbol='TSLA', lastTradeDateOrContractMonth='20210115', strike=395.0, right='P', exchange='SMART')
# Error 200, reqId 721: No security definition has been found for the request, contract: Option(symbol='TSLA', lastTradeDateOrContractMonth='20210115', strike=405.0, right='P', exchange='SMART')
# Error 200, reqId 723: No security definition has been found for the request, contract: Option(symbol='TSLA', lastTradeDateOrContractMonth='20210115', strike=415.0, right='P', exchange='SMART')
# Error 200, reqId 725: No security definition has been found for the request, contract: Option(symbol='TSLA', lastTradeDateOrContractMonth='20210115', strike=425.0, right='P', exchange='SMART')
# Error 200, reqId 727: No security definition has been found for the request, contract: Option(symbol='TSLA', lastTradeDateOrContractMonth='20210115', strike=435.0, right='P', exchange='SMART')
# Error 200, reqId 731: No security definition has been found for the request, contract: Option(symbol='TSLA', lastTradeDateOrContractMonth='20210115', strike=455.0, right='P', exchange='SMART')
# Error 200, reqId 729: No security definition has been found for the request, contract: Option(symbol='TSLA', lastTradeDateOrContractMonth='20210115', strike=445.0, right='P', exchange='SMART')
# Error 200, reqId 733: No security definition has been found for the request, contract: Option(symbol='TSLA', lastTradeDateOrContractMonth='20210115', strike=465.0, right='P', exchange='SMART')
# Error 200, reqId 735: No security definition has been found for the request, contract: Option(symbol='TSLA', lastTradeDateOrContractMonth='20210115', strike=475.0, right='P', exchange='SMART')
# Error 200, reqId 739: No security definition has been found for the request, contract: Option(symbol='TSLA', lastTradeDateOrContractMonth='20210115', strike=495.0, right='P', exchange='SMART')
# Error 200, reqId 737: No security definition has been found for the request, contract: Option(symbol='TSLA', lastTradeDateOrContractMonth='20210115', strike=485.0, right='P', exchange='SMART')
# Error 200, reqId 741: No security definition has been found for the request, contract: Option(symbol='TSLA', lastTradeDateOrContractMonth='20210115', strike=505.0, right='P', exchange='SMART')
# Error 200, reqId 743: No security definition has been found for the request, contract: Option(symbol='TSLA', lastTradeDateOrContractMonth='20210115', strike=515.0, right='C', exchange='SMART')
# Error 200, reqId 744: No security definition has been found for the request, contract: Option(symbol='TSLA', lastTradeDateOrContractMonth='20210115', strike=5.0, right='C', exchange='SMART')
# Error 200, reqId 747: No security definition has been found for the request, contract: Option(symbol='TSLA', lastTradeDateOrContractMonth='20210115', strike=525.0, right='C', exchange='SMART')
# Error 200, reqId 751: No security definition has been found for the request, contract: Option(symbol='TSLA', lastTradeDateOrContractMonth='20210115', strike=535.0, right='C', exchange='SMART')
# Error 100, reqId 9: Max rate of messages per second has been exceeded:max=50 rec=53 (1)
# Error 200, reqId 794: No security definition has been found for the request, contract: Option(symbol='TSLA', lastTradeDateOrContractMonth='20210115', strike=162.5, right='C', exchange='SMART')
# Error 200, reqId 796: No security definition has been found for the request, contract: Option(symbol='TSLA', lastTradeDateOrContractMonth='20210115', strike=167.5, right='C', exchange='SMART')
# Error 200, reqId 799: No security definition has been found for the request, contract: Option(symbol='TSLA', lastTradeDateOrContractMonth='20210115', strike=172.5, right='C', exchange='SMART')
# Error 200, reqId 801: No security definition has been found for the request, contract: Option(symbol='TSLA', lastTradeDateOrContractMonth='20210115', strike=177.5, right='C', exchange='SMART')
# Error 200, reqId 804: No security definition has been found for the request, contract: Option(symbol='TSLA', lastTradeDateOrContractMonth='20210115', strike=182.5, right='C', exchange='SMART')
# Error 200, reqId 806: No security definition has been found for the request, contract: Option(symbol='TSLA', lastTradeDateOrContractMonth='20210115', strike=187.5, right='C', exchange='SMART')
# Error 200, reqId 807: No security definition has been found for the request, contract: Option(symbol='TSLA', lastTradeDateOrContractMonth='20210115', strike=700.0, right='C', exchange='SMART')
# Error 200, reqId 809: No security definition has been found for the request, contract: Option(symbol='TSLA', lastTradeDateOrContractMonth='20210115', strike=192.5, right='C', exchange='SMART')
# Error 200, reqId 811: No security definition has been found for the request, contract: Option(symbol='TSLA', lastTradeDateOrContractMonth='20210115', strike=197.5, right='C', exchange='SMART')
# Error 200, reqId 813: No security definition has been found for the request, contract: Option(symbol='TSLA', lastTradeDateOrContractMonth='20210115', strike=202.5, right='C', exchange='SMART')
# Error 200, reqId 814: No security definition has been found for the request, contract: Option(symbol='TSLA', lastTradeDateOrContractMonth='20210115', strike=205.0, right='C', exchange='SMART')
# Error 200, reqId 815: No security definition has been found for the request, contract: Option(symbol='TSLA', lastTradeDateOrContractMonth='20210115', strike=207.5, right='C', exchange='SMART')
# Error 200, reqId 817: No security definition has been found for the request, contract: Option(symbol='TSLA', lastTradeDateOrContractMonth='20210115', strike=212.5, right='C', exchange='SMART')
# Error 200, reqId 818: No security definition has been found for the request, contract: Option(symbol='TSLA', lastTradeDateOrContractMonth='20210115', strike=215.0, right='C', exchange='SMART')
# Error 200, reqId 819: No security definition has been found for the request, contract: Option(symbol='TSLA', lastTradeDateOrContractMonth='20210115', strike=217.5, right='C', exchange='SMART')
# Error 200, reqId 821: No security definition has been found for the request, contract: Option(symbol='TSLA', lastTradeDateOrContractMonth='20210115', strike=222.5, right='C', exchange='SMART')
# Error 200, reqId 822: No security definition has been found for the request, contract: Option(symbol='TSLA', lastTradeDateOrContractMonth='20210115', strike=225.0, right='C', exchange='SMART')
# Error 200, reqId 823: No security definition has been found for the request, contract: Option(symbol='TSLA', lastTradeDateOrContractMonth='20210115', strike=227.5, right='C', exchange='SMART')
# Error 200, reqId 825: No security definition has been found for the request, contract: Option(symbol='TSLA', lastTradeDateOrContractMonth='20210115', strike=232.5, right='C', exchange='SMART')
# Error 200, reqId 826: No security definition has been found for the request, contract: Option(symbol='TSLA', lastTradeDateOrContractMonth='20210115', strike=235.0, right='C', exchange='SMART')
# Error 200, reqId 827: No security definition has been found for the request, contract: Option(symbol='TSLA', lastTradeDateOrContractMonth='20210115', strike=237.5, right='C', exchange='SMART')
# Error 200, reqId 829: No security definition has been found for the request, contract: Option(symbol='TSLA', lastTradeDateOrContractMonth='20210115', strike=242.5, right='C', exchange='SMART')
# Error 200, reqId 831: No security definition has been found for the request, contract: Option(symbol='TSLA', lastTradeDateOrContractMonth='20210115', strike=247.5, right='C', exchange='SMART')
# Error 200, reqId 833: No security definition has been found for the request, contract: Option(symbol='TSLA', lastTradeDateOrContractMonth='20210115', strike=252.5, right='C', exchange='SMART')
# Error 200, reqId 835: No security definition has been found for the request, contract: Option(symbol='TSLA', lastTradeDateOrContractMonth='20210115', strike=257.5, right='C', exchange='SMART')
# Error 200, reqId 837: No security definition has been found for the request, contract: Option(symbol='TSLA', lastTradeDateOrContractMonth='20210115', strike=262.5, right='C', exchange='SMART')
# Error 200, reqId 839: No security definition has been found for the request, contract: Option(symbol='TSLA', lastTradeDateOrContractMonth='20210115', strike=267.5, right='C', exchange='SMART')
# Error 200, reqId 857: No security definition has been found for the request, contract: Option(symbol='TSLA', lastTradeDateOrContractMonth='20210115', strike=355.0, right='C', exchange='SMART')
# Error 200, reqId 855: No security definition has been found for the request, contract: Option(symbol='TSLA', lastTradeDateOrContractMonth='20210115', strike=345.0, right='C', exchange='SMART')
# Error 200, reqId 859: No security definition has been found for the request, contract: Option(symbol='TSLA', lastTradeDateOrContractMonth='20210115', strike=365.0, right='C', exchange='SMART')
# Error 200, reqId 861: No security definition has been found for the request, contract: Option(symbol='TSLA', lastTradeDateOrContractMonth='20210115', strike=375.0, right='C', exchange='SMART')
# Error 200, reqId 863: No security definition has been found for the request, contract: Option(symbol='TSLA', lastTradeDateOrContractMonth='20210115', strike=385.0, right='C', exchange='SMART')
# Error 200, reqId 865: No security definition has been found for the request, contract: Option(symbol='TSLA', lastTradeDateOrContractMonth='20210115', strike=395.0, right='C', exchange='SMART')
# Error 200, reqId 867: No security definition has been found for the request, contract: Option(symbol='TSLA', lastTradeDateOrContractMonth='20210115', strike=405.0, right='C', exchange='SMART')
# Error 200, reqId 869: No security definition has been found for the request, contract: Option(symbol='TSLA', lastTradeDateOrContractMonth='20210115', strike=415.0, right='C', exchange='SMART')
# Error 200, reqId 871: No security definition has been found for the request, contract: Option(symbol='TSLA', lastTradeDateOrContractMonth='20210115', strike=425.0, right='C', exchange='SMART')
# Error 200, reqId 873: No security definition has been found for the request, contract: Option(symbol='TSLA', lastTradeDateOrContractMonth='20210115', strike=435.0, right='C', exchange='SMART')
# Error 200, reqId 875: No security definition has been found for the request, contract: Option(symbol='TSLA', lastTradeDateOrContractMonth='20210115', strike=445.0, right='C', exchange='SMART')
# Error 200, reqId 877: No security definition has been found for the request, contract: Option(symbol='TSLA', lastTradeDateOrContractMonth='20210115', strike=455.0, right='C', exchange='SMART')
# Error 200, reqId 879: No security definition has been found for the request, contract: Option(symbol='TSLA', lastTradeDateOrContractMonth='20210115', strike=465.0, right='C', exchange='SMART')
# Error 200, reqId 881: No security definition has been found for the request, contract: Option(symbol='TSLA', lastTradeDateOrContractMonth='20210115', strike=475.0, right='C', exchange='SMART')
# Stopped to throttle requests
# Error 200, reqId 883: No security definition has been found for the request, contract: Option(symbol='TSLA', lastTradeDateOrContractMonth='20210115', strike=485.0, right='C', exchange='SMART')
# Error 200, reqId 885: No security definition has been found for the request, contract: Option(symbol='TSLA', lastTradeDateOrContractMonth='20210115', strike=495.0, right='C', exchange='SMART')
# Error 200, reqId 887: No security definition has been found for the request, contract: Option(symbol='TSLA', lastTradeDateOrContractMonth='20210115', strike=505.0, right='C', exchange='SMART')
# Unknown contract: Option(symbol='TSLA', lastTradeDateOrContractMonth='20210115', strike=515.0, right='P', exchange='SMART')
# Unknown contract: Option(symbol='TSLA', lastTradeDateOrContractMonth='20210115', strike=5.0, right='P', exchange='SMART')
# Unknown contract: Option(symbol='TSLA', lastTradeDateOrContractMonth='20210115', strike=525.0, right='P', exchange='SMART')
# Unknown contract: Option(symbol='TSLA', lastTradeDateOrContractMonth='20210115', strike=535.0, right='P', exchange='SMART')
# Unknown contract: Option(symbol='TSLA', lastTradeDateOrContractMonth='20210115', strike=162.5, right='P', exchange='SMART')
# Unknown contract: Option(symbol='TSLA', lastTradeDateOrContractMonth='20210115', strike=167.5, right='P', exchange='SMART')
# Unknown contract: Option(symbol='TSLA', lastTradeDateOrContractMonth='20210115', strike=172.5, right='P', exchange='SMART')
# Unknown contract: Option(symbol='TSLA', lastTradeDateOrContractMonth='20210115', strike=177.5, right='P', exchange='SMART')
# Unknown contract: Option(symbol='TSLA', lastTradeDateOrContractMonth='20210115', strike=182.5, right='P', exchange='SMART')
# Unknown contract: Option(symbol='TSLA', lastTradeDateOrContractMonth='20210115', strike=187.5, right='P', exchange='SMART')
# Unknown contract: Option(symbol='TSLA', lastTradeDateOrContractMonth='20210115', strike=700.0, right='P', exchange='SMART')
# Unknown contract: Option(symbol='TSLA', lastTradeDateOrContractMonth='20210115', strike=192.5, right='P', exchange='SMART')
# Unknown contract: Option(symbol='TSLA', lastTradeDateOrContractMonth='20210115', strike=197.5, right='P', exchange='SMART')
# Unknown contract: Option(symbol='TSLA', lastTradeDateOrContractMonth='20210115', strike=202.5, right='P', exchange='SMART')
# Unknown contract: Option(symbol='TSLA', lastTradeDateOrContractMonth='20210115', strike=205.0, right='P', exchange='SMART')
# Unknown contract: Option(symbol='TSLA', lastTradeDateOrContractMonth='20210115', strike=207.5, right='P', exchange='SMART')
# Unknown contract: Option(symbol='TSLA', lastTradeDateOrContractMonth='20210115', strike=212.5, right='P', exchange='SMART')
# Unknown contract: Option(symbol='TSLA', lastTradeDateOrContractMonth='20210115', strike=215.0, right='P', exchange='SMART')
# Unknown contract: Option(symbol='TSLA', lastTradeDateOrContractMonth='20210115', strike=217.5, right='P', exchange='SMART')
# Unknown contract: Option(symbol='TSLA', lastTradeDateOrContractMonth='20210115', strike=222.5, right='P', exchange='SMART')
# Unknown contract: Option(symbol='TSLA', lastTradeDateOrContractMonth='20210115', strike=225.0, right='P', exchange='SMART')
# Unknown contract: Option(symbol='TSLA', lastTradeDateOrContractMonth='20210115', strike=227.5, right='P', exchange='SMART')
# Unknown contract: Option(symbol='TSLA', lastTradeDateOrContractMonth='20210115', strike=232.5, right='P', exchange='SMART')
# Unknown contract: Option(symbol='TSLA', lastTradeDateOrContractMonth='20210115', strike=235.0, right='P', exchange='SMART')
# Unknown contract: Option(symbol='TSLA', lastTradeDateOrContractMonth='20210115', strike=237.5, right='P', exchange='SMART')
# Unknown contract: Option(symbol='TSLA', lastTradeDateOrContractMonth='20210115', strike=242.5, right='P', exchange='SMART')
# Unknown contract: Option(symbol='TSLA', lastTradeDateOrContractMonth='20210115', strike=247.5, right='P', exchange='SMART')
# Unknown contract: Option(symbol='TSLA', lastTradeDateOrContractMonth='20210115', strike=252.5, right='P', exchange='SMART')
# Unknown contract: Option(symbol='TSLA', lastTradeDateOrContractMonth='20210115', strike=257.5, right='P', exchange='SMART')
# Unknown contract: Option(symbol='TSLA', lastTradeDateOrContractMonth='20210115', strike=262.5, right='P', exchange='SMART')
# Unknown contract: Option(symbol='TSLA', lastTradeDateOrContractMonth='20210115', strike=267.5, right='P', exchange='SMART')
# Unknown contract: Option(symbol='TSLA', lastTradeDateOrContractMonth='20210115', strike=345.0, right='P', exchange='SMART')
# Unknown contract: Option(symbol='TSLA', lastTradeDateOrContractMonth='20210115', strike=355.0, right='P', exchange='SMART')
# Unknown contract: Option(symbol='TSLA', lastTradeDateOrContractMonth='20210115', strike=365.0, right='P', exchange='SMART')
# Unknown contract: Option(symbol='TSLA', lastTradeDateOrContractMonth='20210115', strike=375.0, right='P', exchange='SMART')
# Unknown contract: Option(symbol='TSLA', lastTradeDateOrContractMonth='20210115', strike=385.0, right='P', exchange='SMART')
# Unknown contract: Option(symbol='TSLA', lastTradeDateOrContractMonth='20210115', strike=395.0, right='P', exchange='SMART')
# Unknown contract: Option(symbol='TSLA', lastTradeDateOrContractMonth='20210115', strike=405.0, right='P', exchange='SMART')
# Unknown contract: Option(symbol='TSLA', lastTradeDateOrContractMonth='20210115', strike=415.0, right='P', exchange='SMART')
# Unknown contract: Option(symbol='TSLA', lastTradeDateOrContractMonth='20210115', strike=425.0, right='P', exchange='SMART')
# Unknown contract: Option(symbol='TSLA', lastTradeDateOrContractMonth='20210115', strike=435.0, right='P', exchange='SMART')
# Unknown contract: Option(symbol='TSLA', lastTradeDateOrContractMonth='20210115', strike=445.0, right='P', exchange='SMART')
# Unknown contract: Option(symbol='TSLA', lastTradeDateOrContractMonth='20210115', strike=455.0, right='P', exchange='SMART')
# Unknown contract: Option(symbol='TSLA', lastTradeDateOrContractMonth='20210115', strike=465.0, right='P', exchange='SMART')
# Unknown contract: Option(symbol='TSLA', lastTradeDateOrContractMonth='20210115', strike=475.0, right='P', exchange='SMART')
# Unknown contract: Option(symbol='TSLA', lastTradeDateOrContractMonth='20210115', strike=485.0, right='P', exchange='SMART')
# Unknown contract: Option(symbol='TSLA', lastTradeDateOrContractMonth='20210115', strike=495.0, right='P', exchange='SMART')
# Unknown contract: Option(symbol='TSLA', lastTradeDateOrContractMonth='20210115', strike=505.0, right='P', exchange='SMART')
# Unknown contract: Option(symbol='TSLA', lastTradeDateOrContractMonth='20210115', strike=515.0, right='C', exchange='SMART')
# Unknown contract: Option(symbol='TSLA', lastTradeDateOrContractMonth='20210115', strike=5.0, right='C', exchange='SMART')
# Unknown contract: Option(symbol='TSLA', lastTradeDateOrContractMonth='20210115', strike=525.0, right='C', exchange='SMART')
# Unknown contract: Option(symbol='TSLA', lastTradeDateOrContractMonth='20210115', strike=535.0, right='C', exchange='SMART')
# Unknown contract: Option(symbol='TSLA', lastTradeDateOrContractMonth='20210115', strike=162.5, right='C', exchange='SMART')
# Unknown contract: Option(symbol='TSLA', lastTradeDateOrContractMonth='20210115', strike=167.5, right='C', exchange='SMART')
# Unknown contract: Option(symbol='TSLA', lastTradeDateOrContractMonth='20210115', strike=172.5, right='C', exchange='SMART')
# Unknown contract: Option(symbol='TSLA', lastTradeDateOrContractMonth='20210115', strike=177.5, right='C', exchange='SMART')
# Unknown contract: Option(symbol='TSLA', lastTradeDateOrContractMonth='20210115', strike=182.5, right='C', exchange='SMART')
# Unknown contract: Option(symbol='TSLA', lastTradeDateOrContractMonth='20210115', strike=187.5, right='C', exchange='SMART')
# Unknown contract: Option(symbol='TSLA', lastTradeDateOrContractMonth='20210115', strike=700.0, right='C', exchange='SMART')
# Unknown contract: Option(symbol='TSLA', lastTradeDateOrContractMonth='20210115', strike=192.5, right='C', exchange='SMART')
# Unknown contract: Option(symbol='TSLA', lastTradeDateOrContractMonth='20210115', strike=197.5, right='C', exchange='SMART')
# Unknown contract: Option(symbol='TSLA', lastTradeDateOrContractMonth='20210115', strike=202.5, right='C', exchange='SMART')
# Unknown contract: Option(symbol='TSLA', lastTradeDateOrContractMonth='20210115', strike=205.0, right='C', exchange='SMART')
# Unknown contract: Option(symbol='TSLA', lastTradeDateOrContractMonth='20210115', strike=207.5, right='C', exchange='SMART')
# Unknown contract: Option(symbol='TSLA', lastTradeDateOrContractMonth='20210115', strike=212.5, right='C', exchange='SMART')
# Unknown contract: Option(symbol='TSLA', lastTradeDateOrContractMonth='20210115', strike=215.0, right='C', exchange='SMART')
# Unknown contract: Option(symbol='TSLA', lastTradeDateOrContractMonth='20210115', strike=217.5, right='C', exchange='SMART')
# Unknown contract: Option(symbol='TSLA', lastTradeDateOrContractMonth='20210115', strike=222.5, right='C', exchange='SMART')
# Unknown contract: Option(symbol='TSLA', lastTradeDateOrContractMonth='20210115', strike=225.0, right='C', exchange='SMART')
# Unknown contract: Option(symbol='TSLA', lastTradeDateOrContractMonth='20210115', strike=227.5, right='C', exchange='SMART')
# Unknown contract: Option(symbol='TSLA', lastTradeDateOrContractMonth='20210115', strike=232.5, right='C', exchange='SMART')
# Unknown contract: Option(symbol='TSLA', lastTradeDateOrContractMonth='20210115', strike=235.0, right='C', exchange='SMART')
# Unknown contract: Option(symbol='TSLA', lastTradeDateOrContractMonth='20210115', strike=237.5, right='C', exchange='SMART')
# Unknown contract: Option(symbol='TSLA', lastTradeDateOrContractMonth='20210115', strike=242.5, right='C', exchange='SMART')
# Unknown contract: Option(symbol='TSLA', lastTradeDateOrContractMonth='20210115', strike=247.5, right='C', exchange='SMART')
# Unknown contract: Option(symbol='TSLA', lastTradeDateOrContractMonth='20210115', strike=252.5, right='C', exchange='SMART')
# Unknown contract: Option(symbol='TSLA', lastTradeDateOrContractMonth='20210115', strike=257.5, right='C', exchange='SMART')
# Unknown contract: Option(symbol='TSLA', lastTradeDateOrContractMonth='20210115', strike=262.5, right='C', exchange='SMART')
# Unknown contract: Option(symbol='TSLA', lastTradeDateOrContractMonth='20210115', strike=267.5, right='C', exchange='SMART')
# Unknown contract: Option(symbol='TSLA', lastTradeDateOrContractMonth='20210115', strike=345.0, right='C', exchange='SMART')
# Unknown contract: Option(symbol='TSLA', lastTradeDateOrContractMonth='20210115', strike=355.0, right='C', exchange='SMART')
# Unknown contract: Option(symbol='TSLA', lastTradeDateOrContractMonth='20210115', strike=365.0, right='C', exchange='SMART')
# Unknown contract: Option(symbol='TSLA', lastTradeDateOrContractMonth='20210115', strike=375.0, right='C', exchange='SMART')
# Unknown contract: Option(symbol='TSLA', lastTradeDateOrContractMonth='20210115', strike=385.0, right='C', exchange='SMART')
# Unknown contract: Option(symbol='TSLA', lastTradeDateOrContractMonth='20210115', strike=395.0, right='C', exchange='SMART')
# Unknown contract: Option(symbol='TSLA', lastTradeDateOrContractMonth='20210115', strike=405.0, right='C', exchange='SMART')
# Unknown contract: Option(symbol='TSLA', lastTradeDateOrContractMonth='20210115', strike=415.0, right='C', exchange='SMART')
# Unknown contract: Option(symbol='TSLA', lastTradeDateOrContractMonth='20210115', strike=425.0, right='C', exchange='SMART')
# Unknown contract: Option(symbol='TSLA', lastTradeDateOrContractMonth='20210115', strike=435.0, right='C', exchange='SMART')
# Unknown contract: Option(symbol='TSLA', lastTradeDateOrContractMonth='20210115', strike=445.0, right='C', exchange='SMART')
# Unknown contract: Option(symbol='TSLA', lastTradeDateOrContractMonth='20210115', strike=455.0, right='C', exchange='SMART')
# Unknown contract: Option(symbol='TSLA', lastTradeDateOrContractMonth='20210115', strike=465.0, right='C', exchange='SMART')
# Unknown contract: Option(symbol='TSLA', lastTradeDateOrContractMonth='20210115', strike=475.0, right='C', exchange='SMART')
# Unknown contract: Option(symbol='TSLA', lastTradeDateOrContractMonth='20210115', strike=485.0, right='C', exchange='SMART')
# Unknown contract: Option(symbol='TSLA', lastTradeDateOrContractMonth='20210115', strike=495.0, right='C', exchange='SMART')
# Unknown contract: Option(symbol='TSLA', lastTradeDateOrContractMonth='20210115', strike=505.0, right='C', exchange='SMART')
# Started to throttle requests
# Error 200, reqId 889: No security definition has been found for the request, contract: Option(symbol='TSLA', lastTradeDateOrContractMonth='20210115', strike=515.0, right='P', exchange='SMART')
# Error 200, reqId 890: No security definition has been found for the request, contract: Option(symbol='TSLA', lastTradeDateOrContractMonth='20210115', strike=5.0, right='P', exchange='SMART')
# Error 200, reqId 893: No security definition has been found for the request, contract: Option(symbol='TSLA', lastTradeDateOrContractMonth='20210115', strike=525.0, right='P', exchange='SMART')
# Error 200, reqId 897: No security definition has been found for the request, contract: Option(symbol='TSLA', lastTradeDateOrContractMonth='20210115', strike=535.0, right='P', exchange='SMART')
# Error 200, reqId 940: No security definition has been found for the request, contract: Option(symbol='TSLA', lastTradeDateOrContractMonth='20210115', strike=162.5, right='P', exchange='SMART')
# Error 200, reqId 942: No security definition has been found for the request, contract: Option(symbol='TSLA', lastTradeDateOrContractMonth='20210115', strike=167.5, right='P', exchange='SMART')
# Error 200, reqId 945: No security definition has been found for the request, contract: Option(symbol='TSLA', lastTradeDateOrContractMonth='20210115', strike=172.5, right='P', exchange='SMART')
# Error 200, reqId 947: No security definition has been found for the request, contract: Option(symbol='TSLA', lastTradeDateOrContractMonth='20210115', strike=177.5, right='P', exchange='SMART')
# Error 200, reqId 950: No security definition has been found for the request, contract: Option(symbol='TSLA', lastTradeDateOrContractMonth='20210115', strike=182.5, right='P', exchange='SMART')
# Error 200, reqId 952: No security definition has been found for the request, contract: Option(symbol='TSLA', lastTradeDateOrContractMonth='20210115', strike=187.5, right='P', exchange='SMART')
# Error 200, reqId 953: No security definition has been found for the request, contract: Option(symbol='TSLA', lastTradeDateOrContractMonth='20210115', strike=700.0, right='P', exchange='SMART')
# Error 200, reqId 955: No security definition has been found for the request, contract: Option(symbol='TSLA', lastTradeDateOrContractMonth='20210115', strike=192.5, right='P', exchange='SMART')
# Error 200, reqId 957: No security definition has been found for the request, contract: Option(symbol='TSLA', lastTradeDateOrContractMonth='20210115', strike=197.5, right='P', exchange='SMART')
# Error 200, reqId 959: No security definition has been found for the request, contract: Option(symbol='TSLA', lastTradeDateOrContractMonth='20210115', strike=202.5, right='P', exchange='SMART')
# Error 200, reqId 960: No security definition has been found for the request, contract: Option(symbol='TSLA', lastTradeDateOrContractMonth='20210115', strike=205.0, right='P', exchange='SMART')
# Error 200, reqId 961: No security definition has been found for the request, contract: Option(symbol='TSLA', lastTradeDateOrContractMonth='20210115', strike=207.5, right='P', exchange='SMART')
# Error 200, reqId 963: No security definition has been found for the request, contract: Option(symbol='TSLA', lastTradeDateOrContractMonth='20210115', strike=212.5, right='P', exchange='SMART')
# Error 200, reqId 964: No security definition has been found for the request, contract: Option(symbol='TSLA', lastTradeDateOrContractMonth='20210115', strike=215.0, right='P', exchange='SMART')
# Error 200, reqId 965: No security definition has been found for the request, contract: Option(symbol='TSLA', lastTradeDateOrContractMonth='20210115', strike=217.5, right='P', exchange='SMART')
# Error 200, reqId 967: No security definition has been found for the request, contract: Option(symbol='TSLA', lastTradeDateOrContractMonth='20210115', strike=222.5, right='P', exchange='SMART')
# Error 200, reqId 968: No security definition has been found for the request, contract: Option(symbol='TSLA', lastTradeDateOrContractMonth='20210115', strike=225.0, right='P', exchange='SMART')
# Error 200, reqId 969: No security definition has been found for the request, contract: Option(symbol='TSLA', lastTradeDateOrContractMonth='20210115', strike=227.5, right='P', exchange='SMART')
# Error 200, reqId 971: No security definition has been found for the request, contract: Option(symbol='TSLA', lastTradeDateOrContractMonth='20210115', strike=232.5, right='P', exchange='SMART')
# Error 200, reqId 972: No security definition has been found for the request, contract: Option(symbol='TSLA', lastTradeDateOrContractMonth='20210115', strike=235.0, right='P', exchange='SMART')
# Error 200, reqId 973: No security definition has been found for the request, contract: Option(symbol='TSLA', lastTradeDateOrContractMonth='20210115', strike=237.5, right='P', exchange='SMART')
# Error 200, reqId 975: No security definition has been found for the request, contract: Option(symbol='TSLA', lastTradeDateOrContractMonth='20210115', strike=242.5, right='P', exchange='SMART')
# Error 200, reqId 977: No security definition has been found for the request, contract: Option(symbol='TSLA', lastTradeDateOrContractMonth='20210115', strike=247.5, right='P', exchange='SMART')
# Error 200, reqId 979: No security definition has been found for the request, contract: Option(symbol='TSLA', lastTradeDateOrContractMonth='20210115', strike=252.5, right='P', exchange='SMART')
# Error 200, reqId 981: No security definition has been found for the request, contract: Option(symbol='TSLA', lastTradeDateOrContractMonth='20210115', strike=257.5, right='P', exchange='SMART')
# Error 200, reqId 983: No security definition has been found for the request, contract: Option(symbol='TSLA', lastTradeDateOrContractMonth='20210115', strike=262.5, right='P', exchange='SMART')
# Error 200, reqId 985: No security definition has been found for the request, contract: Option(symbol='TSLA', lastTradeDateOrContractMonth='20210115', strike=267.5, right='P', exchange='SMART')
# Error 200, reqId 1001: No security definition has been found for the request, contract: Option(symbol='TSLA', lastTradeDateOrContractMonth='20210115', strike=345.0, right='P', exchange='SMART')
# Error 200, reqId 1003: No security definition has been found for the request, contract: Option(symbol='TSLA', lastTradeDateOrContractMonth='20210115', strike=355.0, right='P', exchange='SMART')
# Error 200, reqId 1005: No security definition has been found for the request, contract: Option(symbol='TSLA', lastTradeDateOrContractMonth='20210115', strike=365.0, right='P', exchange='SMART')
# Error 200, reqId 1007: No security definition has been found for the request, contract: Option(symbol='TSLA', lastTradeDateOrContractMonth='20210115', strike=375.0, right='P', exchange='SMART')
# Error 200, reqId 1009: No security definition has been found for the request, contract: Option(symbol='TSLA', lastTradeDateOrContractMonth='20210115', strike=385.0, right='P', exchange='SMART')
# Error 200, reqId 1011: No security definition has been found for the request, contract: Option(symbol='TSLA', lastTradeDateOrContractMonth='20210115', strike=395.0, right='P', exchange='SMART')
# Error 200, reqId 1013: No security definition has been found for the request, contract: Option(symbol='TSLA', lastTradeDateOrContractMonth='20210115', strike=405.0, right='P', exchange='SMART')
# Error 200, reqId 1015: No security definition has been found for the request, contract: Option(symbol='TSLA', lastTradeDateOrContractMonth='20210115', strike=415.0, right='P', exchange='SMART')
# Error 200, reqId 1017: No security definition has been found for the request, contract: Option(symbol='TSLA', lastTradeDateOrContractMonth='20210115', strike=425.0, right='P', exchange='SMART')
# Error 200, reqId 1019: No security definition has been found for the request, contract: Option(symbol='TSLA', lastTradeDateOrContractMonth='20210115', strike=435.0, right='P', exchange='SMART')
# Error 200, reqId 1021: No security definition has been found for the request, contract: Option(symbol='TSLA', lastTradeDateOrContractMonth='20210115', strike=445.0, right='P', exchange='SMART')
# Error 200, reqId 1023: No security definition has been found for the request, contract: Option(symbol='TSLA', lastTradeDateOrContractMonth='20210115', strike=455.0, right='P', exchange='SMART')
# Error 200, reqId 1025: No security definition has been found for the request, contract: Option(symbol='TSLA', lastTradeDateOrContractMonth='20210115', strike=465.0, right='P', exchange='SMART')
# Error 200, reqId 1027: No security definition has been found for the request, contract: Option(symbol='TSLA', lastTradeDateOrContractMonth='20210115', strike=475.0, right='P', exchange='SMART')
# Error 200, reqId 1029: No security definition has been found for the request, contract: Option(symbol='TSLA', lastTradeDateOrContractMonth='20210115', strike=485.0, right='P', exchange='SMART')
# Error 200, reqId 1031: No security definition has been found for the request, contract: Option(symbol='TSLA', lastTradeDateOrContractMonth='20210115', strike=495.0, right='P', exchange='SMART')
# Error 200, reqId 1033: No security definition has been found for the request, contract: Option(symbol='TSLA', lastTradeDateOrContractMonth='20210115', strike=505.0, right='P', exchange='SMART')
# Error 200, reqId 1035: No security definition has been found for the request, contract: Option(symbol='TSLA', lastTradeDateOrContractMonth='20210115', strike=515.0, right='C', exchange='SMART')
# Error 200, reqId 1036: No security definition has been found for the request, contract: Option(symbol='TSLA', lastTradeDateOrContractMonth='20210115', strike=5.0, right='C', exchange='SMART')
# Error 200, reqId 1039: No security definition has been found for the request, contract: Option(symbol='TSLA', lastTradeDateOrContractMonth='20210115', strike=525.0, right='C', exchange='SMART')
# Error 200, reqId 1043: No security definition has been found for the request, contract: Option(symbol='TSLA', lastTradeDateOrContractMonth='20210115', strike=535.0, right='C', exchange='SMART')
# Error 200, reqId 1086: No security definition has been found for the request, contract: Option(symbol='TSLA', lastTradeDateOrContractMonth='20210115', strike=162.5, right='C', exchange='SMART')
# Error 200, reqId 1088: No security definition has been found for the request, contract: Option(symbol='TSLA', lastTradeDateOrContractMonth='20210115', strike=167.5, right='C', exchange='SMART')
# Error 200, reqId 1091: No security definition has been found for the request, contract: Option(symbol='TSLA', lastTradeDateOrContractMonth='20210115', strike=172.5, right='C', exchange='SMART')
# Error 200, reqId 1093: No security definition has been found for the request, contract: Option(symbol='TSLA', lastTradeDateOrContractMonth='20210115', strike=177.5, right='C', exchange='SMART')
# Error 200, reqId 1096: No security definition has been found for the request, contract: Option(symbol='TSLA', lastTradeDateOrContractMonth='20210115', strike=182.5, right='C', exchange='SMART')
# Error 200, reqId 1098: No security definition has been found for the request, contract: Option(symbol='TSLA', lastTradeDateOrContractMonth='20210115', strike=187.5, right='C', exchange='SMART')
# Error 200, reqId 1099: No security definition has been found for the request, contract: Option(symbol='TSLA', lastTradeDateOrContractMonth='20210115', strike=700.0, right='C', exchange='SMART')
# Error 200, reqId 1101: No security definition has been found for the request, contract: Option(symbol='TSLA', lastTradeDateOrContractMonth='20210115', strike=192.5, right='C', exchange='SMART')
# Error 200, reqId 1103: No security definition has been found for the request, contract: Option(symbol='TSLA', lastTradeDateOrContractMonth='20210115', strike=197.5, right='C', exchange='SMART')
# Error 200, reqId 1105: No security definition has been found for the request, contract: Option(symbol='TSLA', lastTradeDateOrContractMonth='20210115', strike=202.5, right='C', exchange='SMART')
# Error 200, reqId 1106: No security definition has been found for the request, contract: Option(symbol='TSLA', lastTradeDateOrContractMonth='20210115', strike=205.0, right='C', exchange='SMART')
# Error 200, reqId 1107: No security definition has been found for the request, contract: Option(symbol='TSLA', lastTradeDateOrContractMonth='20210115', strike=207.5, right='C', exchange='SMART')
# Error 200, reqId 1109: No security definition has been found for the request, contract: Option(symbol='TSLA', lastTradeDateOrContractMonth='20210115', strike=212.5, right='C', exchange='SMART')
# Error 200, reqId 1110: No security definition has been found for the request, contract: Option(symbol='TSLA', lastTradeDateOrContractMonth='20210115', strike=215.0, right='C', exchange='SMART')
# Error 200, reqId 1111: No security definition has been found for the request, contract: Option(symbol='TSLA', lastTradeDateOrContractMonth='20210115', strike=217.5, right='C', exchange='SMART')
# Error 200, reqId 1113: No security definition has been found for the request, contract: Option(symbol='TSLA', lastTradeDateOrContractMonth='20210115', strike=222.5, right='C', exchange='SMART')
# Error 200, reqId 1114: No security definition has been found for the request, contract: Option(symbol='TSLA', lastTradeDateOrContractMonth='20210115', strike=225.0, right='C', exchange='SMART')
# Error 200, reqId 1115: No security definition has been found for the request, contract: Option(symbol='TSLA', lastTradeDateOrContractMonth='20210115', strike=227.5, right='C', exchange='SMART')
# Error 200, reqId 1117: No security definition has been found for the request, contract: Option(symbol='TSLA', lastTradeDateOrContractMonth='20210115', strike=232.5, right='C', exchange='SMART')
# Error 200, reqId 1118: No security definition has been found for the request, contract: Option(symbol='TSLA', lastTradeDateOrContractMonth='20210115', strike=235.0, right='C', exchange='SMART')
# Error 200, reqId 1119: No security definition has been found for the request, contract: Option(symbol='TSLA', lastTradeDateOrContractMonth='20210115', strike=237.5, right='C', exchange='SMART')
# Error 200, reqId 1121: No security definition has been found for the request, contract: Option(symbol='TSLA', lastTradeDateOrContractMonth='20210115', strike=242.5, right='C', exchange='SMART')
# Error 200, reqId 1123: No security definition has been found for the request, contract: Option(symbol='TSLA', lastTradeDateOrContractMonth='20210115', strike=247.5, right='C', exchange='SMART')
# Error 200, reqId 1125: No security definition has been found for the request, contract: Option(symbol='TSLA', lastTradeDateOrContractMonth='20210115', strike=252.5, right='C', exchange='SMART')
# Error 200, reqId 1127: No security definition has been found for the request, contract: Option(symbol='TSLA', lastTradeDateOrContractMonth='20210115', strike=257.5, right='C', exchange='SMART')
# Error 200, reqId 1129: No security definition has been found for the request, contract: Option(symbol='TSLA', lastTradeDateOrContractMonth='20210115', strike=262.5, right='C', exchange='SMART')
# Error 200, reqId 1131: No security definition has been found for the request, contract: Option(symbol='TSLA', lastTradeDateOrContractMonth='20210115', strike=267.5, right='C', exchange='SMART')
# Error 200, reqId 1147: No security definition has been found for the request, contract: Option(symbol='TSLA', lastTradeDateOrContractMonth='20210115', strike=345.0, right='C', exchange='SMART')
# Error 200, reqId 1149: No security definition has been found for the request, contract: Option(symbol='TSLA', lastTradeDateOrContractMonth='20210115', strike=355.0, right='C', exchange='SMART')
# Error 200, reqId 1151: No security definition has been found for the request, contract: Option(symbol='TSLA', lastTradeDateOrContractMonth='20210115', strike=365.0, right='C', exchange='SMART')
# Error 200, reqId 1153: No security definition has been found for the request, contract: Option(symbol='TSLA', lastTradeDateOrContractMonth='20210115', strike=375.0, right='C', exchange='SMART')
# Error 200, reqId 1155: No security definition has been found for the request, contract: Option(symbol='TSLA', lastTradeDateOrContractMonth='20210115', strike=385.0, right='C', exchange='SMART')
# Error 200, reqId 1157: No security definition has been found for the request, contract: Option(symbol='TSLA', lastTradeDateOrContractMonth='20210115', strike=395.0, right='C', exchange='SMART')
# Error 200, reqId 1159: No security definition has been found for the request, contract: Option(symbol='TSLA', lastTradeDateOrContractMonth='20210115', strike=405.0, right='C', exchange='SMART')
# Error 200, reqId 1161: No security definition has been found for the request, contract: Option(symbol='TSLA', lastTradeDateOrContractMonth='20210115', strike=415.0, right='C', exchange='SMART')
# Error 200, reqId 1163: No security definition has been found for the request, contract: Option(symbol='TSLA', lastTradeDateOrContractMonth='20210115', strike=425.0, right='C', exchange='SMART')
# Error 200, reqId 1165: No security definition has been found for the request, contract: Option(symbol='TSLA', lastTradeDateOrContractMonth='20210115', strike=435.0, right='C', exchange='SMART')
# Error 200, reqId 1167: No security definition has been found for the request, contract: Option(symbol='TSLA', lastTradeDateOrContractMonth='20210115', strike=445.0, right='C', exchange='SMART')
# Error 200, reqId 1169: No security definition has been found for the request, contract: Option(symbol='TSLA', lastTradeDateOrContractMonth='20210115', strike=455.0, right='C', exchange='SMART')
# Error 200, reqId 1171: No security definition has been found for the request, contract: Option(symbol='TSLA', lastTradeDateOrContractMonth='20210115', strike=465.0, right='C', exchange='SMART')
# Error 200, reqId 1173: No security definition has been found for the request, contract: Option(symbol='TSLA', lastTradeDateOrContractMonth='20210115', strike=475.0, right='C', exchange='SMART')
# Stopped to throttle requests
# Error 200, reqId 1175: No security definition has been found for the request, contract: Option(symbol='TSLA', lastTradeDateOrContractMonth='20210115', strike=485.0, right='C', exchange='SMART')
# Error 200, reqId 1177: No security definition has been found for the request, contract: Option(symbol='TSLA', lastTradeDateOrContractMonth='20210115', strike=495.0, right='C', exchange='SMART')
# Error 200, reqId 1179: No security definition has been found for the request, contract: Option(symbol='TSLA', lastTradeDateOrContractMonth='20210115', strike=505.0, right='C', exchange='SMART')

# %%
maxshift = 30

arteHedges_upside = []
for expiry_index in range(len(curr_calls.Expiry.drop_duplicates())):
    bias = 'upside'
    possible_pos = art_hedges(curr_calls, curr_puts, curr_price, expiry_index, bias,
                              maxshift = maxshift, commissions = 0.0266)
    arteHedges_upside.append(possible_pos)

arteHedges_upside = pd.concat(arteHedges_upside,axis = 0)

# %%
arteHedges_downside = []
for expiry_index in range(len(curr_calls.Expiry.drop_duplicates())):
    bias = 'downside'
    possible_pos = art_hedges(curr_calls, curr_puts, curr_price, expiry_index, bias,
                              maxshift = maxshift, commissions = 0.0266)
    arteHedges_downside.append(possible_pos)
arteHedges_downside = pd.concat(arteHedges_downside,axis = 0)

arteHedges_upside['ReturnOnRisk'] = abs(arteHedges_upside.Credit/arteHedges_upside.MaxLoss)
arteHedges_downside['ReturnOnRisk'] = abs(arteHedges_downside.Credit/arteHedges_downside.MaxLoss)

# %%
potential_ups = arteHedges_upside[(arteHedges_upside.Short_Put_Strike < curr_price) &
                                  (arteHedges_upside.Short_Put_Strike > 0.001)].sort_values(['Maturity', 
                                                                                             'ReturnOnRisk'], ascending = False)
try:
    potential_ups['downmove_to_breach'] = potential_ups['Short_Put_Strike']/curr_price - 1
    potential_ups['upmove_to_win'] = potential_ups['Long_Call_Strike']/curr_price - 1
    potential_ups = potential_ups.sort_values('MaxLoss').reset_index(drop = True)
    potential_ups['MaxLossScore'] = potential_ups.index
    
    potential_ups = potential_ups.sort_values('downmove_to_breach', ascending = False).reset_index(drop = True)
    potential_ups['DownMoveScore'] = potential_ups.index
    
    potential_ups = potential_ups.sort_values('upmove_to_win', ascending = False).reset_index(drop = True)
    potential_ups['UpMoveScore'] = potential_ups.index
    
    potential_ups['Score'] = potential_ups.MaxLossScore + potential_ups.DownMoveScore + potential_ups.UpMoveScore
    potential_ups = potential_ups.sort_values('Score', ascending = False)
except:
    None
# 1106 0.0089 0.0169          1.6130 23.5601 -12,143.9900   141.4399 2021-01-15
#
#       ReturnOnRisk  downmove_to_breach  upmove_to_win  MaxLossScore  \
# 417         0.0006             -0.7619         1.6841          1218
# 341         0.0006             -0.7619         1.7274          1223
# 315         0.0006             -0.7619         1.7707          1224
# 709         0.0007             -0.6753         1.4676           901
# 695         0.0008             -0.6753         1.5109           907
# 416         0.0008             -0.6970         1.6841          1134
# 275         0.0007             -0.7402         1.8140          1235
# 205         0.0007             -0.7619         1.8573          1281
# 203         0.0006             -0.7835         1.8573          1276
# 393         0.0007             -0.7402         1.6841          1112
# 388         0.0007             -0.7186         1.6841          1121
# 256         0.0007             -0.7619         1.8140          1228
# 642         0.0007             -0.6970         1.5109           892
# 365         0.0009             -0.6970         1.7274          1143
# 357         0.0008             -0.7186         1.7274          1130
# 350         0.0007             -0.7402         1.7274          1119
# 243         0.0008             -0.7186         1.8140          1241
# 684         0.0009             -0.6537         1.5109           916
# 206         0.0007             -0.7619         1.8573          1232
# 600         0.0007             -0.6970         1.5542           897
# 197         0.0008             -0.7402         1.8573          1239
# 745         0.0008             -0.6537         1.4676           790
# 260         0.0011             -0.6753         1.8140          1253
# 310         0.0007             -0.7402         1.7707          1120
# 307         0.0008             -0.7186         1.7707          1132
# 443         0.0007             -0.7186         1.6408          1006
# 587         0.0008             -0.6753         1.5542           912
# 725         0.0008             -0.6753         1.4676           781
# 195         0.0009             -0.7186         1.8573          1247
# 298         0.0009             -0.6970         1.7707          1144
# ...            ...                 ...            ...           ...
# 910         0.0023             -0.3073         1.3378           298
# 843         0.0020             -0.3506         1.3378           275
# 1152        0.0028             -0.1775         1.1213           138
# 1127        0.0018             -0.3073         1.1213            70
# 1171        0.0020             -0.2640         1.0780            85
# 1168        0.0023             -0.2207         1.0780           109
# 1173        0.0019             -0.2857         1.0780            47
# 1169        0.0022             -0.2424         1.0780            97
# 1107        0.0020             -0.2857         1.1213           119
# 1185        0.0017             -0.3073         1.0780            12
# 1144        0.0026             -0.1991         1.1213           128
# 1145        0.0023             -0.2424         1.1213           106
# 1110        0.0017             -0.3290         1.1213            11
# 1140        0.0024             -0.2207         1.1213           117
# 848         0.0022             -0.3290         1.3378           288
# 1134        0.0021             -0.2640         1.1213            91
# 1183        0.0023             -0.2207         1.0780            72
# 1123        0.0018             -0.3073         1.1213            41
# 1150        0.0027             -0.1775         1.1213           105
# 1175        0.0019             -0.2857         1.0780            20
# 899         0.0025             -0.2857         1.3378           314
# 1157        0.0022             -0.2424         1.1213            65
# 1113        0.0020             -0.2857         1.1213            53
# 1111        0.0030             -0.1342         1.1213           126
# 1104        0.0020             -0.2857         1.1213            86
# 1142        0.0024             -0.2207         1.1213            81
# 1118        0.0029             -0.1558         1.1213           115
# 1135        0.0026             -0.1991         1.1213            90
# 1129        0.0018             -0.3073         1.1213            15
# 1106        0.0019             -0.2857         1.1213            25
#
#       DownMoveScore  UpMoveScore  Score
# 417            1279          417   2914
# 341            1271          341   2835
# 315            1270          315   2809
# 709            1174          709   2784
# 695            1176          695   2778
# 416            1217          416   2767
# 275            1256          275   2766
# 205            1277          205   2763
# 203            1282          203   2761
# 393            1255          393   2760
# 388            1245          388   2754
# 256            1268          256   2752
# 642            1208          642   2742
# 365            1231          365   2739
# 357            1247          357   2734
# 350            1265          350   2734
# 243            1242          243   2726
# 684            1117          684   2717
# 206            1273          206   2711
# 600            1214          600   2711
# 197            1266          197   2702
# 745            1164          745   2699
# 260            1183          260   2696
# 310            1263          310   2693
# 307            1249          307   2688
# 443            1236          443   2685
# 587            1178          587   2677
# 725            1171          725   2677
# 195            1233          195   2675
# 298            1230          298   2672
# ...             ...          ...    ...
# 910              90          910   1298
# 843             176          843   1294
# 1152              3         1152   1293
# 1127             95         1127   1292
# 1171             36         1171   1292
# 1168             14         1168   1291
# 1173             69         1173   1289
# 1169             17         1169   1283
# 1107             55         1107   1281
# 1185             83         1185   1280
# 1144              7         1144   1279
# 1145             23         1145   1274
# 1110            150         1110   1271
# 1140             13         1140   1270
# 848             132          848   1268
# 1134             40         1134   1265
# 1183              9         1183   1264
# 1123             97         1123   1261
# 1150              4         1150   1259
# 1175             62         1175   1257
# 899              43          899   1256
# 1157             26         1157   1248
# 1113             74         1113   1240
# 1111              0         1111   1237
# 1104             47         1104   1237
# 1142             11         1142   1234
# 1118              1         1118   1234
# 1135              8         1135   1233
# 1129             82         1129   1226
# 1106             58         1106   1189
#
# [1284 rows x 19 columns]

# %%
potential_downs = arteHedges_downside[(arteHedges_downside.Short_Call_Strike > curr_price)].sort_values(['Maturity', 
                                                                                                         'Long_Put_Strike'], ascending = False)
try:
    potential_downs['upmove_to_breach'] = potential_downs['Short_Call_Strike']/curr_price - 1
    potential_downs['downmove_to_win'] = potential_downs['Long_Put_Strike']/curr_price - 1
    potential_downs = potential_downs.sort_values('MaxLoss').reset_index(drop = True)
    potential_downs['MaxLossScore'] = potential_downs.index
    
    potential_downs = potential_downs.sort_values('upmove_to_breach').reset_index(drop = True)
    potential_downs['UpMoveScore'] = potential_downs.index
    
    potential_downs = potential_downs.sort_values('downmove_to_win').reset_index(drop = True)
    potential_downs['DownMoveScore'] = potential_downs.index
    
    potential_downs['Score'] = potential_downs.MaxLossScore + potential_downs.UpMoveScore + potential_downs.DownMoveScore
    potential_downs = potential_downs.sort_values('Score', ascending = False)
except:
    None
potential_downs
# Out:
#      Short_Call_Strike  Long_Call_Strike  Long_Put_Strike   Delta  Gamma  \
# 91            280.0000          360.0000          20.0000 -0.1837 0.0000
# 103           275.0000          360.0000          25.0000 -0.2008 0.0001
# 87            275.0000          350.0000          20.0000 -0.1804 0.0001
# 123           275.0000          370.0000          30.0000 -0.2269 0.0001
# 163           275.0000          390.0000          45.0000 -0.2775 0.0001
# 89            275.0000          360.0000          20.0000 -0.1981 0.0000
# 35            285.0000          330.0000          10.0000 -0.1050 0.0000
# 184           275.0000          410.0000          55.0000 -0.3168 0.0000
# 172        0.0024            0.1905          -0.7835            77
# 102        0.0031            0.1905          -0.8918           143
# 85         0.0035            0.1689          -0.9134           168
# 116        0.0031            0.1689          -0.8701           131
# 137        0.0027            0.1905          -0.8268            91
# 67         0.0033            0.1905          -0.9351           161
# 169        0.0025            0.1689          -0.7835            73
# 86         0.0032            0.1905          -0.9134           144
# 153        0.0026            0.1689          -0.8052            81
# 98         0.0035            0.1472          -0.8918           162
# 83         0.0033            0.1689          -0.9134           154
# 99         0.0034            0.1472          -0.8918           147
# 19         0.0039            0.1905          -0.9567           193
# 174        0.0026            0.1472          -0.7835            68
# 100        0.0032            0.1689          -0.8918           134
# 21         0.0040            0.1905          -0.9567           201
# 47         0.0040            0.1472          -0.9351           190
# 20         0.0039            0.1905          -0.9567           197
# 4          0.0037            0.2122          -0.9567           200
# 122        0.0032            0.1472          -0.8701           121
# 134        0.0027            0.1689          -0.8268            83
# ..            ...               ...              ...           ...
# 39         0.0049            0.0390          -0.9567           173
# 148        0.0033            0.0390          -0.8052            58
# 160        0.0032            0.0390          -0.8052            39
# 50         0.0039            0.0607          -0.9351            93
# 165        0.0031            0.0390          -0.8052            19
# 9          0.0039            0.0823          -0.9567           122
# 42         0.0047            0.0390          -0.9567           159
# 108        0.0032            0.0607          -0.8918            32
# 14         0.0043            0.0607          -0.9567           140
# 72         0.0040            0.0390          -0.9134           102
# 133        0.0034            0.0390          -0.8268            60
# 139        0.0032            0.0390          -0.8268            41
# 52         0.0043            0.0390          -0.9351           129
# 126        0.0034            0.0390          -0.8485            61
# 140        0.0031            0.0390          -0.8268            20
# 130        0.0032            0.0390          -0.8485            42
# 13         0.0041            0.0607          -0.9567           115
# 10         0.0038            0.0823          -0.9567            99
# 49         0.0041            0.0390          -0.9351           104
# 71         0.0039            0.0390          -0.9134            85
# 115        0.0034            0.0390          -0.8701            43
# 12         0.0039            0.0607          -0.9567            94
# 125        0.0031            0.0390          -0.8485            21
# 36         0.0042            0.0390          -0.9567           106
# 95         0.0034            0.0390          -0.8918            45
# 107        0.0033            0.0390          -0.8918            24
# 51         0.0040            0.0390          -0.9351            86
# 120        0.0032            0.0390          -0.8701            23
# 41         0.0041            0.0390          -0.9567            87
# 0          0.0044            0.0390          -0.9567           132
#
#      UpMoveScore  DownMoveScore  Score
# 91           201             91    458
# 103          195            103    456
# 87           193             87    455
# 123          190            123    455
# 163          199            163    450
# 89           196             89    445
# 35           203             35    441
# 184          194            184    441
# 101          185            101    439
# 172          188            172    437
# 102          191            102    436
# 85           181             85    434
# 116          186            116    433
# 137          198            137    426
# 67           197             67    425
# 169          180            169    422
# 86           192             86    422
# 153          182            153    416
# 98           156             98    416
# 83           178             83    415
# 99           167             99    413
# 19           200             19    412
# 174          169            174    411
# 100          176            100    410
# 21           187             21    409
# 47           171             47    408
# 20           189             20    406
# 4            202              4    406
# 122          160            122    403
# 134          184            134    401
# ..           ...            ...    ...
# 39             2             39    214
# 148            7            148    213
# 160           13            160    212
# 50            65             50    208
# 165           21            165    205
# 9             74              9    205
# 42             4             42    205
# 108           63            108    203
# 14            47             14    201
# 72            25             72    199
# 133            6            133    199
# 139           14            139    194
# 52            12             52    193
# 126            5            126    192
# 140           27            140    187
# 130           15            130    187
# 13            54             13    182
# 10            72             10    181
# 49            23             49    176
# 71            18             71    174
# 115           16            115    174
# 12            64             12    170
# 125           19            125    165
# 36            22             36    164
# 95            17             95    157
# 107           20            107    151
# 51             9             51    146
# 120            1            120    144
# 41            10             41    138
# 0              0              0    132
#
# [204 rows x 19 columns]

# %%
potential_downs[potential_downs.Long_Put_Strike >= 55]
# Out:
#      Short_Call_Strike  Long_Call_Strike  Long_Put_Strike   Delta  Gamma  \
# 184           275.0000          410.0000          55.0000 -0.3168 0.0000
# 181           265.0000          410.0000          55.0000 -0.3416 0.0000
# 200           265.0000          440.0000          75.0000 -0.4030 0.0000
# 196           265.0000          430.0000          70.0000 -0.3868 0.0000
# 182           260.0000          410.0000          55.0000 -0.3534 0.0001
# 194           260.0000          430.0000          70.0000 -0.3987 0.0001
# 186           255.0000          410.0000          55.0000 -0.3661 0.0001
# 197           255.0000          440.0000          70.0000 -0.4224 0.0000
# 192           255.0000          430.0000          65.0000 -0.4065 0.0000
# 203           255.0000          450.0000          80.0000 -0.4515 0.0000
# 180           250.0000          410.0000          55.0000 -0.3797 0.0001
# 198           250.0000          430.0000          70.0000 -0.4250 0.0001
# 199           250.0000          440.0000          70.0000 -0.4360 0.0001
# 187           250.0000          430.0000          65.0000 -0.4201 0.0001
# 201           250.0000          450.0000          75.0000 -0.4594 0.0000
# 202           250.0000          450.0000          80.0000 -0.4651 0.0001
# 188           250.0000          440.0000          65.0000 -0.4311 0.0000
# 183           245.0000          410.0000          55.0000 -0.3924 0.0002
# 191           245.0000          430.0000          65.0000 -0.4328 0.0001
# 193           245.0000          440.0000          70.0000 -0.4487 0.0001
# 189           245.0000          440.0000          65.0000 -0.4438 0.0001
# 185           240.0000          410.0000          55.0000 -0.4062 0.0002
# 190           240.0000          430.0000          65.0000 -0.4466 0.0002
# 195           240.0000          430.0000          70.0000 -0.4514 0.0002
#
#      Theta   Vega  time_remaining  Credit      MaxLoss  BreakEven   Maturity  \
# 184 0.0002 0.0744          0.6493 24.8101 -11,018.9900   299.8101 2021-01-15
# 181 0.0008 0.0994          0.6493 28.4601 -11,653.9900   293.4601 2021-01-15
# 200 0.0002 0.0566          0.6493 28.3351 -14,666.4900   293.3351 2021-01-15
# 196 0.0004 0.0331          0.6493 28.4601 -13,653.9900   293.4601 2021-01-15
# 182 0.0006 0.0671          0.6493 30.2101 -11,978.9900   290.2101 2021-01-15
# 194 0.0002 0.0008          0.6493 30.2101 -13,978.9900   290.2101 2021-01-15
# 186 0.0004 0.0802          0.6493 32.2851 -12,271.4900   287.2851 2021-01-15
# 197 0.0010 0.0251          0.6493 33.1851 -15,181.4900   288.1851 2021-01-15
# 192 0.0012 0.0015          0.6493 33.0601 -14,193.9900   288.0601 2021-01-15
# 203 0.0006 0.0636          0.6493 32.3601 -16,263.9900   287.3601 2021-01-15
# 180 0.0005 0.0943          0.6493 34.1101 -12,588.9900   284.1101 2021-01-15
# 198 0.0001 0.0280          0.6493 34.1101 -14,588.9900   284.1101 2021-01-15
# 199 0.0011 0.0392          0.6493 35.0101 -15,498.9900   285.0101 2021-01-15
# 187 0.0013 0.0155          0.6493 34.8851 -14,511.4900   284.8851 2021-01-15
# 201 0.0021 0.0657          0.6493 34.9601 -16,503.9900   284.9601 2021-01-15
# 202 0.0006 0.0777          0.6493 34.1851 -16,581.4900   284.1851 2021-01-15
# 188 0.0023 0.0267          0.6493 35.7851 -15,421.4900   285.7851 2021-01-15
# 183 0.0004 0.1076          0.6493 36.3601 -12,863.9900   281.3601 2021-01-15
# 191 0.0012 0.0289          0.6493 37.1351 -14,786.4900   282.1351 2021-01-15
# 193 0.0010 0.0525          0.6493 37.2601 -15,773.9900   282.2601 2021-01-15
# 189 0.0022 0.0400          0.6493 38.0351 -15,696.4900   283.0351 2021-01-15
# 185 0.0007 0.1222          0.6493 38.5351 -13,146.4900   278.5351 2021-01-15
# 190 0.0015 0.0434          0.6493 39.3101 -15,068.9900   279.3101 2021-01-15
# 195 0.0003 0.0559          0.6493 38.5351 -15,146.4900   278.5351 2021-01-15
#
#      ReturnOnRisk  upmove_to_breach  downmove_to_win  MaxLossScore  \
# 184        0.0023            0.1905          -0.7619            63
# 181        0.0024            0.1472          -0.7619            52
# 200        0.0019            0.1472          -0.6753            11
# 196        0.0021            0.1472          -0.6970            16
# 182        0.0025            0.1256          -0.7619            44
# 194        0.0022            0.1256          -0.6970            15
# 186        0.0026            0.1039          -0.7619            36
# 197        0.0022            0.1039          -0.6970             7
# 192        0.0023            0.1039          -0.7186            14
# 203        0.0020            0.1039          -0.6537             2
# 180        0.0027            0.0823          -0.7619            29
# 198        0.0023            0.0823          -0.6970            12
# 199        0.0023            0.0823          -0.6970             5
# 187        0.0024            0.0823          -0.7186            13
# 201        0.0021            0.0823          -0.6753             1
# 202        0.0021            0.0823          -0.6537             0
# 188        0.0023            0.0823          -0.7186             6
# 183        0.0028            0.0607          -0.7619            22
# 191        0.0025            0.0607          -0.7186            10
# 193        0.0024            0.0607          -0.6970             3
# 189        0.0024            0.0607          -0.7186             4
# 185        0.0029            0.0390          -0.7619            17
# 190        0.0026            0.0390          -0.7186             9
# 195        0.0025            0.0390          -0.6970             8
#
#      UpMoveScore  DownMoveScore  Score
# 184          194            184    441
# 181          145            181    378
# 200          157            200    368
# 196          147            196    359
# 182          125            182    351
# 194          136            194    345
# 186          117            186    339
# 197          124            197    328
# 192          121            192    327
# 203          119            203    324
# 180           87            180    296
# 198           84            198    294
# 199           82            199    286
# 187           85            187    285
# 201           80            201    282
# 202           78            202    280
# 188           83            188    277
# 183           56            183    261
# 191           55            191    256
# 193           52            193    248
# 189           53            189    246
# 185           31            185    233
# 190           30            190    229
# 195           26            195    229

# %%
ib.disconnect()
