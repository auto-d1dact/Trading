# %%
import warnings
warnings.filterwarnings('ignore')
import os

import tws_data 
import statsmodels.tsa.stattools as ts
import statsmodels.api as sm
from ib_insync import *
import numpy as np
import pandas as pd
import datetime as dt
import time
pd.options.display.float_format = '{:,.4f}'.format
# %matplotlib inline
from scipy.stats import norm as norm
import matplotlib.pyplot as plt
import requests as req
from bs4 import BeautifulSoup as bs
import plotly.plotly as py
import plotly.graph_objs as go
from plotly.offline import download_plotlyjs, init_notebook_mode, plot, iplot
init_notebook_mode(connected=True)
import math
# Out:
# <script>requirejs.config({paths: { 'plotly': ['https://cdn.plot.ly/plotly-latest.min']},});if(!window.Plotly) {{require(['plotly'],function(plotly) {window.Plotly=plotly;});}}</script>

# %%
os.chdir('D:\Options Data\IB Intraday')

def create_dfrow(curr_option):
    df_row = pd.DataFrame({'Symbol': curr_option.contract.localSymbol, 
                           'Type':curr_option.contract.right, 
                           'Bid': curr_option.bid, 
                           'Ask': curr_option.ask, 
                           'Volume': curr_option.volume, 
                           'Strike': curr_option.contract.strike,
                           'Expiry': dt.datetime.strptime(curr_option.contract.lastTradeDateOrContractMonth, '%Y%m%d'),
                           'bidIV': curr_option.bidGreeks.impliedVol, 
                           'bidDelta': curr_option.bidGreeks.delta,
                           'bidGamma': curr_option.bidGreeks.gamma, 
                           'bidVega': curr_option.bidGreeks.vega,
                           'bidTheta': curr_option.bidGreeks.theta, 
                           'askIV': curr_option.askGreeks.impliedVol, 
                           'askDelta': curr_option.askGreeks.delta,
                           'askGamma': curr_option.askGreeks.gamma, 
                           'askVega': curr_option.askGreeks.vega,
                           'askTheta': curr_option.askGreeks.theta,
                           'modelIV': curr_option.modelGreeks.impliedVol, 
                           'modelDelta': curr_option.modelGreeks.delta,
                           'modelGamma': curr_option.modelGreeks.gamma, 
                           'modelVega': curr_option.modelGreeks.vega,
                           'modelTheta': curr_option.modelGreeks.theta}, index = [0])
    return df_row

def get_movers():

    indexarb_url = 'http://www.indexarb.com/stockVsIndexesMiddleColumn.html#djIndexAnalysis'
    indexarb_soup = bs(req.get(indexarb_url).text,'lxml')
    indexarb_tables = indexarb_soup.select('table[align="LEFT"]')

    movers = []

    for i, table_html in enumerate(indexarb_tables):
        curr_table = pd.read_html(str(table_html))[2]
        curr_table.columns = curr_table.loc[1,:].tolist()

        if i == 0:
            curr_table = curr_table.iloc[2:,:4].set_index('Index').apply(pd.to_numeric)
        else:
            curr_table = curr_table.iloc[2:,[1,3,4,5,6]].dropna().set_index('Sym').apply(pd.to_numeric)

        curr_table.columns = [x.split(' ')[0] for x in curr_table.columns.tolist()]
        movers.append(curr_table)

    index = movers[0]
    movers = pd.concat(movers[1:], axis = 0)
    movers = movers.sort_values('OneMonth')
    
    return index, movers

def time_remaining(weekly_options, curr_spx):
    typ = weekly_options.reset_index().loc[0,'Type']

    try:
        interest_rate = bs(req.get('https://www.marketwatch.com/investing/bond/tmubmusd01m?countrycode=bx','lxml').text, 'lxml')
        interest_rate = float(interest_rate.select_one('h3[class*="intraday__price"]').select_one('bg-quote').text)/100
    except:
        interest_rate = 0.02422

    weekly_options['a'] = interest_rate - (weekly_options['modelIV']**2)/2

    if typ == 'P':
        weekly_options['b'] = weekly_options['modelIV']*norm.ppf(-weekly_options['modelDelta'])
    if typ == 'C':
        weekly_options['b'] = -weekly_options['modelIV']*norm.ppf(weekly_options['modelDelta'])
    weekly_options['c'] = np.log(curr_spx/weekly_options['Strike'])

    weekly_options_otm = weekly_options[abs(weekly_options.modelDelta) <= 0.5]
    weekly_options_itm = weekly_options[abs(weekly_options.modelDelta) > 0.5]

    if typ == 'P':
        weekly_options_otm['time_remaining'] = ((-weekly_options_otm.b - 
                                                 np.sqrt(weekly_options_otm.b**2 - 
                                                         4*weekly_options_otm.a*weekly_options_otm.c))/(2*weekly_options_otm.a))**2
        weekly_options_itm['time_remaining'] = ((-weekly_options_itm.b + 
                                                 np.sqrt(weekly_options_itm.b**2 - 
                                                         4*weekly_options_itm.a*weekly_options_itm.c))/(2*weekly_options_itm.a))**2
    if typ == 'C':
        weekly_options_otm['time_remaining'] = ((-weekly_options_otm.b + 
                                                 np.sqrt(weekly_options_otm.b**2 - 
                                                         4*weekly_options_otm.a*weekly_options_otm.c))/(2*weekly_options_otm.a))**2
        weekly_options_itm['time_remaining'] = ((-weekly_options_itm.b - 
                                                 np.sqrt(weekly_options_itm.b**2 - 
                                                         4*weekly_options_itm.a*weekly_options_itm.c))/(2*weekly_options_itm.a))**2
    weekly_times = pd.concat([weekly_options_otm, 
                              weekly_options_itm], axis = 0)[['Expiry','time_remaining']].dropna().groupby('Expiry').mean()

    del weekly_options['a'], weekly_options['b'], weekly_options['c'], weekly_options_itm, weekly_options_otm

    return weekly_options.merge(weekly_times.reset_index(), on = 'Expiry')


def get_options(ticker, exchange, contractType, earliest_date, latest_date, curr_iv, stdevs, save_csv = False):
    if contractType == 'Stock':
        security = Stock(ticker,exchange)
    else:
        security = Index(ticker, exchange)

    ib.qualifyContracts(security)

    chains = ib.reqSecDefOptParams(security.symbol, '', security.secType, security.conId)

    chains_df = util.df(chains)
    chain = next(c for c in chains if c.tradingClass == ticker and c.exchange == 'SMART')

    all_expirations = sorted(exp for exp in chain.expirations)
    expirations_dates = [dt.datetime.strptime(x, '%Y%m%d') for x in all_expirations]

    expirations = list(filter(lambda x: x[0] >= earliest_date and x[0] <= latest_date, list(zip(expirations_dates,all_expirations))))
    dte_expirations = [(expir[0] - dt.datetime.today()).days for expir in expirations]
    expirations = [expir[1] for expir in expirations]

    ib.reqHeadTimeStamp(security, whatToShow='TRADES', useRTH=True)

    end_date = '' #'20100506 13:00:00 PST'
    duration = '1 D'

    sec_bars = ib.reqHistoricalData(
            security,
            endDateTime=end_date,
            durationStr=duration,
            barSizeSetting='1 min',
            whatToShow='TRADES',
            useRTH=True,
            formatDate=1)


    sec_df = util.df(sec_bars).set_index('date')
    sec_df.index = pd.to_datetime(sec_df.index)

    curr_sec_price = sec_df.reset_index().loc[len(sec_df) - 1, 'close']
    bounds_lst = [curr_sec_price*(stdevs*stdevs/(100*np.sqrt(365.25/dte))) for dte in dte_expirations]


    contracts_list = []

    for bounds, expiration in zip(bounds_lst, expirations):
        strikes = [strike for strike in chain.strikes
                   if strike % 5 == 0
                   and curr_sec_price - bounds < strike < curr_sec_price + bounds]

        rights = ['P', 'C']

        curr_contracts = [Option(ticker, expiration, strike, right, 'SMART')
                          for right in rights
                          for strike in strikes]
        contracts_list += [curr_contracts]

    puts_list = []
    calls_list = []

    for contracts in contracts_list:
        ib.qualifyContracts(*contracts)
        sec_options = ib.reqTickers(*contracts)

        puts_rows = []
        calls_rows = []

        for curr_option in sec_options:
            try:
                curr_row = create_dfrow(curr_option)
                if curr_option.contract.right == 'P':
                    puts_rows.append(curr_row)
                elif curr_option.contract.right == 'C':
                    calls_rows.append(curr_row)
            except:
                continue

        puts = pd.concat(puts_rows).reset_index(drop = True).sort_values(['Expiry','Strike'])
        calls = pd.concat(calls_rows).reset_index(drop = True).sort_values(['Expiry','Strike'])
        puts = time_remaining(puts, curr_sec_price)
        calls = time_remaining(calls, curr_sec_price)
        puts_list.append(puts)
        calls_list.append(calls)
        time.sleep(5)

    puts_df = pd.concat(puts_list,axis = 0).reset_index(drop = True)
    calls_df = pd.concat(calls_list,axis = 0).reset_index(drop = True)

    if save_csv:
        curr_time = dt.datetime.now().strftime('%Y%m%d-%H-%M')
        puts_df.to_csv('ib_puts' + curr_time + '.csv')
        calls_df.to_csv('ib_calls' + curr_time + '.csv')
        
    return puts_df, calls_df, curr_sec_price


def get_spreads(weekly_options, curr_spx, expiry_index = 0, rowshift = 1, commissions = 0.0266):

    expirations_dates = weekly_options.Expiry.drop_duplicates().tolist()

    weekly_options = weekly_options[weekly_options.Expiry == expirations_dates[expiry_index]]

    typ = weekly_options.reset_index().loc[0,'Type']

    if typ == 'P':
        weekly_options = weekly_options.sort_values('Strike', ascending = False).reset_index(drop = True)
    if typ == 'C':
        weekly_options = weekly_options.sort_values('Strike', ascending = True).reset_index(drop = True)

    time_remaining = weekly_options.reset_index(drop = True).loc[0,'time_remaining']

    weekly_options['Mid'] = (weekly_options.Ask + weekly_options.Bid)/2
    shorts = weekly_options[['Mid', 'Strike', 'bidDelta', 'bidGamma', 'bidTheta', 'bidVega']]
    shorts.columns = ['Price','Strike','Delta','Gamma','Theta','Vega']
    longs = weekly_options[['Mid','Strike', 'askDelta', 'askGamma','askTheta', 'askVega']]
    longs.columns = ['Price','Strike','Delta','Gamma','Theta','Vega']

    spreads = shorts - longs.shift(-rowshift)
    spreads['Short_Strike'] = shorts.Strike
    spreads['Short_Delta'] = shorts.Delta
    spreads['Long_Strike'] = longs.Strike.shift(-rowshift)
    spreads = spreads[['Short_Strike', 'Long_Strike', 'Short_Delta', 'Price',
                       'Strike', 'Delta', 'Gamma', 'Theta', 'Vega']]

    spreads['Credit'] = spreads.Price - commissions

    if typ == 'P':
        spreads['MaxLoss'] = (-spreads.Strike + spreads.Credit)*100
        spreads['BreakEven'] = spreads['Short_Strike'] - spreads.Credit
    if typ == 'C':
        spreads['MaxLoss'] = (spreads.Strike + spreads.Credit)*100
        spreads['BreakEven'] = spreads['Short_Strike'] + spreads.Credit

    del spreads['Price'], spreads['Strike']

    spreads = spreads[spreads.Credit > 0].dropna().reset_index(drop = True)
    spreads['Expiry'] = expirations_dates[expiry_index]

    return spreads

def art_hedges(curr_calls, curr_puts, curr_price, expiry_index, bias = 'upside',
               maxshift = 6, commissions = 0.0266):
    
    hedge = []
    for rowshift in range(1,maxshift):

        if bias == 'upside':
            spreads = get_spreads(curr_puts, curr_price, expiry_index, rowshift, commissions = 0.0266)
        else:
            spreads = get_spreads(curr_calls, curr_price, expiry_index, rowshift, commissions = 0.0266)
        spreads = spreads[(spreads.Credit > 0.5)]
        hedge.append(spreads)

    hedge = pd.concat(hedge, axis = 0).reset_index(drop = True)

    if bias == 'upside':
        expirations_dates = curr_calls.Expiry.drop_duplicates().tolist()

        long_hedge = curr_calls[(curr_calls.Expiry == expirations_dates[expiry_index])][['Ask', 'Bid', 'Expiry', 'Strike',
                                                                             'modelDelta', 'modelGamma',
                                                                             'modelTheta', 'modelVega', 'time_remaining']].reset_index(drop = True)
    else:
        expirations_dates = curr_puts.Expiry.drop_duplicates().tolist()

        long_hedge = curr_puts[(curr_puts.Expiry == expirations_dates[expiry_index])][['Ask', 'Bid', 'Expiry', 'Strike',
                                                                             'modelDelta', 'modelGamma',
                                                                             'modelTheta', 'modelVega', 'time_remaining']].reset_index(drop = True)

    long_hedge['Mid'] = (long_hedge['Ask'] + long_hedge['Bid'])/2
    long_hedge.columns = [x.replace('model','') for x in long_hedge.columns.tolist()]

    hedges_lst = []

    for idx, row in hedge.iterrows():

        curr_hedge = long_hedge[long_hedge.Mid < row.Credit][['Mid','Expiry', 'Strike',
                                                              'Delta', 'Gamma',
                                                              'Theta', 'Vega', 'time_remaining']]
        curr_hedge['Gamma'] = curr_hedge['Gamma'] - row.Gamma
        curr_hedge['Delta'] = curr_hedge['Delta'] - row.Delta
        curr_hedge['Theta'] = curr_hedge['Theta'] - row.Theta
        curr_hedge['Vega'] = curr_hedge['Vega'] - row.Vega
        if bias == 'upside':
            curr_hedge = curr_hedge[(curr_hedge.Delta > 0) &
                                    (curr_hedge.Gamma > 0) &
                                    (curr_hedge.Theta > 0) &
                                    (curr_hedge.Vega > 0)]
        else:
            curr_hedge = curr_hedge[(curr_hedge.Delta < 0) &
                                (curr_hedge.Gamma > 0) &
                                (curr_hedge.Theta > 0) &
                                (curr_hedge.Vega > 0)]
        curr_hedge['Credit'] = -curr_hedge.Mid + row.Credit - 0.0133

        if bias == 'upside':
            curr_hedge['MaxLoss'] = (row.Long_Strike - row.Short_Strike + curr_hedge.Credit)*100
            curr_hedge['BreakEven'] = row.Short_Strike - curr_hedge['Credit']
        else:
            curr_hedge['MaxLoss'] = (row.Short_Strike - row.Long_Strike + curr_hedge.Credit)*100
            curr_hedge['BreakEven'] = row.Short_Strike + curr_hedge['Credit']
        curr_hedge['Maturity'] = curr_hedge['Expiry']
        curr_hedge['Mid'] = row.Short_Strike
        curr_hedge['Expiry'] = row.Long_Strike

        if bias == 'upside':
            curr_hedge.columns = ['Short_Put_Strike','Long_Put_Strike','Long_Call_Strike'] + curr_hedge.columns.tolist()[3:]
        else:
            curr_hedge.columns = ['Short_Call_Strike','Long_Call_Strike','Long_Put_Strike'] + curr_hedge.columns.tolist()[3:]

        hedges_lst.append(curr_hedge)

    hedges_df = pd.concat(hedges_lst, axis = 0)
    
    return hedges_df

# %%
index, movers = get_movers()

# %%
losers = movers.head()
winners = movers.tail().sort_values('OneMonth', ascending = False)

# %%
client_id = 11

ib = IB()
ib.connect('127.0.0.1', 7496, clientId=client_id)
# Out:
# <IB connected to 127.0.0.1:7496 clientId=11>

# %%
exchange = 'NYSE'
contractType = 'Stock'
earliest_date = dt.datetime(2019,4,6)
latest_date = dt.datetime(2019,6,30)
curr_iv = 40
stdevs = 9

stock_prices = {}
stock_puts = {}
stock_calls = {}

for ticker in losers.index:

    curr_puts, curr_calls, curr_price = get_options(ticker, exchange, contractType, earliest_date, latest_date, curr_iv, stdevs, save_csv = False)
    
    stock_prices[ticker] = curr_price
    stock_puts[ticker] = curr_puts
    stock_calls[ticker] = curr_calls
    break

# %%
exchange = 'NYSE'
contractType = 'Stock'
earliest_date = dt.datetime(2019,6,6)
latest_date = dt.datetime(2019,10,1)

ticker = 'AMZN'
curr_iv = 30
stdevs = 9
curr_puts, curr_calls, curr_price = get_options(ticker, exchange, contractType, earliest_date, latest_date, curr_iv, stdevs, save_csv = False)
# Out:
# commissionReport: No execution found for CommissionReport(execId='0000d4b5.5c922544.02.01', commission=1.0888, currency='USD')
# commissionReport: No execution found for CommissionReport(execId='0000d4b5.5c922544.03.01', commission=1.099224, currency='USD')
# commissionReport: No execution found for CommissionReport(execId='0000d4b5.5c922544.04.01', commission=1.0888, currency='USD')
# commissionReport: No execution found for CommissionReport(execId='00014247.5c923d62.02.01', commission=0.9588, currency='USD')
# commissionReport: No execution found for CommissionReport(execId='00014247.5c923d62.03.01', commission=0.969237, currency='USD')
# commissionReport: No execution found for CommissionReport(execId='00014247.5c923d62.04.01', commission=0.9588, currency='USD')
# commissionReport: No execution found for CommissionReport(execId='0000d6a1.5c925527.02.01', commission=0.7888, currency='USD')
# commissionReport: No execution found for CommissionReport(execId='0000d6a1.5c925527.03.01', commission=0.799211, currency='USD')
# commissionReport: No execution found for CommissionReport(execId='0000d6a1.5c925527.04.01', commission=0.7888, currency='USD')
# Started to throttle requests
# Error 200, reqId 1321: No security definition has been found for the request, contract: Option(symbol='AMZN', lastTradeDateOrContractMonth='20190621', strike=2050.0, right='P', exchange='SMART')
# Error 200, reqId 1327: No security definition has been found for the request, contract: Option(symbol='AMZN', lastTradeDateOrContractMonth='20190621', strike=2080.0, right='P', exchange='SMART')
# Error 200, reqId 1323: No security definition has been found for the request, contract: Option(symbol='AMZN', lastTradeDateOrContractMonth='20190621', strike=2060.0, right='P', exchange='SMART')
# Error 200, reqId 1325: No security definition has been found for the request, contract: Option(symbol='AMZN', lastTradeDateOrContractMonth='20190621', strike=2070.0, right='P', exchange='SMART')
# Error 200, reqId 1329: No security definition has been found for the request, contract: Option(symbol='AMZN', lastTradeDateOrContractMonth='20190621', strike=2090.0, right='P', exchange='SMART')
# Error 200, reqId 1333: No security definition has been found for the request, contract: Option(symbol='AMZN', lastTradeDateOrContractMonth='20190621', strike=2110.0, right='P', exchange='SMART')
# Error 200, reqId 1335: No security definition has been found for the request, contract: Option(symbol='AMZN', lastTradeDateOrContractMonth='20190621', strike=2120.0, right='P', exchange='SMART')
# Error 200, reqId 1341: No security definition has been found for the request, contract: Option(symbol='AMZN', lastTradeDateOrContractMonth='20190621', strike=2150.0, right='P', exchange='SMART')
# Error 200, reqId 1339: No security definition has been found for the request, contract: Option(symbol='AMZN', lastTradeDateOrContractMonth='20190621', strike=2140.0, right='P', exchange='SMART')
# Error 200, reqId 1337: No security definition has been found for the request, contract: Option(symbol='AMZN', lastTradeDateOrContractMonth='20190621', strike=2130.0, right='P', exchange='SMART')
# Error 200, reqId 1343: No security definition has been found for the request, contract: Option(symbol='AMZN', lastTradeDateOrContractMonth='20190621', strike=2160.0, right='P', exchange='SMART')
# Error 200, reqId 1345: No security definition has been found for the request, contract: Option(symbol='AMZN', lastTradeDateOrContractMonth='20190621', strike=2170.0, right='P', exchange='SMART')
# Error 200, reqId 1347: No security definition has been found for the request, contract: Option(symbol='AMZN', lastTradeDateOrContractMonth='20190621', strike=2180.0, right='P', exchange='SMART')
# Error 200, reqId 1359: No security definition has been found for the request, contract: Option(symbol='AMZN', lastTradeDateOrContractMonth='20190621', strike=2240.0, right='P', exchange='SMART')
# Error 200, reqId 1355: No security definition has been found for the request, contract: Option(symbol='AMZN', lastTradeDateOrContractMonth='20190621', strike=2220.0, right='P', exchange='SMART')
# Error 200, reqId 1361: No security definition has been found for the request, contract: Option(symbol='AMZN', lastTradeDateOrContractMonth='20190621', strike=2250.0, right='P', exchange='SMART')
# Error 200, reqId 1363: No security definition has been found for the request, contract: Option(symbol='AMZN', lastTradeDateOrContractMonth='20190621', strike=2260.0, right='P', exchange='SMART')
# Error 200, reqId 1367: No security definition has been found for the request, contract: Option(symbol='AMZN', lastTradeDateOrContractMonth='20190621', strike=2280.0, right='P', exchange='SMART')
# Error 200, reqId 1375: No security definition has been found for the request, contract: Option(symbol='AMZN', lastTradeDateOrContractMonth='20190621', strike=2320.0, right='P', exchange='SMART')
# Error 200, reqId 1381: No security definition has been found for the request, contract: Option(symbol='AMZN', lastTradeDateOrContractMonth='20190621', strike=2350.0, right='P', exchange='SMART')
# Error 200, reqId 1379: No security definition has been found for the request, contract: Option(symbol='AMZN', lastTradeDateOrContractMonth='20190621', strike=2340.0, right='P', exchange='SMART')
# Error 200, reqId 1383: No security definition has been found for the request, contract: Option(symbol='AMZN', lastTradeDateOrContractMonth='20190621', strike=2360.0, right='P', exchange='SMART')
# Error 200, reqId 1395: No security definition has been found for the request, contract: Option(symbol='AMZN', lastTradeDateOrContractMonth='20190621', strike=2420.0, right='P', exchange='SMART')
# Error 200, reqId 1387: No security definition has been found for the request, contract: Option(symbol='AMZN', lastTradeDateOrContractMonth='20190621', strike=2380.0, right='P', exchange='SMART')
# Error 200, reqId 1401: No security definition has been found for the request, contract: Option(symbol='AMZN', lastTradeDateOrContractMonth='20190621', strike=2450.0, right='P', exchange='SMART')
# Error 200, reqId 1412: No security definition has been found for the request, contract: Option(symbol='AMZN', lastTradeDateOrContractMonth='20190621', strike=1065.0, right='P', exchange='SMART')
# Error 200, reqId 1414: No security definition has been found for the request, contract: Option(symbol='AMZN', lastTradeDateOrContractMonth='20190621', strike=1075.0, right='P', exchange='SMART')
# Error 200, reqId 1416: No security definition has been found for the request, contract: Option(symbol='AMZN', lastTradeDateOrContractMonth='20190621', strike=1085.0, right='P', exchange='SMART')
# Error 200, reqId 1418: No security definition has been found for the request, contract: Option(symbol='AMZN', lastTradeDateOrContractMonth='20190621', strike=1095.0, right='P', exchange='SMART')
# Error 200, reqId 1422: No security definition has been found for the request, contract: Option(symbol='AMZN', lastTradeDateOrContractMonth='20190621', strike=1115.0, right='P', exchange='SMART')
# Error 200, reqId 1420: No security definition has been found for the request, contract: Option(symbol='AMZN', lastTradeDateOrContractMonth='20190621', strike=1105.0, right='P', exchange='SMART')
# Error 200, reqId 1424: No security definition has been found for the request, contract: Option(symbol='AMZN', lastTradeDateOrContractMonth='20190621', strike=1125.0, right='P', exchange='SMART')
# Error 200, reqId 1426: No security definition has been found for the request, contract: Option(symbol='AMZN', lastTradeDateOrContractMonth='20190621', strike=1135.0, right='P', exchange='SMART')
# Error 200, reqId 1428: No security definition has been found for the request, contract: Option(symbol='AMZN', lastTradeDateOrContractMonth='20190621', strike=1145.0, right='P', exchange='SMART')
# Error 200, reqId 1430: No security definition has been found for the request, contract: Option(symbol='AMZN', lastTradeDateOrContractMonth='20190621', strike=1155.0, right='P', exchange='SMART')
# Error 200, reqId 1432: No security definition has been found for the request, contract: Option(symbol='AMZN', lastTradeDateOrContractMonth='20190621', strike=1165.0, right='P', exchange='SMART')
# Error 200, reqId 1436: No security definition has been found for the request, contract: Option(symbol='AMZN', lastTradeDateOrContractMonth='20190621', strike=1185.0, right='P', exchange='SMART')
# Error 200, reqId 1434: No security definition has been found for the request, contract: Option(symbol='AMZN', lastTradeDateOrContractMonth='20190621', strike=1175.0, right='P', exchange='SMART')
# Error 200, reqId 1438: No security definition has been found for the request, contract: Option(symbol='AMZN', lastTradeDateOrContractMonth='20190621', strike=1195.0, right='P', exchange='SMART')
# Error 200, reqId 1440: No security definition has been found for the request, contract: Option(symbol='AMZN', lastTradeDateOrContractMonth='20190621', strike=1205.0, right='P', exchange='SMART')
# Error 200, reqId 1442: No security definition has been found for the request, contract: Option(symbol='AMZN', lastTradeDateOrContractMonth='20190621', strike=1215.0, right='P', exchange='SMART')
# Error 200, reqId 1444: No security definition has been found for the request, contract: Option(symbol='AMZN', lastTradeDateOrContractMonth='20190621', strike=1225.0, right='P', exchange='SMART')
# Error 200, reqId 1446: No security definition has been found for the request, contract: Option(symbol='AMZN', lastTradeDateOrContractMonth='20190621', strike=1235.0, right='P', exchange='SMART')
# Error 200, reqId 1450: No security definition has been found for the request, contract: Option(symbol='AMZN', lastTradeDateOrContractMonth='20190621', strike=1255.0, right='P', exchange='SMART')
# Error 200, reqId 1448: No security definition has been found for the request, contract: Option(symbol='AMZN', lastTradeDateOrContractMonth='20190621', strike=1245.0, right='P', exchange='SMART')
# Error 200, reqId 1452: No security definition has been found for the request, contract: Option(symbol='AMZN', lastTradeDateOrContractMonth='20190621', strike=1265.0, right='P', exchange='SMART')
# Error 200, reqId 1454: No security definition has been found for the request, contract: Option(symbol='AMZN', lastTradeDateOrContractMonth='20190621', strike=1275.0, right='P', exchange='SMART')
# Error 200, reqId 1458: No security definition has been found for the request, contract: Option(symbol='AMZN', lastTradeDateOrContractMonth='20190621', strike=1295.0, right='P', exchange='SMART')
# Error 200, reqId 1456: No security definition has been found for the request, contract: Option(symbol='AMZN', lastTradeDateOrContractMonth='20190621', strike=1285.0, right='P', exchange='SMART')
# Error 200, reqId 1460: No security definition has been found for the request, contract: Option(symbol='AMZN', lastTradeDateOrContractMonth='20190621', strike=1305.0, right='P', exchange='SMART')
# Error 200, reqId 1464: No security definition has been found for the request, contract: Option(symbol='AMZN', lastTradeDateOrContractMonth='20190621', strike=1325.0, right='P', exchange='SMART')
# Error 200, reqId 1462: No security definition has been found for the request, contract: Option(symbol='AMZN', lastTradeDateOrContractMonth='20190621', strike=1315.0, right='P', exchange='SMART')
# Error 200, reqId 1466: No security definition has been found for the request, contract: Option(symbol='AMZN', lastTradeDateOrContractMonth='20190621', strike=1335.0, right='P', exchange='SMART')
# Error 200, reqId 1468: No security definition has been found for the request, contract: Option(symbol='AMZN', lastTradeDateOrContractMonth='20190621', strike=1345.0, right='P', exchange='SMART')
# Error 200, reqId 1490: No security definition has been found for the request, contract: Option(symbol='AMZN', lastTradeDateOrContractMonth='20190621', strike=1455.0, right='P', exchange='SMART')
# Error 200, reqId 1492: No security definition has been found for the request, contract: Option(symbol='AMZN', lastTradeDateOrContractMonth='20190621', strike=1465.0, right='P', exchange='SMART')
# Error 200, reqId 1494: No security definition has been found for the request, contract: Option(symbol='AMZN', lastTradeDateOrContractMonth='20190621', strike=1475.0, right='P', exchange='SMART')
# Error 200, reqId 1496: No security definition has been found for the request, contract: Option(symbol='AMZN', lastTradeDateOrContractMonth='20190621', strike=1485.0, right='P', exchange='SMART')
# Error 200, reqId 1498: No security definition has been found for the request, contract: Option(symbol='AMZN', lastTradeDateOrContractMonth='20190621', strike=1495.0, right='P', exchange='SMART')
# Error 200, reqId 1500: No security definition has been found for the request, contract: Option(symbol='AMZN', lastTradeDateOrContractMonth='20190621', strike=1505.0, right='P', exchange='SMART')
# Error 200, reqId 1502: No security definition has been found for the request, contract: Option(symbol='AMZN', lastTradeDateOrContractMonth='20190621', strike=1515.0, right='P', exchange='SMART')
# Error 200, reqId 1504: No security definition has been found for the request, contract: Option(symbol='AMZN', lastTradeDateOrContractMonth='20190621', strike=1525.0, right='P', exchange='SMART')
# Error 200, reqId 1508: No security definition has been found for the request, contract: Option(symbol='AMZN', lastTradeDateOrContractMonth='20190621', strike=1545.0, right='P', exchange='SMART')
# Error 200, reqId 1506: No security definition has been found for the request, contract: Option(symbol='AMZN', lastTradeDateOrContractMonth='20190621', strike=1535.0, right='P', exchange='SMART')
# Error 200, reqId 1564: No security definition has been found for the request, contract: Option(symbol='AMZN', lastTradeDateOrContractMonth='20190621', strike=1825.0, right='P', exchange='SMART')
# Error 200, reqId 1565: No security definition has been found for the request, contract: Option(symbol='AMZN', lastTradeDateOrContractMonth='20190621', strike=1830.0, right='P', exchange='SMART')
# Error 200, reqId 1566: No security definition has been found for the request, contract: Option(symbol='AMZN', lastTradeDateOrContractMonth='20190621', strike=1835.0, right='P', exchange='SMART')
# Error 200, reqId 1568: No security definition has been found for the request, contract: Option(symbol='AMZN', lastTradeDateOrContractMonth='20190621', strike=1845.0, right='P', exchange='SMART')
# Error 200, reqId 1569: No security definition has been found for the request, contract: Option(symbol='AMZN', lastTradeDateOrContractMonth='20190621', strike=1850.0, right='P', exchange='SMART')
# Error 200, reqId 1574: No security definition has been found for the request, contract: Option(symbol='AMZN', lastTradeDateOrContractMonth='20190621', strike=1875.0, right='P', exchange='SMART')
# Error 200, reqId 1573: No security definition has been found for the request, contract: Option(symbol='AMZN', lastTradeDateOrContractMonth='20190621', strike=1870.0, right='P', exchange='SMART')
# Error 200, reqId 1576: No security definition has been found for the request, contract: Option(symbol='AMZN', lastTradeDateOrContractMonth='20190621', strike=1885.0, right='P', exchange='SMART')
# Error 200, reqId 1578: No security definition has been found for the request, contract: Option(symbol='AMZN', lastTradeDateOrContractMonth='20190621', strike=1895.0, right='P', exchange='SMART')
# Error 200, reqId 1577: No security definition has been found for the request, contract: Option(symbol='AMZN', lastTradeDateOrContractMonth='20190621', strike=1890.0, right='P', exchange='SMART')
# Error 200, reqId 1580: No security definition has been found for the request, contract: Option(symbol='AMZN', lastTradeDateOrContractMonth='20190621', strike=1905.0, right='P', exchange='SMART')
# Error 200, reqId 1582: No security definition has been found for the request, contract: Option(symbol='AMZN', lastTradeDateOrContractMonth='20190621', strike=1915.0, right='P', exchange='SMART')
# Error 200, reqId 1581: No security definition has been found for the request, contract: Option(symbol='AMZN', lastTradeDateOrContractMonth='20190621', strike=1910.0, right='P', exchange='SMART')
# Error 200, reqId 1584: No security definition has been found for the request, contract: Option(symbol='AMZN', lastTradeDateOrContractMonth='20190621', strike=1925.0, right='P', exchange='SMART')
# Error 200, reqId 1585: No security definition has been found for the request, contract: Option(symbol='AMZN', lastTradeDateOrContractMonth='20190621', strike=1930.0, right='P', exchange='SMART')
# Error 200, reqId 1586: No security definition has been found for the request, contract: Option(symbol='AMZN', lastTradeDateOrContractMonth='20190621', strike=1935.0, right='P', exchange='SMART')
# Error 200, reqId 1589: No security definition has been found for the request, contract: Option(symbol='AMZN', lastTradeDateOrContractMonth='20190621', strike=1950.0, right='P', exchange='SMART')
# Error 200, reqId 1593: No security definition has been found for the request, contract: Option(symbol='AMZN', lastTradeDateOrContractMonth='20190621', strike=1970.0, right='P', exchange='SMART')
# Error 200, reqId 1601: No security definition has been found for the request, contract: Option(symbol='AMZN', lastTradeDateOrContractMonth='20190621', strike=2010.0, right='P', exchange='SMART')
# Error 200, reqId 1597: No security definition has been found for the request, contract: Option(symbol='AMZN', lastTradeDateOrContractMonth='20190621', strike=1990.0, right='P', exchange='SMART')
# Error 200, reqId 1603: No security definition has been found for the request, contract: Option(symbol='AMZN', lastTradeDateOrContractMonth='20190621', strike=2020.0, right='P', exchange='SMART')
# Error 200, reqId 1605: No security definition has been found for the request, contract: Option(symbol='AMZN', lastTradeDateOrContractMonth='20190621', strike=2030.0, right='P', exchange='SMART')
# Error 200, reqId 1609: No security definition has been found for the request, contract: Option(symbol='AMZN', lastTradeDateOrContractMonth='20190621', strike=2050.0, right='C', exchange='SMART')
# Error 200, reqId 1607: No security definition has been found for the request, contract: Option(symbol='AMZN', lastTradeDateOrContractMonth='20190621', strike=2040.0, right='P', exchange='SMART')
# Error 200, reqId 1611: No security definition has been found for the request, contract: Option(symbol='AMZN', lastTradeDateOrContractMonth='20190621', strike=2060.0, right='C', exchange='SMART')
# Error 200, reqId 1613: No security definition has been found for the request, contract: Option(symbol='AMZN', lastTradeDateOrContractMonth='20190621', strike=2070.0, right='C', exchange='SMART')
# Error 200, reqId 1615: No security definition has been found for the request, contract: Option(symbol='AMZN', lastTradeDateOrContractMonth='20190621', strike=2080.0, right='C', exchange='SMART')
# Error 200, reqId 1617: No security definition has been found for the request, contract: Option(symbol='AMZN', lastTradeDateOrContractMonth='20190621', strike=2090.0, right='C', exchange='SMART')
# Error 200, reqId 1621: No security definition has been found for the request, contract: Option(symbol='AMZN', lastTradeDateOrContractMonth='20190621', strike=2110.0, right='C', exchange='SMART')
# Error 200, reqId 1623: No security definition has been found for the request, contract: Option(symbol='AMZN', lastTradeDateOrContractMonth='20190621', strike=2120.0, right='C', exchange='SMART')
# Error 200, reqId 1625: No security definition has been found for the request, contract: Option(symbol='AMZN', lastTradeDateOrContractMonth='20190621', strike=2130.0, right='C', exchange='SMART')
# Error 200, reqId 1627: No security definition has been found for the request, contract: Option(symbol='AMZN', lastTradeDateOrContractMonth='20190621', strike=2140.0, right='C', exchange='SMART')
# Error 200, reqId 1629: No security definition has been found for the request, contract: Option(symbol='AMZN', lastTradeDateOrContractMonth='20190621', strike=2150.0, right='C', exchange='SMART')
# Error 200, reqId 1631: No security definition has been found for the request, contract: Option(symbol='AMZN', lastTradeDateOrContractMonth='20190621', strike=2160.0, right='C', exchange='SMART')
# Error 200, reqId 1633: No security definition has been found for the request, contract: Option(symbol='AMZN', lastTradeDateOrContractMonth='20190621', strike=2170.0, right='C', exchange='SMART')
# Error 200, reqId 1635: No security definition has been found for the request, contract: Option(symbol='AMZN', lastTradeDateOrContractMonth='20190621', strike=2180.0, right='C', exchange='SMART')
# Error 200, reqId 1643: No security definition has been found for the request, contract: Option(symbol='AMZN', lastTradeDateOrContractMonth='20190621', strike=2220.0, right='C', exchange='SMART')
# Error 200, reqId 1647: No security definition has been found for the request, contract: Option(symbol='AMZN', lastTradeDateOrContractMonth='20190621', strike=2240.0, right='C', exchange='SMART')
# Error 200, reqId 1649: No security definition has been found for the request, contract: Option(symbol='AMZN', lastTradeDateOrContractMonth='20190621', strike=2250.0, right='C', exchange='SMART')
# Error 200, reqId 1651: No security definition has been found for the request, contract: Option(symbol='AMZN', lastTradeDateOrContractMonth='20190621', strike=2260.0, right='C', exchange='SMART')
# Error 200, reqId 1655: No security definition has been found for the request, contract: Option(symbol='AMZN', lastTradeDateOrContractMonth='20190621', strike=2280.0, right='C', exchange='SMART')
# Error 200, reqId 1663: No security definition has been found for the request, contract: Option(symbol='AMZN', lastTradeDateOrContractMonth='20190621', strike=2320.0, right='C', exchange='SMART')
# Error 200, reqId 1667: No security definition has been found for the request, contract: Option(symbol='AMZN', lastTradeDateOrContractMonth='20190621', strike=2340.0, right='C', exchange='SMART')
# Error 200, reqId 1669: No security definition has been found for the request, contract: Option(symbol='AMZN', lastTradeDateOrContractMonth='20190621', strike=2350.0, right='C', exchange='SMART')
# Error 200, reqId 1671: No security definition has been found for the request, contract: Option(symbol='AMZN', lastTradeDateOrContractMonth='20190621', strike=2360.0, right='C', exchange='SMART')
# Error 200, reqId 1675: No security definition has been found for the request, contract: Option(symbol='AMZN', lastTradeDateOrContractMonth='20190621', strike=2380.0, right='C', exchange='SMART')
# Error 200, reqId 1683: No security definition has been found for the request, contract: Option(symbol='AMZN', lastTradeDateOrContractMonth='20190621', strike=2420.0, right='C', exchange='SMART')
# Error 200, reqId 1689: No security definition has been found for the request, contract: Option(symbol='AMZN', lastTradeDateOrContractMonth='20190621', strike=2450.0, right='C', exchange='SMART')
# Error 200, reqId 1700: No security definition has been found for the request, contract: Option(symbol='AMZN', lastTradeDateOrContractMonth='20190621', strike=1065.0, right='C', exchange='SMART')
# Error 0, reqId -1: Warning: Approaching max rate of 50 messages per second (50)
# Error 200, reqId 1704: No security definition has been found for the request, contract: Option(symbol='AMZN', lastTradeDateOrContractMonth='20190621', strike=1085.0, right='C', exchange='SMART')
# Error 200, reqId 1702: No security definition has been found for the request, contract: Option(symbol='AMZN', lastTradeDateOrContractMonth='20190621', strike=1075.0, right='C', exchange='SMART')
# Error 200, reqId 1706: No security definition has been found for the request, contract: Option(symbol='AMZN', lastTradeDateOrContractMonth='20190621', strike=1095.0, right='C', exchange='SMART')
# Error 200, reqId 1708: No security definition has been found for the request, contract: Option(symbol='AMZN', lastTradeDateOrContractMonth='20190621', strike=1105.0, right='C', exchange='SMART')
# Error 200, reqId 1710: No security definition has been found for the request, contract: Option(symbol='AMZN', lastTradeDateOrContractMonth='20190621', strike=1115.0, right='C', exchange='SMART')
# Error 200, reqId 1712: No security definition has been found for the request, contract: Option(symbol='AMZN', lastTradeDateOrContractMonth='20190621', strike=1125.0, right='C', exchange='SMART')
# Error 200, reqId 1714: No security definition has been found for the request, contract: Option(symbol='AMZN', lastTradeDateOrContractMonth='20190621', strike=1135.0, right='C', exchange='SMART')
# Error 200, reqId 1716: No security definition has been found for the request, contract: Option(symbol='AMZN', lastTradeDateOrContractMonth='20190621', strike=1145.0, right='C', exchange='SMART')
# Error 200, reqId 1718: No security definition has been found for the request, contract: Option(symbol='AMZN', lastTradeDateOrContractMonth='20190621', strike=1155.0, right='C', exchange='SMART')
# Error 200, reqId 1720: No security definition has been found for the request, contract: Option(symbol='AMZN', lastTradeDateOrContractMonth='20190621', strike=1165.0, right='C', exchange='SMART')
# Error 200, reqId 1722: No security definition has been found for the request, contract: Option(symbol='AMZN', lastTradeDateOrContractMonth='20190621', strike=1175.0, right='C', exchange='SMART')
# Error 200, reqId 1724: No security definition has been found for the request, contract: Option(symbol='AMZN', lastTradeDateOrContractMonth='20190621', strike=1185.0, right='C', exchange='SMART')
# Error 200, reqId 1726: No security definition has been found for the request, contract: Option(symbol='AMZN', lastTradeDateOrContractMonth='20190621', strike=1195.0, right='C', exchange='SMART')
# Error 200, reqId 1728: No security definition has been found for the request, contract: Option(symbol='AMZN', lastTradeDateOrContractMonth='20190621', strike=1205.0, right='C', exchange='SMART')
# Error 200, reqId 1730: No security definition has been found for the request, contract: Option(symbol='AMZN', lastTradeDateOrContractMonth='20190621', strike=1215.0, right='C', exchange='SMART')
# Error 200, reqId 1732: No security definition has been found for the request, contract: Option(symbol='AMZN', lastTradeDateOrContractMonth='20190621', strike=1225.0, right='C', exchange='SMART')
# Error 200, reqId 1736: No security definition has been found for the request, contract: Option(symbol='AMZN', lastTradeDateOrContractMonth='20190621', strike=1245.0, right='C', exchange='SMART')
# Error 200, reqId 1734: No security definition has been found for the request, contract: Option(symbol='AMZN', lastTradeDateOrContractMonth='20190621', strike=1235.0, right='C', exchange='SMART')
# Error 200, reqId 1738: No security definition has been found for the request, contract: Option(symbol='AMZN', lastTradeDateOrContractMonth='20190621', strike=1255.0, right='C', exchange='SMART')
# Error 200, reqId 1740: No security definition has been found for the request, contract: Option(symbol='AMZN', lastTradeDateOrContractMonth='20190621', strike=1265.0, right='C', exchange='SMART')
# Error 200, reqId 1742: No security definition has been found for the request, contract: Option(symbol='AMZN', lastTradeDateOrContractMonth='20190621', strike=1275.0, right='C', exchange='SMART')
# Error 200, reqId 1746: No security definition has been found for the request, contract: Option(symbol='AMZN', lastTradeDateOrContractMonth='20190621', strike=1295.0, right='C', exchange='SMART')
# Error 200, reqId 1744: No security definition has been found for the request, contract: Option(symbol='AMZN', lastTradeDateOrContractMonth='20190621', strike=1285.0, right='C', exchange='SMART')
# Error 200, reqId 1750: No security definition has been found for the request, contract: Option(symbol='AMZN', lastTradeDateOrContractMonth='20190621', strike=1315.0, right='C', exchange='SMART')
# Error 200, reqId 1748: No security definition has been found for the request, contract: Option(symbol='AMZN', lastTradeDateOrContractMonth='20190621', strike=1305.0, right='C', exchange='SMART')
# Error 200, reqId 1752: No security definition has been found for the request, contract: Option(symbol='AMZN', lastTradeDateOrContractMonth='20190621', strike=1325.0, right='C', exchange='SMART')
# Error 200, reqId 1754: No security definition has been found for the request, contract: Option(symbol='AMZN', lastTradeDateOrContractMonth='20190621', strike=1335.0, right='C', exchange='SMART')
# Error 200, reqId 1756: No security definition has been found for the request, contract: Option(symbol='AMZN', lastTradeDateOrContractMonth='20190621', strike=1345.0, right='C', exchange='SMART')
# Error 200, reqId 1780: No security definition has been found for the request, contract: Option(symbol='AMZN', lastTradeDateOrContractMonth='20190621', strike=1465.0, right='C', exchange='SMART')
# Error 200, reqId 1782: No security definition has been found for the request, contract: Option(symbol='AMZN', lastTradeDateOrContractMonth='20190621', strike=1475.0, right='C', exchange='SMART')
# Error 200, reqId 1784: No security definition has been found for the request, contract: Option(symbol='AMZN', lastTradeDateOrContractMonth='20190621', strike=1485.0, right='C', exchange='SMART')
# Error 200, reqId 1786: No security definition has been found for the request, contract: Option(symbol='AMZN', lastTradeDateOrContractMonth='20190621', strike=1495.0, right='C', exchange='SMART')
# Error 200, reqId 1778: No security definition has been found for the request, contract: Option(symbol='AMZN', lastTradeDateOrContractMonth='20190621', strike=1455.0, right='C', exchange='SMART')
# Error 200, reqId 1788: No security definition has been found for the request, contract: Option(symbol='AMZN', lastTradeDateOrContractMonth='20190621', strike=1505.0, right='C', exchange='SMART')
# Error 200, reqId 1790: No security definition has been found for the request, contract: Option(symbol='AMZN', lastTradeDateOrContractMonth='20190621', strike=1515.0, right='C', exchange='SMART')
# Error 200, reqId 1792: No security definition has been found for the request, contract: Option(symbol='AMZN', lastTradeDateOrContractMonth='20190621', strike=1525.0, right='C', exchange='SMART')
# Error 200, reqId 1794: No security definition has been found for the request, contract: Option(symbol='AMZN', lastTradeDateOrContractMonth='20190621', strike=1535.0, right='C', exchange='SMART')
# Error 200, reqId 1796: No security definition has been found for the request, contract: Option(symbol='AMZN', lastTradeDateOrContractMonth='20190621', strike=1545.0, right='C', exchange='SMART')
# Error 200, reqId 1852: No security definition has been found for the request, contract: Option(symbol='AMZN', lastTradeDateOrContractMonth='20190621', strike=1825.0, right='C', exchange='SMART')
# Error 200, reqId 1853: No security definition has been found for the request, contract: Option(symbol='AMZN', lastTradeDateOrContractMonth='20190621', strike=1830.0, right='C', exchange='SMART')
# Error 200, reqId 1854: No security definition has been found for the request, contract: Option(symbol='AMZN', lastTradeDateOrContractMonth='20190621', strike=1835.0, right='C', exchange='SMART')
# Error 200, reqId 1857: No security definition has been found for the request, contract: Option(symbol='AMZN', lastTradeDateOrContractMonth='20190621', strike=1850.0, right='C', exchange='SMART')
# Error 200, reqId 1856: No security definition has been found for the request, contract: Option(symbol='AMZN', lastTradeDateOrContractMonth='20190621', strike=1845.0, right='C', exchange='SMART')
# Error 200, reqId 1861: No security definition has been found for the request, contract: Option(symbol='AMZN', lastTradeDateOrContractMonth='20190621', strike=1870.0, right='C', exchange='SMART')
# Error 200, reqId 1862: No security definition has been found for the request, contract: Option(symbol='AMZN', lastTradeDateOrContractMonth='20190621', strike=1875.0, right='C', exchange='SMART')
# Error 200, reqId 1865: No security definition has been found for the request, contract: Option(symbol='AMZN', lastTradeDateOrContractMonth='20190621', strike=1890.0, right='C', exchange='SMART')
# Error 200, reqId 1866: No security definition has been found for the request, contract: Option(symbol='AMZN', lastTradeDateOrContractMonth='20190621', strike=1895.0, right='C', exchange='SMART')
# Error 200, reqId 1868: No security definition has been found for the request, contract: Option(symbol='AMZN', lastTradeDateOrContractMonth='20190621', strike=1905.0, right='C', exchange='SMART')
# Error 200, reqId 1864: No security definition has been found for the request, contract: Option(symbol='AMZN', lastTradeDateOrContractMonth='20190621', strike=1885.0, right='C', exchange='SMART')
# Error 200, reqId 1870: No security definition has been found for the request, contract: Option(symbol='AMZN', lastTradeDateOrContractMonth='20190621', strike=1915.0, right='C', exchange='SMART')
# Error 200, reqId 1869: No security definition has been found for the request, contract: Option(symbol='AMZN', lastTradeDateOrContractMonth='20190621', strike=1910.0, right='C', exchange='SMART')
# Error 200, reqId 1872: No security definition has been found for the request, contract: Option(symbol='AMZN', lastTradeDateOrContractMonth='20190621', strike=1925.0, right='C', exchange='SMART')
# Error 200, reqId 1873: No security definition has been found for the request, contract: Option(symbol='AMZN', lastTradeDateOrContractMonth='20190621', strike=1930.0, right='C', exchange='SMART')
# Error 200, reqId 1874: No security definition has been found for the request, contract: Option(symbol='AMZN', lastTradeDateOrContractMonth='20190621', strike=1935.0, right='C', exchange='SMART')
# Error 200, reqId 1877: No security definition has been found for the request, contract: Option(symbol='AMZN', lastTradeDateOrContractMonth='20190621', strike=1950.0, right='C', exchange='SMART')
# Error 200, reqId 1881: No security definition has been found for the request, contract: Option(symbol='AMZN', lastTradeDateOrContractMonth='20190621', strike=1970.0, right='C', exchange='SMART')
# Error 200, reqId 1885: No security definition has been found for the request, contract: Option(symbol='AMZN', lastTradeDateOrContractMonth='20190621', strike=1990.0, right='C', exchange='SMART')
# Error 200, reqId 1889: No security definition has been found for the request, contract: Option(symbol='AMZN', lastTradeDateOrContractMonth='20190621', strike=2010.0, right='C', exchange='SMART')
# Stopped to throttle requests
# Error 200, reqId 1891: No security definition has been found for the request, contract: Option(symbol='AMZN', lastTradeDateOrContractMonth='20190621', strike=2020.0, right='C', exchange='SMART')
# Error 200, reqId 1893: No security definition has been found for the request, contract: Option(symbol='AMZN', lastTradeDateOrContractMonth='20190621', strike=2030.0, right='C', exchange='SMART')
# Error 200, reqId 1895: No security definition has been found for the request, contract: Option(symbol='AMZN', lastTradeDateOrContractMonth='20190621', strike=2040.0, right='C', exchange='SMART')
# Unknown contract: Option(symbol='AMZN', lastTradeDateOrContractMonth='20190621', strike=2050.0, right='P', exchange='SMART')
# Unknown contract: Option(symbol='AMZN', lastTradeDateOrContractMonth='20190621', strike=2060.0, right='P', exchange='SMART')
# Unknown contract: Option(symbol='AMZN', lastTradeDateOrContractMonth='20190621', strike=2070.0, right='P', exchange='SMART')
# Unknown contract: Option(symbol='AMZN', lastTradeDateOrContractMonth='20190621', strike=2080.0, right='P', exchange='SMART')
# Unknown contract: Option(symbol='AMZN', lastTradeDateOrContractMonth='20190621', strike=2090.0, right='P', exchange='SMART')
# Unknown contract: Option(symbol='AMZN', lastTradeDateOrContractMonth='20190621', strike=2110.0, right='P', exchange='SMART')
# Unknown contract: Option(symbol='AMZN', lastTradeDateOrContractMonth='20190621', strike=2120.0, right='P', exchange='SMART')
# Unknown contract: Option(symbol='AMZN', lastTradeDateOrContractMonth='20190621', strike=2130.0, right='P', exchange='SMART')
# Unknown contract: Option(symbol='AMZN', lastTradeDateOrContractMonth='20190621', strike=2140.0, right='P', exchange='SMART')
# Unknown contract: Option(symbol='AMZN', lastTradeDateOrContractMonth='20190621', strike=2150.0, right='P', exchange='SMART')
# Unknown contract: Option(symbol='AMZN', lastTradeDateOrContractMonth='20190621', strike=2160.0, right='P', exchange='SMART')
# Unknown contract: Option(symbol='AMZN', lastTradeDateOrContractMonth='20190621', strike=2170.0, right='P', exchange='SMART')
# Unknown contract: Option(symbol='AMZN', lastTradeDateOrContractMonth='20190621', strike=2180.0, right='P', exchange='SMART')
# Unknown contract: Option(symbol='AMZN', lastTradeDateOrContractMonth='20190621', strike=2220.0, right='P', exchange='SMART')
# Unknown contract: Option(symbol='AMZN', lastTradeDateOrContractMonth='20190621', strike=2240.0, right='P', exchange='SMART')
# Unknown contract: Option(symbol='AMZN', lastTradeDateOrContractMonth='20190621', strike=2250.0, right='P', exchange='SMART')
# Unknown contract: Option(symbol='AMZN', lastTradeDateOrContractMonth='20190621', strike=2260.0, right='P', exchange='SMART')
# Unknown contract: Option(symbol='AMZN', lastTradeDateOrContractMonth='20190621', strike=2280.0, right='P', exchange='SMART')
# Unknown contract: Option(symbol='AMZN', lastTradeDateOrContractMonth='20190621', strike=2320.0, right='P', exchange='SMART')
# Unknown contract: Option(symbol='AMZN', lastTradeDateOrContractMonth='20190621', strike=2340.0, right='P', exchange='SMART')
# Unknown contract: Option(symbol='AMZN', lastTradeDateOrContractMonth='20190621', strike=2350.0, right='P', exchange='SMART')
# Unknown contract: Option(symbol='AMZN', lastTradeDateOrContractMonth='20190621', strike=2360.0, right='P', exchange='SMART')
# Unknown contract: Option(symbol='AMZN', lastTradeDateOrContractMonth='20190621', strike=2380.0, right='P', exchange='SMART')
# Unknown contract: Option(symbol='AMZN', lastTradeDateOrContractMonth='20190621', strike=2420.0, right='P', exchange='SMART')
# Unknown contract: Option(symbol='AMZN', lastTradeDateOrContractMonth='20190621', strike=2450.0, right='P', exchange='SMART')
# Unknown contract: Option(symbol='AMZN', lastTradeDateOrContractMonth='20190621', strike=1065.0, right='P', exchange='SMART')
# Unknown contract: Option(symbol='AMZN', lastTradeDateOrContractMonth='20190621', strike=1075.0, right='P', exchange='SMART')
# Unknown contract: Option(symbol='AMZN', lastTradeDateOrContractMonth='20190621', strike=1085.0, right='P', exchange='SMART')
# Unknown contract: Option(symbol='AMZN', lastTradeDateOrContractMonth='20190621', strike=1095.0, right='P', exchange='SMART')
# Unknown contract: Option(symbol='AMZN', lastTradeDateOrContractMonth='20190621', strike=1105.0, right='P', exchange='SMART')
# Unknown contract: Option(symbol='AMZN', lastTradeDateOrContractMonth='20190621', strike=1115.0, right='P', exchange='SMART')
# Unknown contract: Option(symbol='AMZN', lastTradeDateOrContractMonth='20190621', strike=1125.0, right='P', exchange='SMART')
# Unknown contract: Option(symbol='AMZN', lastTradeDateOrContractMonth='20190621', strike=1135.0, right='P', exchange='SMART')
# Unknown contract: Option(symbol='AMZN', lastTradeDateOrContractMonth='20190621', strike=1145.0, right='P', exchange='SMART')
# Unknown contract: Option(symbol='AMZN', lastTradeDateOrContractMonth='20190621', strike=1155.0, right='P', exchange='SMART')
# Unknown contract: Option(symbol='AMZN', lastTradeDateOrContractMonth='20190621', strike=1165.0, right='P', exchange='SMART')
# Unknown contract: Option(symbol='AMZN', lastTradeDateOrContractMonth='20190621', strike=1175.0, right='P', exchange='SMART')
# Unknown contract: Option(symbol='AMZN', lastTradeDateOrContractMonth='20190621', strike=1185.0, right='P', exchange='SMART')
# Unknown contract: Option(symbol='AMZN', lastTradeDateOrContractMonth='20190621', strike=1195.0, right='P', exchange='SMART')
# Unknown contract: Option(symbol='AMZN', lastTradeDateOrContractMonth='20190621', strike=1205.0, right='P', exchange='SMART')
# Unknown contract: Option(symbol='AMZN', lastTradeDateOrContractMonth='20190621', strike=1215.0, right='P', exchange='SMART')
# Unknown contract: Option(symbol='AMZN', lastTradeDateOrContractMonth='20190621', strike=1225.0, right='P', exchange='SMART')
# Unknown contract: Option(symbol='AMZN', lastTradeDateOrContractMonth='20190621', strike=1235.0, right='P', exchange='SMART')
# Unknown contract: Option(symbol='AMZN', lastTradeDateOrContractMonth='20190621', strike=1245.0, right='P', exchange='SMART')
# Unknown contract: Option(symbol='AMZN', lastTradeDateOrContractMonth='20190621', strike=1255.0, right='P', exchange='SMART')
# Unknown contract: Option(symbol='AMZN', lastTradeDateOrContractMonth='20190621', strike=1265.0, right='P', exchange='SMART')
# Unknown contract: Option(symbol='AMZN', lastTradeDateOrContractMonth='20190621', strike=1275.0, right='P', exchange='SMART')
# Unknown contract: Option(symbol='AMZN', lastTradeDateOrContractMonth='20190621', strike=1285.0, right='P', exchange='SMART')
# Unknown contract: Option(symbol='AMZN', lastTradeDateOrContractMonth='20190621', strike=1295.0, right='P', exchange='SMART')
# Unknown contract: Option(symbol='AMZN', lastTradeDateOrContractMonth='20190621', strike=1305.0, right='P', exchange='SMART')
# Unknown contract: Option(symbol='AMZN', lastTradeDateOrContractMonth='20190621', strike=1315.0, right='P', exchange='SMART')
# Unknown contract: Option(symbol='AMZN', lastTradeDateOrContractMonth='20190621', strike=1325.0, right='P', exchange='SMART')
# Unknown contract: Option(symbol='AMZN', lastTradeDateOrContractMonth='20190621', strike=1335.0, right='P', exchange='SMART')
# Unknown contract: Option(symbol='AMZN', lastTradeDateOrContractMonth='20190621', strike=1345.0, right='P', exchange='SMART')
# Unknown contract: Option(symbol='AMZN', lastTradeDateOrContractMonth='20190621', strike=1455.0, right='P', exchange='SMART')
# Unknown contract: Option(symbol='AMZN', lastTradeDateOrContractMonth='20190621', strike=1465.0, right='P', exchange='SMART')
# Unknown contract: Option(symbol='AMZN', lastTradeDateOrContractMonth='20190621', strike=1475.0, right='P', exchange='SMART')
# Unknown contract: Option(symbol='AMZN', lastTradeDateOrContractMonth='20190621', strike=1485.0, right='P', exchange='SMART')
# Unknown contract: Option(symbol='AMZN', lastTradeDateOrContractMonth='20190621', strike=1495.0, right='P', exchange='SMART')
# Unknown contract: Option(symbol='AMZN', lastTradeDateOrContractMonth='20190621', strike=1505.0, right='P', exchange='SMART')
# Unknown contract: Option(symbol='AMZN', lastTradeDateOrContractMonth='20190621', strike=1515.0, right='P', exchange='SMART')
# Unknown contract: Option(symbol='AMZN', lastTradeDateOrContractMonth='20190621', strike=1525.0, right='P', exchange='SMART')
# Unknown contract: Option(symbol='AMZN', lastTradeDateOrContractMonth='20190621', strike=1535.0, right='P', exchange='SMART')
# Unknown contract: Option(symbol='AMZN', lastTradeDateOrContractMonth='20190621', strike=1545.0, right='P', exchange='SMART')
# Unknown contract: Option(symbol='AMZN', lastTradeDateOrContractMonth='20190621', strike=1825.0, right='P', exchange='SMART')
# Unknown contract: Option(symbol='AMZN', lastTradeDateOrContractMonth='20190621', strike=1830.0, right='P', exchange='SMART')
# Unknown contract: Option(symbol='AMZN', lastTradeDateOrContractMonth='20190621', strike=1835.0, right='P', exchange='SMART')
# Unknown contract: Option(symbol='AMZN', lastTradeDateOrContractMonth='20190621', strike=1845.0, right='P', exchange='SMART')
# Unknown contract: Option(symbol='AMZN', lastTradeDateOrContractMonth='20190621', strike=1850.0, right='P', exchange='SMART')
# Unknown contract: Option(symbol='AMZN', lastTradeDateOrContractMonth='20190621', strike=1870.0, right='P', exchange='SMART')
# Unknown contract: Option(symbol='AMZN', lastTradeDateOrContractMonth='20190621', strike=1875.0, right='P', exchange='SMART')
# Unknown contract: Option(symbol='AMZN', lastTradeDateOrContractMonth='20190621', strike=1885.0, right='P', exchange='SMART')
# Unknown contract: Option(symbol='AMZN', lastTradeDateOrContractMonth='20190621', strike=1890.0, right='P', exchange='SMART')
# Unknown contract: Option(symbol='AMZN', lastTradeDateOrContractMonth='20190621', strike=1895.0, right='P', exchange='SMART')
# Unknown contract: Option(symbol='AMZN', lastTradeDateOrContractMonth='20190621', strike=1905.0, right='P', exchange='SMART')
# Unknown contract: Option(symbol='AMZN', lastTradeDateOrContractMonth='20190621', strike=1910.0, right='P', exchange='SMART')
# Unknown contract: Option(symbol='AMZN', lastTradeDateOrContractMonth='20190621', strike=1915.0, right='P', exchange='SMART')
# Unknown contract: Option(symbol='AMZN', lastTradeDateOrContractMonth='20190621', strike=1925.0, right='P', exchange='SMART')
# Unknown contract: Option(symbol='AMZN', lastTradeDateOrContractMonth='20190621', strike=1930.0, right='P', exchange='SMART')
# Unknown contract: Option(symbol='AMZN', lastTradeDateOrContractMonth='20190621', strike=1935.0, right='P', exchange='SMART')
# Unknown contract: Option(symbol='AMZN', lastTradeDateOrContractMonth='20190621', strike=1950.0, right='P', exchange='SMART')
# Unknown contract: Option(symbol='AMZN', lastTradeDateOrContractMonth='20190621', strike=1970.0, right='P', exchange='SMART')
# Unknown contract: Option(symbol='AMZN', lastTradeDateOrContractMonth='20190621', strike=1990.0, right='P', exchange='SMART')
# Unknown contract: Option(symbol='AMZN', lastTradeDateOrContractMonth='20190621', strike=2010.0, right='P', exchange='SMART')
# Unknown contract: Option(symbol='AMZN', lastTradeDateOrContractMonth='20190621', strike=2020.0, right='P', exchange='SMART')
# Unknown contract: Option(symbol='AMZN', lastTradeDateOrContractMonth='20190621', strike=2030.0, right='P', exchange='SMART')
# Unknown contract: Option(symbol='AMZN', lastTradeDateOrContractMonth='20190621', strike=2040.0, right='P', exchange='SMART')
# Unknown contract: Option(symbol='AMZN', lastTradeDateOrContractMonth='20190621', strike=2050.0, right='C', exchange='SMART')
# Unknown contract: Option(symbol='AMZN', lastTradeDateOrContractMonth='20190621', strike=2060.0, right='C', exchange='SMART')
# Unknown contract: Option(symbol='AMZN', lastTradeDateOrContractMonth='20190621', strike=2070.0, right='C', exchange='SMART')
# Unknown contract: Option(symbol='AMZN', lastTradeDateOrContractMonth='20190621', strike=2080.0, right='C', exchange='SMART')
# Unknown contract: Option(symbol='AMZN', lastTradeDateOrContractMonth='20190621', strike=2090.0, right='C', exchange='SMART')
# Unknown contract: Option(symbol='AMZN', lastTradeDateOrContractMonth='20190621', strike=2110.0, right='C', exchange='SMART')
# Unknown contract: Option(symbol='AMZN', lastTradeDateOrContractMonth='20190621', strike=2120.0, right='C', exchange='SMART')
# Unknown contract: Option(symbol='AMZN', lastTradeDateOrContractMonth='20190621', strike=2130.0, right='C', exchange='SMART')
# Unknown contract: Option(symbol='AMZN', lastTradeDateOrContractMonth='20190621', strike=2140.0, right='C', exchange='SMART')
# Unknown contract: Option(symbol='AMZN', lastTradeDateOrContractMonth='20190621', strike=2150.0, right='C', exchange='SMART')
# Unknown contract: Option(symbol='AMZN', lastTradeDateOrContractMonth='20190621', strike=2160.0, right='C', exchange='SMART')
# Unknown contract: Option(symbol='AMZN', lastTradeDateOrContractMonth='20190621', strike=2170.0, right='C', exchange='SMART')
# Unknown contract: Option(symbol='AMZN', lastTradeDateOrContractMonth='20190621', strike=2180.0, right='C', exchange='SMART')
# Unknown contract: Option(symbol='AMZN', lastTradeDateOrContractMonth='20190621', strike=2220.0, right='C', exchange='SMART')
# Unknown contract: Option(symbol='AMZN', lastTradeDateOrContractMonth='20190621', strike=2240.0, right='C', exchange='SMART')
# ...
# Error 200, reqId 2556: No security definition has been found for the request, contract: Option(symbol='AMZN', lastTradeDateOrContractMonth='20190719', strike=2465.0, right='P', exchange='SMART')
# Error 200, reqId 2554: No security definition has been found for the request, contract: Option(symbol='AMZN', lastTradeDateOrContractMonth='20190719', strike=2455.0, right='P', exchange='SMART')
# Error 200, reqId 2557: No security definition has been found for the request, contract: Option(symbol='AMZN', lastTradeDateOrContractMonth='20190719', strike=2470.0, right='P', exchange='SMART')
# Error 200, reqId 2558: No security definition has been found for the request, contract: Option(symbol='AMZN', lastTradeDateOrContractMonth='20190719', strike=2475.0, right='P', exchange='SMART')
# Error 200, reqId 2559: No security definition has been found for the request, contract: Option(symbol='AMZN', lastTradeDateOrContractMonth='20190719', strike=2480.0, right='P', exchange='SMART')
# Error 200, reqId 2561: No security definition has been found for the request, contract: Option(symbol='AMZN', lastTradeDateOrContractMonth='20190719', strike=2490.0, right='P', exchange='SMART')
# Error 200, reqId 2562: No security definition has been found for the request, contract: Option(symbol='AMZN', lastTradeDateOrContractMonth='20190719', strike=2495.0, right='P', exchange='SMART')
# Error 200, reqId 2566: No security definition has been found for the request, contract: Option(symbol='AMZN', lastTradeDateOrContractMonth='20190719', strike=965.0, right='P', exchange='SMART')
# Error 200, reqId 2560: No security definition has been found for the request, contract: Option(symbol='AMZN', lastTradeDateOrContractMonth='20190719', strike=2485.0, right='P', exchange='SMART')
# Error 200, reqId 2568: No security definition has been found for the request, contract: Option(symbol='AMZN', lastTradeDateOrContractMonth='20190719', strike=975.0, right='P', exchange='SMART')
# Error 200, reqId 2572: No security definition has been found for the request, contract: Option(symbol='AMZN', lastTradeDateOrContractMonth='20190719', strike=995.0, right='P', exchange='SMART')
# Error 200, reqId 2574: No security definition has been found for the request, contract: Option(symbol='AMZN', lastTradeDateOrContractMonth='20190719', strike=1005.0, right='P', exchange='SMART')
# Error 200, reqId 2570: No security definition has been found for the request, contract: Option(symbol='AMZN', lastTradeDateOrContractMonth='20190719', strike=985.0, right='P', exchange='SMART')
# Error 200, reqId 2578: No security definition has been found for the request, contract: Option(symbol='AMZN', lastTradeDateOrContractMonth='20190719', strike=1025.0, right='P', exchange='SMART')
# Error 200, reqId 2576: No security definition has been found for the request, contract: Option(symbol='AMZN', lastTradeDateOrContractMonth='20190719', strike=1015.0, right='P', exchange='SMART')
# Error 200, reqId 2579: No security definition has been found for the request, contract: Option(symbol='AMZN', lastTradeDateOrContractMonth='20190719', strike=1030.0, right='P', exchange='SMART')
# Error 200, reqId 2580: No security definition has been found for the request, contract: Option(symbol='AMZN', lastTradeDateOrContractMonth='20190719', strike=1035.0, right='P', exchange='SMART')
# Error 200, reqId 2582: No security definition has been found for the request, contract: Option(symbol='AMZN', lastTradeDateOrContractMonth='20190719', strike=1045.0, right='P', exchange='SMART')
# Error 200, reqId 2583: No security definition has been found for the request, contract: Option(symbol='AMZN', lastTradeDateOrContractMonth='20190719', strike=1050.0, right='P', exchange='SMART')
# Error 200, reqId 2584: No security definition has been found for the request, contract: Option(symbol='AMZN', lastTradeDateOrContractMonth='20190719', strike=1055.0, right='P', exchange='SMART')
# Error 200, reqId 2586: No security definition has been found for the request, contract: Option(symbol='AMZN', lastTradeDateOrContractMonth='20190719', strike=1065.0, right='P', exchange='SMART')
# Error 200, reqId 2588: No security definition has been found for the request, contract: Option(symbol='AMZN', lastTradeDateOrContractMonth='20190719', strike=1075.0, right='P', exchange='SMART')
# Error 200, reqId 2587: No security definition has been found for the request, contract: Option(symbol='AMZN', lastTradeDateOrContractMonth='20190719', strike=1070.0, right='P', exchange='SMART')
# Error 200, reqId 2590: No security definition has been found for the request, contract: Option(symbol='AMZN', lastTradeDateOrContractMonth='20190719', strike=1085.0, right='P', exchange='SMART')
# Error 200, reqId 2591: No security definition has been found for the request, contract: Option(symbol='AMZN', lastTradeDateOrContractMonth='20190719', strike=1090.0, right='P', exchange='SMART')
# Error 200, reqId 2592: No security definition has been found for the request, contract: Option(symbol='AMZN', lastTradeDateOrContractMonth='20190719', strike=1095.0, right='P', exchange='SMART')
# Error 200, reqId 2594: No security definition has been found for the request, contract: Option(symbol='AMZN', lastTradeDateOrContractMonth='20190719', strike=1105.0, right='P', exchange='SMART')
# Error 200, reqId 2595: No security definition has been found for the request, contract: Option(symbol='AMZN', lastTradeDateOrContractMonth='20190719', strike=1110.0, right='P', exchange='SMART')
# Error 200, reqId 2596: No security definition has been found for the request, contract: Option(symbol='AMZN', lastTradeDateOrContractMonth='20190719', strike=1115.0, right='P', exchange='SMART')
# Error 200, reqId 2598: No security definition has been found for the request, contract: Option(symbol='AMZN', lastTradeDateOrContractMonth='20190719', strike=1125.0, right='P', exchange='SMART')
# Error 200, reqId 2599: No security definition has been found for the request, contract: Option(symbol='AMZN', lastTradeDateOrContractMonth='20190719', strike=1130.0, right='P', exchange='SMART')
# Error 200, reqId 2602: No security definition has been found for the request, contract: Option(symbol='AMZN', lastTradeDateOrContractMonth='20190719', strike=1145.0, right='P', exchange='SMART')
# Error 200, reqId 2600: No security definition has been found for the request, contract: Option(symbol='AMZN', lastTradeDateOrContractMonth='20190719', strike=1135.0, right='P', exchange='SMART')
# Error 200, reqId 2603: No security definition has been found for the request, contract: Option(symbol='AMZN', lastTradeDateOrContractMonth='20190719', strike=1150.0, right='P', exchange='SMART')
# Error 200, reqId 2604: No security definition has been found for the request, contract: Option(symbol='AMZN', lastTradeDateOrContractMonth='20190719', strike=1155.0, right='P', exchange='SMART')
# Error 200, reqId 2606: No security definition has been found for the request, contract: Option(symbol='AMZN', lastTradeDateOrContractMonth='20190719', strike=1165.0, right='P', exchange='SMART')
# Error 200, reqId 2607: No security definition has been found for the request, contract: Option(symbol='AMZN', lastTradeDateOrContractMonth='20190719', strike=1170.0, right='P', exchange='SMART')
# Error 200, reqId 2610: No security definition has been found for the request, contract: Option(symbol='AMZN', lastTradeDateOrContractMonth='20190719', strike=1185.0, right='P', exchange='SMART')
# Error 200, reqId 2608: No security definition has been found for the request, contract: Option(symbol='AMZN', lastTradeDateOrContractMonth='20190719', strike=1175.0, right='P', exchange='SMART')
# Error 200, reqId 2611: No security definition has been found for the request, contract: Option(symbol='AMZN', lastTradeDateOrContractMonth='20190719', strike=1190.0, right='P', exchange='SMART')
# Error 200, reqId 2612: No security definition has been found for the request, contract: Option(symbol='AMZN', lastTradeDateOrContractMonth='20190719', strike=1195.0, right='P', exchange='SMART')
# Error 200, reqId 2614: No security definition has been found for the request, contract: Option(symbol='AMZN', lastTradeDateOrContractMonth='20190719', strike=1205.0, right='P', exchange='SMART')
# Error 200, reqId 2615: No security definition has been found for the request, contract: Option(symbol='AMZN', lastTradeDateOrContractMonth='20190719', strike=1210.0, right='P', exchange='SMART')
# Error 200, reqId 2616: No security definition has been found for the request, contract: Option(symbol='AMZN', lastTradeDateOrContractMonth='20190719', strike=1215.0, right='P', exchange='SMART')
# Error 200, reqId 2618: No security definition has been found for the request, contract: Option(symbol='AMZN', lastTradeDateOrContractMonth='20190719', strike=1225.0, right='P', exchange='SMART')
# Error 200, reqId 2619: No security definition has been found for the request, contract: Option(symbol='AMZN', lastTradeDateOrContractMonth='20190719', strike=1230.0, right='P', exchange='SMART')
# Error 200, reqId 2620: No security definition has been found for the request, contract: Option(symbol='AMZN', lastTradeDateOrContractMonth='20190719', strike=1235.0, right='P', exchange='SMART')
# Error 200, reqId 2622: No security definition has been found for the request, contract: Option(symbol='AMZN', lastTradeDateOrContractMonth='20190719', strike=1245.0, right='P', exchange='SMART')
# Error 200, reqId 2623: No security definition has been found for the request, contract: Option(symbol='AMZN', lastTradeDateOrContractMonth='20190719', strike=1250.0, right='P', exchange='SMART')
# Error 200, reqId 2624: No security definition has been found for the request, contract: Option(symbol='AMZN', lastTradeDateOrContractMonth='20190719', strike=1255.0, right='P', exchange='SMART')
# Error 200, reqId 2627: No security definition has been found for the request, contract: Option(symbol='AMZN', lastTradeDateOrContractMonth='20190719', strike=1270.0, right='P', exchange='SMART')
# Error 200, reqId 2626: No security definition has been found for the request, contract: Option(symbol='AMZN', lastTradeDateOrContractMonth='20190719', strike=1265.0, right='P', exchange='SMART')
# Error 200, reqId 2628: No security definition has been found for the request, contract: Option(symbol='AMZN', lastTradeDateOrContractMonth='20190719', strike=1275.0, right='P', exchange='SMART')
# Error 200, reqId 2630: No security definition has been found for the request, contract: Option(symbol='AMZN', lastTradeDateOrContractMonth='20190719', strike=1285.0, right='P', exchange='SMART')
# Error 200, reqId 2631: No security definition has been found for the request, contract: Option(symbol='AMZN', lastTradeDateOrContractMonth='20190719', strike=1290.0, right='P', exchange='SMART')
# Error 200, reqId 2632: No security definition has been found for the request, contract: Option(symbol='AMZN', lastTradeDateOrContractMonth='20190719', strike=1295.0, right='P', exchange='SMART')
# Error 200, reqId 2634: No security definition has been found for the request, contract: Option(symbol='AMZN', lastTradeDateOrContractMonth='20190719', strike=1305.0, right='P', exchange='SMART')
# Error 200, reqId 2636: No security definition has been found for the request, contract: Option(symbol='AMZN', lastTradeDateOrContractMonth='20190719', strike=1315.0, right='P', exchange='SMART')
# Error 200, reqId 2635: No security definition has been found for the request, contract: Option(symbol='AMZN', lastTradeDateOrContractMonth='20190719', strike=1310.0, right='P', exchange='SMART')
# Error 200, reqId 2638: No security definition has been found for the request, contract: Option(symbol='AMZN', lastTradeDateOrContractMonth='20190719', strike=1325.0, right='P', exchange='SMART')
# Error 200, reqId 2639: No security definition has been found for the request, contract: Option(symbol='AMZN', lastTradeDateOrContractMonth='20190719', strike=1330.0, right='P', exchange='SMART')
# Error 200, reqId 2642: No security definition has been found for the request, contract: Option(symbol='AMZN', lastTradeDateOrContractMonth='20190719', strike=1345.0, right='P', exchange='SMART')
# Error 200, reqId 2643: No security definition has been found for the request, contract: Option(symbol='AMZN', lastTradeDateOrContractMonth='20190719', strike=1350.0, right='P', exchange='SMART')
# Error 200, reqId 2640: No security definition has been found for the request, contract: Option(symbol='AMZN', lastTradeDateOrContractMonth='20190719', strike=1335.0, right='P', exchange='SMART')
# Error 200, reqId 2644: No security definition has been found for the request, contract: Option(symbol='AMZN', lastTradeDateOrContractMonth='20190719', strike=1355.0, right='P', exchange='SMART')
# Error 200, reqId 2646: No security definition has been found for the request, contract: Option(symbol='AMZN', lastTradeDateOrContractMonth='20190719', strike=1365.0, right='P', exchange='SMART')
# Error 200, reqId 2647: No security definition has been found for the request, contract: Option(symbol='AMZN', lastTradeDateOrContractMonth='20190719', strike=1370.0, right='P', exchange='SMART')
# Error 200, reqId 2648: No security definition has been found for the request, contract: Option(symbol='AMZN', lastTradeDateOrContractMonth='20190719', strike=1375.0, right='P', exchange='SMART')
# Error 200, reqId 2650: No security definition has been found for the request, contract: Option(symbol='AMZN', lastTradeDateOrContractMonth='20190719', strike=1385.0, right='P', exchange='SMART')
# Error 200, reqId 2652: No security definition has been found for the request, contract: Option(symbol='AMZN', lastTradeDateOrContractMonth='20190719', strike=1395.0, right='P', exchange='SMART')
# Error 200, reqId 2651: No security definition has been found for the request, contract: Option(symbol='AMZN', lastTradeDateOrContractMonth='20190719', strike=1390.0, right='P', exchange='SMART')
# Error 200, reqId 2654: No security definition has been found for the request, contract: Option(symbol='AMZN', lastTradeDateOrContractMonth='20190719', strike=1405.0, right='P', exchange='SMART')
# Error 200, reqId 2655: No security definition has been found for the request, contract: Option(symbol='AMZN', lastTradeDateOrContractMonth='20190719', strike=1410.0, right='P', exchange='SMART')
# Error 200, reqId 2656: No security definition has been found for the request, contract: Option(symbol='AMZN', lastTradeDateOrContractMonth='20190719', strike=1415.0, right='P', exchange='SMART')
# Error 200, reqId 2658: No security definition has been found for the request, contract: Option(symbol='AMZN', lastTradeDateOrContractMonth='20190719', strike=1425.0, right='P', exchange='SMART')
# Error 200, reqId 2659: No security definition has been found for the request, contract: Option(symbol='AMZN', lastTradeDateOrContractMonth='20190719', strike=1430.0, right='P', exchange='SMART')
# Error 200, reqId 2662: No security definition has been found for the request, contract: Option(symbol='AMZN', lastTradeDateOrContractMonth='20190719', strike=1445.0, right='P', exchange='SMART')
# Error 200, reqId 2660: No security definition has been found for the request, contract: Option(symbol='AMZN', lastTradeDateOrContractMonth='20190719', strike=1435.0, right='P', exchange='SMART')
# Error 100, reqId 9: Max rate of messages per second has been exceeded:max=50 rec=62 (3)
# Error 200, reqId 2663: No security definition has been found for the request, contract: Option(symbol='AMZN', lastTradeDateOrContractMonth='20190719', strike=1450.0, right='P', exchange='SMART')
# Error 200, reqId 2666: No security definition has been found for the request, contract: Option(symbol='AMZN', lastTradeDateOrContractMonth='20190719', strike=1465.0, right='P', exchange='SMART')
# Error 200, reqId 2664: No security definition has been found for the request, contract: Option(symbol='AMZN', lastTradeDateOrContractMonth='20190719', strike=1455.0, right='P', exchange='SMART')
# Peer closed connection

# %%
maxshift = 9

arteHedges_upside = []
for expiry_index in range(len(curr_calls.Expiry.drop_duplicates())):
    bias = 'upside'
    possible_pos = art_hedges(curr_calls, curr_puts, curr_price, expiry_index, bias,
                              maxshift = 6, commissions = 0.0266)
    arteHedges_upside.append(possible_pos)

arteHedges_upside = pd.concat(arteHedges_upside,axis = 0)

# %%
arteHedges_downside = []
for expiry_index in range(len(curr_calls.Expiry.drop_duplicates())):
    bias = 'downside'
    possible_pos = art_hedges(curr_calls, curr_puts, curr_price, expiry_index, bias,
                              maxshift = 6, commissions = 0.0266)
    arteHedges_downside.append(possible_pos)
arteHedges_downside = pd.concat(arteHedges_downside,axis = 0)

arteHedges_upside['ReturnOnRisk'] = abs(arteHedges_upside.Credit/arteHedges_upside.MaxLoss)
arteHedges_downside['ReturnOnRisk'] = abs(arteHedges_downside.Credit/arteHedges_downside.MaxLoss)

# %%
arteHedges_upside[(arteHedges_upside.Short_Put_Strike < curr_price) &
                  (arteHedges_upside.Short_Put_Strike > 0.001)].sort_values(['Maturity', 
                                                                             'ReturnOnRisk'], ascending = False)

# %%
arteHedges_downside[(arteHedges_upside.Short_Put_Strike > curr_price) &
                    (arteHedges_upside.Short_Put_Strike > 0.001)].sort_values(['Maturity', 
                                                                               'ReturnOnRisk'], ascending = False)
