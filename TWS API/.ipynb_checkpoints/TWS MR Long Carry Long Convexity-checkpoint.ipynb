# %%
import warnings
warnings.filterwarnings('ignore')
import os

import tws_data 
import statsmodels.tsa.stattools as ts
import statsmodels.api as sm
from ib_insync import *
import numpy as np
import pandas as pd
import datetime as dt
import time
pd.options.display.float_format = '{:,.4f}'.format
# %matplotlib inline
from scipy.stats import norm as norm
import matplotlib.pyplot as plt
import requests as req
from bs4 import BeautifulSoup as bs
import plotly.plotly as py
import plotly.graph_objs as go
from plotly.offline import download_plotlyjs, init_notebook_mode, plot, iplot
init_notebook_mode(connected=True)
import math
# Out:
# <script>requirejs.config({paths: { 'plotly': ['https://cdn.plot.ly/plotly-latest.min']},});if(!window.Plotly) {{require(['plotly'],function(plotly) {window.Plotly=plotly;});}}</script>

# %%
os.chdir('D:\Options Data\IB Intraday')

def create_dfrow(curr_option):
    df_row = pd.DataFrame({'Symbol': curr_option.contract.localSymbol, 
                           'Type':curr_option.contract.right, 
                           'Bid': curr_option.bid, 
                           'Ask': curr_option.ask, 
                           'Volume': curr_option.volume, 
                           'Strike': curr_option.contract.strike,
                           'Expiry': dt.datetime.strptime(curr_option.contract.lastTradeDateOrContractMonth, '%Y%m%d'),
                           'bidIV': curr_option.bidGreeks.impliedVol, 
                           'bidDelta': curr_option.bidGreeks.delta,
                           'bidGamma': curr_option.bidGreeks.gamma, 
                           'bidVega': curr_option.bidGreeks.vega,
                           'bidTheta': curr_option.bidGreeks.theta, 
                           'askIV': curr_option.askGreeks.impliedVol, 
                           'askDelta': curr_option.askGreeks.delta,
                           'askGamma': curr_option.askGreeks.gamma, 
                           'askVega': curr_option.askGreeks.vega,
                           'askTheta': curr_option.askGreeks.theta,
                           'modelIV': curr_option.modelGreeks.impliedVol, 
                           'modelDelta': curr_option.modelGreeks.delta,
                           'modelGamma': curr_option.modelGreeks.gamma, 
                           'modelVega': curr_option.modelGreeks.vega,
                           'modelTheta': curr_option.modelGreeks.theta}, index = [0])
    return df_row

def get_movers():

    indexarb_url = 'http://www.indexarb.com/stockVsIndexesMiddleColumn.html#djIndexAnalysis'
    indexarb_soup = bs(req.get(indexarb_url).text,'lxml')
    indexarb_tables = indexarb_soup.select('table[align="LEFT"]')

    movers = []

    for i, table_html in enumerate(indexarb_tables):
        curr_table = pd.read_html(str(table_html))[2]
        curr_table.columns = curr_table.loc[1,:].tolist()

        if i == 0:
            curr_table = curr_table.iloc[2:,:4].set_index('Index').apply(pd.to_numeric)
        else:
            curr_table = curr_table.iloc[2:,[1,3,4,5,6]].dropna().set_index('Sym').apply(pd.to_numeric)

        curr_table.columns = [x.split(' ')[0] for x in curr_table.columns.tolist()]
        movers.append(curr_table)

    index = movers[0]
    movers = pd.concat(movers[1:], axis = 0)
    movers = movers.sort_values('OneMonth')
    
    return index, movers

def time_remaining(weekly_options, curr_spx):
    typ = weekly_options.reset_index().loc[0,'Type']

    try:
        interest_rate = bs(req.get('https://www.marketwatch.com/investing/bond/tmubmusd01m?countrycode=bx','lxml').text, 'lxml')
        interest_rate = float(interest_rate.select_one('h3[class*="intraday__price"]').select_one('bg-quote').text)/100
    except:
        interest_rate = 0.02422

    weekly_options['a'] = interest_rate - (weekly_options['modelIV']**2)/2

    if typ == 'P':
        weekly_options['b'] = weekly_options['modelIV']*norm.ppf(-weekly_options['modelDelta'])
    if typ == 'C':
        weekly_options['b'] = -weekly_options['modelIV']*norm.ppf(weekly_options['modelDelta'])
    weekly_options['c'] = np.log(curr_spx/weekly_options['Strike'])

    weekly_options_otm = weekly_options[abs(weekly_options.modelDelta) <= 0.5]
    weekly_options_itm = weekly_options[abs(weekly_options.modelDelta) > 0.5]

    if typ == 'P':
        weekly_options_otm['time_remaining'] = ((-weekly_options_otm.b - 
                                                 np.sqrt(weekly_options_otm.b**2 - 
                                                         4*weekly_options_otm.a*weekly_options_otm.c))/(2*weekly_options_otm.a))**2
        weekly_options_itm['time_remaining'] = ((-weekly_options_itm.b + 
                                                 np.sqrt(weekly_options_itm.b**2 - 
                                                         4*weekly_options_itm.a*weekly_options_itm.c))/(2*weekly_options_itm.a))**2
    if typ == 'C':
        weekly_options_otm['time_remaining'] = ((-weekly_options_otm.b + 
                                                 np.sqrt(weekly_options_otm.b**2 - 
                                                         4*weekly_options_otm.a*weekly_options_otm.c))/(2*weekly_options_otm.a))**2
        weekly_options_itm['time_remaining'] = ((-weekly_options_itm.b - 
                                                 np.sqrt(weekly_options_itm.b**2 - 
                                                         4*weekly_options_itm.a*weekly_options_itm.c))/(2*weekly_options_itm.a))**2
    weekly_times = pd.concat([weekly_options_otm, 
                              weekly_options_itm], axis = 0)[['Expiry','time_remaining']].dropna().groupby('Expiry').mean()

    del weekly_options['a'], weekly_options['b'], weekly_options['c'], weekly_options_itm, weekly_options_otm

    return weekly_options.merge(weekly_times.reset_index(), on = 'Expiry')


def get_options(ticker, exchange, contractType, earliest_date, latest_date, curr_iv, stdevs, save_csv = False):
    if contractType == 'Stock':
        security = Stock(ticker,exchange)
    else:
        security = Index(ticker, exchange)

    ib.qualifyContracts(security)

    chains = ib.reqSecDefOptParams(security.symbol, '', security.secType, security.conId)

    chains_df = util.df(chains)
    chain = next(c for c in chains if c.tradingClass == ticker and c.exchange == 'SMART')

    all_expirations = sorted(exp for exp in chain.expirations)
    expirations_dates = [dt.datetime.strptime(x, '%Y%m%d') for x in all_expirations]

    expirations = list(filter(lambda x: x[0] >= earliest_date and x[0] <= latest_date, list(zip(expirations_dates,all_expirations))))
    dte_expirations = [(expir[0] - dt.datetime.today()).days for expir in expirations]
    expirations = [expir[1] for expir in expirations]

    ib.reqHeadTimeStamp(security, whatToShow='TRADES', useRTH=True)

    end_date = '' #'20100506 13:00:00 PST'
    duration = '1 D'

    sec_bars = ib.reqHistoricalData(
            security,
            endDateTime=end_date,
            durationStr=duration,
            barSizeSetting='1 min',
            whatToShow='TRADES',
            useRTH=True,
            formatDate=1)


    sec_df = util.df(sec_bars).set_index('date')
    sec_df.index = pd.to_datetime(sec_df.index)

    curr_sec_price = sec_df.reset_index().loc[len(sec_df) - 1, 'close']
    bounds_lst = [curr_sec_price*(stdevs*stdevs/(100*np.sqrt(365.25/dte))) for dte in dte_expirations]


    contracts_list = []

    for bounds, expiration in zip(bounds_lst, expirations):
        strikes = [strike for strike in chain.strikes
                   if strike % 5 == 0
                   and curr_sec_price - bounds < strike < curr_sec_price + bounds]

        rights = ['P', 'C']

        curr_contracts = [Option(ticker, expiration, strike, right, 'SMART')
                          for right in rights
                          for strike in strikes]
        contracts_list += [curr_contracts]

    puts_list = []
    calls_list = []

    for contracts in contracts_list:
        ib.qualifyContracts(*contracts)
        sec_options = ib.reqTickers(*contracts)

        puts_rows = []
        calls_rows = []

        for curr_option in sec_options:
            try:
                curr_row = create_dfrow(curr_option)
                if curr_option.contract.right == 'P':
                    puts_rows.append(curr_row)
                elif curr_option.contract.right == 'C':
                    calls_rows.append(curr_row)
            except:
                continue

        puts = pd.concat(puts_rows).reset_index(drop = True).sort_values(['Expiry','Strike'])
        calls = pd.concat(calls_rows).reset_index(drop = True).sort_values(['Expiry','Strike'])
        puts = time_remaining(puts, curr_sec_price)
        calls = time_remaining(calls, curr_sec_price)
        puts_list.append(puts)
        calls_list.append(calls)
        time.sleep(5)

    puts_df = pd.concat(puts_list,axis = 0).reset_index(drop = True)
    calls_df = pd.concat(calls_list,axis = 0).reset_index(drop = True)

    if save_csv:
        curr_time = dt.datetime.now().strftime('%Y%m%d-%H-%M')
        puts_df.to_csv('ib_puts' + curr_time + '.csv')
        calls_df.to_csv('ib_calls' + curr_time + '.csv')
        
    return puts_df, calls_df, curr_sec_price


def get_spreads(weekly_options, curr_spx, expiry_index = 0, rowshift = 1, commissions = 0.0266):

    expirations_dates = weekly_options.Expiry.drop_duplicates().tolist()

    weekly_options = weekly_options[weekly_options.Expiry == expirations_dates[expiry_index]]

    typ = weekly_options.reset_index().loc[0,'Type']

    if typ == 'P':
        weekly_options = weekly_options.sort_values('Strike', ascending = False).reset_index(drop = True)
    if typ == 'C':
        weekly_options = weekly_options.sort_values('Strike', ascending = True).reset_index(drop = True)

    time_remaining = weekly_options.reset_index(drop = True).loc[0,'time_remaining']

    weekly_options['Mid'] = (weekly_options.Ask + weekly_options.Bid)/2
    shorts = weekly_options[['Mid', 'Strike', 'bidDelta', 'bidGamma', 'bidTheta', 'bidVega']]
    shorts.columns = ['Price','Strike','Delta','Gamma','Theta','Vega']
    longs = weekly_options[['Mid','Strike', 'askDelta', 'askGamma','askTheta', 'askVega']]
    longs.columns = ['Price','Strike','Delta','Gamma','Theta','Vega']

    spreads = shorts - longs.shift(-rowshift)
    spreads['Short_Strike'] = shorts.Strike
    spreads['Short_Delta'] = shorts.Delta
    spreads['Long_Strike'] = longs.Strike.shift(-rowshift)
    spreads = spreads[['Short_Strike', 'Long_Strike', 'Short_Delta', 'Price',
                       'Strike', 'Delta', 'Gamma', 'Theta', 'Vega']]

    spreads['Credit'] = spreads.Price - commissions

    if typ == 'P':
        spreads['MaxLoss'] = (-spreads.Strike + spreads.Credit)*100
        spreads['BreakEven'] = spreads['Short_Strike'] - spreads.Credit
    if typ == 'C':
        spreads['MaxLoss'] = (spreads.Strike + spreads.Credit)*100
        spreads['BreakEven'] = spreads['Short_Strike'] + spreads.Credit

    del spreads['Price'], spreads['Strike']

    spreads = spreads[spreads.Credit > 0].dropna().reset_index(drop = True)
    spreads['Expiry'] = expirations_dates[expiry_index]

    return spreads

def art_hedges(curr_calls, curr_puts, curr_price, expiry_index, bias = 'upside',
               maxshift = 6, commissions = 0.0266):
    
    hedge = []
    for rowshift in range(1,maxshift):

        if bias == 'upside':
            spreads = get_spreads(curr_puts, curr_price, expiry_index, rowshift, commissions = 0.0266)
        else:
            spreads = get_spreads(curr_calls, curr_price, expiry_index, rowshift, commissions = 0.0266)
        spreads = spreads[(spreads.Credit > 0.5)]
        hedge.append(spreads)

    hedge = pd.concat(hedge, axis = 0).reset_index(drop = True)

    if bias == 'upside':
        expirations_dates = curr_calls.Expiry.drop_duplicates().tolist()

        long_hedge = curr_calls[(curr_calls.Expiry == expirations_dates[expiry_index])][['Ask', 'Bid', 'Expiry', 'Strike',
                                                                             'modelDelta', 'modelGamma',
                                                                             'modelTheta', 'modelVega', 'time_remaining']].reset_index(drop = True)
    else:
        expirations_dates = curr_puts.Expiry.drop_duplicates().tolist()

        long_hedge = curr_puts[(curr_puts.Expiry == expirations_dates[expiry_index])][['Ask', 'Bid', 'Expiry', 'Strike',
                                                                             'modelDelta', 'modelGamma',
                                                                             'modelTheta', 'modelVega', 'time_remaining']].reset_index(drop = True)

    long_hedge['Mid'] = (long_hedge['Ask'] + long_hedge['Bid'])/2
    long_hedge.columns = [x.replace('model','') for x in long_hedge.columns.tolist()]

    hedges_lst = []

    for idx, row in hedge.iterrows():

        curr_hedge = long_hedge[long_hedge.Mid < row.Credit][['Mid','Expiry', 'Strike',
                                                              'Delta', 'Gamma',
                                                              'Theta', 'Vega', 'time_remaining']]
        curr_hedge['Gamma'] = curr_hedge['Gamma'] - row.Gamma
        curr_hedge['Delta'] = curr_hedge['Delta'] - row.Delta
        curr_hedge['Theta'] = curr_hedge['Theta'] - row.Theta
        curr_hedge['Vega'] = curr_hedge['Vega'] - row.Vega
        if bias == 'upside':
            curr_hedge = curr_hedge[(curr_hedge.Delta > 0) &
                                    (curr_hedge.Gamma > 0) &
                                    (curr_hedge.Theta > 0) &
                                    (curr_hedge.Vega > 0)]
        else:
            curr_hedge = curr_hedge[(curr_hedge.Delta < 0) &
                                (curr_hedge.Gamma > 0) &
                                (curr_hedge.Theta > 0) &
                                (curr_hedge.Vega > 0)]
        curr_hedge['Credit'] = -curr_hedge.Mid + row.Credit - 0.0133

        if bias == 'upside':
            curr_hedge['MaxLoss'] = (row.Long_Strike - row.Short_Strike + curr_hedge.Credit)*100
            curr_hedge['BreakEven'] = row.Short_Strike - curr_hedge['Credit']
        else:
            curr_hedge['MaxLoss'] = (row.Short_Strike - row.Long_Strike + curr_hedge.Credit)*100
            curr_hedge['BreakEven'] = row.Short_Strike + curr_hedge['Credit']
        curr_hedge['Maturity'] = curr_hedge['Expiry']
        curr_hedge['Mid'] = row.Short_Strike
        curr_hedge['Expiry'] = row.Long_Strike

        if bias == 'upside':
            curr_hedge.columns = ['Short_Put_Strike','Long_Put_Strike','Long_Call_Strike'] + curr_hedge.columns.tolist()[3:]
        else:
            curr_hedge.columns = ['Short_Call_Strike','Long_Call_Strike','Long_Put_Strike'] + curr_hedge.columns.tolist()[3:]

        hedges_lst.append(curr_hedge)

    hedges_df = pd.concat(hedges_lst, axis = 0)
    
    return hedges_df

# %%
index, movers = get_movers()

# %%
losers = movers.head()
winners = movers.tail().sort_values('OneMonth', ascending = False)

# %%
client_id = 11

ib = IB()
ib.connect('127.0.0.1', 7496, clientId=client_id)
# Out:
# commissionReport: No execution found for CommissionReport(execId='0001417f.5ca4aee0.02.01', commission=3.7314, currency='USD')
# commissionReport: No execution found for CommissionReport(execId='0001417f.5ca4aee0.03.01', commission=4.0014, currency='USD')
# commissionReport: No execution found for CommissionReport(execId='0001417f.5ca4aee2.02.01', commission=3.7314, currency='USD')
# commissionReport: No execution found for CommissionReport(execId='0001417f.5ca4aee2.03.01', commission=4.0014, currency='USD')
# commissionReport: No execution found for CommissionReport(execId='0001417f.5ca4aee4.02.01', commission=3.7314, currency='USD')
# commissionReport: No execution found for CommissionReport(execId='0001417f.5ca4aee4.03.01', commission=4.0014, currency='USD')
# commissionReport: No execution found for CommissionReport(execId='0001417f.5ca4aee6.02.01', commission=3.7314, currency='USD')
# commissionReport: No execution found for CommissionReport(execId='0001417f.5ca4aee6.03.01', commission=4.0014, currency='USD')
# commissionReport: No execution found for CommissionReport(execId='0000ec4a.5ca4552a.02.01', commission=4.0014, currency='USD')
# commissionReport: No execution found for CommissionReport(execId='0000ec4a.5ca4552a.03.01', commission=4.0014, currency='USD')
# commissionReport: No execution found for CommissionReport(execId='0000ec4a.5ca4552a.04.01', commission=4.0014, currency='USD')
# commissionReport: No execution found for CommissionReport(execId='0000ec4a.5ca4552c.02.01', commission=4.0014, currency='USD')
# commissionReport: No execution found for CommissionReport(execId='0000ec4a.5ca4552c.03.01', commission=4.0014, currency='USD')
# commissionReport: No execution found for CommissionReport(execId='0000ec4a.5ca4552c.04.01', commission=4.0014, currency='USD')
# commissionReport: No execution found for CommissionReport(execId='0000ec4a.5ca45530.02.01', commission=4.0014, currency='USD')
# commissionReport: No execution found for CommissionReport(execId='0000ec4a.5ca45530.03.01', commission=4.0014, currency='USD')
# commissionReport: No execution found for CommissionReport(execId='0000ec4a.5ca45530.04.01', commission=4.0014, currency='USD')
# commissionReport: No execution found for CommissionReport(execId='0000ec4a.5ca45542.02.01', commission=4.0014, currency='USD')
# commissionReport: No execution found for CommissionReport(execId='0000ec4a.5ca45542.03.01', commission=4.0014, currency='USD')
# commissionReport: No execution found for CommissionReport(execId='0000ec4a.5ca45542.04.01', commission=4.0014, currency='USD')
# Peer closed connection
# <IB connected to 127.0.0.1:7496 clientId=11>

# %%
exchange = 'NYSE'
contractType = 'Stock'
earliest_date = dt.datetime(2019,4,6)
latest_date = dt.datetime(2019,6,30)
curr_iv = 40
stdevs = 9

stock_prices = {}
stock_puts = {}
stock_calls = {}

for ticker in losers.index:

    curr_puts, curr_calls, curr_price = get_options(ticker, exchange, contractType, earliest_date, latest_date, curr_iv, stdevs, save_csv = False)
    
    stock_prices[ticker] = curr_price
    stock_puts[ticker] = curr_puts
    stock_calls[ticker] = curr_calls
    break

# %%
exchange = 'NYSE'
contractType = 'Stock'
earliest_date = dt.datetime(2019,7,6)
latest_date = dt.datetime(2019,10,1)

ticker = 'TSLA'
curr_iv = 30
stdevs = 9
curr_puts, curr_calls, curr_price = get_options(ticker, exchange, contractType, earliest_date, latest_date, curr_iv, stdevs, save_csv = False)
# Out:
# Started to throttle requests
# Stopped to throttle requests
# Error 200, reqId 19: No security definition has been found for the request, contract: Option(symbol='TSLA', lastTradeDateOrContractMonth='20190719', strike=205.0, right='P', exchange='SMART')
# Error 200, reqId 21: No security definition has been found for the request, contract: Option(symbol='TSLA', lastTradeDateOrContractMonth='20190719', strike=215.0, right='P', exchange='SMART')
# Error 200, reqId 23: No security definition has been found for the request, contract: Option(symbol='TSLA', lastTradeDateOrContractMonth='20190719', strike=225.0, right='P', exchange='SMART')
# Error 200, reqId 25: No security definition has been found for the request, contract: Option(symbol='TSLA', lastTradeDateOrContractMonth='20190719', strike=235.0, right='P', exchange='SMART')
# Error 200, reqId 27: No security definition has been found for the request, contract: Option(symbol='TSLA', lastTradeDateOrContractMonth='20190719', strike=245.0, right='P', exchange='SMART')
# Error 200, reqId 66: No security definition has been found for the request, contract: Option(symbol='TSLA', lastTradeDateOrContractMonth='20190719', strike=205.0, right='C', exchange='SMART')
# Error 200, reqId 68: No security definition has been found for the request, contract: Option(symbol='TSLA', lastTradeDateOrContractMonth='20190719', strike=215.0, right='C', exchange='SMART')
# Error 200, reqId 70: No security definition has been found for the request, contract: Option(symbol='TSLA', lastTradeDateOrContractMonth='20190719', strike=225.0, right='C', exchange='SMART')
# Error 200, reqId 72: No security definition has been found for the request, contract: Option(symbol='TSLA', lastTradeDateOrContractMonth='20190719', strike=235.0, right='C', exchange='SMART')
# Error 200, reqId 74: No security definition has been found for the request, contract: Option(symbol='TSLA', lastTradeDateOrContractMonth='20190719', strike=245.0, right='C', exchange='SMART')
# Unknown contract: Option(symbol='TSLA', lastTradeDateOrContractMonth='20190719', strike=205.0, right='P', exchange='SMART')
# Unknown contract: Option(symbol='TSLA', lastTradeDateOrContractMonth='20190719', strike=215.0, right='P', exchange='SMART')
# Unknown contract: Option(symbol='TSLA', lastTradeDateOrContractMonth='20190719', strike=225.0, right='P', exchange='SMART')
# Unknown contract: Option(symbol='TSLA', lastTradeDateOrContractMonth='20190719', strike=235.0, right='P', exchange='SMART')
# Unknown contract: Option(symbol='TSLA', lastTradeDateOrContractMonth='20190719', strike=245.0, right='P', exchange='SMART')
# Unknown contract: Option(symbol='TSLA', lastTradeDateOrContractMonth='20190719', strike=205.0, right='C', exchange='SMART')
# Unknown contract: Option(symbol='TSLA', lastTradeDateOrContractMonth='20190719', strike=215.0, right='C', exchange='SMART')
# Unknown contract: Option(symbol='TSLA', lastTradeDateOrContractMonth='20190719', strike=225.0, right='C', exchange='SMART')
# Unknown contract: Option(symbol='TSLA', lastTradeDateOrContractMonth='20190719', strike=235.0, right='C', exchange='SMART')
# Unknown contract: Option(symbol='TSLA', lastTradeDateOrContractMonth='20190719', strike=245.0, right='C', exchange='SMART')
# Error 200, reqId 113: No security definition has been found for the request, contract: Option(symbol='TSLA', lastTradeDateOrContractMonth='20190719', strike=205.0, right='P', exchange='SMART')
# Error 200, reqId 115: No security definition has been found for the request, contract: Option(symbol='TSLA', lastTradeDateOrContractMonth='20190719', strike=215.0, right='P', exchange='SMART')
# Error 200, reqId 117: No security definition has been found for the request, contract: Option(symbol='TSLA', lastTradeDateOrContractMonth='20190719', strike=225.0, right='P', exchange='SMART')
# Error 200, reqId 119: No security definition has been found for the request, contract: Option(symbol='TSLA', lastTradeDateOrContractMonth='20190719', strike=235.0, right='P', exchange='SMART')
# Error 200, reqId 121: No security definition has been found for the request, contract: Option(symbol='TSLA', lastTradeDateOrContractMonth='20190719', strike=245.0, right='P', exchange='SMART')
# Error 200, reqId 160: No security definition has been found for the request, contract: Option(symbol='TSLA', lastTradeDateOrContractMonth='20190719', strike=205.0, right='C', exchange='SMART')
# Error 200, reqId 162: No security definition has been found for the request, contract: Option(symbol='TSLA', lastTradeDateOrContractMonth='20190719', strike=215.0, right='C', exchange='SMART')
# Error 200, reqId 164: No security definition has been found for the request, contract: Option(symbol='TSLA', lastTradeDateOrContractMonth='20190719', strike=225.0, right='C', exchange='SMART')
# Error 200, reqId 166: No security definition has been found for the request, contract: Option(symbol='TSLA', lastTradeDateOrContractMonth='20190719', strike=235.0, right='C', exchange='SMART')
# Error 200, reqId 168: No security definition has been found for the request, contract: Option(symbol='TSLA', lastTradeDateOrContractMonth='20190719', strike=245.0, right='C', exchange='SMART')
# Error 10197, reqId 142: No market data during competing live session, contract: Option(conId=348512795, symbol='TSLA', lastTradeDateOrContractMonth='20190719', strike=350.0, right='P', multiplier='100', exchange='SMART', currency='USD', localSymbol='TSLA  190719P00350000', tradingClass='TSLA')
# Error 10197, reqId 109: No market data during competing live session, contract: Option(conId=348708474, symbol='TSLA', lastTradeDateOrContractMonth='20190719', strike=185.0, right='P', multiplier='100', exchange='SMART', currency='USD', localSymbol='TSLA  190719P00185000', tradingClass='TSLA')
# Error 10197, reqId 120: No market data during competing live session, contract: Option(conId=348708605, symbol='TSLA', lastTradeDateOrContractMonth='20190719', strike=240.0, right='P', multiplier='100', exchange='SMART', currency='USD', localSymbol='TSLA  190719P00240000', tradingClass='TSLA')
# Error 10197, reqId 152: No market data during competing live session, contract: Option(conId=348708290, symbol='TSLA', lastTradeDateOrContractMonth='20190719', strike=165.0, right='C', multiplier='100', exchange='SMART', currency='USD', localSymbol='TSLA  190719C00165000', tradingClass='TSLA')
# Error 10197, reqId 155: No market data during competing live session, contract: Option(conId=348708301, symbol='TSLA', lastTradeDateOrContractMonth='20190719', strike=180.0, right='C', multiplier='100', exchange='SMART', currency='USD', localSymbol='TSLA  190719C00180000', tradingClass='TSLA')
# Error 10197, reqId 138: No market data during competing live session, contract: Option(conId=348512744, symbol='TSLA', lastTradeDateOrContractMonth='20190719', strike=330.0, right='P', multiplier='100', exchange='SMART', currency='USD', localSymbol='TSLA  190719P00330000', tradingClass='TSLA')
# Error 10197, reqId 182: No market data during competing live session, contract: Option(conId=348512530, symbol='TSLA', lastTradeDateOrContractMonth='20190719', strike=315.0, right='C', multiplier='100', exchange='SMART', currency='USD', localSymbol='TSLA  190719C00315000', tradingClass='TSLA')
# Error 10197, reqId 163: No market data during competing live session, contract: Option(conId=348708325, symbol='TSLA', lastTradeDateOrContractMonth='20190719', strike=220.0, right='C', multiplier='100', exchange='SMART', currency='USD', localSymbol='TSLA  190719C00220000', tradingClass='TSLA')
# Error 10197, reqId 185: No market data during competing live session, contract: Option(conId=348512548, symbol='TSLA', lastTradeDateOrContractMonth='20190719', strike=330.0, right='C', multiplier='100', exchange='SMART', currency='USD', localSymbol='TSLA  190719C00330000', tradingClass='TSLA')
# Error 10197, reqId 153: No market data during competing live session, contract: Option(conId=348708295, symbol='TSLA', lastTradeDateOrContractMonth='20190719', strike=170.0, right='C', multiplier='100', exchange='SMART', currency='USD', localSymbol='TSLA  190719C00170000', tradingClass='TSLA')
# Error 10197, reqId 141: No market data during competing live session, contract: Option(conId=348512778, symbol='TSLA', lastTradeDateOrContractMonth='20190719', strike=345.0, right='P', multiplier='100', exchange='SMART', currency='USD', localSymbol='TSLA  190719P00345000', tradingClass='TSLA')
# Error 10197, reqId 196: No market data during competing live session, contract: Option(conId=348512623, symbol='TSLA', lastTradeDateOrContractMonth='20190719', strike=385.0, right='C', multiplier='100', exchange='SMART', currency='USD', localSymbol='TSLA  190719C00385000', tradingClass='TSLA')
# Error 10197, reqId 188: No market data during competing live session, contract: Option(conId=348512570, symbol='TSLA', lastTradeDateOrContractMonth='20190719', strike=345.0, right='C', multiplier='100', exchange='SMART', currency='USD', localSymbol='TSLA  190719C00345000', tradingClass='TSLA')
# Error 10197, reqId 191: No market data during competing live session, contract: Option(conId=348512595, symbol='TSLA', lastTradeDateOrContractMonth='20190719', strike=360.0, right='C', multiplier='100', exchange='SMART', currency='USD', localSymbol='TSLA  190719C00360000', tradingClass='TSLA')
# Error 10197, reqId 145: No market data during competing live session, contract: Option(conId=348512833, symbol='TSLA', lastTradeDateOrContractMonth='20190719', strike=365.0, right='P', multiplier='100', exchange='SMART', currency='USD', localSymbol='TSLA  190719P00365000', tradingClass='TSLA')
# Error 10197, reqId 159: No market data during competing live session, contract: Option(conId=348708316, symbol='TSLA', lastTradeDateOrContractMonth='20190719', strike=200.0, right='C', multiplier='100', exchange='SMART', currency='USD', localSymbol='TSLA  190719C00200000', tradingClass='TSLA')
# Error 10197, reqId 195: No market data during competing live session, contract: Option(conId=348512618, symbol='TSLA', lastTradeDateOrContractMonth='20190719', strike=380.0, right='C', multiplier='100', exchange='SMART', currency='USD', localSymbol='TSLA  190719C00380000', tradingClass='TSLA')
# Error 10197, reqId 183: No market data during competing live session, contract: Option(conId=348512535, symbol='TSLA', lastTradeDateOrContractMonth='20190719', strike=320.0, right='C', multiplier='100', exchange='SMART', currency='USD', localSymbol='TSLA  190719C00320000', tradingClass='TSLA')
# Error 10197, reqId 135: No market data during competing live session, contract: Option(conId=348512714, symbol='TSLA', lastTradeDateOrContractMonth='20190719', strike=315.0, right='P', multiplier='100', exchange='SMART', currency='USD', localSymbol='TSLA  190719P00315000', tradingClass='TSLA')
# Error 10197, reqId 161: No market data during competing live session, contract: Option(conId=348708320, symbol='TSLA', lastTradeDateOrContractMonth='20190719', strike=210.0, right='C', multiplier='100', exchange='SMART', currency='USD', localSymbol='TSLA  190719C00210000', tradingClass='TSLA')
# Error 10197, reqId 139: No market data during competing live session, contract: Option(conId=348512755, symbol='TSLA', lastTradeDateOrContractMonth='20190719', strike=335.0, right='P', multiplier='100', exchange='SMART', currency='USD', localSymbol='TSLA  190719P00335000', tradingClass='TSLA')
# Error 10197, reqId 112: No market data during competing live session, contract: Option(conId=348708519, symbol='TSLA', lastTradeDateOrContractMonth='20190719', strike=200.0, right='P', multiplier='100', exchange='SMART', currency='USD', localSymbol='TSLA  190719P00200000', tradingClass='TSLA')
# Started to throttle requests
# Stopped to throttle requests
# Started to throttle requests
# Stopped to throttle requests
# Error 10197, reqId 341: No market data during competing live session, contract: Option(conId=316990913, symbol='TSLA', lastTradeDateOrContractMonth='20190816', strike=330.0, right='P', multiplier='100', exchange='SMART', currency='USD', localSymbol='TSLA  190816P00330000', tradingClass='TSLA')
# Error 10197, reqId 315: No market data during competing live session, contract: Option(conId=316990745, symbol='TSLA', lastTradeDateOrContractMonth='20190816', strike=200.0, right='P', multiplier='100', exchange='SMART', currency='USD', localSymbol='TSLA  190816P00200000', tradingClass='TSLA')
# Error 10197, reqId 338: No market data during competing live session, contract: Option(conId=316990888, symbol='TSLA', lastTradeDateOrContractMonth='20190816', strike=315.0, right='P', multiplier='100', exchange='SMART', currency='USD', localSymbol='TSLA  190816P00315000', tradingClass='TSLA')
# Error 10197, reqId 323: No market data during competing live session, contract: Option(conId=316990827, symbol='TSLA', lastTradeDateOrContractMonth='20190816', strike=240.0, right='P', multiplier='100', exchange='SMART', currency='USD', localSymbol='TSLA  190816P00240000', tradingClass='TSLA')
# Error 10197, reqId 383: No market data during competing live session, contract: Option(conId=316990467, symbol='TSLA', lastTradeDateOrContractMonth='20190816', strike=275.0, right='C', multiplier='100', exchange='SMART', currency='USD', localSymbol='TSLA  190816C00275000', tradingClass='TSLA')
# Error 10197, reqId 345: No market data during competing live session, contract: Option(conId=316990943, symbol='TSLA', lastTradeDateOrContractMonth='20190816', strike=350.0, right='P', multiplier='100', exchange='SMART', currency='USD', localSymbol='TSLA  190816P00350000', tradingClass='TSLA')
# Error 10197, reqId 373: No market data during competing live session, contract: Option(conId=316990382, symbol='TSLA', lastTradeDateOrContractMonth='20190816', strike=225.0, right='C', multiplier='100', exchange='SMART', currency='USD', localSymbol='TSLA  190816C00225000', tradingClass='TSLA')
# Error 10197, reqId 337: No market data during competing live session, contract: Option(conId=316990887, symbol='TSLA', lastTradeDateOrContractMonth='20190816', strike=310.0, right='P', multiplier='100', exchange='SMART', currency='USD', localSymbol='TSLA  190816P00310000', tradingClass='TSLA')
# Error 10197, reqId 340: No market data during competing live session, contract: Option(conId=316990905, symbol='TSLA', lastTradeDateOrContractMonth='20190816', strike=325.0, right='P', multiplier='100', exchange='SMART', currency='USD', localSymbol='TSLA  190816P00325000', tradingClass='TSLA')
# Error 10197, reqId 343: No market data during competing live session, contract: Option(conId=316990926, symbol='TSLA', lastTradeDateOrContractMonth='20190816', strike=340.0, right='P', multiplier='100', exchange='SMART', currency='USD', localSymbol='TSLA  190816P00340000', tradingClass='TSLA')
# Error 10197, reqId 329: No market data during competing live session, contract: Option(conId=316990848, symbol='TSLA', lastTradeDateOrContractMonth='20190816', strike=270.0, right='P', multiplier='100', exchange='SMART', currency='USD', localSymbol='TSLA  190816P00270000', tradingClass='TSLA')
# Error 10197, reqId 375: No market data during competing live session, contract: Option(conId=316990399, symbol='TSLA', lastTradeDateOrContractMonth='20190816', strike=235.0, right='C', multiplier='100', exchange='SMART', currency='USD', localSymbol='TSLA  190816C00235000', tradingClass='TSLA')
# Error 10197, reqId 313: No market data during competing live session, contract: Option(conId=316990716, symbol='TSLA', lastTradeDateOrContractMonth='20190816', strike=190.0, right='P', multiplier='100', exchange='SMART', currency='USD', localSymbol='TSLA  190816P00190000', tradingClass='TSLA')
# Error 10197, reqId 328: No market data during competing live session, contract: Option(conId=316990847, symbol='TSLA', lastTradeDateOrContractMonth='20190816', strike=265.0, right='P', multiplier='100', exchange='SMART', currency='USD', localSymbol='TSLA  190816P00265000', tradingClass='TSLA')
# Error 10197, reqId 327: No market data during competing live session, contract: Option(conId=316990842, symbol='TSLA', lastTradeDateOrContractMonth='20190816', strike=260.0, right='P', multiplier='100', exchange='SMART', currency='USD', localSymbol='TSLA  190816P00260000', tradingClass='TSLA')
# Error 10197, reqId 306: No market data during competing live session, contract: Option(conId=317101612, symbol='TSLA', lastTradeDateOrContractMonth='20190816', strike=155.0, right='P', multiplier='100', exchange='SMART', currency='USD', localSymbol='TSLA  190816P00155000', tradingClass='TSLA')
# Error 10197, reqId 312: No market data during competing live session, contract: Option(conId=317101637, symbol='TSLA', lastTradeDateOrContractMonth='20190816', strike=185.0, right='P', multiplier='100', exchange='SMART', currency='USD', localSymbol='TSLA  190816P00185000', tradingClass='TSLA')
# Error 10197, reqId 342: No market data during competing live session, contract: Option(conId=316990923, symbol='TSLA', lastTradeDateOrContractMonth='20190816', strike=335.0, right='P', multiplier='100', exchange='SMART', currency='USD', localSymbol='TSLA  190816P00335000', tradingClass='TSLA')
# Error 10197, reqId 351: No market data during competing live session, contract: Option(conId=317203346, symbol='TSLA', lastTradeDateOrContractMonth='20190816', strike=380.0, right='P', multiplier='100', exchange='SMART', currency='USD', localSymbol='TSLA  190816P00380000', tradingClass='TSLA')
# Error 10197, reqId 333: No market data during competing live session, contract: Option(conId=316990865, symbol='TSLA', lastTradeDateOrContractMonth='20190816', strike=290.0, right='P', multiplier='100', exchange='SMART', currency='USD', localSymbol='TSLA  190816P00290000', tradingClass='TSLA')
# Error 10197, reqId 385: No market data during competing live session, contract: Option(conId=316990482, symbol='TSLA', lastTradeDateOrContractMonth='20190816', strike=285.0, right='C', multiplier='100', exchange='SMART', currency='USD', localSymbol='TSLA  190816C00285000', tradingClass='TSLA')
# Error 10197, reqId 308: No market data during competing live session, contract: Option(conId=317101623, symbol='TSLA', lastTradeDateOrContractMonth='20190816', strike=165.0, right='P', multiplier='100', exchange='SMART', currency='USD', localSymbol='TSLA  190816P00165000', tradingClass='TSLA')
# Error 10197, reqId 368: No market data during competing live session, contract: Option(conId=316990339, symbol='TSLA', lastTradeDateOrContractMonth='20190816', strike=200.0, right='C', multiplier='100', exchange='SMART', currency='USD', localSymbol='TSLA  190816C00200000', tradingClass='TSLA')
# Error 10197, reqId 322: No market data during competing live session, contract: Option(conId=316990817, symbol='TSLA', lastTradeDateOrContractMonth='20190816', strike=235.0, right='P', multiplier='100', exchange='SMART', currency='USD', localSymbol='TSLA  190816P00235000', tradingClass='TSLA')
# Error 10197, reqId 335: No market data during competing live session, contract: Option(conId=316990878, symbol='TSLA', lastTradeDateOrContractMonth='20190816', strike=300.0, right='P', multiplier='100', exchange='SMART', currency='USD', localSymbol='TSLA  190816P00300000', tradingClass='TSLA')
# Error 10197, reqId 365: No market data during competing live session, contract: Option(conId=317101445, symbol='TSLA', lastTradeDateOrContractMonth='20190816', strike=185.0, right='C', multiplier='100', exchange='SMART', currency='USD', localSymbol='TSLA  190816C00185000', tradingClass='TSLA')
# Error 10197, reqId 304: No market data during competing live session, contract: Option(conId=317101606, symbol='TSLA', lastTradeDateOrContractMonth='20190816', strike=145.0, right='P', multiplier='100', exchange='SMART', currency='USD', localSymbol='TSLA  190816P00145000', tradingClass='TSLA')
# Error 10197, reqId 364: No market data during competing live session, contract: Option(conId=317101440, symbol='TSLA', lastTradeDateOrContractMonth='20190816', strike=180.0, right='C', multiplier='100', exchange='SMART', currency='USD', localSymbol='TSLA  190816C00180000', tradingClass='TSLA')
# Error 10197, reqId 317: No market data during competing live session, contract: Option(conId=316990772, symbol='TSLA', lastTradeDateOrContractMonth='20190816', strike=210.0, right='P', multiplier='100', exchange='SMART', currency='USD', localSymbol='TSLA  190816P00210000', tradingClass='TSLA')
# Error 10197, reqId 372: No market data during competing live session, contract: Option(conId=316990372, symbol='TSLA', lastTradeDateOrContractMonth='20190816', strike=220.0, right='C', multiplier='100', exchange='SMART', currency='USD', localSymbol='TSLA  190816C00220000', tradingClass='TSLA')
# Error 10197, reqId 361: No market data during competing live session, contract: Option(conId=317101429, symbol='TSLA', lastTradeDateOrContractMonth='20190816', strike=165.0, right='C', multiplier='100', exchange='SMART', currency='USD', localSymbol='TSLA  190816C00165000', tradingClass='TSLA')
# Error 10197, reqId 367: No market data during competing live session, contract: Option(conId=316990326, symbol='TSLA', lastTradeDateOrContractMonth='20190816', strike=195.0, right='C', multiplier='100', exchange='SMART', currency='USD', localSymbol='TSLA  190816C00195000', tradingClass='TSLA')
# Error 10197, reqId 384: No market data during competing live session, contract: Option(conId=316990473, symbol='TSLA', lastTradeDateOrContractMonth='20190816', strike=280.0, right='C', multiplier='100', exchange='SMART', currency='USD', localSymbol='TSLA  190816C00280000', tradingClass='TSLA')
# Error 10197, reqId 352: No market data during competing live session, contract: Option(conId=317203351, symbol='TSLA', lastTradeDateOrContractMonth='20190816', strike=385.0, right='P', multiplier='100', exchange='SMART', currency='USD', localSymbol='TSLA  190816P00385000', tradingClass='TSLA')
# Error 10197, reqId 376: No market data during competing live session, contract: Option(conId=316990408, symbol='TSLA', lastTradeDateOrContractMonth='20190816', strike=240.0, right='C', multiplier='100', exchange='SMART', currency='USD', localSymbol='TSLA  190816C00240000', tradingClass='TSLA')
# Error 10197, reqId 355: No market data during competing live session, contract: Option(conId=317203361, symbol='TSLA', lastTradeDateOrContractMonth='20190816', strike=400.0, right='P', multiplier='100', exchange='SMART', currency='USD', localSymbol='TSLA  190816P00400000', tradingClass='TSLA')
# Error 10197, reqId 334: No market data during competing live session, contract: Option(conId=316990868, symbol='TSLA', lastTradeDateOrContractMonth='20190816', strike=295.0, right='P', multiplier='100', exchange='SMART', currency='USD', localSymbol='TSLA  190816P00295000', tradingClass='TSLA')
# Error 10197, reqId 326: No market data during competing live session, contract: Option(conId=316990837, symbol='TSLA', lastTradeDateOrContractMonth='20190816', strike=255.0, right='P', multiplier='100', exchange='SMART', currency='USD', localSymbol='TSLA  190816P00255000', tradingClass='TSLA')
# Error 10197, reqId 370: No market data during competing live session, contract: Option(conId=316990359, symbol='TSLA', lastTradeDateOrContractMonth='20190816', strike=210.0, right='C', multiplier='100', exchange='SMART', currency='USD', localSymbol='TSLA  190816C00210000', tradingClass='TSLA')
# Error 10197, reqId 379: No market data during competing live session, contract: Option(conId=316990442, symbol='TSLA', lastTradeDateOrContractMonth='20190816', strike=255.0, right='C', multiplier='100', exchange='SMART', currency='USD', localSymbol='TSLA  190816C00255000', tradingClass='TSLA')
# Error 10197, reqId 332: No market data during competing live session, contract: Option(conId=316990863, symbol='TSLA', lastTradeDateOrContractMonth='20190816', strike=285.0, right='P', multiplier='100', exchange='SMART', currency='USD', localSymbol='TSLA  190816P00285000', tradingClass='TSLA')
# Error 10197, reqId 381: No market data during competing live session, contract: Option(conId=316990452, symbol='TSLA', lastTradeDateOrContractMonth='20190816', strike=265.0, right='C', multiplier='100', exchange='SMART', currency='USD', localSymbol='TSLA  190816C00265000', tradingClass='TSLA')
# Error 10197, reqId 366: No market data during competing live session, contract: Option(conId=316990299, symbol='TSLA', lastTradeDateOrContractMonth='20190816', strike=190.0, right='C', multiplier='100', exchange='SMART', currency='USD', localSymbol='TSLA  190816C00190000', tradingClass='TSLA')
# Error 10197, reqId 362: No market data during competing live session, contract: Option(conId=317101434, symbol='TSLA', lastTradeDateOrContractMonth='20190816', strike=170.0, right='C', multiplier='100', exchange='SMART', currency='USD', localSymbol='TSLA  190816C00170000', tradingClass='TSLA')
# Error 10197, reqId 354: No market data during competing live session, contract: Option(conId=317203357, symbol='TSLA', lastTradeDateOrContractMonth='20190816', strike=395.0, right='P', multiplier='100', exchange='SMART', currency='USD', localSymbol='TSLA  190816P00395000', tradingClass='TSLA')
# Error 10197, reqId 346: No market data during competing live session, contract: Option(conId=316990950, symbol='TSLA', lastTradeDateOrContractMonth='20190816', strike=355.0, right='P', multiplier='100', exchange='SMART', currency='USD', localSymbol='TSLA  190816P00355000', tradingClass='TSLA')
# Error 10197, reqId 325: No market data during competing live session, contract: Option(conId=316990832, symbol='TSLA', lastTradeDateOrContractMonth='20190816', strike=250.0, right='P', multiplier='100', exchange='SMART', currency='USD', localSymbol='TSLA  190816P00250000', tradingClass='TSLA')
# Error 10197, reqId 369: No market data during competing live session, contract: Option(conId=316990345, symbol='TSLA', lastTradeDateOrContractMonth='20190816', strike=205.0, right='C', multiplier='100', exchange='SMART', currency='USD', localSymbol='TSLA  190816C00205000', tradingClass='TSLA')
# Error 10197, reqId 353: No market data during competing live session, contract: Option(conId=317203352, symbol='TSLA', lastTradeDateOrContractMonth='20190816', strike=390.0, right='P', multiplier='100', exchange='SMART', currency='USD', localSymbol='TSLA  190816P00390000', tradingClass='TSLA')
# Error 10197, reqId 331: No market data during competing live session, contract: Option(conId=316990858, symbol='TSLA', lastTradeDateOrContractMonth='20190816', strike=280.0, right='P', multiplier='100', exchange='SMART', currency='USD', localSymbol='TSLA  190816P00280000', tradingClass='TSLA')
# Error 10197, reqId 380: No market data during competing live session, contract: Option(conId=316990449, symbol='TSLA', lastTradeDateOrContractMonth='20190816', strike=260.0, right='C', multiplier='100', exchange='SMART', currency='USD', localSymbol='TSLA  190816C00260000', tradingClass='TSLA')
# Error 10197, reqId 374: No market data during competing live session, contract: Option(conId=316990389, symbol='TSLA', lastTradeDateOrContractMonth='20190816', strike=230.0, right='C', multiplier='100', exchange='SMART', currency='USD', localSymbol='TSLA  190816C00230000', tradingClass='TSLA')
# Error 10197, reqId 371: No market data during competing live session, contract: Option(conId=316990365, symbol='TSLA', lastTradeDateOrContractMonth='20190816', strike=215.0, right='C', multiplier='100', exchange='SMART', currency='USD', localSymbol='TSLA  190816C00215000', tradingClass='TSLA')
# Error 10197, reqId 363: No market data during competing live session, contract: Option(conId=317101439, symbol='TSLA', lastTradeDateOrContractMonth='20190816', strike=175.0, right='C', multiplier='100', exchange='SMART', currency='USD', localSymbol='TSLA  190816C00175000', tradingClass='TSLA')
# Error 10197, reqId 324: No market data during competing live session, contract: Option(conId=316990830, symbol='TSLA', lastTradeDateOrContractMonth='20190816', strike=245.0, right='P', multiplier='100', exchange='SMART', currency='USD', localSymbol='TSLA  190816P00245000', tradingClass='TSLA')
# Error 10197, reqId 310: No market data during competing live session, contract: Option(conId=317101629, symbol='TSLA', lastTradeDateOrContractMonth='20190816', strike=175.0, right='P', multiplier='100', exchange='SMART', currency='USD', localSymbol='TSLA  190816P00175000', tradingClass='TSLA')
# Error 10197, reqId 382: No market data during competing live session, contract: Option(conId=316990459, symbol='TSLA', lastTradeDateOrContractMonth='20190816', strike=270.0, right='C', multiplier='100', exchange='SMART', currency='USD', localSymbol='TSLA  190816C00270000', tradingClass='TSLA')
# Error 10197, reqId 348: No market data during competing live session, contract: Option(conId=316990980, symbol='TSLA', lastTradeDateOrContractMonth='20190816', strike=365.0, right='P', multiplier='100', exchange='SMART', currency='USD', localSymbol='TSLA  190816P00365000', tradingClass='TSLA')
# Error 10197, reqId 330: No market data during competing live session, contract: Option(conId=316990853, symbol='TSLA', lastTradeDateOrContractMonth='20190816', strike=275.0, right='P', multiplier='100', exchange='SMART', currency='USD', localSymbol='TSLA  190816P00275000', tradingClass='TSLA')
# Error 10197, reqId 386: No market data during competing live session, contract: Option(conId=316990488, symbol='TSLA', lastTradeDateOrContractMonth='20190816', strike=290.0, right='C', multiplier='100', exchange='SMART', currency='USD', localSymbol='TSLA  190816C00290000', tradingClass='TSLA')
# Error 10197, reqId 305: No market data during competing live session, contract: Option(conId=317101609, symbol='TSLA', lastTradeDateOrContractMonth='20190816', strike=150.0, right='P', multiplier='100', exchange='SMART', currency='USD', localSymbol='TSLA  190816P00150000', tradingClass='TSLA')
# Error 10197, reqId 318: No market data during competing live session, contract: Option(conId=316990782, symbol='TSLA', lastTradeDateOrContractMonth='20190816', strike=215.0, right='P', multiplier='100', exchange='SMART', currency='USD', localSymbol='TSLA  190816P00215000', tradingClass='TSLA')
# Error 10197, reqId 316: No market data during competing live session, contract: Option(conId=316990762, symbol='TSLA', lastTradeDateOrContractMonth='20190816', strike=205.0, right='P', multiplier='100', exchange='SMART', currency='USD', localSymbol='TSLA  190816P00205000', tradingClass='TSLA')
# Error 10197, reqId 350: No market data during competing live session, contract: Option(conId=316991002, symbol='TSLA', lastTradeDateOrContractMonth='20190816', strike=375.0, right='P', multiplier='100', exchange='SMART', currency='USD', localSymbol='TSLA  190816P00375000', tradingClass='TSLA')
# Error 10197, reqId 344: No market data during competing live session, contract: Option(conId=316990933, symbol='TSLA', lastTradeDateOrContractMonth='20190816', strike=345.0, right='P', multiplier='100', exchange='SMART', currency='USD', localSymbol='TSLA  190816P00345000', tradingClass='TSLA')
# Error 10197, reqId 339: No market data during competing live session, contract: Option(conId=316990893, symbol='TSLA', lastTradeDateOrContractMonth='20190816', strike=320.0, right='P', multiplier='100', exchange='SMART', currency='USD', localSymbol='TSLA  190816P00320000', tradingClass='TSLA')
# Error 10197, reqId 311: No market data during competing live session, contract: Option(conId=317101632, symbol='TSLA', lastTradeDateOrContractMonth='20190816', strike=180.0, right='P', multiplier='100', exchange='SMART', currency='USD', localSymbol='TSLA  190816P00180000', tradingClass='TSLA')
# Error 10197, reqId 377: No market data during competing live session, contract: Option(conId=316990419, symbol='TSLA', lastTradeDateOrContractMonth='20190816', strike=245.0, right='C', multiplier='100', exchange='SMART', currency='USD', localSymbol='TSLA  190816C00245000', tradingClass='TSLA')
# Error 10197, reqId 309: No market data during competing live session, contract: Option(conId=317101624, symbol='TSLA', lastTradeDateOrContractMonth='20190816', strike=170.0, right='P', multiplier='100', exchange='SMART', currency='USD', localSymbol='TSLA  190816P00170000', tradingClass='TSLA')
# Error 10197, reqId 378: No market data during competing live session, contract: Option(conId=316990428, symbol='TSLA', lastTradeDateOrContractMonth='20190816', strike=250.0, right='C', multiplier='100', exchange='SMART', currency='USD', localSymbol='TSLA  190816C00250000', tradingClass='TSLA')
# Error 10197, reqId 347: No market data during competing live session, contract: Option(conId=316990968, symbol='TSLA', lastTradeDateOrContractMonth='20190816', strike=360.0, right='P', multiplier='100', exchange='SMART', currency='USD', localSymbol='TSLA  190816P00360000', tradingClass='TSLA')
# Error 10197, reqId 349: No market data during competing live session, contract: Option(conId=316990992, symbol='TSLA', lastTradeDateOrContractMonth='20190816', strike=370.0, right='P', multiplier='100', exchange='SMART', currency='USD', localSymbol='TSLA  190816P00370000', tradingClass='TSLA')
# Error 10197, reqId 320: No market data during competing live session, contract: Option(conId=316990802, symbol='TSLA', lastTradeDateOrContractMonth='20190816', strike=225.0, right='P', multiplier='100', exchange='SMART', currency='USD', localSymbol='TSLA  190816P00225000', tradingClass='TSLA')
# Error 10197, reqId 336: No market data during competing live session, contract: Option(conId=316990882, symbol='TSLA', lastTradeDateOrContractMonth='20190816', strike=305.0, right='P', multiplier='100', exchange='SMART', currency='USD', localSymbol='TSLA  190816P00305000', tradingClass='TSLA')
# Error 10197, reqId 319: No market data during competing live session, contract: Option(conId=316990793, symbol='TSLA', lastTradeDateOrContractMonth='20190816', strike=220.0, right='P', multiplier='100', exchange='SMART', currency='USD', localSymbol='TSLA  190816P00220000', tradingClass='TSLA')
# Error 10197, reqId 321: No market data during competing live session, contract: Option(conId=316990808, symbol='TSLA', lastTradeDateOrContractMonth='20190816', strike=230.0, right='P', multiplier='100', exchange='SMART', currency='USD', localSymbol='TSLA  190816P00230000', tradingClass='TSLA')
# Error 10197, reqId 314: No market data during competing live session, contract: Option(conId=316990728, symbol='TSLA', lastTradeDateOrContractMonth='20190816', strike=195.0, right='P', multiplier='100', exchange='SMART', currency='USD', localSymbol='TSLA  190816P00195000', tradingClass='TSLA')
# Started to throttle requests
# Stopped to throttle requests
# Started to throttle requests
# Stopped to throttle requests
# Error 10197, reqId 619: No market data during competing live session, contract: Option(conId=350770107, symbol='TSLA', lastTradeDateOrContractMonth='20190920', strike=290.0, right='C', multiplier='100', exchange='SMART', currency='USD', localSymbol='TSLA  190920C00290000', tradingClass='TSLA')
# Error 10197, reqId 564: No market data during competing live session, contract: Option(conId=350770796, symbol='TSLA', lastTradeDateOrContractMonth='20190920', strike=310.0, right='P', multiplier='100', exchange='SMART', currency='USD', localSymbol='TSLA  190920P00310000', tradingClass='TSLA')
# Error 10197, reqId 576: No market data during competing live session, contract: Option(conId=350770913, symbol='TSLA', lastTradeDateOrContractMonth='20190920', strike=370.0, right='P', multiplier='100', exchange='SMART', currency='USD', localSymbol='TSLA  190920P00370000', tradingClass='TSLA')
# Error 10197, reqId 578: No market data during competing live session, contract: Option(conId=350770933, symbol='TSLA', lastTradeDateOrContractMonth='20190920', strike=380.0, right='P', multiplier='100', exchange='SMART', currency='USD', localSymbol='TSLA  190920P00380000', tradingClass='TSLA')
# Error 10197, reqId 546: No market data during competing live session, contract: Option(conId=351125454, symbol='TSLA', lastTradeDateOrContractMonth='20190920', strike=220.0, right='P', multiplier='100', exchange='SMART', currency='USD', localSymbol='TSLA  190920P00220000', tradingClass='TSLA')
# Error 10197, reqId 594: No market data during competing live session, contract: Option(conId=351125199, symbol='TSLA', lastTradeDateOrContractMonth='20190920', strike=165.0, right='C', multiplier='100', exchange='SMART', currency='USD', localSymbol='TSLA  190920C00165000', tradingClass='TSLA')
# Error 10197, reqId 581: No market data during competing live session, contract: Option(conId=350770975, symbol='TSLA', lastTradeDateOrContractMonth='20190920', strike=395.0, right='P', multiplier='100', exchange='SMART', currency='USD', localSymbol='TSLA  190920P00395000', tradingClass='TSLA')
# Error 10197, reqId 550: No market data during competing live session, contract: Option(conId=351125478, symbol='TSLA', lastTradeDateOrContractMonth='20190920', strike=240.0, right='P', multiplier='100', exchange='SMART', currency='USD', localSymbol='TSLA  190920P00240000', tradingClass='TSLA')
# Error 10197, reqId 606: No market data during competing live session, contract: Option(conId=355135991, symbol='TSLA', lastTradeDateOrContractMonth='20190920', strike=225.0, right='C', multiplier='100', exchange='SMART', currency='USD', localSymbol='TSLA  190920C00225000', tradingClass='TSLA')
# Error 10197, reqId 587: No market data during competing live session, contract: Option(conId=358325080, symbol='TSLA', lastTradeDateOrContractMonth='20190920', strike=130.0, right='C', multiplier='100', exchange='SMART', currency='USD', localSymbol='TSLA  190920C00130000', tradingClass='TSLA')
# Error 10197, reqId 548: No market data during competing live session, contract: Option(conId=351125471, symbol='TSLA', lastTradeDateOrContractMonth='20190920', strike=230.0, right='P', multiplier='100', exchange='SMART', currency='USD', localSymbol='TSLA  190920P00230000', tradingClass='TSLA')
# Error 10197, reqId 570: No market data during competing live session, contract: Option(conId=350770841, symbol='TSLA', lastTradeDateOrContractMonth='20190920', strike=340.0, right='P', multiplier='100', exchange='SMART', currency='USD', localSymbol='TSLA  190920P00340000', tradingClass='TSLA')
# Error 10197, reqId 604: No market data during competing live session, contract: Option(conId=355135977, symbol='TSLA', lastTradeDateOrContractMonth='20190920', strike=215.0, right='C', multiplier='100', exchange='SMART', currency='USD', localSymbol='TSLA  190920C00215000', tradingClass='TSLA')
# Error 10197, reqId 599: No market data during competing live session, contract: Option(conId=351125241, symbol='TSLA', lastTradeDateOrContractMonth='20190920', strike=190.0, right='C', multiplier='100', exchange='SMART', currency='USD', localSymbol='TSLA  190920C00190000', tradingClass='TSLA')
# Error 10197, reqId 549: No market data during competing live session, contract: Option(conId=355136038, symbol='TSLA', lastTradeDateOrContractMonth='20190920', strike=235.0, right='P', multiplier='100', exchange='SMART', currency='USD', localSymbol='TSLA  190920P00235000', tradingClass='TSLA')
# Error 10197, reqId 559: No market data during competing live session, contract: Option(conId=350770733, symbol='TSLA', lastTradeDateOrContractMonth='20190920', strike=285.0, right='P', multiplier='100', exchange='SMART', currency='USD', localSymbol='TSLA  190920P00285000', tradingClass='TSLA')
# Error 10197, reqId 595: No market data during competing live session, contract: Option(conId=351125204, symbol='TSLA', lastTradeDateOrContractMonth='20190920', strike=170.0, right='C', multiplier='100', exchange='SMART', currency='USD', localSymbol='TSLA  190920C00170000', tradingClass='TSLA')
# Error 10197, reqId 580: No market data during competing live session, contract: Option(conId=350770955, symbol='TSLA', lastTradeDateOrContractMonth='20190920', strike=390.0, right='P', multiplier='100', exchange='SMART', currency='USD', localSymbol='TSLA  190920P00390000', tradingClass='TSLA')
# Error 10197, reqId 589: No market data during competing live session, contract: Option(conId=355994912, symbol='TSLA', lastTradeDateOrContractMonth='20190920', strike=140.0, right='C', multiplier='100', exchange='SMART', currency='USD', localSymbol='TSLA  190920C00140000', tradingClass='TSLA')
# Error 10197, reqId 575: No market data during competing live session, contract: Option(conId=350770898, symbol='TSLA', lastTradeDateOrContractMonth='20190920', strike=365.0, right='P', multiplier='100', exchange='SMART', currency='USD', localSymbol='TSLA  190920P00365000', tradingClass='TSLA')
# Error 10197, reqId 597: No market data during competing live session, contract: Option(conId=351125218, symbol='TSLA', lastTradeDateOrContractMonth='20190920', strike=180.0, right='C', multiplier='100', exchange='SMART', currency='USD', localSymbol='TSLA  190920C00180000', tradingClass='TSLA')
# Error 10197, reqId 614: No market data during competing live session, contract: Option(conId=350770022, symbol='TSLA', lastTradeDateOrContractMonth='20190920', strike=265.0, right='C', multiplier='100', exchange='SMART', currency='USD', localSymbol='TSLA  190920C00265000', tradingClass='TSLA')
# Error 10197, reqId 574: No market data during competing live session, contract: Option(conId=350770889, symbol='TSLA', lastTradeDateOrContractMonth='20190920', strike=360.0, right='P', multiplier='100', exchange='SMART', currency='USD', localSymbol='TSLA  190920P00360000', tradingClass='TSLA')
# Error 10197, reqId 543: No market data during competing live session, contract: Option(conId=355136001, symbol='TSLA', lastTradeDateOrContractMonth='20190920', strike=205.0, right='P', multiplier='100', exchange='SMART', currency='USD', localSymbol='TSLA  190920P00205000', tradingClass='TSLA')
# Error 10197, reqId 561: No market data during competing live session, contract: Option(conId=350770763, symbol='TSLA', lastTradeDateOrContractMonth='20190920', strike=295.0, right='P', multiplier='100', exchange='SMART', currency='USD', localSymbol='TSLA  190920P00295000', tradingClass='TSLA')
# Error 10197, reqId 566: No market data during competing live session, contract: Option(conId=350770813, symbol='TSLA', lastTradeDateOrContractMonth='20190920', strike=320.0, right='P', multiplier='100', exchange='SMART', currency='USD', localSymbol='TSLA  190920P00320000', tradingClass='TSLA')
# Error 10197, reqId 609: No market data during competing live session, contract: Option(conId=351125315, symbol='TSLA', lastTradeDateOrContractMonth='20190920', strike=240.0, right='C', multiplier='100', exchange='SMART', currency='USD', localSymbol='TSLA  190920C00240000', tradingClass='TSLA')
# Error 10197, reqId 533: No market data during competing live session, contract: Option(conId=351125341, symbol='TSLA', lastTradeDateOrContractMonth='20190920', strike=155.0, right='P', multiplier='100', exchange='SMART', currency='USD', localSymbol='TSLA  190920P00155000', tradingClass='TSLA')
# Error 10197, reqId 577: No market data during competing live session, contract: Option(conId=350770926, symbol='TSLA', lastTradeDateOrContractMonth='20190920', strike=375.0, right='P', multiplier='100', exchange='SMART', currency='USD', localSymbol='TSLA  190920P00375000', tradingClass='TSLA')
# Error 10197, reqId 600: No market data during competing live session, contract: Option(conId=351125255, symbol='TSLA', lastTradeDateOrContractMonth='20190920', strike=195.0, right='C', multiplier='100', exchange='SMART', currency='USD', localSymbol='TSLA  190920C00195000', tradingClass='TSLA')
# Error 10197, reqId 573: No market data during competing live session, contract: Option(conId=350770875, symbol='TSLA', lastTradeDateOrContractMonth='20190920', strike=355.0, right='P', multiplier='100', exchange='SMART', currency='USD', localSymbol='TSLA  190920P00355000', tradingClass='TSLA')
# Error 10197, reqId 598: No market data during competing live session, contract: Option(conId=351125223, symbol='TSLA', lastTradeDateOrContractMonth='20190920', strike=185.0, right='C', multiplier='100', exchange='SMART', currency='USD', localSymbol='TSLA  190920C00185000', tradingClass='TSLA')
# Error 10197, reqId 568: No market data during competing live session, contract: Option(conId=350770829, symbol='TSLA', lastTradeDateOrContractMonth='20190920', strike=330.0, right='P', multiplier='100', exchange='SMART', currency='USD', localSymbol='TSLA  190920P00330000', tradingClass='TSLA')
# Error 10197, reqId 558: No market data during competing live session, contract: Option(conId=350770708, symbol='TSLA', lastTradeDateOrContractMonth='20190920', strike=280.0, right='P', multiplier='100', exchange='SMART', currency='USD', localSymbol='TSLA  190920P00280000', tradingClass='TSLA')
# Error 10197, reqId 584: No market data during competing live session, contract: Option(conId=350771025, symbol='TSLA', lastTradeDateOrContractMonth='20190920', strike=410.0, right='P', multiplier='100', exchange='SMART', currency='USD', localSymbol='TSLA  190920P00410000', tradingClass='TSLA')
# Error 10197, reqId 569: No market data during competing live session, contract: Option(conId=350770835, symbol='TSLA', lastTradeDateOrContractMonth='20190920', strike=335.0, right='P', multiplier='100', exchange='SMART', currency='USD', localSymbol='TSLA  190920P00335000', tradingClass='TSLA')
# Error 10197, reqId 608: No market data during competing live session, contract: Option(conId=355135992, symbol='TSLA', lastTradeDateOrContractMonth='20190920', strike=235.0, right='C', multiplier='100', exchange='SMART', currency='USD', localSymbol='TSLA  190920C00235000', tradingClass='TSLA')
# Error 10197, reqId 563: No market data during competing live session, contract: Option(conId=350770787, symbol='TSLA', lastTradeDateOrContractMonth='20190920', strike=305.0, right='P', multiplier='100', exchange='SMART', currency='USD', localSymbol='TSLA  190920P00305000', tradingClass='TSLA')
# Error 10197, reqId 612: No market data during competing live session, contract: Option(conId=350769977, symbol='TSLA', lastTradeDateOrContractMonth='20190920', strike=255.0, right='C', multiplier='100', exchange='SMART', currency='USD', localSymbol='TSLA  190920C00255000', tradingClass='TSLA')
# Error 10197, reqId 529: No market data during competing live session, contract: Option(conId=358325268, symbol='TSLA', lastTradeDateOrContractMonth='20190920', strike=135.0, right='P', multiplier='100', exchange='SMART', currency='USD', localSymbol='TSLA  190920P00135000', tradingClass='TSLA')
# Error 10197, reqId 545: No market data during competing live session, contract: Option(conId=355136016, symbol='TSLA', lastTradeDateOrContractMonth='20190920', strike=215.0, right='P', multiplier='100', exchange='SMART', currency='USD', localSymbol='TSLA  190920P00215000', tradingClass='TSLA')
# Error 10197, reqId 579: No market data during competing live session, contract: Option(conId=350770945, symbol='TSLA', lastTradeDateOrContractMonth='20190920', strike=385.0, right='P', multiplier='100', exchange='SMART', currency='USD', localSymbol='TSLA  190920P00385000', tradingClass='TSLA')
# Error 10197, reqId 603: No market data during competing live session, contract: Option(conId=351125280, symbol='TSLA', lastTradeDateOrContractMonth='20190920', strike=210.0, right='C', multiplier='100', exchange='SMART', currency='USD', localSymbol='TSLA  190920C00210000', tradingClass='TSLA')
# Error 10197, reqId 541: No market data during competing live session, contract: Option(conId=351125433, symbol='TSLA', lastTradeDateOrContractMonth='20190920', strike=195.0, right='P', multiplier='100', exchange='SMART', currency='USD', localSymbol='TSLA  190920P00195000', tradingClass='TSLA')
# Error 10197, reqId 611: No market data during competing live session, contract: Option(conId=350769965, symbol='TSLA', lastTradeDateOrContractMonth='20190920', strike=250.0, right='C', multiplier='100', exchange='SMART', currency='USD', localSymbol='TSLA  190920C00250000', tradingClass='TSLA')
# Error 10197, reqId 540: No market data during competing live session, contract: Option(conId=351125427, symbol='TSLA', lastTradeDateOrContractMonth='20190920', strike=190.0, right='P', multiplier='100', exchange='SMART', currency='USD', localSymbol='TSLA  190920P00190000', tradingClass='TSLA')
# Error 10197, reqId 553: No market data during competing live session, contract: Option(conId=350770634, symbol='TSLA', lastTradeDateOrContractMonth='20190920', strike=255.0, right='P', multiplier='100', exchange='SMART', currency='USD', localSymbol='TSLA  190920P00255000', tradingClass='TSLA')
# Error 10197, reqId 536: No market data during competing live session, contract: Option(conId=351125381, symbol='TSLA', lastTradeDateOrContractMonth='20190920', strike=170.0, right='P', multiplier='100', exchange='SMART', currency='USD', localSymbol='TSLA  190920P00170000', tradingClass='TSLA')
# Error 10197, reqId 640: No market data during competing live session, contract: Option(conId=350770429, symbol='TSLA', lastTradeDateOrContractMonth='20190920', strike=395.0, right='C', multiplier='100', exchange='SMART', currency='USD', localSymbol='TSLA  190920C00395000', tradingClass='TSLA')
# Error 10197, reqId 571: No market data during competing live session, contract: Option(conId=350770848, symbol='TSLA', lastTradeDateOrContractMonth='20190920', strike=345.0, right='P', multiplier='100', exchange='SMART', currency='USD', localSymbol='TSLA  190920P00345000', tradingClass='TSLA')
# Error 10197, reqId 555: No market data during competing live session, contract: Option(conId=350770663, symbol='TSLA', lastTradeDateOrContractMonth='20190920', strike=265.0, right='P', multiplier='100', exchange='SMART', currency='USD', localSymbol='TSLA  190920P00265000', tradingClass='TSLA')
# Error 10197, reqId 530: No market data during competing live session, contract: Option(conId=355994927, symbol='TSLA', lastTradeDateOrContractMonth='20190920', strike=140.0, right='P', multiplier='100', exchange='SMART', currency='USD', localSymbol='TSLA  190920P00140000', tradingClass='TSLA')
# Error 10197, reqId 590: No market data during competing live session, contract: Option(conId=355904720, symbol='TSLA', lastTradeDateOrContractMonth='20190920', strike=145.0, right='C', multiplier='100', exchange='SMART', currency='USD', localSymbol='TSLA  190920C00145000', tradingClass='TSLA')
# Error 10197, reqId 613: No market data during competing live session, contract: Option(conId=350770000, symbol='TSLA', lastTradeDateOrContractMonth='20190920', strike=260.0, right='C', multiplier='100', exchange='SMART', currency='USD', localSymbol='TSLA  190920C00260000', tradingClass='TSLA')
# Error 10197, reqId 544: No market data during competing live session, contract: Option(conId=351125444, symbol='TSLA', lastTradeDateOrContractMonth='20190920', strike=210.0, right='P', multiplier='100', exchange='SMART', currency='USD', localSymbol='TSLA  190920P00210000', tradingClass='TSLA')
# Error 10197, reqId 610: No market data during competing live session, contract: Option(conId=350769925, symbol='TSLA', lastTradeDateOrContractMonth='20190920', strike=245.0, right='C', multiplier='100', exchange='SMART', currency='USD', localSymbol='TSLA  190920C00245000', tradingClass='TSLA')
# Error 10197, reqId 585: No market data during competing live session, contract: Option(conId=350771047, symbol='TSLA', lastTradeDateOrContractMonth='20190920', strike=415.0, right='P', multiplier='100', exchange='SMART', currency='USD', localSymbol='TSLA  190920P00415000', tradingClass='TSLA')
# Error 10197, reqId 607: No market data during competing live session, contract: Option(conId=351125297, symbol='TSLA', lastTradeDateOrContractMonth='20190920', strike=230.0, right='C', multiplier='100', exchange='SMART', currency='USD', localSymbol='TSLA  190920C00230000', tradingClass='TSLA')
# Error 10197, reqId 592: No market data during competing live session, contract: Option(conId=351125176, symbol='TSLA', lastTradeDateOrContractMonth='20190920', strike=155.0, right='C', multiplier='100', exchange='SMART', currency='USD', localSymbol='TSLA  190920C00155000', tradingClass='TSLA')
# Error 10197, reqId 596: No market data during competing live session, contract: Option(conId=351125211, symbol='TSLA', lastTradeDateOrContractMonth='20190920', strike=175.0, right='C', multiplier='100', exchange='SMART', currency='USD', localSymbol='TSLA  190920C00175000', tradingClass='TSLA')
# Error 10197, reqId 621: No market data during competing live session, contract: Option(conId=350770130, symbol='TSLA', lastTradeDateOrContractMonth='20190920', strike=300.0, right='C', multiplier='100', exchange='SMART', currency='USD', localSymbol='TSLA  190920C00300000', tradingClass='TSLA')
# Error 10197, reqId 554: No market data during competing live session, contract: Option(conId=350770644, symbol='TSLA', lastTradeDateOrContractMonth='20190920', strike=260.0, right='P', multiplier='100', exchange='SMART', currency='USD', localSymbol='TSLA  190920P00260000', tradingClass='TSLA')
# Error 10197, reqId 551: No market data during competing live session, contract: Option(conId=350770598, symbol='TSLA', lastTradeDateOrContractMonth='20190920', strike=245.0, right='P', multiplier='100', exchange='SMART', currency='USD', localSymbol='TSLA  190920P00245000', tradingClass='TSLA')
# Error 10197, reqId 631: No market data during competing live session, contract: Option(conId=350770286, symbol='TSLA', lastTradeDateOrContractMonth='20190920', strike=350.0, right='C', multiplier='100', exchange='SMART', currency='USD', localSymbol='TSLA  190920C00350000', tradingClass='TSLA')
# Error 10197, reqId 565: No market data during competing live session, contract: Option(conId=350770808, symbol='TSLA', lastTradeDateOrContractMonth='20190920', strike=315.0, right='P', multiplier='100', exchange='SMART', currency='USD', localSymbol='TSLA  190920P00315000', tradingClass='TSLA')
# Error 10197, reqId 591: No market data during competing live session, contract: Option(conId=351631827, symbol='TSLA', lastTradeDateOrContractMonth='20190920', strike=150.0, right='C', multiplier='100', exchange='SMART', currency='USD', localSymbol='TSLA  190920C00150000', tradingClass='TSLA')
# Error 10197, reqId 534: No market data during competing live session, contract: Option(conId=351125355, symbol='TSLA', lastTradeDateOrContractMonth='20190920', strike=160.0, right='P', multiplier='100', exchange='SMART', currency='USD', localSymbol='TSLA  190920P00160000', tradingClass='TSLA')
# Error 10197, reqId 618: No market data during competing live session, contract: Option(conId=350770090, symbol='TSLA', lastTradeDateOrContractMonth='20190920', strike=285.0, right='C', multiplier='100', exchange='SMART', currency='USD', localSymbol='TSLA  190920C00285000', tradingClass='TSLA')
# Error 10197, reqId 601: No market data during competing live session, contract: Option(conId=351125267, symbol='TSLA', lastTradeDateOrContractMonth='20190920', strike=200.0, right='C', multiplier='100', exchange='SMART', currency='USD', localSymbol='TSLA  190920C00200000', tradingClass='TSLA')
# Error 10197, reqId 572: No market data during competing live session, contract: Option(conId=350770858, symbol='TSLA', lastTradeDateOrContractMonth='20190920', strike=350.0, right='P', multiplier='100', exchange='SMART', currency='USD', localSymbol='TSLA  190920P00350000', tradingClass='TSLA')
# Error 10197, reqId 617: No market data during competing live session, contract: Option(conId=350770080, symbol='TSLA', lastTradeDateOrContractMonth='20190920', strike=280.0, right='C', multiplier='100', exchange='SMART', currency='USD', localSymbol='TSLA  190920C00280000', tradingClass='TSLA')
# Error 10197, reqId 538: No market data during competing live session, contract: Option(conId=351125403, symbol='TSLA', lastTradeDateOrContractMonth='20190920', strike=180.0, right='P', multiplier='100', exchange='SMART', currency='USD', localSymbol='TSLA  190920P00180000', tradingClass='TSLA')
# Error 10197, reqId 535: No market data during competing live session, contract: Option(conId=351125360, symbol='TSLA', lastTradeDateOrContractMonth='20190920', strike=165.0, right='P', multiplier='100', exchange='SMART', currency='USD', localSymbol='TSLA  190920P00165000', tradingClass='TSLA')
# Error 10197, reqId 567: No market data during competing live session, contract: Option(conId=350770823, symbol='TSLA', lastTradeDateOrContractMonth='20190920', strike=325.0, right='P', multiplier='100', exchange='SMART', currency='USD', localSymbol='TSLA  190920P00325000', tradingClass='TSLA')
# Error 10197, reqId 588: No market data during competing live session, contract: Option(conId=358325099, symbol='TSLA', lastTradeDateOrContractMonth='20190920', strike=135.0, right='C', multiplier='100', exchange='SMART', currency='USD', localSymbol='TSLA  190920C00135000', tradingClass='TSLA')
# Error 10197, reqId 560: No market data during competing live session, contract: Option(conId=350770753, symbol='TSLA', lastTradeDateOrContractMonth='20190920', strike=290.0, right='P', multiplier='100', exchange='SMART', currency='USD', localSymbol='TSLA  190920P00290000', tradingClass='TSLA')
# Error 10197, reqId 620: No market data during competing live session, contract: Option(conId=350770118, symbol='TSLA', lastTradeDateOrContractMonth='20190920', strike=295.0, right='C', multiplier='100', exchange='SMART', currency='USD', localSymbol='TSLA  190920C00295000', tradingClass='TSLA')
# Error 10197, reqId 583: No market data during competing live session, contract: Option(conId=350771008, symbol='TSLA', lastTradeDateOrContractMonth='20190920', strike=405.0, right='P', multiplier='100', exchange='SMART', currency='USD', localSymbol='TSLA  190920P00405000', tradingClass='TSLA')
# Error 10197, reqId 593: No market data during competing live session, contract: Option(conId=351125189, symbol='TSLA', lastTradeDateOrContractMonth='20190920', strike=160.0, right='C', multiplier='100', exchange='SMART', currency='USD', localSymbol='TSLA  190920C00160000', tradingClass='TSLA')
# Error 10197, reqId 557: No market data during competing live session, contract: Option(conId=350770688, symbol='TSLA', lastTradeDateOrContractMonth='20190920', strike=275.0, right='P', multiplier='100', exchange='SMART', currency='USD', localSymbol='TSLA  190920P00275000', tradingClass='TSLA')
# Error 10197, reqId 643: No market data during competing live session, contract: Option(conId=350770478, symbol='TSLA', lastTradeDateOrContractMonth='20190920', strike=410.0, right='C', multiplier='100', exchange='SMART', currency='USD', localSymbol='TSLA  190920C00410000', tradingClass='TSLA')
# Error 10197, reqId 539: No market data during competing live session, contract: Option(conId=351125410, symbol='TSLA', lastTradeDateOrContractMonth='20190920', strike=185.0, right='P', multiplier='100', exchange='SMART', currency='USD', localSymbol='TSLA  190920P00185000', tradingClass='TSLA')
# Error 10197, reqId 615: No market data during competing live session, contract: Option(conId=350770045, symbol='TSLA', lastTradeDateOrContractMonth='20190920', strike=270.0, right='C', multiplier='100', exchange='SMART', currency='USD', localSymbol='TSLA  190920C00270000', tradingClass='TSLA')
# Error 10197, reqId 562: No market data during competing live session, contract: Option(conId=350770773, symbol='TSLA', lastTradeDateOrContractMonth='20190920', strike=300.0, right='P', multiplier='100', exchange='SMART', currency='USD', localSymbol='TSLA  190920P00300000', tradingClass='TSLA')
# Error 10197, reqId 582: No market data during competing live session, contract: Option(conId=350770994, symbol='TSLA', lastTradeDateOrContractMonth='20190920', strike=400.0, right='P', multiplier='100', exchange='SMART', currency='USD', localSymbol='TSLA  190920P00400000', tradingClass='TSLA')
# Error 10197, reqId 605: No market data during competing live session, contract: Option(conId=351125290, symbol='TSLA', lastTradeDateOrContractMonth='20190920', strike=220.0, right='C', multiplier='100', exchange='SMART', currency='USD', localSymbol='TSLA  190920C00220000', tradingClass='TSLA')
# Error 10197, reqId 531: No market data during competing live session, contract: Option(conId=355904725, symbol='TSLA', lastTradeDateOrContractMonth='20190920', strike=145.0, right='P', multiplier='100', exchange='SMART', currency='USD', localSymbol='TSLA  190920P00145000', tradingClass='TSLA')
# Error 10197, reqId 556: No market data during competing live session, contract: Option(conId=350770678, symbol='TSLA', lastTradeDateOrContractMonth='20190920', strike=270.0, right='P', multiplier='100', exchange='SMART', currency='USD', localSymbol='TSLA  190920P00270000', tradingClass='TSLA')
# Error 10197, reqId 628: No market data during competing live session, contract: Option(conId=350770238, symbol='TSLA', lastTradeDateOrContractMonth='20190920', strike=335.0, right='C', multiplier='100', exchange='SMART', currency='USD', localSymbol='TSLA  190920C00335000', tradingClass='TSLA')
# Error 10197, reqId 637: No market data during competing live session, contract: Option(conId=350770394, symbol='TSLA', lastTradeDateOrContractMonth='20190920', strike=380.0, right='C', multiplier='100', exchange='SMART', currency='USD', localSymbol='TSLA  190920C00380000', tradingClass='TSLA')

# %%
maxshift = 9

arteHedges_upside = []
for expiry_index in range(len(curr_calls.Expiry.drop_duplicates())):
    bias = 'upside'
    possible_pos = art_hedges(curr_calls, curr_puts, curr_price, expiry_index, bias,
                              maxshift = 6, commissions = 0.0266)
    arteHedges_upside.append(possible_pos)

arteHedges_upside = pd.concat(arteHedges_upside,axis = 0)

# %%
arteHedges_downside = []
for expiry_index in range(len(curr_calls.Expiry.drop_duplicates())):
    bias = 'downside'
    possible_pos = art_hedges(curr_calls, curr_puts, curr_price, expiry_index, bias,
                              maxshift = 6, commissions = 0.0266)
    arteHedges_downside.append(possible_pos)
arteHedges_downside = pd.concat(arteHedges_downside,axis = 0)

arteHedges_upside['ReturnOnRisk'] = abs(arteHedges_upside.Credit/arteHedges_upside.MaxLoss)
arteHedges_downside['ReturnOnRisk'] = abs(arteHedges_downside.Credit/arteHedges_downside.MaxLoss)

# %%
arteHedges_upside[(arteHedges_upside.Short_Put_Strike < curr_price) &
                  (arteHedges_upside.Short_Put_Strike > 0.001)].sort_values(['Maturity', 
                                                                             'ReturnOnRisk'], ascending = False)
# Out:
#     Short_Put_Strike  Long_Put_Strike  Long_Call_Strike  Delta  Gamma  Theta  \
# 20          225.0000         125.0000          415.0000 0.3170 0.0001 0.0022
#
#      Vega  time_remaining  Credit     MaxLoss  BreakEven   Maturity  \
# 20 0.0317          0.9544 12.9851 -8,701.4900   212.0149 2019-09-20
#
#     ReturnOnRisk
# 20        0.0015

# %%
arteHedges_downside[(arteHedges_downside.Short_Call_Strike > curr_price) &
                    (arteHedges_downside.Short_Call_Strike > 0.001)].sort_values(['Maturity', 
                                                                               'ReturnOnRisk'], ascending = False)
# Out:
# Empty DataFrame
# Columns: [Short_Call_Strike, Long_Call_Strike, Long_Put_Strike, Delta, Gamma, Theta, Vega, time_remaining, Credit, MaxLoss, BreakEven, Maturity, ReturnOnRisk]
# Index: []

# %%
ib.disconnect()
