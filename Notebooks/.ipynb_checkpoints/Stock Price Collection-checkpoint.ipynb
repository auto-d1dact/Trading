# %%
# -*- coding: utf-8 -*-
"""
Created on Tue Dec  4 15:11:48 2018

@author: Fang
"""

import pandas as pd
import numpy as np
from sqlalchemy import *
from sqlalchemy import create_engine
import os
import datetime as dt
import time
import urllib.request as urlreq
import json

module_dir = 'C:\\Users\\Fang\\Desktop\\Python Trading\\Trading\\Trading\Modules\\DataCollection'
os.chdir(module_dir)


def hist_prices(ticker, start_date, end_date = dt.datetime.today()):
    start_date_unix = int(start_date.timestamp())
    end_date = dt.datetime.today()
    end_date_unix = int(end_date.timestamp())

    hist_price_url = 'https://query1.finance.yahoo.com/v8/finance/chart/{0}?symbol={0}&period1={1}&period2={2}&interval=1d'.format(ticker,start_date_unix,end_date_unix)
    #print(hist_price_url)
    with urlreq.urlopen(hist_price_url) as url:
        data = json.loads(url.read().decode())
        hist_prices = pd.DataFrame({**data['chart']['result'][0]['indicators']['quote'][0], **data['chart']['result'][0]['indicators']['adjclose'][0]},
                                        index = [dt.datetime.utcfromtimestamp(int(x)).date() for x in 
                                                 data['chart']['result'][0]['timestamp']])
        hist_prices.index = pd.to_datetime(hist_prices.index)
    
    return hist_prices

start_date = dt.datetime(1999,1,1)

# Initializing Stock Universe
os.chdir('..\\')
os.chdir('..\\')
os.chdir('..\\Data\\Stock Universe')
#tsx = pd.read_csv('TSX.csv')['Symbol']#.tolist()
nyse = pd.read_csv('NYSE.csv')['Symbol']#.tolist()
nasdaq = pd.read_csv('NASDAQ.csv')['Symbol']#.tolist()
amex = pd.read_csv('AMEX.csv')['Symbol']#.tolist()
us_names = pd.concat([nyse,nasdaq,amex]).drop_duplicates().values.tolist()

del nyse, nasdaq, amex

dbs_dir = 'C:\\Users\\Fang\\Desktop\\Python Trading\\Trading\\Data\\DBs'

os.chdir(dbs_dir)

earn_engine = create_engine('sqlite:///earningsHistory.db', echo=False)
yahoo_engine = create_engine('sqlite:///yahoo.db', echo = False)

prices_db_dir = 'D:\\Price Data'
os.chdir(prices_db_dir)
hisprices_engine = create_engine('sqlite:///histprices.db', echo = False)

run_update = True

def return_profiles(ticker):
    start_time = time.time()
    prices_query = 'SELECT Date, adjclose FROM historicalPrices WHERE Underlying = "{}"'.format(ticker)
    curr_closes = pd.read_sql_query(prices_query, con=hisprices_engine, index_col = 'Date')
    
    if len(curr_closes) == 0:
        return (ticker,)*8
    curr_closes.index = pd.to_datetime(curr_closes.index)

    yahoo_db_query = 'SELECT Underlying, industry, sector FROM profiles WHERE Underlying = "{}"'.format(ticker)
    curr_yahoo_db = pd.read_sql_query(yahoo_db_query, con = yahoo_engine, index_col = 'Underlying').reset_index().drop_duplicates('Underlying').reset_index(drop = True)
    if len(curr_yahoo_db) == 0:
        curr_yahoo_db = pd.DataFrame({'Underlying': [ticker], 'industry': [np.nan], 'sector': [np.nan]})
        
    quarter_mapping = {1: 1, 2:1, 3:1, 
                       4:2, 5:2, 6:2,
                       7:3, 8:3, 9:3,
                       10:4, 11:4, 12:4}

    curr_closes['year'] = curr_closes.index.year
    curr_closes['month'] = curr_closes.index.month
    curr_closes['boy'] = curr_closes['year'] - curr_closes['year'].shift(1)
    curr_closes['bom'] = curr_closes['month'] - curr_closes['month'].shift(1)
    curr_closes['boq'] = curr_closes['month'] % 3
    curr_closes['quarter'] = curr_closes['month'].replace(quarter_mapping)
    curr_closes['Q'] = curr_closes['year'].apply(lambda x: str(x)) + ' Q' + curr_closes['quarter'].apply(lambda x: str(x))
    curr_closes['dailyReturns'] = curr_closes['adjclose'].pct_change()

    annual_returns = curr_closes[curr_closes['boy'] != 0][['adjclose','year']]
    annual_returns['adjclose'] = annual_returns['adjclose'].pct_change().shift(-1)
    annual_returns = annual_returns.set_index('year').dropna()
    annual_returns.columns = ['return']

    quarterly_returns = curr_closes[curr_closes['bom'] != 0][['adjclose','boq','Q']]
    quarterly_returns = quarterly_returns[quarterly_returns['boq'] == 1][['adjclose','Q']]
    quarterly_returns['adjclose'] = quarterly_returns['adjclose'].pct_change().shift(-1)
    quarterly_returns = quarterly_returns.set_index('Q').dropna()
    quarterly_returns.columns = ['return']

    def risk_profiles(returns_df, curr_closes, curr_yahoo_db):
        maxDrawDowns = pd.DataFrame(index = returns_df.index, columns = ['maxDrawDowns'])
        downsideVols = pd.DataFrame(index = returns_df.index, columns = ['downsideVols'])
        returnVols = pd.DataFrame(index = returns_df.index, columns = ['vol'])

        for period in returns_df.index:
            curr_year = curr_closes[curr_closes[returns_df.index.name] == period][['adjclose','dailyReturns']]
            curr_year['cumReturns'] = (curr_year['dailyReturns'] + 1).cumprod()
            curr_year['rollingMax'] = curr_year['cumReturns'].expanding(min_periods=1).max()
            curr_year['drawDown'] = curr_year['cumReturns']/curr_year['rollingMax'] - 1
            curr_downside = curr_year[curr_year['dailyReturns'] < 0]

            maxDrawDowns.loc[period,'maxDrawDowns'] = curr_year['drawDown'].min()
            downsideVols.loc[period,'downsideVols'] = curr_downside['dailyReturns'].std()*np.sqrt(len(curr_downside))
            returnVols.loc[period, 'vol'] = curr_year['dailyReturns'].std()*np.sqrt(252)

        maxDrawDowns, downsideVols, returnVols = maxDrawDowns.T, downsideVols.T, returnVols.T
        maxDrawDowns.index, downsideVols.index, returnVols.index = curr_yahoo_db.Underlying, curr_yahoo_db.Underlying, curr_yahoo_db.Underlying
        maxDrawDowns[['industry','sector']], downsideVols[['industry','sector']], returnVols[['industry','sector']] = curr_yahoo_db[['industry','sector']], curr_yahoo_db[['industry','sector']], curr_yahoo_db[['industry','sector']]
        maxDrawDowns[['industry','sector']], downsideVols[['industry','sector']], returnVols[['industry','sector']] = curr_yahoo_db.iloc[:,1:].values, curr_yahoo_db.iloc[:,1:].values, curr_yahoo_db.iloc[:,1:].values
        return  maxDrawDowns, downsideVols, returnVols

    annualDDs, annualDownsides, annualVols = risk_profiles(annual_returns, curr_closes, curr_yahoo_db)
    quarterlyDDs, quarterlyDownsides, quarterlyVols = risk_profiles(quarterly_returns, curr_closes, curr_yahoo_db)
    annual_returns, quarterly_returns = annual_returns.T, quarterly_returns.T
    annual_returns.index, quarterly_returns.index = curr_yahoo_db.Underlying, curr_yahoo_db.Underlying
    annual_returns[['industry','sector']], quarterly_returns[['industry','sector']] = curr_yahoo_db[['industry','sector']], curr_yahoo_db[['industry','sector']]
    annual_returns[['industry','sector']], quarterly_returns[['industry','sector']] = curr_yahoo_db.iloc[:,1:].values, curr_yahoo_db.iloc[:,1:].values

    print("Completed in %s seconds" % (time.time() - start_time))
    
    return annual_returns, annualDDs, annualDownsides, annualVols, quarterly_returns, quarterlyDDs, quarterlyDownsides, quarterlyVols



if run_update:
    
    start_time = time.time()
    i = 0
    total_length = len(us_names)
    for ticker in us_names:
        

        try:
            curr_hist_prices = hist_prices(ticker, start_date)
            curr_hist_prices = curr_hist_prices.sort_index(ascending = True)
            curr_hist_prices['Underlying'] = ticker
        except:
            print('Failed prices for {}'.format(ticker))
            print('{0:.2f}% Completed'.format(i/total_length*100))
            continue

        table_in_db = True

        try:
            query = 'SELECT Date, Underlying FROM historicalPrices WHERE Underlying = "{}"'.format(ticker)
            curr_hist_db = pd.read_sql_query(query, con=hisprices_engine, index_col = 'Date').tail(1)
            curr_hist_db.index = pd.to_datetime(curr_hist_db.index)
        except:
            table_in_db = False

        if table_in_db and len(curr_hist_db) != 0:
            latest_date_in_db = curr_hist_db.index.tolist()[0]
            curr_hist_prices = curr_hist_prices[curr_hist_prices.index > latest_date_in_db]

        curr_hist_prices.to_sql('historicalPrices', con=hisprices_engine, 
                                if_exists='append', index_label = 'Date')
        i += 1
        print('{0:.2f}% Completed'.format(i/total_length*100))

    print("Completed in %s seconds" % (time.time() - start_time))
# Out:
# 0.01% Completed
# 0.02% Completed
# 0.03% Completed
# 0.05% Completed
# 0.06% Completed
# 0.07% Completed
# 0.08% Completed
# 0.09% Completed
# 0.10% Completed
# 0.12% Completed
# 0.13% Completed
# 0.14% Completed
# 0.15% Completed
# 0.16% Completed
# 0.17% Completed
# Failed prices for ABR-A
# 0.17% Completed
# Failed prices for ABR-B
# 0.17% Completed
# Failed prices for ABR-C
# 0.17% Completed
# 0.18% Completed
# 0.20% Completed
# 0.21% Completed
# 0.22% Completed
# 0.23% Completed
# 0.24% Completed
# 0.25% Completed
# 0.27% Completed
# 0.28% Completed
# 0.29% Completed
# 0.30% Completed
# 0.31% Completed
# 0.32% Completed
# 0.33% Completed
# 0.35% Completed
# 0.36% Completed
# 0.37% Completed
# 0.38% Completed
# 0.39% Completed
# 0.40% Completed
# 0.42% Completed
# 0.43% Completed
# 0.44% Completed
# 0.45% Completed
# 0.46% Completed
# 0.47% Completed
# 0.48% Completed
# 0.50% Completed
# 0.51% Completed
# 0.52% Completed
# 0.53% Completed
# 0.54% Completed
# 0.55% Completed
# 0.57% Completed
# 0.58% Completed
# 0.59% Completed
# 0.60% Completed
# Failed prices for AFS-A
# 0.60% Completed
# Failed prices for AFS-B
# 0.60% Completed
# Failed prices for AFS-C
# 0.60% Completed
# Failed prices for AFS-D
# 0.60% Completed
# Failed prices for AFS-E
# 0.60% Completed
# Failed prices for AFS-F
# 0.60% Completed
# 0.61% Completed
# 0.62% Completed
# 0.63% Completed
# 0.65% Completed
# 0.66% Completed
# 0.67% Completed
# 0.68% Completed
# 0.69% Completed
# 0.70% Completed
# 0.72% Completed
# Failed prices for AGM-B
# 0.72% Completed
# Failed prices for AGM-C
# 0.72% Completed
# Failed prices for AGM.A
# 0.72% Completed
# 0.73% Completed
# 0.74% Completed
# Failed prices for AGO-B
# 0.74% Completed
# Failed prices for AGO-E
# 0.74% Completed
# Failed prices for AGO-F
# 0.74% Completed
# 0.75% Completed
# 0.76% Completed
# 0.77% Completed
# 0.78% Completed
# 0.80% Completed
# 0.81% Completed
# 0.82% Completed
# Failed prices for AHL-C
# 0.82% Completed
# Failed prices for AHL-D
# 0.82% Completed
# 0.83% Completed
# Failed prices for AHT-D
# 0.83% Completed
# Failed prices for AHT-F
# 0.83% Completed
# Failed prices for AHT-G
# 0.83% Completed
# Failed prices for AHT-H
# 0.83% Completed
# Failed prices for AHT-I
# 0.83% Completed
# 0.84% Completed
# Failed prices for AI-B
# 0.84% Completed
# 0.85% Completed
# 0.87% Completed
# 0.88% Completed
# Failed prices for AIG.W
# 0.88% Completed
# 0.89% Completed
# 0.90% Completed
# 0.91% Completed
# 0.92% Completed
# Failed prices for AIV-A
# 0.92% Completed
# 0.94% Completed
# 0.95% Completed
# 0.96% Completed
# 0.97% Completed
# 0.98% Completed
# 0.99% Completed
# 1.00% Completed
# 1.02% Completed
# Failed prices for AKO.A
# 1.02% Completed
# Failed prices for AKO.B
# 1.02% Completed
# 1.03% Completed
# 1.04% Completed
# 1.05% Completed
# 1.06% Completed
# 1.07% Completed
# 1.09% Completed
# 1.10% Completed
# 1.11% Completed
# 1.12% Completed
# 1.13% Completed
# Failed prices for ALL-A
# 1.13% Completed
# Failed prices for ALL-B
# 1.13% Completed
# Failed prices for ALL-C
# 1.13% Completed
# Failed prices for ALL-D
# 1.13% Completed
# Failed prices for ALL-E
# 1.13% Completed
# Failed prices for ALL-F
# 1.13% Completed
# Failed prices for ALL-G
# 1.13% Completed
# Failed prices for ALL-Y
# 1.13% Completed
# 1.14% Completed
# 1.15% Completed
# Failed prices for ALP-Q
# 1.15% Completed
# 1.17% Completed
# 1.18% Completed
# 1.19% Completed
# 1.20% Completed
# 1.21% Completed
# 1.22% Completed
# 1.24% Completed
# 1.25% Completed
# 1.26% Completed
# 1.27% Completed
# Failed prices for AMH-D
# 1.27% Completed
# Failed prices for AMH-E
# 1.27% Completed
# Failed prices for AMH-F
# 1.27% Completed
# Failed prices for AMH-G
# 1.27% Completed
# 1.28% Completed
# 1.29% Completed
# 1.30% Completed
# 1.32% Completed
# 1.33% Completed
# 1.34% Completed
# 1.35% Completed
# 1.36% Completed
# 1.37% Completed
# Failed prices for ANDV
# 1.37% Completed
# 1.39% Completed
# 1.40% Completed
# 1.41% Completed
# 1.42% Completed
# 1.43% Completed
# Failed prices for ANH-A
# 1.43% Completed
# Failed prices for ANH-B
# 1.43% Completed
# Failed prices for ANH-C
# 1.43% Completed
# 1.44% Completed
# 1.45% Completed
# 1.47% Completed
# 1.48% Completed
# 1.49% Completed
# 1.50% Completed
# 1.51% Completed
# 1.52% Completed
# 1.54% Completed
# 1.55% Completed
# 1.56% Completed
# 1.57% Completed
# 1.58% Completed
# 1.59% Completed
# 1.60% Completed
# 1.62% Completed
# Failed prices for APO-A
# 1.62% Completed
# Failed prices for APO-B
# 1.62% Completed
# 1.63% Completed
# 1.64% Completed
# 1.65% Completed
# 1.66% Completed
# 1.67% Completed
# 1.69% Completed
# 1.70% Completed
# 1.71% Completed
# 1.72% Completed
# 1.73% Completed
# 1.74% Completed
# 1.75% Completed
# 1.77% Completed
# 1.78% Completed
# 1.79% Completed
# 1.80% Completed
# Failed prices for ARE-A
# 1.80% Completed
# Failed prices for ARE-D
# 1.80% Completed
# 1.81% Completed
# 1.82% Completed
# 1.84% Completed
# 1.85% Completed
# Failed prices for ARI-C
# 1.85% Completed
# 1.86% Completed
# 1.87% Completed
# 1.88% Completed
# 1.89% Completed
# 1.90% Completed
# 1.92% Completed
# Failed prices for ARR-A
# 1.92% Completed
# Failed prices for ARR-B
# 1.92% Completed
# 1.93% Completed
# 1.94% Completed
# 1.95% Completed
# Failed prices for ASB-C
# 1.95% Completed
# Failed prices for ASB-D
# 1.95% Completed
# 1.96% Completed
# 1.97% Completed
# 1.99% Completed
# 2.00% Completed
# 2.01% Completed
# 2.02% Completed
# 2.03% Completed
# 2.04% Completed
# 2.05% Completed
# 2.07% Completed
# 2.08% Completed
# 2.09% Completed
# 2.10% Completed
# 2.11% Completed
# 2.12% Completed
# 2.14% Completed
# 2.15% Completed
# 2.16% Completed
# 2.17% Completed
# 2.18% Completed
# 2.19% Completed
# 2.20% Completed
# 2.22% Completed
# 2.23% Completed
# 2.24% Completed
# 2.25% Completed
# 2.26% Completed
# 2.27% Completed
# 2.29% Completed
# 2.30% Completed
# 2.31% Completed
# 2.32% Completed
# 2.33% Completed
# 2.34% Completed
# 2.35% Completed
# 2.37% Completed
# 2.38% Completed
# 2.39% Completed
# 2.40% Completed
# 2.41% Completed
# 2.42% Completed
# 2.44% Completed
# 2.45% Completed
# 2.46% Completed
# 2.47% Completed
# 2.48% Completed
# Failed prices for AXS-D
# 2.48% Completed
# Failed prices for AXS-E
# 2.48% Completed
# 2.49% Completed
# 2.50% Completed
# 2.52% Completed
# 2.53% Completed
# 2.54% Completed
# 2.55% Completed
# 2.56% Completed
# 2.57% Completed
# 2.59% Completed
# 2.60% Completed
# 2.61% Completed
# 2.62% Completed
# 2.63% Completed
# Failed prices for BAC-A
# 2.63% Completed
# Failed prices for BAC-B
# 2.63% Completed
# Failed prices for BAC-C
# 2.63% Completed
# Failed prices for BAC-E
# 2.63% Completed
# Failed prices for BAC-K
# 2.63% Completed
# Failed prices for BAC-L
# 2.63% Completed
# Failed prices for BAC-W
# 2.63% Completed
# Failed prices for BAC-Y
# 2.63% Completed
# Failed prices for BAC.A
# 2.63% Completed
# Failed prices for BAC.B
# 2.63% Completed
# 2.64% Completed
# 2.65% Completed
# 2.67% Completed
# 2.68% Completed
# Failed prices for BAN-D
# 2.68% Completed
# Failed prices for BAN-E
# 2.68% Completed
# 2.69% Completed
# 2.70% Completed
# 2.71% Completed
# 2.72% Completed
# 2.74% Completed
# 2.75% Completed
# 2.76% Completed
# 2.77% Completed
# 2.78% Completed
# 2.79% Completed
# 2.81% Completed
# 2.82% Completed
# 2.83% Completed
# Failed prices for BBT-D
# 2.83% Completed
# Failed prices for BBT-E
# 2.83% Completed
# Failed prices for BBT-F
# 2.83% Completed
# Failed prices for BBT-G
# 2.83% Completed
# Failed prices for BBT-H
# 2.83% Completed
# 2.84% Completed
# 2.85% Completed
# 2.86% Completed
# 2.87% Completed
# 2.89% Completed
# 2.90% Completed
# 2.91% Completed
# 2.92% Completed
# 2.93% Completed
# 2.94% Completed
# 2.96% Completed
# 2.97% Completed
# 2.98% Completed
# Failed prices for BCS-D
# 2.98% Completed
# 2.99% Completed
# 3.00% Completed
# Failed prices for BDC-B
# 3.00% Completed
# 3.01% Completed
# 3.02% Completed
# 3.04% Completed
# 3.05% Completed
# 3.06% Completed
# 3.07% Completed
# 3.08% Completed
# 3.09% Completed
# 3.11% Completed
# 3.12% Completed
# Failed prices for BF.A
# 3.12% Completed
# Failed prices for BF.B
# 3.12% Completed
# 3.13% Completed
# 3.14% Completed
# 3.15% Completed
# 3.16% Completed
# 3.17% Completed
# Failed prices for BFS-C
# 3.17% Completed
# Failed prices for BFS-D
# 3.17% Completed
# 3.19% Completed
# 3.20% Completed
# 3.21% Completed
# 3.22% Completed
# 3.23% Completed
# 3.24% Completed
# 3.26% Completed
# 3.27% Completed
# 3.28% Completed
# 3.29% Completed
# 3.30% Completed
# 3.31% Completed
# 3.32% Completed
# 3.34% Completed
# Failed prices for BH.A
# 3.34% Completed
# 3.35% Completed
# 3.36% Completed
# 3.37% Completed
# 3.38% Completed
# 3.39% Completed
# 3.41% Completed
# 3.42% Completed
# Failed prices for BHR-B
# 3.42% Completed
# 3.43% Completed
# 3.44% Completed
# 3.45% Completed
# 3.46% Completed
# 3.47% Completed
# 3.49% Completed
# Failed prices for BIO.B
# 3.49% Completed
# 3.50% Completed
# 3.51% Completed
# 3.52% Completed
# 3.53% Completed
# 3.54% Completed
# 3.56% Completed
# Failed prices for BK-C
# 3.56% Completed
# 3.57% Completed
# 3.58% Completed
# 3.59% Completed
# 3.60% Completed
# 3.61% Completed
# 3.62% Completed
# 3.64% Completed
# 3.65% Completed
# 3.66% Completed
# 3.67% Completed
# 3.68% Completed
# 3.69% Completed
# 3.71% Completed
# 3.72% Completed
# 3.73% Completed
# 3.74% Completed
# 3.75% Completed
# 3.76% Completed
# 3.77% Completed
# 3.79% Completed
# Failed prices for BML-G
# 3.79% Completed
# Failed prices for BML-H
# 3.79% Completed
# Failed prices for BML-J
# 3.79% Completed
# Failed prices for BML-L
# 3.79% Completed
# 3.80% Completed
# 3.81% Completed
# 3.82% Completed
# 3.83% Completed
# 3.84% Completed
# 3.86% Completed
# 3.87% Completed
# 3.88% Completed
# 3.89% Completed
# 3.90% Completed
# 3.91% Completed
# 3.92% Completed
# 3.94% Completed
# 3.95% Completed
# 3.96% Completed
# 3.97% Completed
# 3.98% Completed
# 3.99% Completed
# 4.01% Completed
# 4.02% Completed
# 4.03% Completed
# Failed prices for BRK.A
# 4.03% Completed
# Failed prices for BRK.B
# 4.03% Completed
# 4.04% Completed
# 4.05% Completed
# 4.06% Completed
# 4.07% Completed
# 4.09% Completed
# 4.10% Completed
# 4.11% Completed
# 4.12% Completed
# 4.13% Completed
# 4.14% Completed
# 4.16% Completed
# 4.17% Completed
# 4.18% Completed
# 4.19% Completed
# 4.20% Completed
# 4.21% Completed
# 4.22% Completed
# 4.24% Completed
# 4.25% Completed
# 4.26% Completed
# 4.27% Completed
# 4.28% Completed
# 4.29% Completed
# 4.31% Completed
# 4.32% Completed
# 4.33% Completed
# 4.34% Completed
# 4.35% Completed
# 4.36% Completed
# 4.37% Completed
# 4.39% Completed
# 4.40% Completed
# 4.41% Completed
# 4.42% Completed
# 4.43% Completed
# 4.44% Completed
# 4.46% Completed
# 4.47% Completed
# 4.48% Completed
# 4.49% Completed
# 4.50% Completed
# Failed prices for BXP-B
# 4.50% Completed
# 4.51% Completed
# 4.52% Completed
# 4.54% Completed
# 4.55% Completed
# 4.56% Completed
# 4.57% Completed
# 4.58% Completed
# Failed prices for C-C
# 4.58% Completed
# Failed prices for C-J
# 4.58% Completed
# Failed prices for C-K
# 4.58% Completed
# Failed prices for C-L
# 4.58% Completed
# Failed prices for C-N
# 4.58% Completed
# Failed prices for C-S
# 4.58% Completed
# Failed prices for C.A
# 4.58% Completed
# 4.59% Completed
# 4.61% Completed
# 4.62% Completed
# 4.63% Completed
# 4.64% Completed
# 4.65% Completed
# 4.66% Completed
# 4.68% Completed
# 4.69% Completed
# Failed prices for CAI-A
# 4.69% Completed
# Failed prices for CAI-B
# 4.69% Completed
# 4.70% Completed
# 4.71% Completed
# 4.72% Completed
# 4.73% Completed
# 4.74% Completed
# 4.76% Completed
# 4.77% Completed
# 4.78% Completed
# 4.79% Completed
# 4.80% Completed
# 4.81% Completed
# Failed prices for CBB-B
# 4.81% Completed
# 4.83% Completed
# 4.84% Completed
# 4.85% Completed
# 4.86% Completed
# Failed prices for CBL-D
# 4.86% Completed
# Failed prices for CBL-E
# 4.86% Completed
# 4.87% Completed
# 4.88% Completed
# 4.89% Completed
# 4.91% Completed
# 4.92% Completed
# Failed prices for CBS.A
# 4.92% Completed
# 4.93% Completed
# 4.94% Completed
# 4.95% Completed
# 4.96% Completed
# 4.98% Completed
# Failed prices for CCC.U
# 4.98% Completed
# 4.99% Completed
# 5.00% Completed
# Failed prices for CCI-A
# 5.00% Completed
# 5.01% Completed
# 5.02% Completed
# 5.03% Completed
# 5.04% Completed
# 5.06% Completed
# 5.07% Completed
# 5.08% Completed
# 5.09% Completed
# 5.10% Completed
# 5.11% Completed
# 5.13% Completed
# 5.14% Completed
# 5.15% Completed
# Failed prices for CDR-B
# 5.15% Completed
# Failed prices for CDR-C
# 5.15% Completed
# 5.16% Completed
# 5.17% Completed
# 5.18% Completed
# 5.19% Completed
# 5.21% Completed
# 5.22% Completed
# 5.23% Completed
# 5.24% Completed
# 5.25% Completed
# 5.26% Completed
# 5.28% Completed
# 5.29% Completed
# 5.30% Completed
# 5.31% Completed
# Failed prices for CFR-A
# 5.31% Completed
# 5.32% Completed
# 5.33% Completed
# 5.34% Completed
# 5.36% Completed
# 5.37% Completed
# 5.38% Completed
# 5.39% Completed
# 5.40% Completed
# 5.41% Completed
# 5.43% Completed
# 5.44% Completed
# 5.45% Completed
# Failed prices for CHK-D
# 5.45% Completed
# 5.46% Completed
# 5.47% Completed
# Failed prices for CHM-A
# 5.47% Completed
# 5.48% Completed
# 5.49% Completed
# 5.51% Completed
# 5.52% Completed
# 5.53% Completed
# 5.54% Completed
# 5.55% Completed
# 5.56% Completed
# 5.58% Completed
# 5.59% Completed
# 5.60% Completed
# Failed prices for CIC.U
# 5.60% Completed
# Failed prices for CIC.W
# 5.60% Completed
# 5.61% Completed
# 5.62% Completed
# 5.63% Completed
# Failed prices for CIG.C
# 5.63% Completed
# 5.64% Completed
# 5.66% Completed
# Failed prices for CIM-A
# 5.66% Completed
# Failed prices for CIM-B
# 5.66% Completed
# 5.67% Completed
# 5.68% Completed
# Failed prices for CIO-A
# 5.68% Completed
# 5.69% Completed
# 5.70% Completed
# 5.71% Completed
# 5.73% Completed
# 5.74% Completed
# 5.75% Completed
# 5.76% Completed
# 5.77% Completed
# 5.78% Completed
# 5.79% Completed
# 5.81% Completed
# 5.82% Completed
# 5.83% Completed
# 5.84% Completed
# 5.85% Completed
# Failed prices for CLN-B
# 5.85% Completed
# Failed prices for CLN-E
# 5.85% Completed
# Failed prices for CLN-G
# 5.85% Completed
# Failed prices for CLN-H
# 5.85% Completed
# Failed prices for CLN-I
# 5.85% Completed
# Failed prices for CLN-J
# 5.85% Completed
# 5.86% Completed
# 5.88% Completed
# 5.89% Completed
# 5.90% Completed
# 5.91% Completed
# 5.92% Completed
# 5.93% Completed
# 5.94% Completed
# 5.96% Completed
# Failed prices for CMA.W
# 5.96% Completed
# 5.97% Completed
# 5.98% Completed
# 5.99% Completed
# 6.00% Completed
# 6.01% Completed
# 6.03% Completed
# Failed prices for CMO-E
# 6.03% Completed
# 6.04% Completed
# Failed prices for CMR-B
# 6.04% Completed
# Failed prices for CMR-C
# 6.04% Completed
# Failed prices for CMR-D
# 6.04% Completed
# Failed prices for CMR-E
# 6.04% Completed
# 6.05% Completed
# 6.06% Completed
# Failed prices for CMS-B
# 6.06% Completed
# 6.07% Completed
# 6.08% Completed
# 6.09% Completed
# 6.11% Completed
# 6.12% Completed
# 6.13% Completed
# 6.14% Completed
# 6.15% Completed
# 6.16% Completed
# 6.18% Completed
# 6.19% Completed
# 6.20% Completed
# 6.21% Completed
# 6.22% Completed
# 6.23% Completed
# 6.24% Completed
# Failed prices for COD-A
# 6.24% Completed
# Failed prices for COD-B
# 6.24% Completed
# 6.26% Completed
# 6.27% Completed
# 6.28% Completed
# Failed prices for COF-C
# 6.28% Completed
# Failed prices for COF-D
# 6.28% Completed
# Failed prices for COF-F
# 6.28% Completed
# Failed prices for COF-G
# 6.28% Completed
# Failed prices for COF-H
# 6.28% Completed
# Failed prices for COF-P
# 6.28% Completed
# Failed prices for COF.W
# 6.28% Completed
# 6.29% Completed
# 6.30% Completed
# 6.31% Completed
# 6.33% Completed
# 6.34% Completed
# 6.35% Completed
# Failed prices for COR-Z
# 6.35% Completed
# 6.36% Completed
# 6.37% Completed
# Failed prices for COTV
# 6.37% Completed
# 6.38% Completed
# 6.40% Completed
# 6.41% Completed
# 6.42% Completed
# 6.43% Completed
# 6.44% Completed
# Failed prices for CPE-A
# 6.44% Completed
# 6.45% Completed
# 6.46% Completed
# 6.48% Completed
# 6.49% Completed
# 6.50% Completed
# 6.51% Completed
# 6.52% Completed
# 6.53% Completed
# 6.55% Completed
# 6.56% Completed
# Failed prices for CRD.A
# 6.56% Completed
# Failed prices for CRD.B
# 6.56% Completed
# 6.57% Completed
# 6.58% Completed
# 6.59% Completed
# 6.60% Completed
# 6.61% Completed
# 6.63% Completed
# 6.64% Completed
# 6.65% Completed
# 6.66% Completed
# 6.67% Completed
# 6.68% Completed
# 6.70% Completed
# 6.71% Completed
# 6.72% Completed
# 6.73% Completed
# 6.74% Completed
# 6.75% Completed
# 6.76% Completed
# 6.78% Completed
# 6.79% Completed
# 6.80% Completed
# 6.81% Completed
# 6.82% Completed
# 6.83% Completed
# 6.85% Completed
# 6.86% Completed
# 6.87% Completed
# 6.88% Completed
# 6.89% Completed
# 6.90% Completed
# 6.91% Completed
# 6.93% Completed
# Failed prices for CUB-C
# 6.93% Completed
# Failed prices for CUB-D
# 6.93% Completed
# Failed prices for CUB-E
# 6.93% Completed
# Failed prices for CUB-F
# 6.93% Completed
# 6.94% Completed
# 6.95% Completed
# 6.96% Completed
# 6.97% Completed
# 6.98% Completed
# 7.00% Completed
# 7.01% Completed
# 7.02% Completed
# 7.03% Completed
# Failed prices for CVG
# 7.03% Completed
# 7.04% Completed
# 7.05% Completed
# 7.06% Completed
# 7.08% Completed
# 7.09% Completed
# 7.10% Completed
# 7.11% Completed
# 7.12% Completed
# 7.13% Completed
# 7.15% Completed
# 7.16% Completed
# 7.17% Completed
# 7.18% Completed
# 7.19% Completed
# 7.20% Completed
# 7.21% Completed
# 7.23% Completed
# 7.24% Completed
# 7.25% Completed
# 7.26% Completed
# 7.27% Completed
# 7.28% Completed
# 7.30% Completed
# 7.31% Completed
# 7.32% Completed
# 7.33% Completed
# 7.34% Completed
# 7.35% Completed
# 7.36% Completed
# 7.38% Completed
# 7.39% Completed
# 7.40% Completed
# 7.41% Completed
# Failed prices for DCP-B
# 7.41% Completed
# Failed prices for DCT
# 7.41% Completed
# 7.42% Completed
# Failed prices for DD-A
# 7.42% Completed
# Failed prices for DD-B
# 7.42% Completed
# 7.43% Completed
# 7.45% Completed
# 7.46% Completed
# 7.47% Completed
# Failed prices for DDR-A
# 7.47% Completed
# Failed prices for DDR-J
# 7.47% Completed
# Failed prices for DDR-K
# 7.47% Completed
# 7.48% Completed
# 7.49% Completed
# 7.50% Completed
# 7.51% Completed
# 7.53% Completed
# 7.54% Completed
# 7.55% Completed
# 7.56% Completed
# 7.57% Completed
# 7.58% Completed
# 7.60% Completed
# 7.61% Completed
# 7.62% Completed
# 7.63% Completed
# 7.64% Completed
# Failed prices for DHC.X
# 7.64% Completed
# 7.65% Completed
# 7.66% Completed
# 7.68% Completed
# 7.69% Completed
# 7.70% Completed
# 7.71% Completed
# 7.72% Completed
# 7.73% Completed
# 7.75% Completed
# 7.76% Completed
# 7.77% Completed
# 7.78% Completed
# 7.79% Completed
# 7.80% Completed
# 7.81% Completed
# Failed prices for DLN-A
# 7.81% Completed
# 7.83% Completed
# 7.84% Completed
# 7.85% Completed
# Failed prices for DLR-C
# 7.85% Completed
# Failed prices for DLR-G
# 7.85% Completed
# Failed prices for DLR-H
# 7.85% Completed
# Failed prices for DLR-I
# 7.85% Completed
# Failed prices for DLR-J
# 7.85% Completed
# 7.86% Completed
# 7.87% Completed
# 7.88% Completed
# 7.90% Completed
# 7.91% Completed
# 7.92% Completed
# 7.93% Completed
# 7.94% Completed
# 7.95% Completed
# 7.96% Completed
# 7.98% Completed
# 7.99% Completed
# 8.00% Completed
# 8.01% Completed
# 8.02% Completed
# 8.03% Completed
# 8.05% Completed
# 8.06% Completed
# 8.07% Completed
# 8.08% Completed
# 8.09% Completed
# 8.10% Completed
# 8.11% Completed
# 8.13% Completed
# Failed prices for DS-B
# 8.13% Completed
# Failed prices for DS-C
# 8.13% Completed
# Failed prices for DS-D
# 8.13% Completed
# 8.14% Completed
# 8.15% Completed
# 8.16% Completed
# 8.17% Completed
# 8.18% Completed
# 8.20% Completed
# Failed prices for DSX-B
# 8.20% Completed
# 8.21% Completed
# 8.22% Completed
# 8.23% Completed
# 8.24% Completed
# Failed prices for DTL.P
# 8.24% Completed
# 8.25% Completed
# 8.27% Completed
# 8.28% Completed
# 8.29% Completed
# 8.30% Completed
# 8.31% Completed
# 8.32% Completed
# 8.33% Completed
# 8.35% Completed
# 8.36% Completed
# 8.37% Completed
# 8.38% Completed
# 8.39% Completed
# Failed prices for DX-A
# 8.39% Completed
# Failed prices for DX-B
# 8.39% Completed
# 8.40% Completed
# 8.42% Completed
# 8.43% Completed
# 8.44% Completed
# 8.45% Completed
# 8.46% Completed
# 8.47% Completed
# 8.48% Completed
# 8.50% Completed
# 8.51% Completed
# 8.52% Completed
# 8.53% Completed
# 8.54% Completed
# Failed prices for EBR.B
# 8.54% Completed
# 8.55% Completed
# 8.57% Completed
# 8.58% Completed
# 8.59% Completed
# 8.60% Completed
# 8.61% Completed
# 8.62% Completed
# 8.63% Completed
# 8.65% Completed
# 8.66% Completed
# 8.67% Completed
# 8.68% Completed
# 8.69% Completed
# 8.70% Completed
# 8.72% Completed
# 8.73% Completed
# 8.74% Completed
# Failed prices for EDR
# 8.74% Completed
# 8.75% Completed
# 8.76% Completed
# 8.77% Completed
# 8.78% Completed
# 8.80% Completed
# 8.81% Completed
# 8.82% Completed
# 8.83% Completed
# 8.84% Completed
# 8.85% Completed
# 8.87% Completed
# 8.88% Completed
# 8.89% Completed
# 8.90% Completed
# 8.91% Completed
# 8.92% Completed
# 8.93% Completed
# 8.95% Completed
# 8.96% Completed
# 8.97% Completed
# 8.98% Completed
# 8.99% Completed
# 9.00% Completed
# 9.02% Completed
# 9.03% Completed
# 9.04% Completed
# 9.05% Completed
# 9.06% Completed
# 9.07% Completed
# 9.08% Completed
# 9.10% Completed
# 9.11% Completed
# 9.12% Completed
# 9.13% Completed
# 9.14% Completed
# 9.15% Completed
# 9.17% Completed
# 9.18% Completed
# 9.19% Completed
# 9.20% Completed
# 9.21% Completed
# 9.22% Completed
# 9.23% Completed
# 9.25% Completed
# 9.26% Completed
# 9.27% Completed
# 9.28% Completed
# 9.29% Completed
# 9.30% Completed
# 9.32% Completed
# 9.33% Completed
# 9.34% Completed
# 9.35% Completed
# 9.36% Completed
# 9.37% Completed
# 9.38% Completed
# 9.40% Completed
# 9.41% Completed
# 9.42% Completed
# 9.43% Completed
# 9.44% Completed
# 9.45% Completed
# 9.47% Completed
# 9.48% Completed
# Failed prices for EP-C
# 9.48% Completed
# 9.49% Completed
# 9.50% Completed
# 9.51% Completed
# 9.52% Completed
# 9.53% Completed
# Failed prices for EPR-C
# 9.53% Completed
# Failed prices for EPR-E
# 9.53% Completed
# Failed prices for EPR-G
# 9.53% Completed
# 9.55% Completed
# 9.56% Completed
# Failed prices for EQC-D
# 9.56% Completed
# 9.57% Completed
# 9.58% Completed
# 9.59% Completed
# 9.60% Completed
# 9.62% Completed
# 9.63% Completed
# 9.64% Completed
# 9.65% Completed
# 9.66% Completed
# 9.67% Completed
# 9.68% Completed
# 9.70% Completed
# 9.71% Completed
# 9.72% Completed
# 9.73% Completed
# 9.74% Completed
# 9.75% Completed
# 9.77% Completed
# 9.78% Completed
# 9.79% Completed
# 9.80% Completed
# 9.81% Completed
# 9.82% Completed
# 9.83% Completed
# 9.85% Completed
# 9.86% Completed
# 9.87% Completed
# 9.88% Completed
# Failed prices for ETP-C
# 9.88% Completed
# Failed prices for ETP-D
# 9.88% Completed
# 9.89% Completed
# 9.90% Completed
# 9.92% Completed
# 9.93% Completed
# 9.94% Completed
# 9.95% Completed
# 9.96% Completed
# 9.97% Completed
# 9.98% Completed
# 10.00% Completed
# 10.01% Completed
# 10.02% Completed
# Failed prices for EVHC
# 10.02% Completed
# 10.03% Completed
# 10.04% Completed
# 10.05% Completed
# 10.07% Completed
# 10.08% Completed
# 10.09% Completed
# 10.10% Completed
# 10.11% Completed
# 10.12% Completed
# 10.14% Completed
# 10.15% Completed
# 10.16% Completed
# 10.17% Completed
# 10.18% Completed
# 10.19% Completed
# 10.20% Completed
# 10.22% Completed
# 10.23% Completed
# 10.24% Completed
# 10.25% Completed
# 10.26% Completed
# 10.27% Completed
# 10.29% Completed
# 10.30% Completed
# 10.31% Completed
# 10.32% Completed
# 10.33% Completed
# 10.34% Completed
# Failed prices for FCE.A
# 10.34% Completed
# 10.35% Completed
# 10.37% Completed
# 10.38% Completed
# 10.39% Completed
# 10.40% Completed
# 10.41% Completed
# 10.42% Completed
# 10.44% Completed
# 10.45% Completed
# 10.46% Completed
# 10.47% Completed
# 10.48% Completed
# 10.49% Completed
# 10.50% Completed
# 10.52% Completed
# 10.53% Completed
# 10.54% Completed
# 10.55% Completed
# 10.56% Completed
# 10.57% Completed
# 10.59% Completed
# 10.60% Completed
# 10.61% Completed
# Failed prices for FG.W
# 10.61% Completed
# 10.62% Completed
# 10.63% Completed
# 10.64% Completed
# Failed prices for FHN-A
# 10.64% Completed
# 10.65% Completed
# 10.67% Completed
# 10.68% Completed
# 10.69% Completed
# 10.70% Completed
# 10.71% Completed
# 10.72% Completed
# 10.74% Completed
# 10.75% Completed
# 10.76% Completed
# 10.77% Completed
# 10.78% Completed
# 10.79% Completed
# 10.80% Completed
# 10.82% Completed
# 10.83% Completed
# 10.84% Completed
# 10.85% Completed
# 10.86% Completed
# 10.87% Completed
# 10.89% Completed
# 10.90% Completed
# 10.91% Completed
# 10.92% Completed
# Failed prices for FNB-E
# 10.92% Completed
# 10.93% Completed
# 10.94% Completed
# 10.95% Completed
# 10.97% Completed
# 10.98% Completed
# 10.99% Completed
# Failed prices for FPA.U
# 10.99% Completed
# Failed prices for FPA.W
# 10.99% Completed
# 11.00% Completed
# 11.01% Completed
# 11.02% Completed
# 11.04% Completed
# Failed prices for FPI-B
# 11.04% Completed
# 11.05% Completed
# 11.06% Completed
# 11.07% Completed
# 11.08% Completed
# 11.09% Completed
# Failed prices for FRC-D
# 11.09% Completed
# Failed prices for FRC-E
# 11.09% Completed
# Failed prices for FRC-F
# 11.09% Completed
# Failed prices for FRC-G
# 11.09% Completed
# Failed prices for FRC-H
# 11.09% Completed
# Failed prices for FRC-I
# 11.09% Completed
# 11.10% Completed
# 11.12% Completed
# Failed prices for FRT-C
# 11.12% Completed
# 11.13% Completed
# 11.14% Completed
# 11.15% Completed
# 11.16% Completed
# 11.17% Completed
# 11.19% Completed
# 11.20% Completed
# 11.21% Completed
# 11.22% Completed
# 11.23% Completed
# 11.24% Completed
# 11.25% Completed
# Failed prices for FTV-A
# 11.25% Completed
# 11.27% Completed
# 11.28% Completed
# 11.29% Completed
# 11.30% Completed
# Failed prices for GAB-D
# 11.30% Completed
# Failed prices for GAB-G
# 11.30% Completed
# Failed prices for GAB-H
# 11.30% Completed
# Failed prices for GAB-J
# 11.30% Completed
# 11.31% Completed
# Failed prices for GAM-B
# 11.31% Completed
# 11.32% Completed
# 11.34% Completed
# 11.35% Completed
# 11.36% Completed
# 11.37% Completed
# 11.38% Completed
# 11.39% Completed
# 11.40% Completed
# 11.42% Completed
# Failed prices for GCV-B
# 11.42% Completed
# 11.43% Completed
# 11.44% Completed
# 11.45% Completed
# 11.46% Completed
# Failed prices for GDL-C
# 11.46% Completed
# 11.47% Completed
# 11.49% Completed
# 11.50% Completed
# Failed prices for GDV-A
# 11.50% Completed
# Failed prices for GDV-D
# 11.50% Completed
# Failed prices for GDV-G
# 11.50% Completed
# 11.51% Completed
# 11.52% Completed
# Failed prices for GEF.B
# 11.52% Completed
# 11.53% Completed
# 11.54% Completed
# 11.55% Completed
# 11.57% Completed
# 11.58% Completed
# 11.59% Completed
# 11.60% Completed
# 11.61% Completed
# 11.62% Completed
# 11.64% Completed
# 11.65% Completed
# 11.66% Completed
# 11.67% Completed
# 11.68% Completed
# 11.69% Completed
# Failed prices for GGP-A
# 11.69% Completed
# 11.70% Completed
# Failed prices for GGT-B
# 11.70% Completed
# Failed prices for GGT-E
# 11.70% Completed
# 11.72% Completed
# Failed prices for GGZ-A
# 11.72% Completed
# 11.73% Completed
# 11.74% Completed
# 11.75% Completed
# 11.76% Completed
# 11.77% Completed
# 11.79% Completed
# 11.80% Completed
# Failed prices for GIG.P
# 11.80% Completed
# Failed prices for GIG.U
# 11.80% Completed
# Failed prices for GIG.W
# 11.80% Completed
# 11.81% Completed
# 11.82% Completed
# 11.83% Completed
# 11.84% Completed
# 11.86% Completed
# 11.87% Completed
# 11.88% Completed
# 11.89% Completed
# 11.90% Completed
# 11.91% Completed
# 11.92% Completed
# Failed prices for GLO-A
# 11.92% Completed
# Failed prices for GLO-B
# 11.92% Completed
# Failed prices for GLO-G
# 11.92% Completed
# 11.94% Completed
# 11.95% Completed
# 11.96% Completed
# 11.97% Completed
# Failed prices for GLP-A
# 11.97% Completed
# 11.98% Completed
# 11.99% Completed
# 12.01% Completed
# Failed prices for GM.B
# 12.01% Completed
# 12.02% Completed
# 12.03% Completed
# Failed prices for GMR-A
# 12.03% Completed
# 12.04% Completed
# 12.05% Completed
# 12.06% Completed
# 12.07% Completed
# 12.09% Completed
# 12.10% Completed
# Failed prices for GNE-A
# 12.10% Completed
# 12.11% Completed
# 12.12% Completed
# Failed prices for GNL-A
# 12.12% Completed
# 12.13% Completed
# 12.14% Completed
# Failed prices for GNT-A
# 12.14% Completed
# 12.16% Completed
# 12.17% Completed
# 12.18% Completed
# 12.19% Completed
# 12.20% Completed
# 12.21% Completed
# 12.22% Completed
# 12.24% Completed
# 12.25% Completed
# 12.26% Completed
# 12.27% Completed
# 12.28% Completed
# 12.29% Completed
# 12.31% Completed
# Failed prices for GPT
# 12.31% Completed
# Failed prices for GPT-A
# 12.31% Completed
# 12.32% Completed
# 12.33% Completed
# 12.34% Completed
# 12.35% Completed
# Failed prices for GRP.U
# 12.35% Completed
# 12.36% Completed
# 12.37% Completed
# Failed prices for GRX-A
# 12.37% Completed
# Failed prices for GRX-B
# 12.37% Completed
# 12.39% Completed
# Failed prices for GS-A
# 12.39% Completed
# Failed prices for GS-B
# 12.39% Completed
# Failed prices for GS-C
# 12.39% Completed
# Failed prices for GS-D
# 12.39% Completed
# Failed prices for GS-J
# 12.39% Completed
# Failed prices for GS-K
# 12.39% Completed
# Failed prices for GS-N
# 12.39% Completed
# Failed prices for GSA.U
# 12.39% Completed
# 12.40% Completed
# 12.41% Completed
# 12.42% Completed
# 12.43% Completed
# 12.44% Completed
# Failed prices for GSL-B
# 12.44% Completed
# 12.46% Completed
# 12.47% Completed
# Failed prices for GTN.A
# 12.47% Completed
# 12.48% Completed
# 12.49% Completed
# 12.50% Completed
# 12.51% Completed
# Failed prices for GUT-A
# 12.51% Completed
# Failed prices for GUT-C
# 12.51% Completed
# 12.52% Completed
# 12.54% Completed
# 12.55% Completed
# 12.56% Completed
# 12.57% Completed
# 12.58% Completed
# 12.59% Completed
# 12.61% Completed
# 12.62% Completed
# 12.63% Completed
# 12.64% Completed
# 12.65% Completed
# 12.66% Completed
# 12.67% Completed
# 12.69% Completed
# 12.70% Completed
# 12.71% Completed
# Failed prices for HCF-A
# 12.71% Completed
# 12.72% Completed
# 12.73% Completed
# 12.74% Completed
# 12.76% Completed
# 12.77% Completed
# 12.78% Completed
# 12.79% Completed
# 12.80% Completed
# 12.81% Completed
# Failed prices for HE-U
# 12.81% Completed
# 12.82% Completed
# Failed prices for HEI.A
# 12.82% Completed
# 12.84% Completed
# 12.85% Completed
# 12.86% Completed
# Failed prices for HES-A
# 12.86% Completed
# 12.87% Completed
# 12.88% Completed
# 12.89% Completed
# 12.91% Completed
# 12.92% Completed
# 12.93% Completed
# 12.94% Completed
# 12.95% Completed
# 12.96% Completed
# 12.97% Completed
# 12.99% Completed
# 13.00% Completed
# 13.01% Completed
# Failed prices for HIG.W
# 13.01% Completed
# 13.02% Completed
# 13.03% Completed
# 13.04% Completed
# 13.06% Completed
# 13.07% Completed
# 13.08% Completed
# 13.09% Completed
# Failed prices for HK.W
# 13.09% Completed
# 13.10% Completed
# Failed prices for HL-B
# 13.10% Completed
# 13.11% Completed
# 13.12% Completed
# 13.14% Completed
# 13.15% Completed
# 13.16% Completed
# 13.17% Completed
# Failed prices for HML-A
# 13.17% Completed
# 13.18% Completed
# 13.19% Completed
# 13.21% Completed
# 13.22% Completed
# 13.23% Completed
# 13.24% Completed
# 13.25% Completed
# 13.26% Completed
# 13.27% Completed
# 13.29% Completed
# 13.30% Completed
# 13.31% Completed
# 13.32% Completed
# 13.33% Completed
# 13.34% Completed
# 13.36% Completed
# 13.37% Completed
# 13.38% Completed
# 13.39% Completed
# 13.40% Completed
# 13.41% Completed
# 13.42% Completed
# 13.44% Completed
# 13.45% Completed
# 13.46% Completed
# 13.47% Completed
# 13.48% Completed
# 13.49% Completed
# Failed prices for HSB-A
# 13.49% Completed
# 13.51% Completed
# 13.52% Completed
# 13.53% Completed
# 13.54% Completed
# 13.55% Completed
# Failed prices for HT-C
# 13.55% Completed
# Failed prices for HT-D
# 13.55% Completed
# Failed prices for HT-E
# 13.55% Completed
# 13.56% Completed
# 13.57% Completed
# 13.59% Completed
# 13.60% Completed
# 13.61% Completed
# 13.62% Completed
# 13.63% Completed
# 13.64% Completed
# 13.66% Completed
# 13.67% Completed
# 13.68% Completed
# 13.69% Completed
# 13.70% Completed
# 13.71% Completed
# 13.73% Completed
# Failed prices for HVT.A
# 13.73% Completed
# 13.74% Completed
# 13.75% Completed
# 13.76% Completed
# 13.77% Completed
# 13.78% Completed
# 13.79% Completed
# 13.81% Completed
# 13.82% Completed
# 13.83% Completed
# 13.84% Completed
# 13.85% Completed
# 13.86% Completed
# 13.88% Completed
# 13.89% Completed
# 13.90% Completed
# 13.91% Completed
# 13.92% Completed
# 13.93% Completed
# 13.94% Completed
# 13.96% Completed
# 13.97% Completed
# 13.98% Completed
# 13.99% Completed
# 14.00% Completed
# 14.01% Completed
# 14.03% Completed
# 14.04% Completed
# 14.05% Completed
# 14.06% Completed
# 14.07% Completed
# 14.08% Completed
# 14.09% Completed
# 14.11% Completed
# 14.12% Completed
# 14.13% Completed
# 14.14% Completed
# Failed prices for IIP-A
# 14.14% Completed
# 14.15% Completed
# 14.16% Completed
# 14.18% Completed
# 14.19% Completed
# 14.20% Completed
# 14.21% Completed
# 14.22% Completed
# 14.23% Completed
# Failed prices for INN-D
# 14.23% Completed
# 14.24% Completed
# Failed prices for INS-A
# 14.24% Completed
# 14.26% Completed
# 14.27% Completed
# 14.28% Completed
# 14.29% Completed
# 14.30% Completed
# 14.31% Completed
# 14.33% Completed
# 14.34% Completed
# 14.35% Completed
# 14.36% Completed
# 14.37% Completed
# 14.38% Completed
# Failed prices for IPL-D
# 14.38% Completed
# Failed prices for IPO.U
# 14.38% Completed
# Failed prices for IPO.W
# 14.38% Completed
# 14.39% Completed
# 14.41% Completed
# 14.42% Completed
# 14.43% Completed
# Failed prices for IRE-C
# 14.43% Completed
# 14.44% Completed
# 14.45% Completed
# 14.46% Completed
# 14.48% Completed
# 14.49% Completed
# 14.50% Completed
# 14.51% Completed
# 14.52% Completed
# 14.53% Completed
# 14.54% Completed
# 14.56% Completed
# 14.57% Completed
# 14.58% Completed
# 14.59% Completed
# 14.60% Completed
# 14.61% Completed
# 14.63% Completed
# 14.64% Completed
# 14.65% Completed
# Failed prices for IVR-A
# 14.65% Completed
# Failed prices for IVR-B
# 14.65% Completed
# Failed prices for IVR-C
# 14.65% Completed
# 14.66% Completed
# 14.67% Completed
# 14.68% Completed
# 14.69% Completed
# 14.71% Completed
# 14.72% Completed
# 14.73% Completed
# 14.74% Completed
# 14.75% Completed
# 14.76% Completed
# Failed prices for JCA-B
# 14.76% Completed
# 14.78% Completed
# 14.79% Completed
# 14.80% Completed
# 14.81% Completed
# 14.82% Completed
# 14.83% Completed
# 14.84% Completed
# Failed prices for JE-A
# 14.84% Completed
# 14.86% Completed
# 14.87% Completed
# 14.88% Completed
# 14.89% Completed
# 14.90% Completed
# 14.91% Completed
# 14.93% Completed
# 14.94% Completed
# 14.95% Completed
# 14.96% Completed
# 14.97% Completed
# 14.98% Completed
# 14.99% Completed
# 15.01% Completed
# 15.02% Completed
# 15.03% Completed
# 15.04% Completed
# 15.05% Completed
# 15.06% Completed
# 15.08% Completed
# 15.09% Completed
# 15.10% Completed
# 15.11% Completed
# 15.12% Completed
# 15.13% Completed
# 15.14% Completed
# 15.16% Completed
# 15.17% Completed
# 15.18% Completed
# 15.19% Completed
# 15.20% Completed
# 15.21% Completed
# 15.23% Completed
# 15.24% Completed
# 15.25% Completed
# 15.26% Completed
# Failed prices for JPM-A
# 15.26% Completed
# Failed prices for JPM-B
# 15.26% Completed
# Failed prices for JPM-E
# 15.26% Completed
# Failed prices for JPM-F
# 15.26% Completed
# Failed prices for JPM-G
# 15.26% Completed
# Failed prices for JPM-H
# 15.26% Completed
# Failed prices for JPM.W
# 15.26% Completed
# 15.27% Completed
# 15.28% Completed
# 15.29% Completed
# 15.31% Completed
# 15.32% Completed
# 15.33% Completed
# 15.34% Completed
# 15.35% Completed
# 15.36% Completed
# 15.38% Completed
# Failed prices for JW.A
# 15.38% Completed
# Failed prices for JW.B
# 15.38% Completed
# 15.39% Completed
# 15.40% Completed
# 15.41% Completed
# 15.42% Completed
# 15.43% Completed
# 15.44% Completed
# 15.46% Completed
# 15.47% Completed
# 15.48% Completed
# 15.49% Completed
# 15.50% Completed
# 15.51% Completed
# 15.53% Completed
# 15.54% Completed
# 15.55% Completed
# 15.56% Completed
# 15.57% Completed
# Failed prices for KEY-I
# 15.57% Completed
# Failed prices for KEY-J
# 15.57% Completed
# 15.58% Completed
# 15.60% Completed
# 15.61% Completed
# 15.62% Completed
# 15.63% Completed
# 15.64% Completed
# Failed prices for KIM-I
# 15.64% Completed
# Failed prices for KIM-J
# 15.64% Completed
# Failed prices for KIM-K
# 15.64% Completed
# Failed prices for KIM-L
# 15.64% Completed
# Failed prices for KIM-M
# 15.64% Completed
# 15.65% Completed
# 15.66% Completed
# Failed prices for KKR-A
# 15.66% Completed
# Failed prices for KKR-B
# 15.66% Completed
# 15.68% Completed
# 15.69% Completed
# 15.70% Completed
# 15.71% Completed
# 15.72% Completed
# Failed prices for KMI-A
# 15.72% Completed
# 15.73% Completed
# 15.75% Completed
# 15.76% Completed
# 15.77% Completed
# 15.78% Completed
# 15.79% Completed
# 15.80% Completed
# 15.81% Completed
# 15.83% Completed
# 15.84% Completed
# Failed prices for KOD.W
# 15.84% Completed
# Failed prices for KOD.X
# 15.84% Completed
# 15.85% Completed
# 15.86% Completed
# 15.87% Completed
# 15.88% Completed
# 15.90% Completed
# 15.91% Completed
# 15.92% Completed
# 15.93% Completed
# 15.94% Completed
# 15.95% Completed
# 15.96% Completed
# 15.98% Completed
# 15.99% Completed
# 16.00% Completed
# 16.01% Completed
# 16.02% Completed
# 16.03% Completed
# Failed prices for KSU.P
# 16.03% Completed
# 16.05% Completed
# 16.06% Completed
# 16.07% Completed
# 16.08% Completed
# 16.09% Completed
# 16.10% Completed
# 16.11% Completed
# 16.13% Completed
# Failed prices for KYN-F
# 16.13% Completed
# 16.14% Completed
# 16.15% Completed
# 16.16% Completed
# 16.17% Completed
# 16.18% Completed
# 16.20% Completed
# 16.21% Completed
# 16.22% Completed
# 16.23% Completed
# 16.24% Completed
# 16.25% Completed
# 16.26% Completed
# 16.28% Completed
# 16.29% Completed
# 16.30% Completed
# 16.31% Completed
# 16.32% Completed
# 16.33% Completed
# 16.35% Completed
# 16.36% Completed
# 16.37% Completed
# Failed prices for LEN.B
# 16.37% Completed
# 16.38% Completed
# 16.39% Completed
# 16.40% Completed
# Failed prices for LGC.U
# 16.40% Completed
# Failed prices for LGC.W
# 16.40% Completed
# Failed prices for LGF.A
# 16.40% Completed
# Failed prices for LGF.B
# 16.40% Completed
# 16.41% Completed
# 16.43% Completed
# 16.44% Completed
# Failed prices for LHC.U
# 16.44% Completed
# Failed prices for LHC.W
# 16.44% Completed
# 16.45% Completed
# Failed prices for LHO-I
# 16.45% Completed
# Failed prices for LHO-J
# 16.45% Completed
# 16.46% Completed
# 16.47% Completed
# 16.48% Completed
# 16.50% Completed
# 16.51% Completed
# 16.52% Completed
# 16.53% Completed
# 16.54% Completed
# 16.55% Completed
# 16.56% Completed
# 16.58% Completed
# 16.59% Completed
# 16.60% Completed
# Failed prices for LNC.W
# 16.60% Completed
# 16.61% Completed
# 16.62% Completed
# 16.63% Completed
# 16.65% Completed
# 16.66% Completed
# 16.67% Completed
# 16.68% Completed
# 16.69% Completed
# 16.70% Completed
# 16.71% Completed
# 16.73% Completed
# 16.74% Completed
# 16.75% Completed
# 16.76% Completed
# 16.77% Completed
# 16.78% Completed
# Failed prices for LTN.P
# 16.78% Completed
# Failed prices for LTN.U
# 16.78% Completed
# Failed prices for LTN.W
# 16.78% Completed
# 16.80% Completed
# 16.81% Completed
# 16.82% Completed
# 16.83% Completed
# 16.84% Completed
# 16.85% Completed
# 16.86% Completed
# Failed prices for LXP-C
# 16.86% Completed
# 16.88% Completed
# 16.89% Completed
# 16.90% Completed
# 16.91% Completed
# 16.92% Completed
# 16.93% Completed
# 16.95% Completed
# 16.96% Completed
# Failed prices for MAA-I
# 16.96% Completed
# 16.97% Completed
# 16.98% Completed
# 16.99% Completed
# 17.00% Completed
# 17.01% Completed
# 17.03% Completed
# 17.04% Completed
# 17.05% Completed
# 17.06% Completed
# 17.07% Completed
# 17.08% Completed
# 17.10% Completed
# 17.11% Completed
# 17.12% Completed
# 17.13% Completed
# 17.14% Completed
# 17.15% Completed
# 17.16% Completed
# 17.18% Completed
# 17.19% Completed
# 17.20% Completed
# 17.21% Completed
# 17.22% Completed
# 17.23% Completed
# 17.25% Completed
# 17.26% Completed
# 17.27% Completed
# 17.28% Completed
# 17.29% Completed
# 17.30% Completed
# 17.32% Completed
# 17.33% Completed
# 17.34% Completed
# 17.35% Completed
# 17.36% Completed
# 17.37% Completed
# 17.38% Completed
# Failed prices for MER-K
# 17.38% Completed
# 17.40% Completed
# Failed prices for MET-A
# 17.40% Completed
# Failed prices for MET-E
# 17.40% Completed
# 17.41% Completed
# Failed prices for MFA-B
# 17.41% Completed
# Failed prices for MFA.U
# 17.41% Completed
# 17.42% Completed
# 17.43% Completed
# 17.44% Completed
# 17.45% Completed
# 17.47% Completed
# 17.48% Completed
# 17.49% Completed
# 17.50% Completed
# 17.51% Completed
# 17.52% Completed
# 17.53% Completed
# 17.55% Completed
# 17.56% Completed
# 17.57% Completed
# 17.58% Completed
# 17.59% Completed
# 17.60% Completed
# Failed prices for MGY.W
# 17.60% Completed
# Failed prices for MH-A
# 17.60% Completed
# Failed prices for MH-C
# 17.60% Completed
# 17.62% Completed
# 17.63% Completed
# 17.64% Completed
# 17.65% Completed
# 17.66% Completed
# 17.67% Completed
# 17.68% Completed
# 17.70% Completed
# 17.71% Completed
# 17.72% Completed
# 17.73% Completed
# 17.74% Completed
# 17.75% Completed
# Failed prices for MIT-A
# 17.75% Completed
# Failed prices for MIT-B
# 17.75% Completed
# 17.77% Completed
# 17.78% Completed
# 17.79% Completed
# 17.80% Completed
# Failed prices for MKC.V
# 17.80% Completed
# 17.81% Completed
# 17.82% Completed
# 17.83% Completed
# 17.85% Completed
# 17.86% Completed
# 17.87% Completed
# 17.88% Completed
# 17.89% Completed
# 17.90% Completed
# 17.92% Completed
# 17.93% Completed
# 17.94% Completed
# 17.95% Completed
# 17.96% Completed
# 17.97% Completed
# 17.98% Completed
# 18.00% Completed
# 18.01% Completed
# Failed prices for MNR-C
# 18.01% Completed
# 18.02% Completed
# 18.03% Completed
# 18.04% Completed
# Failed prices for MOG.A
# 18.04% Completed
# Failed prices for MOG.B
# 18.04% Completed
# 18.05% Completed
# 18.07% Completed
# Failed prices for MOS.U
# 18.07% Completed
# Failed prices for MOS.W
# 18.07% Completed
# 18.08% Completed
# 18.09% Completed
# Failed prices for MP-D
# 18.09% Completed
# 18.10% Completed
# 18.11% Completed
# 18.12% Completed
# 18.13% Completed
# 18.15% Completed
# 18.16% Completed
# 18.17% Completed
# 18.18% Completed
# 18.19% Completed
# 18.20% Completed
# 18.22% Completed
# 18.23% Completed
# 18.24% Completed
# 18.25% Completed
# Failed prices for MS-A
# 18.25% Completed
# Failed prices for MS-E
# 18.25% Completed
# Failed prices for MS-F
# 18.25% Completed
# Failed prices for MS-G
# 18.25% Completed
# Failed prices for MS-I
# 18.25% Completed
# Failed prices for MS-K
# 18.25% Completed
# 18.26% Completed
# 18.27% Completed
# 18.28% Completed
# 18.30% Completed
# 18.31% Completed
# 18.32% Completed
# 18.33% Completed
# 18.34% Completed
# 18.35% Completed
# 18.37% Completed
# 18.38% Completed
# 18.39% Completed
# 18.40% Completed
# Failed prices for MTB-C
# 18.40% Completed
# Failed prices for MTB.P
# 18.40% Completed
# Failed prices for MTB.W
# 18.40% Completed
# 18.41% Completed
# 18.42% Completed
# 18.43% Completed
# 18.45% Completed
# 18.46% Completed
# Failed prices for MTL.P
# 18.46% Completed
# 18.47% Completed
# 18.48% Completed
# 18.49% Completed
# 18.50% Completed
# 18.52% Completed
# 18.53% Completed
# 18.54% Completed
# 18.55% Completed
# 18.56% Completed
# 18.57% Completed
# 18.58% Completed
# 18.60% Completed
# 18.61% Completed
# 18.62% Completed
# 18.63% Completed
# 18.64% Completed
# 18.65% Completed
# 18.67% Completed
# 18.68% Completed
# 18.69% Completed
# 18.70% Completed
# 18.71% Completed
# 18.72% Completed
# 18.73% Completed
# 18.75% Completed
# 18.76% Completed
# 18.77% Completed
# 18.78% Completed
# 18.79% Completed
# 18.80% Completed
# 18.82% Completed
# 18.83% Completed
# 18.84% Completed
# 18.85% Completed
# 18.86% Completed
# 18.87% Completed
# 18.88% Completed
# 18.90% Completed
# 18.91% Completed
# 18.92% Completed
# 18.93% Completed
# 18.94% Completed
# 18.95% Completed
# 18.97% Completed
# 18.98% Completed
# Failed prices for NAV-D
# 18.98% Completed
# 18.99% Completed
# 19.00% Completed
# 19.01% Completed
# 19.02% Completed
# 19.03% Completed
# 19.05% Completed
# 19.06% Completed
# Failed prices for NBR-A
# 19.06% Completed
# 19.07% Completed
# 19.08% Completed
# 19.09% Completed
# 19.10% Completed
# 19.12% Completed
# 19.13% Completed
# 19.14% Completed
# 19.15% Completed
# 19.16% Completed
# 19.17% Completed
# 19.19% Completed
# 19.20% Completed
# 19.21% Completed
# 19.22% Completed
# Failed prices for NEE-I
# 19.22% Completed
# Failed prices for NEE-J
# 19.22% Completed
# Failed prices for NEE-K
# 19.22% Completed
# Failed prices for NEE-Q
# 19.22% Completed
# Failed prices for NEE-R
# 19.22% Completed
# 19.23% Completed
# 19.24% Completed
# 19.25% Completed
# 19.27% Completed
# 19.28% Completed
# 19.29% Completed
# 19.30% Completed
# 19.31% Completed
# 19.32% Completed
# 19.34% Completed
# Failed prices for NFC.U
# 19.34% Completed
# Failed prices for NFC.W
# 19.34% Completed
# 19.35% Completed
# 19.36% Completed
# 19.37% Completed
# 19.38% Completed
# 19.39% Completed
# Failed prices for NGL-A
# 19.39% Completed
# Failed prices for NGL-B
# 19.39% Completed
# 19.40% Completed
# 19.42% Completed
# 19.43% Completed
# 19.44% Completed
# 19.45% Completed
# 19.46% Completed
# 19.47% Completed
# 19.49% Completed
# 19.50% Completed
# 19.51% Completed
# 19.52% Completed
# 19.53% Completed
# 19.54% Completed
# 19.55% Completed
# 19.57% Completed
# 19.58% Completed
# 19.59% Completed
# 19.60% Completed
# 19.61% Completed
# 19.62% Completed
# 19.64% Completed
# 19.65% Completed
# Failed prices for NLY-C
# 19.65% Completed
# Failed prices for NLY-D
# 19.65% Completed
# Failed prices for NLY-F
# 19.65% Completed
# Failed prices for NLY-G
# 19.65% Completed
# Failed prices for NLY-H
# 19.65% Completed
# 19.66% Completed
# Failed prices for NM-G
# 19.66% Completed
# Failed prices for NM-H
# 19.66% Completed
# 19.67% Completed
# 19.68% Completed
# Failed prices for NMK-B
# 19.68% Completed
# Failed prices for NMK-C
# 19.68% Completed
# 19.69% Completed
# 19.70% Completed
# 19.72% Completed
# 19.73% Completed
# 19.74% Completed
# 19.75% Completed
# 19.76% Completed
# 19.77% Completed
# 19.79% Completed
# 19.80% Completed
# Failed prices for NNN-E
# 19.80% Completed
# Failed prices for NNN-F
# 19.80% Completed
# 19.81% Completed
# 19.82% Completed
# 19.83% Completed
# 19.84% Completed
# 19.85% Completed
# 19.87% Completed
# 19.88% Completed
# 19.89% Completed
# 19.90% Completed
# 19.91% Completed
# 19.92% Completed
# 19.94% Completed
# 19.95% Completed
# 19.96% Completed
# 19.97% Completed
# 19.98% Completed
# 19.99% Completed
# 20.00% Completed
# 20.02% Completed
# 20.03% Completed
# 20.04% Completed
# 20.05% Completed
# 20.06% Completed
# 20.07% Completed
# Failed prices for NS-A
# 20.07% Completed
# Failed prices for NS-B
# 20.07% Completed
# Failed prices for NS-C
# 20.07% Completed
# 20.09% Completed
# Failed prices for NSA-A
# 20.09% Completed
# 20.10% Completed
# 20.11% Completed
# 20.12% Completed
# 20.13% Completed
# 20.14% Completed
# 20.15% Completed
# 20.17% Completed
# 20.18% Completed
# 20.19% Completed
# 20.20% Completed
# 20.21% Completed
# 20.22% Completed
# 20.24% Completed
# 20.25% Completed
# 20.26% Completed
# 20.27% Completed
# 20.28% Completed
# 20.29% Completed
# 20.30% Completed
# 20.32% Completed
# 20.33% Completed
# 20.34% Completed
# 20.35% Completed
# 20.36% Completed
# 20.37% Completed
# 20.39% Completed
# 20.40% Completed
# 20.41% Completed
# 20.42% Completed
# 20.43% Completed
# 20.44% Completed
# 20.45% Completed
# 20.47% Completed
# 20.48% Completed
# 20.49% Completed
# 20.50% Completed
# 20.51% Completed
# 20.52% Completed
# Failed prices for NYC-A
# 20.52% Completed
# Failed prices for NYC-U
# 20.52% Completed
# 20.54% Completed
# Failed prices for NYL.A
# 20.54% Completed
# Failed prices for NYLD
# 20.54% Completed
# 20.55% Completed
# 20.56% Completed
# 20.57% Completed
# 20.58% Completed
# 20.59% Completed
# 20.60% Completed
# Failed prices for OAK-A
# 20.60% Completed
# Failed prices for OAK-B
# 20.60% Completed
# 20.62% Completed
# 20.63% Completed
# 20.64% Completed
# 20.65% Completed
# 20.66% Completed
# 20.67% Completed
# 20.69% Completed
# 20.70% Completed
# Failed prices for OFG-A
# 20.70% Completed
# Failed prices for OFG-B
# 20.70% Completed
# Failed prices for OFG-D
# 20.70% Completed
# 20.71% Completed
# 20.72% Completed
# 20.73% Completed
# 20.74% Completed
# 20.75% Completed
# Failed prices for OIB.C
# 20.75% Completed
# 20.77% Completed
# 20.78% Completed
# 20.79% Completed
# 20.80% Completed
# 20.81% Completed
# Failed prices for OMA.U
# 20.81% Completed
# Failed prices for OMA.W
# 20.81% Completed
# 20.82% Completed
# 20.84% Completed
# 20.85% Completed
# 20.86% Completed
# 20.87% Completed
# 20.88% Completed
# 20.89% Completed
# 20.90% Completed
# 20.92% Completed
# 20.93% Completed
# 20.94% Completed
# 20.95% Completed
# 20.96% Completed
# 20.97% Completed
# 20.99% Completed
# 21.00% Completed
# 21.01% Completed
# 21.02% Completed
# 21.03% Completed
# 21.04% Completed
# 21.06% Completed
# 21.07% Completed
# 21.08% Completed
# 21.09% Completed
# 21.10% Completed
# 21.11% Completed
# 21.12% Completed
# 21.14% Completed
# 21.15% Completed
# 21.16% Completed
# 21.17% Completed
# 21.18% Completed
# 21.19% Completed
# 21.21% Completed
# 21.22% Completed
# 21.23% Completed
# 21.24% Completed
# 21.25% Completed
# 21.26% Completed
# 21.27% Completed
# 21.29% Completed
# 21.30% Completed
# 21.31% Completed
# 21.32% Completed
# 21.33% Completed
# 21.34% Completed
# Failed prices for PBI-B
# 21.34% Completed
# 21.36% Completed
# Failed prices for PBR.A
# 21.36% Completed
# 21.37% Completed
# 21.38% Completed
# 21.39% Completed
# 21.40% Completed
# 21.41% Completed
# 21.42% Completed
# 21.44% Completed
# 21.45% Completed
# 21.46% Completed
# 21.47% Completed
# 21.48% Completed
# 21.49% Completed
# 21.51% Completed
# 21.52% Completed
# 21.53% Completed
# Failed prices for PEB-C
# 21.53% Completed
# Failed prices for PEB-D
# 21.53% Completed
# 21.54% Completed
# 21.55% Completed
# Failed prices for PEI-B
# 21.55% Completed
# Failed prices for PEI-C
# 21.55% Completed
# Failed prices for PEI-D
# 21.55% Completed
# 21.56% Completed
# 21.57% Completed
# 21.59% Completed
# 21.60% Completed
# Failed prices for PF
# 21.60% Completed
# 21.61% Completed
# 21.62% Completed
# 21.63% Completed
# 21.64% Completed
# 21.66% Completed
# 21.67% Completed
# 21.68% Completed
# 21.69% Completed
# 21.70% Completed
# 21.71% Completed
# 21.72% Completed
# 21.74% Completed
# 21.75% Completed
# 21.76% Completed
# 21.77% Completed
# 21.78% Completed
# 21.79% Completed
# 21.81% Completed
# Failed prices for PHH
# 21.81% Completed
# 21.82% Completed
# 21.83% Completed
# 21.84% Completed
# 21.85% Completed
# 21.86% Completed
# 21.87% Completed
# 21.89% Completed
# 21.90% Completed
# 21.91% Completed
# 21.92% Completed
# 21.93% Completed
# 21.94% Completed
# 21.96% Completed
# 21.97% Completed
# 21.98% Completed
# 21.99% Completed
# 22.00% Completed
# 22.01% Completed
# 22.02% Completed
# 22.04% Completed
# 22.05% Completed
# 22.06% Completed
# 22.07% Completed
# 22.08% Completed
# 22.09% Completed
# 22.11% Completed
# 22.12% Completed
# 22.13% Completed
# 22.14% Completed
# Failed prices for PMT-A
# 22.14% Completed
# Failed prices for PMT-B
# 22.14% Completed
# 22.15% Completed
# 22.16% Completed
# Failed prices for PNC-P
# 22.16% Completed
# Failed prices for PNC-Q
# 22.16% Completed
# Failed prices for PNC.W
# 22.16% Completed
# 22.17% Completed
# 22.19% Completed
# 22.20% Completed
# 22.21% Completed
# 22.22% Completed
# 22.23% Completed
# 22.24% Completed
# 22.26% Completed
# 22.27% Completed
# 22.28% Completed
# 22.29% Completed
# 22.30% Completed
# 22.31% Completed
# 22.32% Completed
# 22.34% Completed
# 22.35% Completed
# Failed prices for PRE-F
# 22.35% Completed
# Failed prices for PRE-G
# 22.35% Completed
# Failed prices for PRE-H
# 22.35% Completed
# Failed prices for PRE-I
# 22.35% Completed
# 22.36% Completed
# 22.37% Completed
# 22.38% Completed
# Failed prices for PRI-A
# 22.38% Completed
# 22.39% Completed
# 22.41% Completed
# 22.42% Completed
# 22.43% Completed
# 22.44% Completed
# 22.45% Completed
# 22.46% Completed
# 22.47% Completed
# Failed prices for PSA-A
# 22.47% Completed
# Failed prices for PSA-B
# 22.47% Completed
# Failed prices for PSA-C
# 22.47% Completed
# Failed prices for PSA-D
# 22.47% Completed
# Failed prices for PSA-E
# 22.47% Completed
# Failed prices for PSA-F
# 22.47% Completed
# Failed prices for PSA-G
# ...
# 82.70% Completed
# 82.71% Completed
# 82.72% Completed
# 82.73% Completed
# 82.74% Completed
# 82.75% Completed
# 82.77% Completed
# 82.78% Completed
# 82.79% Completed
# 82.80% Completed
# 82.81% Completed
# 82.82% Completed
# 82.84% Completed
# 82.85% Completed
# 82.86% Completed
# 82.87% Completed
# 82.88% Completed
# 82.89% Completed
# 82.90% Completed
# 82.92% Completed
# 82.93% Completed
# 82.94% Completed
# 82.95% Completed
# 82.96% Completed
# 82.97% Completed
# 82.99% Completed
# 83.00% Completed
# 83.01% Completed
# 83.02% Completed
# 83.03% Completed
# Failed prices for MLPI
# 83.03% Completed
# 83.04% Completed
# 83.05% Completed
# 83.07% Completed
# 83.08% Completed
# 83.09% Completed
# 83.10% Completed
# 83.11% Completed
# 83.12% Completed
# 83.14% Completed
# 83.15% Completed
# 83.16% Completed
# 83.17% Completed
# 83.18% Completed
# 83.19% Completed
# 83.20% Completed
# 83.22% Completed
# 83.23% Completed
# 83.24% Completed
# 83.25% Completed
# 83.26% Completed
# 83.27% Completed
# 83.29% Completed
# 83.30% Completed
# 83.31% Completed
# 83.32% Completed
# 83.33% Completed
# 83.34% Completed
# 83.35% Completed
# 83.37% Completed
# 83.38% Completed
# 83.39% Completed
# 83.40% Completed
# 83.41% Completed
# 83.42% Completed
# 83.44% Completed
# 83.45% Completed
# 83.46% Completed
# 83.47% Completed
# 83.48% Completed
# 83.49% Completed
# 83.50% Completed
# 83.52% Completed
# 83.53% Completed
# 83.54% Completed
# 83.55% Completed
# 83.56% Completed
# 83.57% Completed
# 83.59% Completed
# 83.60% Completed
# 83.61% Completed
# 83.62% Completed
# 83.63% Completed
# 83.64% Completed
# 83.65% Completed
# 83.67% Completed
# 83.68% Completed
# 83.69% Completed
# 83.70% Completed
# 83.71% Completed
# 83.72% Completed
# 83.74% Completed
# 83.75% Completed
# 83.76% Completed
# 83.77% Completed
# 83.78% Completed
# 83.79% Completed
# 83.80% Completed
# Failed prices for NSP.W
# 83.80% Completed
# Failed prices for NSP.X
# 83.80% Completed
# 83.82% Completed
# 83.83% Completed
# 83.84% Completed
# 83.85% Completed
# 83.86% Completed
# 83.87% Completed
# 83.89% Completed
# 83.90% Completed
# 83.91% Completed
# 83.92% Completed
# 83.93% Completed
# 83.94% Completed
# 83.95% Completed
# 83.97% Completed
# 83.98% Completed
# 83.99% Completed
# 84.00% Completed
# 84.01% Completed
# 84.02% Completed
# 84.04% Completed
# 84.05% Completed
# 84.06% Completed
# 84.07% Completed
# 84.08% Completed
# 84.09% Completed
# 84.10% Completed
# 84.12% Completed
# 84.13% Completed
# 84.14% Completed
# 84.15% Completed
# 84.16% Completed
# 84.17% Completed
# 84.19% Completed
# 84.20% Completed
# 84.21% Completed
# 84.22% Completed
# 84.23% Completed
# 84.24% Completed
# 84.25% Completed
# 84.27% Completed
# 84.28% Completed
# 84.29% Completed
# 84.30% Completed
# 84.31% Completed
# 84.32% Completed
# 84.34% Completed
# 84.35% Completed
# 84.36% Completed
# 84.37% Completed
# 84.38% Completed
# 84.39% Completed
# 84.40% Completed
# 84.42% Completed
# 84.43% Completed
# 84.44% Completed
# 84.45% Completed
# 84.46% Completed
# 84.47% Completed
# 84.49% Completed
# 84.50% Completed
# 84.51% Completed
# 84.52% Completed
# 84.53% Completed
# 84.54% Completed
# 84.56% Completed
# 84.57% Completed
# 84.58% Completed
# 84.59% Completed
# 84.60% Completed
# 84.61% Completed
# 84.62% Completed
# 84.64% Completed
# 84.65% Completed
# 84.66% Completed
# 84.67% Completed
# Failed prices for PCG-A
# 84.67% Completed
# Failed prices for PCG-B
# 84.67% Completed
# Failed prices for PCG-C
# 84.67% Completed
# Failed prices for PCG-D
# 84.67% Completed
# Failed prices for PCG-E
# 84.67% Completed
# Failed prices for PCG-G
# 84.67% Completed
# Failed prices for PCG-H
# 84.67% Completed
# Failed prices for PCG-I
# 84.67% Completed
# 84.68% Completed
# 84.69% Completed
# 84.71% Completed
# 84.72% Completed
# 84.73% Completed
# 84.74% Completed
# 84.75% Completed
# 84.76% Completed
# 84.77% Completed
# 84.79% Completed
# 84.80% Completed
# 84.81% Completed
# 84.82% Completed
# 84.83% Completed
# 84.84% Completed
# 84.86% Completed
# 84.87% Completed
# 84.88% Completed
# 84.89% Completed
# 84.90% Completed
# 84.91% Completed
# 84.92% Completed
# 84.94% Completed
# 84.95% Completed
# 84.96% Completed
# 84.97% Completed
# 84.98% Completed
# 84.99% Completed
# 85.01% Completed
# 85.02% Completed
# 85.03% Completed
# 85.04% Completed
# 85.05% Completed
# 85.06% Completed
# Failed prices for PLY-A
# 85.06% Completed
# 85.07% Completed
# 85.09% Completed
# 85.10% Completed
# 85.11% Completed
# 85.12% Completed
# 85.13% Completed
# 85.14% Completed
# 85.16% Completed
# 85.17% Completed
# 85.18% Completed
# 85.19% Completed
# 85.20% Completed
# 85.21% Completed
# 85.22% Completed
# 85.24% Completed
# 85.25% Completed
# 85.26% Completed
# 85.27% Completed
# 85.28% Completed
# 85.29% Completed
# 85.31% Completed
# 85.32% Completed
# 85.33% Completed
# 85.34% Completed
# 85.35% Completed
# 85.36% Completed
# 85.37% Completed
# 85.39% Completed
# 85.40% Completed
# 85.41% Completed
# 85.42% Completed
# 85.43% Completed
# 85.44% Completed
# 85.46% Completed
# 85.47% Completed
# 85.48% Completed
# 85.49% Completed
# 85.50% Completed
# 85.51% Completed
# 85.52% Completed
# 85.54% Completed
# Failed prices for PW-A
# 85.54% Completed
# 85.55% Completed
# 85.56% Completed
# 85.57% Completed
# 85.58% Completed
# 85.59% Completed
# 85.61% Completed
# 85.62% Completed
# 85.63% Completed
# 85.64% Completed
# 85.65% Completed
# 85.66% Completed
# 85.67% Completed
# 85.69% Completed
# 85.70% Completed
# 85.71% Completed
# Failed prices for PXSG
# 85.71% Completed
# 85.72% Completed
# 85.73% Completed
# 85.74% Completed
# 85.76% Completed
# 85.77% Completed
# 85.78% Completed
# 85.79% Completed
# 85.80% Completed
# 85.81% Completed
# 85.82% Completed
# 85.84% Completed
# 85.85% Completed
# 85.86% Completed
# 85.87% Completed
# 85.88% Completed
# 85.89% Completed
# 85.91% Completed
# 85.92% Completed
# 85.93% Completed
# 85.94% Completed
# 85.95% Completed
# 85.96% Completed
# 85.97% Completed
# 85.99% Completed
# 86.00% Completed
# 86.01% Completed
# 86.02% Completed
# 86.03% Completed
# 86.04% Completed
# 86.06% Completed
# 86.07% Completed
# 86.08% Completed
# 86.09% Completed
# 86.10% Completed
# 86.11% Completed
# 86.12% Completed
# 86.14% Completed
# 86.15% Completed
# 86.16% Completed
# 86.17% Completed
# 86.18% Completed
# 86.19% Completed
# 86.21% Completed
# 86.22% Completed
# 86.23% Completed
# 86.24% Completed
# 86.25% Completed
# 86.26% Completed
# 86.27% Completed
# 86.29% Completed
# 86.30% Completed
# 86.31% Completed
# 86.32% Completed
# 86.33% Completed
# 86.34% Completed
# 86.36% Completed
# 86.37% Completed
# 86.38% Completed
# 86.39% Completed
# 86.40% Completed
# 86.41% Completed
# 86.43% Completed
# 86.44% Completed
# 86.45% Completed
# 86.46% Completed
# 86.47% Completed
# 86.48% Completed
# 86.49% Completed
# 86.51% Completed
# 86.52% Completed
# 86.53% Completed
# 86.54% Completed
# 86.55% Completed
# Failed prices for RHE-A
# 86.55% Completed
# 86.56% Completed
# 86.58% Completed
# 86.59% Completed
# 86.60% Completed
# 86.61% Completed
# 86.62% Completed
# 86.63% Completed
# 86.64% Completed
# 86.66% Completed
# 86.67% Completed
# Failed prices for RLG-A
# 86.67% Completed
# 86.68% Completed
# 86.69% Completed
# 86.70% Completed
# 86.71% Completed
# 86.73% Completed
# 86.74% Completed
# 86.75% Completed
# 86.76% Completed
# 86.77% Completed
# 86.78% Completed
# 86.79% Completed
# 86.81% Completed
# 86.82% Completed
# 86.83% Completed
# 86.84% Completed
# 86.85% Completed
# 86.86% Completed
# 86.88% Completed
# 86.89% Completed
# 86.90% Completed
# 86.91% Completed
# 86.92% Completed
# 86.93% Completed
# 86.94% Completed
# 86.96% Completed
# 86.97% Completed
# 86.98% Completed
# 86.99% Completed
# 87.00% Completed
# 87.01% Completed
# 87.03% Completed
# 87.04% Completed
# 87.05% Completed
# 87.06% Completed
# 87.07% Completed
# 87.08% Completed
# 87.09% Completed
# 87.11% Completed
# 87.12% Completed
# 87.13% Completed
# 87.14% Completed
# 87.15% Completed
# 87.16% Completed
# 87.18% Completed
# 87.19% Completed
# 87.20% Completed
# 87.21% Completed
# 87.22% Completed
# 87.23% Completed
# 87.24% Completed
# 87.26% Completed
# 87.27% Completed
# 87.28% Completed
# 87.29% Completed
# Failed prices for SCE-B
# 87.29% Completed
# Failed prices for SCE-C
# 87.29% Completed
# Failed prices for SCE-D
# 87.29% Completed
# Failed prices for SCE-E
# 87.29% Completed
# 87.30% Completed
# 87.31% Completed
# 87.33% Completed
# 87.34% Completed
# 87.35% Completed
# 87.36% Completed
# 87.37% Completed
# 87.38% Completed
# 87.39% Completed
# 87.41% Completed
# 87.42% Completed
# 87.43% Completed
# 87.44% Completed
# 87.45% Completed
# 87.46% Completed
# 87.48% Completed
# 87.49% Completed
# 87.50% Completed
# 87.51% Completed
# 87.52% Completed
# 87.53% Completed
# 87.54% Completed
# 87.56% Completed
# 87.57% Completed
# 87.58% Completed
# 87.59% Completed
# 87.60% Completed
# 87.61% Completed
# 87.63% Completed
# 87.64% Completed
# 87.65% Completed
# 87.66% Completed
# 87.67% Completed
# 87.68% Completed
# 87.69% Completed
# 87.71% Completed
# 87.72% Completed
# 87.73% Completed
# 87.74% Completed
# 87.75% Completed
# 87.76% Completed
# 87.78% Completed
# 87.79% Completed
# 87.80% Completed
# 87.81% Completed
# 87.82% Completed
# 87.83% Completed
# 87.84% Completed
# 87.86% Completed
# 87.87% Completed
# 87.88% Completed
# 87.89% Completed
# 87.90% Completed
# 87.91% Completed
# 87.93% Completed
# 87.94% Completed
# 87.95% Completed
# 87.96% Completed
# 87.97% Completed
# 87.98% Completed
# 87.99% Completed
# 88.01% Completed
# 88.02% Completed
# 88.03% Completed
# 88.04% Completed
# 88.05% Completed
# 88.06% Completed
# 88.08% Completed
# 88.09% Completed
# 88.10% Completed
# 88.11% Completed
# 88.12% Completed
# 88.13% Completed
# 88.14% Completed
# 88.16% Completed
# 88.17% Completed
# 88.18% Completed
# 88.19% Completed
# 88.20% Completed
# 88.21% Completed
# 88.23% Completed
# 88.24% Completed
# 88.25% Completed
# 88.26% Completed
# 88.27% Completed
# 88.28% Completed
# 88.30% Completed
# 88.31% Completed
# 88.32% Completed
# 88.33% Completed
# 88.34% Completed
# 88.35% Completed
# 88.36% Completed
# 88.38% Completed
# 88.39% Completed
# 88.40% Completed
# 88.41% Completed
# 88.42% Completed
# 88.43% Completed
# 88.45% Completed
# 88.46% Completed
# 88.47% Completed
# 88.48% Completed
# 88.49% Completed
# 88.50% Completed
# 88.51% Completed
# 88.53% Completed
# 88.54% Completed
# 88.55% Completed
# 88.56% Completed
# 88.57% Completed
# 88.58% Completed
# 88.60% Completed
# 88.61% Completed
# 88.62% Completed
# 88.63% Completed
# 88.64% Completed
# 88.65% Completed
# 88.66% Completed
# 88.68% Completed
# 88.69% Completed
# 88.70% Completed
# 88.71% Completed
# 88.72% Completed
# 88.73% Completed
# 88.75% Completed
# 88.76% Completed
# 88.77% Completed
# 88.78% Completed
# 88.79% Completed
# 88.80% Completed
# 88.81% Completed
# 88.83% Completed
# 88.84% Completed
# 88.85% Completed
# 88.86% Completed
# 88.87% Completed
# 88.88% Completed
# 88.90% Completed
# 88.91% Completed
# 88.92% Completed
# 88.93% Completed
# 88.94% Completed
# 88.95% Completed
# 88.96% Completed
# 88.98% Completed
# 88.99% Completed
# 89.00% Completed
# 89.01% Completed
# 89.02% Completed
# 89.03% Completed
# 89.05% Completed
# 89.06% Completed
# 89.07% Completed
# 89.08% Completed
# 89.09% Completed
# 89.10% Completed
# 89.11% Completed
# 89.13% Completed
# 89.14% Completed
# 89.15% Completed
# 89.16% Completed
# Failed prices for TAL.W
# 89.16% Completed
# 89.17% Completed
# 89.18% Completed
# 89.20% Completed
# 89.21% Completed
# 89.22% Completed
# 89.23% Completed
# 89.24% Completed
# 89.25% Completed
# 89.26% Completed
# 89.28% Completed
# 89.29% Completed
# 89.30% Completed
# 89.31% Completed
# 89.32% Completed
# 89.33% Completed
# 89.35% Completed
# 89.36% Completed
# 89.37% Completed
# 89.38% Completed
# 89.39% Completed
# 89.40% Completed
# 89.41% Completed
# 89.43% Completed
# 89.44% Completed
# 89.45% Completed
# 89.46% Completed
# 89.47% Completed
# 89.48% Completed
# 89.50% Completed
# 89.51% Completed
# 89.52% Completed
# 89.53% Completed
# 89.54% Completed
# 89.55% Completed
# 89.56% Completed
# 89.58% Completed
# 89.59% Completed
# 89.60% Completed
# 89.61% Completed
# 89.62% Completed
# 89.63% Completed
# 89.65% Completed
# 89.66% Completed
# 89.67% Completed
# 89.68% Completed
# 89.69% Completed
# 89.70% Completed
# 89.71% Completed
# 89.73% Completed
# 89.74% Completed
# 89.75% Completed
# 89.76% Completed
# 89.77% Completed
# 89.78% Completed
# 89.80% Completed
# 89.81% Completed
# 89.82% Completed
# 89.83% Completed
# 89.84% Completed
# 89.85% Completed
# 89.86% Completed
# 89.88% Completed
# 89.89% Completed
# 89.90% Completed
# 89.91% Completed
# 89.92% Completed
# 89.93% Completed
# 89.95% Completed
# 89.96% Completed
# 89.97% Completed
# 89.98% Completed
# 89.99% Completed
# 90.00% Completed
# 90.02% Completed
# 90.03% Completed
# 90.04% Completed
# 90.05% Completed
# 90.06% Completed
# 90.07% Completed
# 90.08% Completed
# 90.10% Completed
# 90.11% Completed
# 90.12% Completed
# 90.13% Completed
# 90.14% Completed
# 90.15% Completed
# 90.17% Completed
# 90.18% Completed
# 90.19% Completed
# 90.20% Completed
# 90.21% Completed
# 90.22% Completed
# 90.23% Completed
# 90.25% Completed
# 90.26% Completed
# 90.27% Completed
# 90.28% Completed
# 90.29% Completed
# 90.30% Completed
# 90.32% Completed
# 90.33% Completed
# 90.34% Completed
# 90.35% Completed
# 90.36% Completed
# 90.37% Completed
# 90.38% Completed
# 90.40% Completed
# 90.41% Completed
# 90.42% Completed
# 90.43% Completed
# 90.44% Completed
# 90.45% Completed
# 90.47% Completed
# 90.48% Completed
# 90.49% Completed
# 90.50% Completed
# 90.51% Completed
# 90.52% Completed
# 90.53% Completed
# 90.55% Completed
# 90.56% Completed
# 90.57% Completed
# 90.58% Completed
# 90.59% Completed
# 90.60% Completed
# 90.62% Completed
# 90.63% Completed
# 90.64% Completed
# 90.65% Completed
# 90.66% Completed
# 90.67% Completed
# 90.68% Completed
# 90.70% Completed
# 90.71% Completed
# 90.72% Completed
# 90.73% Completed
# 90.74% Completed
# Failed prices for UUU.W
# 90.74% Completed
# 90.75% Completed
# 90.77% Completed
# 90.78% Completed
# 90.79% Completed
# 90.80% Completed
# 90.81% Completed
# 90.82% Completed
# 90.83% Completed
# 90.85% Completed
# 90.86% Completed
# 90.87% Completed
# 90.88% Completed
# 90.89% Completed
# 90.90% Completed
# 90.92% Completed
# 90.93% Completed
# 90.94% Completed
# 90.95% Completed
# 90.96% Completed
# 90.97% Completed
# 90.98% Completed
# 91.00% Completed
# 91.01% Completed
# 91.02% Completed
# 91.03% Completed
# 91.04% Completed
# 91.05% Completed
# 91.07% Completed
# 91.08% Completed
# 91.09% Completed
# 91.10% Completed
# 91.11% Completed
# 91.12% Completed
# 91.13% Completed
# 91.15% Completed
# 91.16% Completed
# 91.17% Completed
# 91.18% Completed
# 91.19% Completed
# 91.20% Completed
# 91.22% Completed
# 91.23% Completed
# 91.24% Completed
# 91.25% Completed
# 91.26% Completed
# 91.27% Completed
# 91.28% Completed
# 91.30% Completed
# 91.31% Completed
# 91.32% Completed
# 91.33% Completed
# 91.34% Completed
# 91.35% Completed
# 91.37% Completed
# 91.38% Completed
# 91.39% Completed
# 91.40% Completed
# 91.41% Completed
# 91.42% Completed
# 91.43% Completed
# 91.45% Completed
# 91.46% Completed
# 91.47% Completed
# 91.48% Completed
# 91.49% Completed
# 91.50% Completed
# 91.52% Completed
# 91.53% Completed
# 91.54% Completed
# 91.55% Completed
# 91.56% Completed
# 91.57% Completed
# 91.58% Completed
# 91.60% Completed
# 91.61% Completed
# 91.62% Completed
# 91.63% Completed
# 91.64% Completed
# 91.65% Completed
# 91.67% Completed
# 91.68% Completed
# 91.69% Completed
# 91.70% Completed
# 91.71% Completed
# 91.72% Completed
# 91.73% Completed
# 91.75% Completed
# 91.76% Completed
# 91.77% Completed
# 91.78% Completed
# 91.79% Completed
# 91.80% Completed
# 91.82% Completed
# 91.83% Completed
# 91.84% Completed
# 91.85% Completed
# 91.86% Completed
# 91.87% Completed
# 91.89% Completed
# 91.90% Completed
# 91.91% Completed
# 91.92% Completed
# 91.93% Completed
# 91.94% Completed
# 91.95% Completed
# 91.97% Completed
# 91.98% Completed
# 91.99% Completed
# 92.00% Completed
# 92.01% Completed
# 92.02% Completed
# 92.04% Completed
# 92.05% Completed
# 92.06% Completed
# 92.07% Completed
# 92.08% Completed
# 92.09% Completed
# 92.10% Completed
# 92.12% Completed
# 92.13% Completed
# 92.14% Completed
# 92.15% Completed
# 92.16% Completed
# 92.17% Completed
# 92.19% Completed
# 92.20% Completed
# 92.21% Completed
# 92.22% Completed
# 92.23% Completed
# 92.24% Completed
# 92.25% Completed
# 92.27% Completed
# 92.28% Completed
# 92.29% Completed
# 92.30% Completed
# 92.31% Completed
# 92.32% Completed
# 92.34% Completed
# 92.35% Completed
# 92.36% Completed
# 92.37% Completed
# 92.38% Completed
# 92.39% Completed
# 92.40% Completed
# 92.42% Completed
# 92.43% Completed
# 92.44% Completed
# 92.45% Completed
# 92.46% Completed
# 92.47% Completed
# 92.49% Completed
# 92.50% Completed
# 92.51% Completed
# 92.52% Completed
# 92.53% Completed
# 92.54% Completed
# 92.55% Completed
# 92.57% Completed
# 92.58% Completed
# 92.59% Completed
# 92.60% Completed
# 92.61% Completed
# 92.62% Completed
# 92.64% Completed
# 92.65% Completed
# 92.66% Completed
# 92.67% Completed
# 92.68% Completed
# 92.69% Completed
# 92.70% Completed
# 92.72% Completed
# 92.73% Completed
# 92.74% Completed
# 92.75% Completed
# 92.76% Completed
# 92.77% Completed
# 92.79% Completed
# 92.80% Completed
# 92.81% Completed
# 92.82% Completed
# 92.83% Completed
# 92.84% Completed
# 92.85% Completed
# 92.87% Completed
# 92.88% Completed
# 92.89% Completed
# 92.90% Completed
# 92.91% Completed
# Completed in 34162.94179940224 seconds

# %%
# spx = hist_prices('^GSPC', start_date)
# spx = spx.sort_index(ascending = True)
# spx['Underlying'] = 'SPX'
# spx = spx[['Underlying','adjclose']]
# spx['industry'] = 'SP500'
# spx['sector'] = 'Index'

# %%
start_time = time.time()
i = 0
total_length = len(us_names)
return_engine = create_engine('sqlite:///returnProfiles.db', echo = False)

for ticker in us_names:
    annual_returns, annualDDs, annualDownsides, annualVols, quarterly_returns, quarterlyDDs, quarterlyDownsides, quarterlyVols = return_profiles(ticker)
    if type(annual_returns) != str and ticker != 'AAPL':
        annual_returns.to_sql('annualReturns', con=return_engine, 
                              if_exists='append', index_label = 'Underlying')
        annualDDs.to_sql('annualDDs', con=return_engine, 
                         if_exists='append', index_label = 'Underlying')
        annualDownsides.to_sql('annualDownsides', con=return_engine, 
                               if_exists='append', index_label = 'Underlying')
        annualVols.to_sql('annualVols', con=return_engine, 
                          if_exists='append', index_label = 'Underlying')
        
        quarterly_returns.to_sql('quarterlyReturns', con=return_engine, 
                                 if_exists='append', index_label = 'Underlying')
        quarterlyDDs.to_sql('quarterlyDDs', con=return_engine, 
                            if_exists='append', index_label = 'Underlying')
        quarterlyDownsides.to_sql('quarterlyDownsides', con=return_engine, 
                                  if_exists='append', index_label = 'Underlying')
        quarterlyVols.to_sql('quarterlyVols', con=return_engine, 
                             if_exists='append', index_label = 'Underlying')    
    i += 1
    print('{0:.2f}% Completed'.format(i/total_length*100))

print("Completed in %s seconds" % (time.time() - start_time))
