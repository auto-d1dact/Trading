# %% [markdown]
# # Portfolio Methodolgy
#
# 1. DGI/Growth Names - Rebalance every 6 months picking around 2 - 3 names from CA and US universe
#     - Sell Covered Calls on names and re-enter if called away.
#     - **GTC Stop Limit of 5% on each name**
# 2. VAA/PAA - Rebalance every month on trading day 1
# 3. LEAPS - Rebalance every 3 months picking around 3 - 8 names from US universe (high growth potential names)
#     - Current Holdings: LOPE STOR PNW SBUX
#     - LOPE Earnings: Nov 8
#     - PNW Earnings: Nov 8
#     - SBUX Earnings: Jan 23
#         - **Exit Criteria: When the call option drops below 60 delta**
# 4. Short Vol - Short SPX Spreads at the beginning of the month and hold until second or last week to maturity
#     - Potentially long UVXY/VXX puts at beginning of the month with bracket orders
#     - **Short ATM SPX Put spreads around 25 points wide**
#         - **Long bi-weekly unit puts, around -7% or so of SPX spot (or something with a cost of 15% of the credit)**
#         - **The SPX put spread will have a capped max loss of 2,500 per contract, while in low volatility, the bi-weekly units are severely underpriced and will explode 10X to 20X in value if the long strike in the spread gets tested. Vega and Gamma play a huge factor in the repricing of these units.**
#         - Initiate the units every 2 weeks letting them run to expiry
# 5. Barbell Hedging
#     - Long SPX puts or VIX calls during high crisis potential moments
#         - Initiate bracket orders with SPX Puts: +/- 30% of Cost Basis
#     - Check VIX Futures volume trends and see impact of Feb 5, 2018
#     - Only trade 4 naked SPX puts in Reg accounts
#         - Sell half into profits/losses
#     - Only trade 6 3:1 Put back ratios in Reg Account: Leg into these positions because of how illiquid the market is
#     - Take losses immediately (10% - 30% of Cost Basis)
#     - NEVER EVER try to put on a position of the market is illiquid: YOU WILL get filled at horrible prices
#     - **Put on 1-5 Delta strangles on the open of the day and close position at the end of the day around 2 pm to 3 pm**
# 6. Treasuries - Re-establish monthly bills beginning of month or at maturity
#
# ##### Strategy Weights
# |Strategy|Weight|Last Rebal|Next Check|Next Full Rebal|
# |-|-|-|-|-|
# |VAA/PAA|25%|11/01/2018|12/01/2018|12/01/2018|
# |LEAPs|5%|11/01/2018|12/01/2018|01/01/2019|
# |Short Vol|2%|NA|NA|NA|
# |Barbell Hedging|1.5%|11/06/2018|11/09/2018|11/19/2018|
# |Treasuries|60%|11/01/2018|11/29/2018|12/01/2018|

# %% [markdown]
# ## Key Modules to Run
#
# - fundamental_data_collect.py to run monthly to collected latest financial statements and key stats from yahoo
# - finstatement_cleaning.py to run right after fundamental_data_collect.py to create cleaned data for earnings plays

# %%
# Importing necessary models
import warnings
warnings.filterwarnings('ignore')

import smtplib
import pandas as pd
import numpy as np
import datetime as dt
import pandas.stats.moments as st
import time
# %matplotlib inline
import plotly.plotly as py
import plotly.graph_objs as go
from plotly.offline import download_plotlyjs, init_notebook_mode, plot, iplot

init_notebook_mode(connected=True)

import os
main_dir = os.getcwd()

os.chdir('C:\\Users\\Fang\\Desktop\\Python Trading\\Trading\\Trading\\Modules\\DataCollection')

from alphavantage import *
from yahoo_query import *
from option_slam_earnings import *
from reuters_query import reuters_query
from alphaquery import alphaquery

os.chdir('C:\\Users\\Fang\\Desktop\\Python Trading\\Trading\\Trading\\Modules\\Options')
from optionsFunctions import *

os.chdir('C:\\Users\\Fang\\Desktop\\Python Trading\\Trading\\Trading\\Modules\\Earnings')
from yahoo_earnings import *
from lookup_earnings import lookup_earnings

os.chdir('C:\\Users\\Fang\\Desktop\\Python Trading\\Trading\\Trading\\Modules\\Processing')
from hv_calc import *

os.chdir(main_dir)
# Out:
# <script>requirejs.config({paths: { 'plotly': ['https://cdn.plot.ly/plotly-latest.min']},});if(!window.Plotly) {{require(['plotly'],function(plotly) {window.Plotly=plotly;});}}</script>

# %% [markdown]
# # Allocate Smartly Checking

# %%
# Short Call Assignment Price - 287.5

portfolio_value =  200000

as_lst = ['DBC',
        'HYG',
        'IEF',
        'IWM',
        'LQD',
        'QQQ',
        'SPY',
        'VNQ']
as_wgt = [0.014,
        0.014,
        0.417,
        0.014,
        0.500,
        0.014,
        0.014,
        0.014]

as_df = pd.DataFrame({'Allocation': as_wgt}, index = as_lst)
curr_spot = curr_batch_quotes(as_lst)
as_df = pd.concat([as_df,curr_spot[['price']]], axis = 1)

as_df['Market Value'] = portfolio_value*as_df.Allocation
as_df['Holdings'] = np.round(as_df['Market Value']/as_df.price,0)

as_df
# Out:
#         Allocation    price  Market Value  Holdings
# symbol
# DBC          0.014   16.705        2800.0     168.0
# HYG          0.014   84.540        2800.0      33.0
# IEF          0.417   99.930       83400.0     835.0
# IWM          0.014  154.610        2800.0      18.0
# LQD          0.500  112.145      100000.0     892.0
# QQQ          0.014  170.710        2800.0      16.0
# SPY          0.014  275.550        2800.0      10.0
# VNQ          0.014   79.585        2800.0      35.0

# %% [markdown]
# ## Checking market correlations

# %%
rolling_window = 60
plot_window = 10000

corr_df, sector_df = check_mkt_corr(rolling_window, plot_window)
print(corr_df.tail())
# Out:
#                 XLRE       XLV       XLI       XLK       XLP       XLU  \
# 2018-10-31  0.395356  0.908453  0.852474  0.916932  0.415250 -0.006917
# 2018-11-01  0.399878  0.910993  0.856426  0.917836  0.427726 -0.016608
# 2018-11-02  0.404528  0.911463  0.855520  0.914758  0.431493 -0.010320
# 2018-11-05  0.406407  0.911579  0.855287  0.911142  0.435100  0.000804
# 2018-11-06  0.410559  0.912896  0.856025  0.912025  0.438923  0.009735
#
#                  XLB       XLF       XLE       XLY  Avg_Corr   SPY_cum
# 2018-10-31  0.759625  0.813259  0.729650  0.906124  0.669021  1.773914
# 2018-11-01  0.759765  0.812704  0.734797  0.907035  0.671055  1.803434
# 2018-11-02  0.761571  0.811104  0.735113  0.901108  0.671634  1.786829
# 2018-11-05  0.760761  0.807639  0.746910  0.898857  0.673448  1.802204
# 2018-11-06  0.761025  0.809330  0.748661  0.898487  0.675767  1.819833

# %%
((sector_df.dropna() + 1).cumprod()-1).tail()
# Out:
#                  SPY      XLRE       XLV       XLI       XLK       XLP  \
# 2018-10-31 -0.017677  0.018730  0.045251 -0.045746 -0.029819  0.077360
# 2018-11-01 -0.007223  0.022540  0.058449 -0.028950 -0.018480  0.084998
# 2018-11-02 -0.013103  0.013968  0.051850 -0.030589 -0.037659  0.079318
# 2018-11-05 -0.007659  0.030794  0.061160 -0.025536 -0.038639  0.092832
# 2018-11-06 -0.001416  0.036508  0.066580 -0.015294 -0.032619  0.099295
#
#                  XLU       XLB       XLF       XLE       XLY       XLC
# 2018-10-31  0.069735 -0.100530 -0.039122 -0.101418 -0.057255 -0.078463
# 2018-11-01  0.064953 -0.075227 -0.034735 -0.093792 -0.038021 -0.073058
# 2018-11-02  0.058976 -0.077449 -0.035466 -0.096066 -0.034085 -0.082466
# 2018-11-05  0.073919 -0.074714 -0.020110 -0.080947 -0.032743 -0.086269
# 2018-11-06  0.081490 -0.059497 -0.014991 -0.076666 -0.028449 -0.080865

# %% [markdown]
# ## Earnings
#
# **Key modules to run**
# - new_earnings_setup.py for given date in string form 'yyyy-mm-dd': this gives the latest input data for earnings_prediction
# - earnings_prediction.py for determining position to take on earnings name

# %%
date_lookup = '2018-11-08'

curr_earnings = date_earnings(date_lookup)
curr_earnings = curr_earnings[curr_earnings['Call Time'].isin(['After Market Close', 'Before Market Open'])]

# %%
acs = curr_earnings[curr_earnings['Call Time'] == 'After Market Close']
bcs = curr_earnings[curr_earnings['Call Time'] == 'Before Market Open']
focus_names = acs.index.drop_duplicates().tolist()
acs
# Out:
#                 Call Time EPS Estimate                                    Name
# UEPS   After Market Close         0.14             Net 1 UEPS Technologies Inc
# JOBS   After Market Close         0.61                               51job Inc
# ARA    After Market Close         0.15  American Renal Associates Holdings Inc
# AMC    After Market Close        -0.47          AMC Entertainment Holdings Inc
# AGO    After Market Close         0.72                    Assured Guaranty Ltd
# AL     After Market Close         1.22                          Air Lease Corp
# ATVI   After Market Close          0.5                 Activision Blizzard Inc
# AUTO   After Market Close        -0.13                             AutoWeb Inc
# AREX   After Market Close        -0.08                  Approach Resources Inc
# DOX    After Market Close         0.99                              Amdocs Ltd
# BREW   After Market Close         0.13                 Craft Brew Alliance Inc
# ARRS   After Market Close         0.67                 ARRIS International plc
# ATAI   After Market Close            -                                 ATA Inc
# NOG    After Market Close         0.12                Northern Oil and Gas Inc
# BDSI   After Market Close        -0.14  BioDelivery Sciences International Inc
# BPI    After Market Close         0.22               Bridgepoint Education Inc
# BRS    After Market Close        -0.64                       Bristow Group Inc
# CHRS   After Market Close            -                 Coherus BioSciences Inc
# CLBS   After Market Close        -0.56               Caladrius Biosciences Inc
# BOJA   After Market Close         0.15                           Bojangles Inc
# BCEI   After Market Close         1.18                Bonanza Creek Energy Inc
# CBPX   After Market Close         0.47       Continental Building Products Inc
# BW     After Market Close         0.03    Babcock &amp; Wilcox Enterprises Inc
# VRTU   After Market Close         0.54                            Virtusa Corp
# LAND   After Market Close        -0.04                     Gladstone Land Corp
# RM     After Market Close         0.83                Regional Management Corp
# UIS    After Market Close         0.41                             Unisys Corp
# CTL    After Market Close          0.3                         CenturyLink Inc
# CLW    After Market Close         0.43                   Clearwater Paper Corp
# TRTC   After Market Close            -                         Terra Tech Corp
# ...                   ...          ...                                     ...
# GLIBA  After Market Close         0.26                         GCI Liberty Inc
# HTZ    After Market Close         1.71               Hertz Global Holdings Inc
# HDP    After Market Close        -0.13                         Hortonworks Inc
# MCFT   After Market Close         0.51                       MCBC Holdings Inc
# ONVO   After Market Close        -0.07                   Organovo Holdings Inc
# HYRE   After Market Close            -                             Hyrecar Inc
# HNGR   After Market Close          0.2                              Hanger Inc
# TCDA   After Market Close        -0.84                             Tricida Inc
# YELP   After Market Close          0.1                                Yelp Inc
# NNI    After Market Close         1.25                              Nelnet Inc
# SWKS   After Market Close         1.92                  Skyworks Solutions Inc
# TRUP   After Market Close        -0.01                           Trupanion Inc
# ISR    After Market Close        -0.02                              IsoRay Inc
# MTD    After Market Close            5        Mettler-Toledo International Inc
# LPSN   After Market Close         0.02                          LivePerson Inc
# NSTG   After Market Close        -0.57             NanoString Technologies Inc
# TNAV   After Market Close        -0.22                             Telenav Inc
# OSTK   After Market Close         -0.8                       Overstock.com Inc
# SGMO   After Market Close        -0.15                Sangamo Therapeutics Inc
# SYNA   After Market Close         1.14                           Synaptics Inc
# INLX   After Market Close        -0.03                       Intellinetics Inc
# NTRA   After Market Close        -0.47                              Natera Inc
# TOCA   After Market Close        -0.45                             Tocagen Inc
# ITP    After Market Close            -                   IT Tech Packaging Inc
# PDFS   After Market Close         0.03                       PDF Solutions Inc
# INWK   After Market Close         0.12                       InnerWorkings Inc
# MIME   After Market Close         0.03                            Mimecast Ltd
# SMLP   After Market Close         0.25            Summit Midstream Partners LP
# RWLK   After Market Close        -0.14                     Rewalk Robotics Ltd
# TSE    After Market Close         1.88                              Trinseo SA
#
# [81 rows x 3 columns]

# %%
start_time = time.time()

start_date = dt.datetime(2018,1,1)

earnings_data = lookup_earnings(focus_names, start_date)

print("--- %s seconds ---" % (time.time() - start_time))

# %%
#################### Preliminary Name Selection ###################################
summary_df = earnings_data[1]
summary_df = summary_df[summary_df['Market Cap(Mil.)'] > 500].sort_values('Market Cap(Mil.)')

eps_df = earnings_data[0]
eps_df = eps_df[eps_df.Underlying.isin(summary_df.index)]
eps_df['NegativeSurprise'] = eps_df['surprisePercent'] < 0 
eps_df['PositiveSurprise'] = eps_df['surprisePercent'] > 0
eps_df['returnDifferentFromEPS'] = eps_df['surprisePercent']*eps_df['Stock_closeToOpen'] < 0
eps_df['LargeMoves'] = abs(eps_df['Stock_closeToOpen']) > 0.02

eps_corr = eps_df[['Underlying','NegativeSurprise',
                   'PositiveSurprise',
                   'returnDifferentFromEPS']].groupby('Underlying').sum()
eps_corr['surpriseReturnCorrelation'] = np.nan
corrs = []
for ticker in eps_corr.index:
    curr_corr = eps_df[eps_df['Underlying'] == ticker]
    corrs.append(curr_corr[['surprisePercent','Stock_closeToOpen']].corr().iloc[0,1])
eps_corr['surpriseReturnCorrelation'] = corrs
eps_corr['LargeMoves'] = eps_df[['Underlying','LargeMoves']].groupby('Underlying').sum()

selected_names = eps_corr[eps_corr['LargeMoves'] > 2].index.tolist()

#################### Filtering on Preliminary Name Selection ###################################
summary_df = summary_df[summary_df.index.isin(selected_names)]

eps_df = eps_df[eps_df.Underlying.isin(summary_df.index)]
eps_corr = eps_corr[eps_corr.index.isin(summary_df.index)]

scores_df = earnings_data[2]
scores_df = scores_df[scores_df.index.isin(summary_df.index)]
scores_df['TotalScore'] = scores_df.mean(axis = 1)
scores_df = scores_df.sort_values('TotalScore')

analyst_df = earnings_data[3]
analyst_df = analyst_df[analyst_df.index.isin(summary_df.index)]

valuations_df = earnings_data[4]
valuations_df = valuations_df[valuations_df.Underlying.isin(summary_df.index)]

growthrate_df = earnings_data[5]
growthrate_df = growthrate_df[growthrate_df.Underlying.isin(summary_df.index)]

profitability_df = earnings_data[6]
profitability_df = profitability_df[profitability_df.Underlying.isin(summary_df.index)]

finstrength_df = earnings_data[7]
finstrength_df = finstrength_df[finstrength_df.Underlying.isin(summary_df.index)]

perf_df = earnings_data[8]
perf_df = perf_df[perf_df.Underlying.isin(summary_df.index)]

rev_revisions_df = earnings_data[9]
rev_revisions_df = rev_revisions_df[rev_revisions_df.Underlying.isin(summary_df.index)]

earnings_revisions_df = earnings_data[10]
earnings_revisions_df = earnings_revisions_df[earnings_revisions_df.Underlying.isin(summary_df.index)]

insider_trades = earnings_data[11]
insider_trades = insider_trades[insider_trades.Underlying.isin(summary_df.index)]
insider_trades['Trading Date'] = pd.to_datetime(insider_trades['Trading Date'])
def aggregate_txns_date(trade_date):
    
    trade_month = trade_date.month
    trade_year = trade_date.year
    if trade_month <= 3:
        return dt.datetime(trade_year,3,31).date()
    elif trade_month <= 6:
        return dt.datetime(trade_year,6,30).date()
    elif trade_month <= 9:
        return dt.datetime(trade_year,9,30).date()
    else:
        return dt.datetime(trade_year,12,31).date()
    
insider_trades['Trading Date'] = insider_trades['Trading Date'].apply(aggregate_txns_date)

growth_sums = earnings_data[12]
growth_sums = growth_sums[growth_sums.Underlying.isin(summary_df.index)]

# %%
selected_names = scores_df.sort_values(['ValuationScore','TotalScore']).index.tolist()

options_dict = {}

for name in selected_names:
    
    try:
        curr_options = all_options(name,100,1,moneyness=0.1)
        if len(curr_options) > 0 and (curr_options['Ask'] - curr_options['Bid']).mean() < 1:
            options_dict[name] = curr_options
    except:
        None

# %%
selected_names = shorts + longs#list(options_dict.keys()) #

for selected_name in selected_names:
    print(selected_name)
    for i, df in enumerate(earnings_data):
        if i == 2 or i == 3 or i == 1:
            None #print(df[df.index == selected_name])
        elif i == 11:
            #print(df[df.Underlying == selected_name][df.columns.tolist()[1:-1]])
            print(insider_trades[insider_trades.Underlying == selected_name].groupby(['Trading Date','Title',
                                                                                      'Type']).agg({'Underlying':'count',
                                                                                                    'Shares Traded': 'sum'}))
        else:
            print(df[df.Underlying == selected_name])
        print('\n')
# Out:
# OSTK
#   epsActual epsDifference epsEstimate  surprisePercent Underlying    Quarter  \
# 0     -0.03          0.06       -0.09            0.667       OSTK 2017-09-30
# 1     -0.47         -0.42       -0.05           -8.400       OSTK 2017-12-31
# 2     -1.78         -0.87       -0.91           -0.956       OSTK 2018-03-31
# 3     -2.25         -1.43       -0.82           -1.744       OSTK 2018-06-30
#
#    Stock_closeToOpen EarningsDate
# 0           0.147132   2017-11-08
# 1          -0.153527   2018-03-15
# 2          -0.022281   2018-05-08
# 3           0.216321   2018-08-09
#
#
#
#
#
#
#
#
#    Company                         Field  industry  sector Underlying
# 0      NaN               P/E Ratio (TTM)     27.05   10.67       OSTK
# 1   124.02        P/E High - Last 5 Yrs.     58.98   22.68       OSTK
# 2     8.87         P/E Low - Last 5 Yrs.     27.01    9.97       OSTK
# 3     1.79                          Beta      1.05    1.10       OSTK
# 4     0.31          Price to Sales (TTM)      6.25  257.49       OSTK
# 5     4.70           Price to Book (MRQ)      5.68    1.95       OSTK
# 6     7.87  Price to Tangible Book (MRQ)      9.30    2.95       OSTK
# 7      NaN      Price to Cash Flow (TTM)     19.33   14.19       OSTK
#
#
#    Company                                 Field  industry  sector Underlying
# 0    11.83         Sales (MRQ) vs Qtr. 1 Yr. Ago     18.70    3.04       OSTK
# 1    -1.28          Sales (TTM) vs TTM 1 Yr. Ago     20.03   17.26       OSTK
# 2     9.68             Sales - 5 Yr. Growth Rate     20.69    5.78       OSTK
# 3  -649.34           EPS (MRQ) vs Qtr. 1 Yr. Ago     54.42   10.46       OSTK
# 4 -1178.26            EPS (TTM) vs TTM 1 Yr. Ago       NaN     NaN       OSTK
# 5      NaN               EPS - 5 Yr. Growth Rate     24.55   16.42       OSTK
# 6    13.55  Capital Spending - 5 Yr. Growth Rate     22.01   12.12       OSTK
#
#
#    Company                           Field  industry  sector Underlying
# 0    19.63              Gross Margin (TTM)     37.00   43.11       OSTK
# 1    18.78       Gross Margin - 5 Yr. Avg.     40.68   38.53       OSTK
# 2    -6.88              EBITD Margin (TTM)       NaN     NaN       OSTK
# 3     1.12               EBITD - 5 Yr. Avg     29.99   23.26       OSTK
# 4    -8.60          Operating Margin (TTM)     21.88   21.32       OSTK
# 5    -0.31   Operating Margin - 5 Yr. Avg.     24.63   14.17       OSTK
# 6    -8.41            Pre-Tax Margin (TTM)     31.58   23.07       OSTK
# 7     0.07     Pre-Tax Margin - 5 Yr. Avg.     27.92   15.47       OSTK
# 8   -10.67         Net Profit Margin (TTM)     25.43   16.95       OSTK
# 9     0.24  Net Profit Margin - 5 Yr. Avg.     20.37   11.65       OSTK
#
#
#    Company                       Field  industry  sector Underlying
# 0     0.85           Quick Ratio (MRQ)      1.21    1.82       OSTK
# 1     0.91         Current Ratio (MRQ)      2.73    2.32       OSTK
# 2     2.55     LT Debt to Equity (MRQ)     32.22    8.16       OSTK
# 3     2.55  Total Debt to Equity (MRQ)     39.07   15.97       OSTK
# 4    -9.35     Interest Coverage (TTM)     20.99   15.24       OSTK
#
#
#    IndustryRank  PercentActual  Percentvs.S&P500   Period  RankInIndustry  \
# 0          13.0         -27.27            -23.98   4 Week            36.0
# 1           7.0         -49.17            -47.27  13 Week            48.0
# 2          18.0         -48.83            -50.38  26 Week            94.0
# 3          12.0         -51.86            -54.73  52 Week            99.0
# 4          10.0         -69.45            -70.36      YTD            61.0
#
#   Underlying
# 0       OSTK
# 1       OSTK
# 2       OSTK
# 3       OSTK
# 4       OSTK
#
#
#    Down Last4Weeks  Down LastWeek      NumberOfRevisions  Up Last4Weeks  \
# 0              0.0            0.0  Quarter Ending Dec-18            0.0
# 1              0.0            0.0  Quarter Ending Mar-19            0.0
# 2              0.0            0.0     Year Ending Dec-18            0.0
# 3              0.0            0.0     Year Ending Dec-19            0.0
#
#    Up LastWeek Underlying
# 0          0.0       OSTK
# 1          0.0       OSTK
# 2          0.0       OSTK
# 3          0.0       OSTK
#
#
# Empty DataFrame
# Columns: [Down Last4Weeks, Down LastWeek, NumberOfRevisions, Up Last4Weeks, Up LastWeek, Underlying]
# Index: []
#
#
#                                            Underlying  Shares Traded
# Trading Date Title                   Type
# 2018-06-30   Director                Buy           24       528024.0
#              Officer                 Buy           16        40000.0
#                                      Gift           8         8000.0
#                                      Sell          40        63744.0
# 2018-09-30   Chief Executive Officer Sell          40      6194424.0
#              Officer                 Gift           8         2664.0
#                                      Sell          48        58400.0
# 2018-12-31   Officer                 Buy            8        24536.0
#                                      Sell           8         7208.0
#
#
#    1 Year  3 Year  5 Year        Field Underlying
# 0   -3.07    5.24    9.68      Sales %       OSTK
# 1 -763.49     NaN     NaN  EPS (TTM) %       OSTK
# 2     NaN     NaN     NaN   Dividend %       OSTK
#
#
# TRUP
#   epsActual epsDifference epsEstimate  surprisePercent Underlying    Quarter  \
# 0      0.01          0.05       -0.04             1.25       TRUP 2017-09-30
# 1     -0.03         -0.01       -0.02            -0.50       TRUP 2017-12-31
# 2     -0.05         -0.01       -0.04            -0.25       TRUP 2018-03-31
# 3     -0.01          0.03       -0.04             0.75       TRUP 2018-06-30
#
#    Stock_closeToOpen EarningsDate
# 0           0.072961   2017-11-02
# 1          -0.055964   2018-02-13
# 2          -0.037346   2018-05-01
# 3           0.159750   2018-08-02
#
#
#
#
#
#
#
#
#      Company                         Field  industry  sector Underlying
# 0        NaN               P/E Ratio (TTM)     14.25   19.19       TRUP
# 1        NaN        P/E High - Last 5 Yrs.     18.14   25.08       TRUP
# 2        NaN         P/E Low - Last 5 Yrs.      9.26   11.20       TRUP
# 3        NaN                          Beta      0.62    1.49       TRUP
# 4       3.81          Price to Sales (TTM)      1.41    5.59       TRUP
# 5      17.21           Price to Book (MRQ)      1.17    2.66       TRUP
# 6      19.23  Price to Tangible Book (MRQ)      1.45    2.77       TRUP
# 7  202844.91      Price to Cash Flow (TTM)     18.37   24.08       TRUP
#
#
#    Company                                 Field  industry  sector Underlying
# 0    27.15         Sales (MRQ) vs Qtr. 1 Yr. Ago      8.11   16.87       TRUP
# 1    27.68          Sales (TTM) vs TTM 1 Yr. Ago     12.86   11.10       TRUP
# 2    38.42             Sales - 5 Yr. Growth Rate      4.90   14.13       TRUP
# 3   136.93           EPS (MRQ) vs Qtr. 1 Yr. Ago      4.96   37.85       TRUP
# 4    61.48            EPS (TTM) vs TTM 1 Yr. Ago       NaN     NaN       TRUP
# 5      NaN               EPS - 5 Yr. Growth Rate     15.77   10.25       TRUP
# 6    25.64  Capital Spending - 5 Yr. Growth Rate      2.34   20.32       TRUP
#
#
#    Company                           Field  industry  sector Underlying
# 0    17.50              Gross Margin (TTM)      0.02    3.34       TRUP
# 1    17.82       Gross Margin - 5 Yr. Avg.      0.02    3.23       TRUP
# 2     5.92              EBITD Margin (TTM)       NaN     NaN       TRUP
# 3    -2.96               EBITD - 5 Yr. Avg      8.74   48.18       TRUP
# 4    -2.41          Operating Margin (TTM)      5.96   35.47       TRUP
# 5    -8.80   Operating Margin - 5 Yr. Avg.      6.72   40.75       TRUP
# 6    -2.06            Pre-Tax Margin (TTM)      6.87   35.96       TRUP
# 7   -10.12     Pre-Tax Margin - 5 Yr. Avg.      7.14   41.23       TRUP
# 8    -2.08         Net Profit Margin (TTM)      5.10   28.72       TRUP
# 9   -10.14  Net Profit Margin - 5 Yr. Avg.      5.35   32.62       TRUP
#
#
#    Company                       Field  industry  sector Underlying
# 0      NaN           Quick Ratio (MRQ)      0.00    0.05       TRUP
# 1     1.93         Current Ratio (MRQ)      0.00    1.81       TRUP
# 2    13.38     LT Debt to Equity (MRQ)     30.91   32.54       TRUP
# 3    13.38  Total Debt to Equity (MRQ)    310.95   75.04       TRUP
# 4    15.37     Interest Coverage (TTM)      7.18   10.62       TRUP
#
#
#    IndustryRank  PercentActual  Percentvs.S&P500   Period  RankInIndustry  \
# 0          32.0          23.12             18.88   4 Week            99.0
# 1          12.0          21.85             15.91  13 Week            99.0
# 2          23.0          82.65             68.76  26 Week            99.0
# 3          22.0          68.33             42.67  52 Week            99.0
# 4          17.0          74.29             53.06      YTD            99.0
#
#   Underlying
# 0       TRUP
# 1       TRUP
# 2       TRUP
# 3       TRUP
# 4       TRUP
#
#
#    Down Last4Weeks  Down LastWeek      NumberOfRevisions  Up Last4Weeks  \
# 0              0.0            0.0  Quarter Ending Dec-18            0.0
# 1              0.0            0.0  Quarter Ending Mar-19            0.0
# 2              0.0            0.0     Year Ending Dec-18            0.0
# 3              0.0            0.0     Year Ending Dec-19            0.0
#
#    Up LastWeek Underlying
# 0          0.0       TRUP
# 1          0.0       TRUP
# 2          0.0       TRUP
# 3          0.0       TRUP
#
#
# Empty DataFrame
# Columns: [Down Last4Weeks, Down LastWeek, NumberOfRevisions, Up Last4Weeks, Up LastWeek, Underlying]
# Index: []
#
#
#                                            Underlying  Shares Traded
# Trading Date Title                   Type
# 2018-09-30   Chief Executive Officer Sell          24        96000.0
#              Director                Buy           88        92104.0
#                                      Sell          40      2034216.0
#              Officer                 Buy            8         1200.0
#                                      Sell           8         1200.0
# 2018-12-31   Chief Executive Officer Sell          16        64000.0
#              Officer                 Buy            8         1200.0
#                                      Sell           8         1200.0
#
#
#    1 Year  3 Year  5 Year        Field Underlying
# 0   28.08   30.95   38.42      Sales %       TRUP
# 1   61.17     NaN     NaN  EPS (TTM) %       TRUP
# 2     NaN     NaN     NaN   Dividend %       TRUP
#
#
# PRAA
#   epsActual epsDifference epsEstimate  surprisePercent Underlying    Quarter  \
# 0      0.34          0.06        0.28            0.214       PRAA 2017-09-30
# 1       0.3         -0.04        0.34           -0.118       PRAA 2017-12-31
# 2      0.47          0.12        0.35            0.343       PRAA 2018-03-31
# 3      0.43             0        0.43            0.000       PRAA 2018-06-30
#
#    Stock_closeToOpen EarningsDate
# 0           0.078853   2017-11-08
# 1           0.148201   2018-02-27
# 2           0.073306   2018-05-09
# 3          -0.047859   2018-08-07
#
#
#
#
#
#
#
#
#    Company                         Field  industry  sector Underlying
# 0    17.85               P/E Ratio (TTM)     28.66   24.46       PRAA
# 1    21.31        P/E High - Last 5 Yrs.     29.85   40.42       PRAA
# 2    10.00         P/E Low - Last 5 Yrs.     15.31   13.95       PRAA
# 3     1.53                          Beta      0.72    0.95       PRAA
# 4     1.69          Price to Sales (TTM)   2219.22   45.95       PRAA
# 5     1.39           Price to Book (MRQ)      4.12    2.68       PRAA
# 6     3.21  Price to Tangible Book (MRQ)     14.55    4.42       PRAA
# 7    12.38      Price to Cash Flow (TTM)     16.21   16.05       PRAA
#
#
#    Company                                 Field  industry  sector Underlying
# 0   -12.31         Sales (MRQ) vs Qtr. 1 Yr. Ago     11.46   32.08       PRAA
# 1   -14.11          Sales (TTM) vs TTM 1 Yr. Ago   1884.64   56.44       PRAA
# 2    12.60             Sales - 5 Yr. Growth Rate      8.72    7.43       PRAA
# 3   -67.74           EPS (MRQ) vs Qtr. 1 Yr. Ago     23.75  109.43       PRAA
# 4   -39.00            EPS (TTM) vs TTM 1 Yr. Ago       NaN     NaN       PRAA
# 5    -1.21               EPS - 5 Yr. Growth Rate     19.10   12.72       PRAA
# 6     8.01  Capital Spending - 5 Yr. Growth Rate      9.76    8.12       PRAA
#
#
#    Company                           Field  industry  sector Underlying
# 0    85.35              Gross Margin (TTM)     33.12   30.50       PRAA
# 1    87.97       Gross Margin - 5 Yr. Avg.     33.04   29.01       PRAA
# 2    25.33              EBITD Margin (TTM)       NaN     NaN       PRAA
# 3    37.23               EBITD - 5 Yr. Avg     21.12   18.99       PRAA
# 4    21.72          Operating Margin (TTM)      4.43   14.65       PRAA
# 5    34.62   Operating Margin - 5 Yr. Avg.     16.44   13.90       PRAA
# 6    17.40            Pre-Tax Margin (TTM)      4.67   13.51       PRAA
# 7    29.71     Pre-Tax Margin - 5 Yr. Avg.     15.11   11.86       PRAA
# 8    10.79         Net Profit Margin (TTM)      0.18    9.65       PRAA
# 9    18.55  Net Profit Margin - 5 Yr. Avg.      9.88    8.24       PRAA
#
#
#    Company                       Field  industry  sector Underlying
# 0      NaN           Quick Ratio (MRQ)      1.61    2.08       PRAA
# 1      NaN         Current Ratio (MRQ)      2.02    2.49       PRAA
# 2   209.39     LT Debt to Equity (MRQ)     36.42   69.58       PRAA
# 3   209.39  Total Debt to Equity (MRQ)     51.07   90.93       PRAA
# 4     3.57     Interest Coverage (TTM)     23.05   63.83       PRAA
#
#
#    IndustryRank  PercentActual  Percentvs.S&P500   Period  RankInIndustry  \
# 0          49.0           3.71              0.13   4 Week            99.0
# 1          52.0         -22.76            -26.52  13 Week            24.0
# 2          55.0          -7.85            -14.85  26 Week            54.0
# 3          46.0         -15.47            -28.35  52 Week            46.0
# 4          43.0         -24.94            -34.08      YTD            34.0
#
#   Underlying
# 0       PRAA
# 1       PRAA
# 2       PRAA
# 3       PRAA
# 4       PRAA
#
#
#    Down Last4Weeks  Down LastWeek      NumberOfRevisions  Up Last4Weeks  \
# 0              0.0            0.0  Quarter Ending Dec-18            0.0
# 1              0.0            0.0  Quarter Ending Mar-19            0.0
# 2              0.0            0.0     Year Ending Dec-18            0.0
# 3              0.0            0.0     Year Ending Dec-19            0.0
#
#    Up LastWeek Underlying
# 0          0.0       PRAA
# 1          0.0       PRAA
# 2          0.0       PRAA
# 3          0.0       PRAA
#
#
# Empty DataFrame
# Columns: [Down Last4Weeks, Down LastWeek, NumberOfRevisions, Up Last4Weeks, Up LastWeek, Underlying]
# Index: []
#
#
#                                            Underlying  Shares Traded
# Trading Date Title                   Type
# 2018-06-30   Director                Buy           64       183680.0
#                                      Sell           8        43960.0
#              Officer                 Buy           16        14472.0
#                                      Sell           8        28744.0
#              Other Executive         Sell           8        41600.0
# 2018-09-30   Chief Financial Officer Sell           8        12032.0
#              Director                Sell          64      2358240.0
#              General Counsel         Sell          24        35472.0
#
#
#    1 Year  3 Year  5 Year        Field Underlying
# 0  -11.83    4.15   12.60      Sales %       PRAA
# 1  -47.12  -18.95   -1.21  EPS (TTM) %       PRAA
# 2     NaN     NaN     NaN   Dividend %       PRAA
#
#
# XON
#   epsActual epsDifference epsEstimate  surprisePercent Underlying    Quarter  \
# 0     -0.33          -0.1       -0.23           -0.435        XON 2017-09-30
# 1     -0.23          0.09       -0.32            0.281        XON 2017-12-31
# 2     -0.33         -0.14       -0.19           -0.737        XON 2018-03-31
# 3     -0.51         -0.22       -0.29           -0.759        XON 2018-06-30
#
#    Stock_closeToOpen EarningsDate
# 0          -0.052897   2017-11-09
# 1           0.029457   2018-03-01
# 2          -0.081009   2018-05-10
# 3          -0.090318   2018-08-09
#
#
#
#
#
#
#
#
#    Company                         Field  industry  sector Underlying
# 0      NaN               P/E Ratio (TTM)     97.91   28.85        XON
# 1      NaN        P/E High - Last 5 Yrs.    262.45   46.38        XON
# 2      NaN         P/E Low - Last 5 Yrs.     83.90   24.36        XON
# 3     1.55                          Beta      0.73    0.87        XON
# 4     8.40          Price to Sales (TTM)    183.10   14.87        XON
# 5     3.00           Price to Book (MRQ)     14.87    3.89        XON
# 6     9.75  Price to Tangible Book (MRQ)     19.40   14.41        XON
# 7      NaN      Price to Cash Flow (TTM)     53.64   20.32        XON
#
#
#    Company                                 Field  industry  sector Underlying
# 0   -16.82         Sales (MRQ) vs Qtr. 1 Yr. Ago    234.89    8.77        XON
# 1     2.37          Sales (TTM) vs TTM 1 Yr. Ago     55.29    5.91        XON
# 2    75.75             Sales - 5 Yr. Growth Rate     21.83    7.39        XON
# 3  -224.39           EPS (MRQ) vs Qtr. 1 Yr. Ago     14.53   38.37        XON
# 4    32.98            EPS (TTM) vs TTM 1 Yr. Ago       NaN     NaN        XON
# 5      NaN               EPS - 5 Yr. Growth Rate     19.61    7.78        XON
# 6    52.05  Capital Spending - 5 Yr. Growth Rate     33.20    7.98        XON
#
#
#    Company                           Field  industry  sector Underlying
# 0    69.12              Gross Margin (TTM)     30.89   54.49        XON
# 1    71.55       Gross Margin - 5 Yr. Avg.     47.36   53.04        XON
# 2   -59.42              EBITD Margin (TTM)       NaN     NaN        XON
# 3   -62.14               EBITD - 5 Yr. Avg   -163.08   15.83        XON
# 4   -83.42          Operating Margin (TTM)  -1160.02   -6.10        XON
# 5   -77.82   Operating Margin - 5 Yr. Avg.   -176.56   10.99        XON
# 6   -94.13            Pre-Tax Margin (TTM)  -1126.19   -5.02        XON
# 7   -72.56     Pre-Tax Margin - 5 Yr. Avg.   -179.50   11.31        XON
# 8   -48.85         Net Profit Margin (TTM)  -1115.09   -8.29        XON
# 9   -59.06  Net Profit Margin - 5 Yr. Avg.   -179.09    7.58        XON
#
#
#    Company                       Field  industry  sector Underlying
# 0     1.53           Quick Ratio (MRQ)      1.98    2.51        XON
# 1     1.78         Current Ratio (MRQ)      6.11    3.47        XON
# 2     1.32     LT Debt to Equity (MRQ)     14.57   11.33        XON
# 3     1.52  Total Debt to Equity (MRQ)     19.59   15.05        XON
# 4      NaN     Interest Coverage (TTM)   -205.05   40.67        XON
#
#
#    IndustryRank  PercentActual  Percentvs.S&P500   Period  RankInIndustry  \
# 0          82.0         -19.04            -15.37   4 Week            19.0
# 1          94.0         -18.15            -15.09  13 Week            38.0
# 2          87.0         -30.39            -32.50  26 Week            33.0
# 3          96.0         -19.95            -24.72  52 Week            45.0
# 4          93.0          10.76              7.47      YTD            68.0
#
#   Underlying
# 0        XON
# 1        XON
# 2        XON
# 3        XON
# 4        XON
#
#
#    Down Last4Weeks  Down LastWeek      NumberOfRevisions  Up Last4Weeks  \
# 0              0.0            0.0  Quarter Ending Dec-18            0.0
# 1              0.0            0.0     Year Ending Dec-18            0.0
# 2              0.0            0.0     Year Ending Dec-19            0.0
#
#    Up LastWeek Underlying
# 0          0.0        XON
# 1          0.0        XON
# 2          0.0        XON
#
#
#    Down Last4Weeks  Down LastWeek      NumberOfRevisions  Up Last4Weeks  \
# 0              0.0            0.0  Quarter Ending Dec-18            0.0
# 1              0.0            0.0     Year Ending Dec-18            0.0
# 2              0.0            0.0     Year Ending Dec-19            0.0
#
#    Up LastWeek Underlying
# 0          0.0        XON
# 1          0.0        XON
# 2          0.0        XON
#
#
#                                            Underlying  Shares Traded
# Trading Date Title                   Type
# 2018-03-31   Chief Executive Officer Buy            8       242204.0
#              Director                Buy           16        59546.0
# 2018-06-30   Chief Executive Officer Buy           24       708404.0
# 2018-09-30   Chief Executive Officer Buy           32     30735332.0
#              Officer                 Buy            4       100000.0
#                                      Sell           4        33608.0
# 2018-12-31   Chief Executive Officer Buy            8       291116.0
#              Officer                 Sell           4       316000.0
#
#
#    1 Year  3 Year  5 Year        Field Underlying
# 0   20.98   47.53   75.75      Sales %        XON
# 1   84.41     NaN     NaN  EPS (TTM) %        XON
# 2     NaN     NaN     NaN   Dividend %        XON
#
#
# HTZ
#   epsActual epsDifference epsEstimate  surprisePercent Underlying    Quarter  \
# 0      1.42          0.07        1.35            0.052        HTZ 2017-09-30
# 1     -0.77         -0.17        -0.6           -0.283        HTZ 2017-12-31
# 2     -1.58         -0.32       -1.26           -0.254        HTZ 2018-03-31
# 3     -0.19          0.05       -0.24            0.208        HTZ 2018-06-30
#
#    Stock_closeToOpen EarningsDate
# 0           0.136932   2017-11-10
# 1          -0.039460   2018-02-27
# 2          -0.097473   2018-05-07
# 3           0.075941   2018-08-06
#
#
#
#
#
#
#
#
#    Company                         Field  industry  sector Underlying
# 0     1.16               P/E Ratio (TTM)     27.51   21.39        HTZ
# 1    44.64        P/E High - Last 5 Yrs.     31.48   38.19        HTZ
# 2     1.82         P/E Low - Last 5 Yrs.     12.91   15.08        HTZ
# 3     1.98                          Beta      0.78    1.02        HTZ
# 4     0.15          Price to Sales (TTM)      1.64    2.14        HTZ
# 5     1.25           Price to Book (MRQ)      1.42    2.38        HTZ
# 6      NaN  Price to Tangible Book (MRQ)      1.51    5.90        HTZ
# 7     0.34      Price to Cash Flow (TTM)      8.38   13.23        HTZ
#
#
#    Company                                 Field  industry  sector Underlying
# 0     7.42         Sales (MRQ) vs Qtr. 1 Yr. Ago      0.66    9.38        HTZ
# 1     4.87          Sales (TTM) vs TTM 1 Yr. Ago      2.64   16.61        HTZ
# 2    -0.47             Sales - 5 Yr. Growth Rate      2.39    9.83        HTZ
# 3    60.60           EPS (MRQ) vs Qtr. 1 Yr. Ago     -2.39   78.90        HTZ
# 4   242.82            EPS (TTM) vs TTM 1 Yr. Ago       NaN     NaN        HTZ
# 5    42.63               EPS - 5 Yr. Growth Rate     12.13   15.13        HTZ
# 6     1.68  Capital Spending - 5 Yr. Growth Rate      4.06    9.32        HTZ
#
#
#    Company                           Field  industry  sector Underlying
# 0    43.44              Gross Margin (TTM)     34.45   29.46        HTZ
# 1    44.39       Gross Margin - 5 Yr. Avg.     32.35   28.03        HTZ
# 2    37.80              EBITD Margin (TTM)       NaN     NaN        HTZ
# 3    39.64               EBITD - 5 Yr. Avg     29.63   17.04        HTZ
# 4     5.84          Operating Margin (TTM)     19.24   13.09        HTZ
# 5     5.71   Operating Margin - 5 Yr. Avg.     17.67   12.20        HTZ
# 6    -3.86            Pre-Tax Margin (TTM)     17.88   12.06        HTZ
# 7    -1.15     Pre-Tax Margin - 5 Yr. Avg.     16.25   11.26        HTZ
# 8    12.32         Net Profit Margin (TTM)     12.72    8.31        HTZ
# 9     1.57  Net Profit Margin - 5 Yr. Avg.     10.99    7.88        HTZ
#
#
#    Company                       Field  industry  sector Underlying
# 0      NaN           Quick Ratio (MRQ)      2.38    1.88        HTZ
# 1      NaN         Current Ratio (MRQ)      2.51    2.33        HTZ
# 2  1639.66     LT Debt to Equity (MRQ)    114.45   59.09        HTZ
# 3  1639.66  Total Debt to Equity (MRQ)    132.45   77.77        HTZ
# 4     1.10     Interest Coverage (TTM)      9.22   22.37        HTZ
#
#
#    IndustryRank  PercentActual  Percentvs.S&P500   Period  RankInIndustry  \
# 0          21.0          -1.50              2.96   4 Week            99.0
# 1          51.0         -19.46            -16.45  13 Week            69.0
# 2          61.0         -12.66            -15.31  26 Week            99.0
# 3          48.0         -38.05            -41.74  52 Week            34.0
# 4          62.0         -28.82            -30.94      YTD            51.0
#
#   Underlying
# 0        HTZ
# 1        HTZ
# 2        HTZ
# 3        HTZ
# 4        HTZ
#
#
#    Down Last4Weeks  Down LastWeek      NumberOfRevisions  Up Last4Weeks  \
# 0              1.0            0.0  Quarter Ending Dec-18            1.0
# 1              0.0            0.0  Quarter Ending Mar-19            0.0
# 2              3.0            1.0     Year Ending Dec-18            1.0
# 3              3.0            1.0     Year Ending Dec-19            1.0
#
#    Up LastWeek Underlying
# 0          0.0        HTZ
# 1          0.0        HTZ
# 2          0.0        HTZ
# 3          0.0        HTZ
#
#
#    Down Last4Weeks  Down LastWeek      NumberOfRevisions  Up Last4Weeks  \
# 0              1.0            0.0  Quarter Ending Dec-18            2.0
# 1              1.0            0.0  Quarter Ending Mar-19            1.0
# 2              2.0            0.0     Year Ending Dec-18            1.0
# 3              3.0            0.0     Year Ending Dec-19            2.0
#
#    Up LastWeek Underlying
# 0          0.0        HTZ
# 1          0.0        HTZ
# 2          0.0        HTZ
# 3          1.0        HTZ
#
#
#                                             Underlying  Shares Traded
# Trading Date Title                    Type
# 2018-03-31   Chief Technology Officer Buy            1         4806.0
#              General Counsel          Buy            2         3604.0
#              Officer                  Sell           3        16350.0
# 2018-06-30   Chief Financial Officer  Buy            6        54381.0
#                                       Sell           3         2286.0
#              Director                 Buy           21       141879.0
#              General Counsel          Buy            3          897.0
#                                       Sell           3          219.0
#              Officer                  Buy            9        25317.0
#                                       Sell           6         2838.0
# 2018-09-30   Chief Financial Officer  Buy            3       207225.0
#              Chief Technology Officer Buy            3        45927.0
#              Director                 Buy            9        19659.0
# 2018-12-31   Officer                  Sell           3         1461.0
#
#
#    1 Year  3 Year  5 Year        Field Underlying
# 0    0.00   -2.42   -0.47      Sales %        HTZ
# 1  314.79     NaN   42.63  EPS (TTM) %        HTZ
# 2     NaN     NaN     NaN   Dividend %        HTZ

# %%
vols_list = []

for selected_name in selected_names:
    curr_vol = historical_data(selected_name, dt.datetime(2018,1,1))[['daily_ann','intra_ann','ovrnt_ann']].tail(1)
    curr_vol.index = [selected_name]
    
    aq = alphaquery(selected_name)
    
    curr_iv = aq.vol_df.loc[['Implied Volatility (Calls)', 'Implied Volatility (Puts)', 
                             'Put-Call Implied Volatility Ratio',
                             'Implied Volatility Skew'],['20-Day']].T
    curr_iv.index = [selected_name]
    vols_list.append(curr_vol.join(curr_iv))
    
hv_df = pd.concat(vols_list,axis = 0)

# %%
insider_agg_lst = []

for selected_name in selected_names:
    curr_insider_agg = insider_trades[insider_trades.Underlying == selected_name].groupby(['Type']).agg({'Shares Traded': 'sum'}).T
    curr_insider_agg.index = [selected_name]
    insider_agg_lst.append(curr_insider_agg)
    
insider_agg = pd.concat(insider_agg_lst,axis = 0)
insider_agg['BuyToSell'] = insider_agg['Buy']/insider_agg['Sell']


hv_df[(hv_df['intra_ann'] > hv_df['Implied Volatility (Calls)']) &
      (hv_df['intra_ann'] > hv_df['Implied Volatility (Puts)'])].dropna().sort_values('intra_ann').join(insider_agg,
                                                                                                        how = 'inner')
# Out:
#       daily_ann  intra_ann  ovrnt_ann  Implied Volatility (Calls)  \
# PRAA   0.409169   0.770406   0.129493                      0.6340
# SYNA   0.429027   0.782602   0.212256                      0.6561
# CBPX   0.420670   0.802272   0.152601                      0.5285
# AMC    0.578697   0.955894   0.175762                      0.6279
# TRUP   0.708554   1.341991   0.134048                      0.9443
# HTZ    0.835090   1.575489   0.274215                      1.0832
# XON    0.820839   1.584590   0.236032                      0.9564
# OSTK   0.851896   1.647085   0.283537                      1.0540
#
#       Implied Volatility (Puts)  Put-Call Implied Volatility Ratio  \
# PRAA                     0.6331                             0.9986
# SYNA                     0.6303                             0.9607
# CBPX                     0.5506                             1.0418
# AMC                      0.6056                             0.9645
# TRUP                     1.0345                             1.0955
# HTZ                      1.0674                             0.9854
# XON                      0.9603                             1.0041
# OSTK                     1.0519                             0.9980
#
#       Implied Volatility Skew         Buy     Gift       Sell  BuyToSell
# PRAA                   0.0984    198152.0      NaN  2520048.0   0.078630
# SYNA                   0.0794   1345992.0      NaN  2728134.0   0.493375
# CBPX                   0.0355    291126.0      NaN    50517.0   5.762931
# AMC                    0.0242    661628.0      NaN   267284.0   2.475375
# TRUP                   0.1022     94504.0      NaN  2196616.0   0.043023
# HTZ                    0.0760    503695.0      NaN    23154.0  21.754125
# XON                    0.0121  32136602.0      NaN   349608.0  91.921815
# OSTK                  -0.0029    592560.0  10664.0  6323776.0   0.093704

# %%
shorts = ['OSTK', 'TRUP', 'PRAA']

longs = ['XON', 'HTZ']

print(scores_df[scores_df.index.isin(shorts + longs)])
print(eps_df[eps_df.Underlying.isin(shorts + longs)][['EarningsDate',
                                                      'surprisePercent',
                                                      'Underlying',
                                                      'Quarter',
                                                      'Stock_closeToOpen']].set_index('Underlying'))
print(analyst_df[analyst_df.index.isin(shorts + longs)].sort_values('Current'))
summary_df[summary_df.index.isin(shorts + longs)].T
# Out:
#       FinStrengthScore  GrowthRateScore  PerfRankScore  ProfitScore  \
# OSTK              40.0            21.43          40.20          0.0
# HTZ                0.0            35.71          60.10         35.0
# XON               40.0            28.57          66.16         55.0
# PRAA               0.0            14.29          50.71         90.0
# TRUP              80.0            71.43          60.71         20.0
#
#       ReturnScore  ValuationScore  TotalScore
# OSTK          0.0           37.50   23.188333
# HTZ          10.0           62.50   33.885000
# XON          20.0           37.50   41.205000
# PRAA         20.0           87.50   43.750000
# TRUP        100.0            6.25   56.398333
#            EarningsDate  surprisePercent    Quarter  Stock_closeToOpen
# Underlying
# XON          2017-11-09           -0.435 2017-09-30          -0.052897
# XON          2018-03-01            0.281 2017-12-31           0.029457
# XON          2018-05-10           -0.737 2018-03-31          -0.081009
# XON          2018-08-09           -0.759 2018-06-30          -0.090318
# PRAA         2017-11-08            0.214 2017-09-30           0.078853
# PRAA         2018-02-27           -0.118 2017-12-31           0.148201
# PRAA         2018-05-09            0.343 2018-03-31           0.073306
# PRAA         2018-08-07            0.000 2018-06-30          -0.047859
# HTZ          2017-11-10            0.052 2017-09-30           0.136932
# HTZ          2018-02-27           -0.283 2017-12-31          -0.039460
# HTZ          2018-05-07           -0.254 2018-03-31          -0.097473
# HTZ          2018-08-06            0.208 2018-06-30           0.075941
# TRUP         2017-11-02            1.250 2017-09-30           0.072961
# TRUP         2018-02-13           -0.500 2017-12-31          -0.055964
# TRUP         2018-05-01           -0.250 2018-03-31          -0.037346
# TRUP         2018-08-02            0.750 2018-06-30           0.159750
# OSTK         2017-11-08            0.667 2017-09-30           0.147132
# OSTK         2018-03-15           -8.400 2017-12-31          -0.153527
# OSTK         2018-05-08           -0.956 2018-03-31          -0.022281
# OSTK         2018-08-09           -1.744 2018-06-30           0.216321
#            1-5LinearScale  1MonthAgo  2MonthAgo  3MonthAgo  Current
# Underlying
# OSTK          Mean Rating       1.33       1.00       1.00     1.33
# TRUP          Mean Rating       1.70       1.67       1.67     1.70
# XON           Mean Rating       2.50       2.20       2.20     2.50
# PRAA          Mean Rating       2.57       2.57       2.57     2.57
# HTZ           Mean Rating       3.00       3.00       3.00     3.00
#                              OSTK    TRUP     PRAA      XON      HTZ
# Beta                         1.26     NaN     1.64     1.55     2.19
# Dividend                      NaN     NaN      NaN      NaN      NaN
# EPS (TTM) Industry            NaN     NaN      NaN      NaN      NaN
# EPS (TTM) Sector              NaN     NaN      NaN      NaN      NaN
# EPS (TTM) Stock             -0.52   -0.15     1.53    -0.69    -9.48
# High52Week                  88.45   46.25    43.75    20.16    25.14
# LastPrice                   20.13   26.31    31.60    12.77    16.53
# Low52Week                   19.08   24.83    27.25    10.26    13.01
# Market Cap(Mil.)           750.01  811.38  1441.90  1748.02  2117.20
# P/E (TTM) Industry          34.43   14.25    29.62    97.91    27.81
# P/E (TTM) Sector          1540.21   19.19    21.39    28.85    24.46
# P/E (TTM) Stock               NaN     NaN    20.82      NaN      NaN
# ROE Industry                20.28    4.76    13.99    -4.22    11.83
# ROE Sector                  13.87   15.35    13.31    13.95    12.40
# ROE Stock                   -8.02   -9.57     6.76   -16.55   -65.54
# ROI Industry                16.72    0.00     9.96    -1.56     4.99
# ROI Sector                  13.95    0.48     7.98    12.67     7.50
# ROI Stock                   -6.70   -8.47     2.30   -13.18    -3.92
# Shares Outstanding(Mil.)    25.00   30.00    45.30   136.99    83.72
# Yield (%)                     NaN     NaN      NaN      NaN      NaN

# %%
selected_name = 'HTZ'

aq = alphaquery(selected_name)
print(aq.vol_df)

insider_trades[insider_trades.Underlying == selected_name].groupby(['Trading Date','Title',
                                                                    'Type']).agg({'Underlying':'count',
                                                                                  'Shares Traded': 'sum'})
# Out:
#                                          10-Day   20-Day   30-Day   60-Day  \
# Field
# Historical Volatility (Close-to-Close)   0.3942   0.9544   0.8206   0.6453
# Historical Volatility (Parkinson)        0.6053   0.7268   0.6510   0.5886
# Implied Volatility (Calls)               1.2016   1.0832   0.9648   0.7566
# Implied Volatility (Puts)                1.1801   1.0674   0.9548   0.7503
# Implied Volatility (Mean)                1.1908   1.0753   0.9598   0.7534
# Put-Call Implied Volatility Ratio        0.9821   0.9854   0.9896   0.9917
# Implied Volatility Skew                  0.0897   0.0760   0.0623   0.0424
# Put-Call Ratio (Volume)                  0.9287   3.3885   5.8483  11.4743
# Put-Call Ratio (Open Interest)           0.8148   0.7271   0.6395   1.5824
# Forward Price                           15.8500  15.8800  15.9100  15.9500
# Call Breakeven Price                    17.8000  17.8900  17.9700  19.5300
# Put Breakeven Price                     14.0100  13.6800  13.3400  12.4900
# Option Breakeven Price                  16.0900  16.1700  16.2400  15.2600
#
#                                          90-Day  120-Day  150-Day  180-Day  \
# Field
# Historical Volatility (Close-to-Close)   0.6179   0.7079   0.7280   0.7064
# Historical Volatility (Parkinson)        0.5743   0.5886   0.5991   0.5863
# Implied Volatility (Calls)               0.7219   0.7170   0.7121   0.7069
# Implied Volatility (Puts)                0.7143   0.7126   0.7110   0.7081
# Implied Volatility (Mean)                0.7181   0.7148   0.7115   0.7075
# Put-Call Implied Volatility Ratio        0.9895   0.9939   0.9985   1.0017
# Implied Volatility Skew                  0.0440   0.0475   0.0510   0.0507
# Put-Call Ratio (Volume)                 10.9817   7.3971   3.8124   2.3636
# Put-Call Ratio (Open Interest)           2.2548   2.0158   1.7769   1.7870
# Forward Price                           15.9600  15.9800  15.9900  16.0300
# Call Breakeven Price                    20.7600  20.9900  21.2200  21.4700
# Put Breakeven Price                     12.1700  12.1200  12.0800  11.9400
# Option Breakeven Price                  14.6400  15.0000  15.3600  15.3600
#
#                                        Underlying
# Field
# Historical Volatility (Close-to-Close)        HTZ
# Historical Volatility (Parkinson)             HTZ
# Implied Volatility (Calls)                    HTZ
# Implied Volatility (Puts)                     HTZ
# Implied Volatility (Mean)                     HTZ
# Put-Call Implied Volatility Ratio             HTZ
# Implied Volatility Skew                       HTZ
# Put-Call Ratio (Volume)                       HTZ
# Put-Call Ratio (Open Interest)                HTZ
# Forward Price                                 HTZ
# Call Breakeven Price                          HTZ
# Put Breakeven Price                           HTZ
# Option Breakeven Price                        HTZ
#                                             Underlying  Shares Traded
# Trading Date Title                    Type
# 2018-03-31   Chief Technology Officer Buy            1         4806.0
#              General Counsel          Buy            2         3604.0
#              Officer                  Sell           3        16350.0
# 2018-06-30   Chief Financial Officer  Buy            6        54381.0
#                                       Sell           3         2286.0
#              Director                 Buy           21       141879.0
#              General Counsel          Buy            3          897.0
#                                       Sell           3          219.0
#              Officer                  Buy            9        25317.0
#                                       Sell           6         2838.0
# 2018-09-30   Chief Financial Officer  Buy            3       207225.0
#              Chief Technology Officer Buy            3        45927.0
#              Director                 Buy            9        19659.0
# 2018-12-31   Officer                  Sell           3         1461.0

# %%
insider_trades[insider_trades.Underlying == selected_name].sort_values('Trading Date').to_csv('HTZ.csv')

# %%
# Saving Selected Names for Reference

os.chdir('C:\\Users\\Fang\\Desktop\\Python Trading\\Trading\\Data\\Historical Queries\\Earnings')

datenow = dt.datetime.today().strftime('%Y-%m-%d')

scores_df.sort_values(['ValuationScore','TotalScore']).join(summary_df).to_csv('earnings-{}.csv'.format(datenow))

os.chdir(main_dir)

# %% [markdown]
# ## Barbell Hedging

# %%
ratios = spx_put_backratios(50, 1, 0.2, 2, 25)

# %%
ratios

# %%
spx_options = all_greeks(all_options('^SPX',50,1,0.2))
spx_options = spx_options[(spx_options['Type'] == 'put') &
                          (spx_options['Strike'] < spx_options['Underlying_Price'])]

# %%
spx_options[(spx_options['DTE'] == 7) &
            (spx_options['Strike'] == 2390.0)]
