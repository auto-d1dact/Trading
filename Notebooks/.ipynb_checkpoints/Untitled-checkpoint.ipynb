# %%
from bs4 import BeautifulSoup as bs
import requests

# %%
url = 'https://www.salt.org/managers'
soup = bs(requests.get(url, 'lxml').text, 'lxml')

# %%
managers = soup.select('div[class="row sqs-row"]')[3]
managers = [x.text.strip() for x in managers.find_all('li')]
managers
# Out:
# ['1832 Asset Management L.P.',
#  '400 Capital Management LLC',
#  'Acadian Asset Management LLC',
#  'Alambic Investment Management',
#  'Alchemy Capital Management PVT LTD',
#  'Alden Global Capital',
#  'AlphaGen Capital',
#  'Analytic Investors, LLC',
#  'Anato Investment Group LLC',
#  'Angel Oak Capital Advisors',
#  'Apollo Global Management',
#  'Arbiter Partners',
#  'Archview Investment Group LP',
#  'Ariel Investments',
#  'ArrowMark Partners',
#  'Artisan Partners',
#  'Aspect Capital',
#  'ATW Partners',
#  'Audubon Communities',
#  'Avenue Capital Group',
#  'Axonic Capital LLC',
#  'Balyasny Asset Management',
#  'Bar Nothin Capital, LLC',
#  'Bayview Asset Management',
#  'BeaconLight Capital',
#  'Bergen Asset Management, LLC',
#  'BlackRock',
#  'BlueBay Asset Management',
#  'Brightstar Capital Partners',
#  'Caerus Investors',
#  'Cairn Capital',
#  'Calixto Global Investors, LP',
#  'Canyon Partners, LLC',
#  'Cartica Management',
# ...

# %% [markdown]
# Anato Investment Group LLC
