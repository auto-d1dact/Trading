# %%
# Importing necessary models
import warnings
warnings.filterwarnings('ignore')

import smtplib
import pandas as pd
import numpy as np
import datetime as dt
import pandas.stats.moments as st
import time
# %matplotlib inline
from bs4 import BeautifulSoup as bs
import requests
import plotly.plotly as py
import plotly.graph_objs as go
from plotly.offline import download_plotlyjs, init_notebook_mode, plot, iplot
import matplotlib.pyplot as plt
pd.options.display.float_format = '{:,.4f}'.format

init_notebook_mode(connected=True)

import os
main_dir = os.getcwd()

dbs_dir = 'C:\\Users\\Fang\\Desktop\\Python Trading\\Trading\\Data\\DBs'

os.chdir('C:\\Users\\Fang\\Desktop\\Python Trading\\Trading\\Trading\\Modules\\DataCollection')

from yahoo_query import *

os.chdir('C:\\Users\\Fang\\Downloads')
# Out:
# <script>requirejs.config({paths: { 'plotly': ['https://cdn.plot.ly/plotly-latest.min']},});if(!window.Plotly) {{require(['plotly'],function(plotly) {window.Plotly=plotly;});}}</script>

# %%
start_date = dt.datetime(1950,1,3)

try:
    
    spx = yahoo_query('^GSPC', start_date)
    spx.hist_prices_query()
    spx = spx.hist_prices
except:
    spx = pd.read_csv('^GSPC.csv', index_col = 0)

# %%
from scipy.optimize import curve_fit


def generate_sim(n, sim_days, sim_nums):
    empirical_dist = np.log(spx[['Close']]/spx[['Close']].shift(n)).sort_values('Close')
    empirical_dist['cumprob'] = np.arange(len(empirical_dist))/len(empirical_dist)


    def sigmoid(x, x0, k):
        y = 1 / (1 + np.exp(-k*(x-x0)))
        return y

    popt, pcov = curve_fit(sigmoid, empirical_dist[empirical_dist.Close < 0].Close, empirical_dist[empirical_dist.Close < 0].cumprob)

    #print(popt)

    x = np.linspace(empirical_dist.Close.min(), empirical_dist.Close.max(), len(empirical_dist.Close))
    y = sigmoid(x, *popt)

    # fig = plt.figure(figsize=(20,20))

    # ax = fig.add_subplot(111)

    # ax.plot(empirical_dist.Close, empirical_dist.cumprob, 'o', label='data')
    # ax.plot(x,y, label='fit')
    # #pylab.ylim(0, 1.05)
    # ax.legend(loc='best')

    def sigmoid_inv(y, x0, k):
        x = -(np.log((1-y)/y)/k) + x0
        return x
    
    return sigmoid_inv(np.random.random(size = (sim_nums, sim_days)), *popt)

# %%
sim_nums = 100000

sim = generate_sim(1, 300, sim_nums)

strike = 2700
curr_spx = spx.reset_index().loc[len(spx) - 1, 'Close']

sum(np.maximum(strike - curr_spx*np.exp(np.sum(sim, axis = 1)),0))/sim_nums

sim
# Out:
# array([[ 0.00746006, -0.00456509,  0.01135826, ...,  0.00066627,
#         -0.02481364,  0.00771151],
#        [-0.00142143,  0.00389354,  0.00099432, ...,  0.00077239,
#          0.01619721, -0.00091859],
#        [ 0.00641565,  0.00534489, -0.00799598, ...,  0.00169888,
#          0.00552178, -0.01160711],
#        ...,
#        [ 0.00576035, -0.00539668, -0.00285539, ...,  0.00178283,
#         -0.00512791,  0.00475185],
#        [-0.00532137, -0.01321605,  0.00461922, ...,  0.00216451,
#          0.0018762 , -0.0036041 ],
#        [ 0.00907376,  0.00140669, -0.00091813, ...,  0.00368678,
#         -0.00434973,  0.00778291]])

# %%
spyconst = pd.read_excel('https://us.spdrs.com/site-content/xls/SPY_All_Holdings.xls?fund=SPY&docname=All+Holdings&onyx_code1=&onyx_code2=',
                         skiprows = 3).dropna()
# Out:
#                                     Name Identifier  Weight  \
# 0                  Microsoft Corporation       MSFT  3.6955
# 1                             Apple Inc.       AAPL  3.3710
# 2                        Amazon.com Inc.       AMZN  2.8931
# 3                  Facebook Inc. Class A         FB  1.7606
# 4        Berkshire Hathaway Inc. Class B      BRK.B  1.6799
# 5                      Johnson & Johnson        JNJ  1.6063
# 6                  Alphabet Inc. Class C       GOOG  1.5239
# 7                  Alphabet Inc. Class A      GOOGL  1.4906
# 8                   JPMorgan Chase & Co.        JPM  1.4840
# 9                Exxon Mobil Corporation        XOM  1.4704
# 10                  Bank of America Corp        BAC  1.1296
# 11                     Visa Inc. Class A          V  1.1182
# 12              Procter & Gamble Company         PG  1.0637
# 13                     Intel Corporation       INTC  1.0404
# 14                           Pfizer Inc.        PFE  1.0370
# 15                   Chevron Corporation        CVX  1.0095
# 16           Verizon Communications Inc.         VZ  1.0079
# 17                    Cisco Systems Inc.       CSCO  0.9996
# 18       UnitedHealth Group Incorporated        UNH  0.9865
# 19                        Boeing Company         BA  0.9672
# 20                             AT&T Inc.          T  0.9434
# 21                 Wells Fargo & Company        WFC  0.9125
# 22                      Merck & Co. Inc.        MRK  0.9070
# 23                       Home Depot Inc.         HD  0.8935
# 24       Mastercard Incorporated Class A         MA  0.8727
# 25           Comcast Corporation Class A      CMCSA  0.7557
# 26                     Coca-Cola Company         KO  0.7515
# 27                   Walt Disney Company        DIS  0.7353
# 28                          PepsiCo Inc.        PEP  0.7101
# 29                          Netflix Inc.       NFLX  0.6661
# ..                                   ...        ...     ...
# 476  Fortune Brands Home & Security Inc.       FBHS  0.0282
# 477                          DaVita Inc.        DVA  0.0276
# 478       People's United Financial Inc.       PBCT  0.0274
# 479                 Harley-Davidson Inc.        HOG  0.0269
# 480                  Nektar Therapeutics       NKTR  0.0266
# 481                        L Brands Inc.         LB  0.0258
# 482               Helmerich & Payne Inc.         HP  0.0254
# 483                         Rollins Inc.        ROL  0.0254
# 484                             Gap Inc.        GPS  0.0252
# 485                      Perrigo Co. Plc       PRGO  0.0252
# 486         Leggett & Platt Incorporated        LEG  0.0251
# 487                Flowserve Corporation        FLS  0.0241
# 488       Affiliated Managers Group Inc.        AMG  0.0239
# 489       Jefferies Financial Group Inc.        JEF  0.0236
# 490            IPG Photonics Corporation       IPGP  0.0230
# 491                        Assurant Inc.        AIZ  0.0228
# 492                     TripAdvisor Inc.       TRIP  0.0225
# 493                 Quanta Services Inc.        PWR  0.0222
# 494                       Nordstrom Inc.        JWN  0.0221
# 495                    Fluor Corporation        FLR  0.0219
# 496                          Mattel Inc.        MAT  0.0214
# 497                       H&R Block Inc.        HRB  0.0212
# 498             News Corporation Class A       NWSA  0.0212
# 499                    Coty Inc. Class A       COTY  0.0210
# 500                     Macerich Company        MAC  0.0196
# 501           Brighthouse Financial Inc.        BHF  0.0193
# 502               Discovery Inc. Class A      DISCA  0.0190
# 503            Under Armour Inc. Class A        UAA  0.0172
# 504            Under Armour Inc. Class C         UA  0.0156
# 505             News Corporation Class B        NWS  0.0065
#
#                      Sector      Shares Held
# 0    Information Technology  84,638,320.0000
# 1    Information Technology  49,407,636.0000
# 2    Consumer Discretionary   4,498,583.0000
# 3    Communication Services  26,318,068.0000
# 4                Financials  21,310,360.0000
# 5               Health Care  29,377,844.0000
# 6    Communication Services   3,369,822.0000
# 7    Communication Services   3,274,620.0000
# 8                Financials  36,437,176.0000
# 9                    Energy  46,375,844.0000
# 10               Financials 100,030,890.0000
# 11   Information Technology  19,254,216.0000
# 12         Consumer Staples  27,288,780.0000
# 13   Information Technology  50,008,824.0000
# 14              Health Care  63,345,010.0000
# 15                   Energy  20,931,452.0000
# 16   Communication Services  45,260,256.0000
# 17   Information Technology  49,272,584.0000
# 18              Health Care  10,537,617.0000
# 19              Industrials   5,787,024.0000
# 20   Communication Services  79,714,136.0000
# 21               Financials  46,438,276.0000
# 22              Health Care  28,503,952.0000
# 23   Consumer Discretionary  12,377,434.0000
# 24   Information Technology   9,920,000.0000
# 25   Communication Services  49,781,730.0000
# 26         Consumer Staples  41,960,588.0000
# 27   Communication Services  16,305,682.0000
# 28         Consumer Staples  15,462,530.0000
# 29   Communication Services   4,776,383.0000
# ..                      ...              ...
# 476             Industrials   1,548,530.0000
# 477             Health Care   1,381,130.0000
# 478              Financials   4,056,020.0000
# 479  Consumer Discretionary   1,812,292.0000
# 480             Health Care   1,879,491.0000
# 481  Consumer Discretionary   2,485,613.0000
# 482                  Energy   1,179,027.0000
# 483             Industrials   1,608,715.0000
# 484  Consumer Discretionary   2,385,310.0000
# 485             Health Care   1,368,940.0000
# 486  Consumer Discretionary   1,432,598.0000
# 487             Industrials   1,416,843.0000
# 488              Financials     581,978.0000
# 489              Financials   3,158,832.0000
# 490  Information Technology     392,074.0000
# 491              Financials     574,499.0000
# 492  Communication Services   1,113,516.0000
# 493             Industrials   1,602,475.0000
# 494  Consumer Discretionary   1,247,327.0000
# 495             Industrials   1,522,322.0000
# 496  Consumer Discretionary   3,725,626.0000
# 497  Consumer Discretionary   2,218,731.0000
# 498  Communication Services   4,150,633.0000
# 499        Consumer Staples   4,900,082.0000
# 500             Real Estate   1,166,291.0000
# 501              Financials   1,298,797.0000
# 502  Communication Services   1,689,968.0000
# 503  Consumer Discretionary   2,013,947.0000
# 504  Consumer Discretionary   2,038,608.0000
# 505  Communication Services   1,241,037.0000
#
# [506 rows x 5 columns]
