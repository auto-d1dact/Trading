# %% [markdown]
# # Portfolio Methodolgy
#
# 1. DGI/Growth Names - Rebalance every 6 months picking around 2 - 3 names from CA and US universe
#     - Sell Covered Calls on names and re-enter if called away.
#     - **GTC Stop Limit of 5% on each name**
# 2. VAA/PAA - Rebalance every month on trading day 1
# 3. LEAPS - Rebalance every 3 months picking around 3 - 8 names from US universe (high growth potential names)
#     - Current Holdings: LOPE STOR PNW SBUX
#     - LOPE Earnings: Nov 8
#     - PNW Earnings: Nov 8
#     - SBUX Earnings: Jan 23
#         - **Exit Criteria: When the call option drops below 60 delta**
# 4. Short Vol - Short SPX Spreads at the beginning of the month and hold until second or last week to maturity
#     - Potentially long UVXY/VXX puts at beginning of the month with bracket orders
#     - **Short ATM SPX Put spreads around 25 points wide**
#         - **Long bi-weekly unit puts, around -7% or so of SPX spot (or something with a cost of 15% of the credit)**
#         - **The SPX put spread will have a capped max loss of 2,500 per contract, while in low volatility, the bi-weekly units are severely underpriced and will explode 10X to 20X in value if the long strike in the spread gets tested. Vega and Gamma play a huge factor in the repricing of these units.**
#         - Initiate the units every 2 weeks letting them run to expiry
#     - ***When in lower vol environment or when skew is less pronounced in high vol environments, it is possible to select spreads and units with the same expiry and still receive a deccent net credit. Otherwise, when IV is very high, check if same expiries are possible, otherwise choose units that expire in half the time.***
# 5. Barbell Hedging
#     - Long SPX puts or VIX calls during high crisis potential moments
#         - Initiate bracket orders with SPX Puts: +/- 30% of Cost Basis
#     - Check VIX Futures volume trends and see impact of Feb 5, 2018
#     - Only trade 4 naked SPX puts in Reg accounts
#         - Sell half into profits/losses
#     - Only trade 6 3:1 Put back ratios in Reg Account: Leg into these positions because of how illiquid the market is
#     - Take losses immediately (10% - 30% of Cost Basis)
#     - NEVER EVER try to put on a position of the market is illiquid: YOU WILL get filled at horrible prices
#     - **Put on 1-5 Delta strangles on the open of the day and close position at the end of the day around 2 pm to 3 pm**
# 6. Treasuries - Re-establish monthly bills beginning of month or at maturity
# 7. Earnings
#     - Filter stocks with market cap > 500M and with post-earnings returns greater than 2% in magnitude for at least 3 quarters
#     - Then filter stocks whose options have bid-ask spreads less than 1 dollar ATM
#     - Aggregate all insider share buys and sells and calculate the ratio Buy/Sells
#         - Candidates for Puts have Buy/Sell < 0.5
#         - Candidates for Calls have Buy/Sell > 2
#
# ##### Strategy Weights
# |Strategy|Weight|Last Rebal|Next Check|Next Full Rebal|
# |-|-|-|-|-|
# |VAA/PAA|25%|11/01/2018|12/01/2018|12/01/2018|
# |LEAPs|5%|11/01/2018|12/01/2018|01/01/2019|
# |Short Vol|2%|NA|NA|NA|
# |Barbell Hedging|1.5%|11/06/2018|11/09/2018|11/19/2018|
# |Treasuries|60%|11/01/2018|11/29/2018|12/01/2018|

# %% [markdown]
# ## Key Modules to Run
#
# - fundamental_data_collect.py to run monthly to collected latest financial statements and key stats from yahoo
# - finstatement_cleaning.py to run right after fundamental_data_collect.py to create cleaned data for earnings plays

# %%
# Importing necessary models
import warnings
warnings.filterwarnings('ignore')

import smtplib
import pandas as pd
import numpy as np
import datetime as dt
import pandas.stats.moments as st
import time
# %matplotlib inline
import plotly.plotly as py
import plotly.graph_objs as go
from plotly.offline import download_plotlyjs, init_notebook_mode, plot, iplot

init_notebook_mode(connected=True)

import os
main_dir = os.getcwd()

os.chdir('C:\\Users\\Fang\\Desktop\\Python Trading\\Trading\\Trading\\Modules\\DataCollection')

from alphavantage import *
from yahoo_query import *
from option_slam_earnings import *
from reuters_query import reuters_query
from alphaquery import alphaquery

os.chdir('C:\\Users\\Fang\\Desktop\\Python Trading\\Trading\\Trading\\Modules\\Options')
from optionsFunctions import *

os.chdir('C:\\Users\\Fang\\Desktop\\Python Trading\\Trading\\Trading\\Modules\\Earnings')
from yahoo_earnings import *
from lookup_earnings import lookup_earnings

os.chdir('C:\\Users\\Fang\\Desktop\\Python Trading\\Trading\\Trading\\Modules\\Processing')
from hv_calc import *

os.chdir(main_dir)
# Out:
# <script>requirejs.config({paths: { 'plotly': ['https://cdn.plot.ly/plotly-latest.min']},});if(!window.Plotly) {{require(['plotly'],function(plotly) {window.Plotly=plotly;});}}</script>

# %% [markdown]
# # Allocate Smartly Checking

# %%
# Short Call Assignment Price - 287.5

portfolio_value =  200000

as_lst = ['DBC',
        'HYG',
        'IEF',
        'IWM',
        'LQD',
        'QQQ',
        'SPY',
        'VNQ']
as_wgt = [0.014,
        0.014,
        0.417,
        0.014,
        0.500,
        0.014,
        0.014,
        0.014]

as_df = pd.DataFrame({'Allocation': as_wgt}, index = as_lst)
curr_spot = curr_batch_quotes(as_lst)
as_df = pd.concat([as_df,curr_spot[['price']]], axis = 1)

as_df['Market Value'] = portfolio_value*as_df.Allocation
as_df['Holdings'] = np.round(as_df['Market Value']/as_df.price,0)

as_df
# Out:
#         Allocation    price  Market Value  Holdings
# symbol
# DBC          0.014   15.310        2800.0     183.0
# HYG          0.014   83.600        2800.0      33.0
# IEF          0.417  101.775       83400.0     819.0
# IWM          0.014  152.570        2800.0      18.0
# LQD          0.500  111.460      100000.0     897.0
# QQQ          0.014  169.420        2800.0      17.0
# SPY          0.014  276.470        2800.0      10.0
# VNQ          0.014   82.020        2800.0      34.0

# %% [markdown]
# ## Checking market correlations

# %%
rolling_window = 60
plot_window = 10000

corr_df, sector_df = check_mkt_corr(rolling_window, plot_window)
print(corr_df.tail())
# Out:
#                 XLRE       XLV       XLI       XLK       XLP       XLE  \
# 2018-11-26  0.401496  0.903008  0.877430  0.929117  0.444210  0.742095
# 2018-11-27  0.403617  0.901434  0.875900  0.928968  0.447309  0.742484
# 2018-11-28  0.415836  0.912305  0.885509  0.934271  0.458347  0.750703
# 2018-11-29  0.418587  0.913073  0.890752  0.934909  0.467654  0.747554
# 2018-11-30  0.425289  0.904943  0.893539  0.935379  0.472589  0.750079
#
#                  XLU       XLB       XLY       XLF  Avg_Corr   SPY_cum
# 2018-11-26  0.050592  0.795702  0.911170  0.818939  0.687376  1.741832
# 2018-11-27  0.056553  0.783248  0.911982  0.818700  0.687019  1.751057
# 2018-11-28  0.050604  0.790911  0.919751  0.829972  0.694821  1.814401
# 2018-11-29  0.055456  0.790964  0.921579  0.829033  0.696956  1.808251
# 2018-11-30  0.071281  0.792779  0.922085  0.829723  0.699768  1.825368

# %%
((sector_df.dropna() + 1).cumprod()-1).tail()
# Out:
#                  SPY      XLRE       XLV       XLI       XLK       XLP  \
# 2018-11-26 -0.029038  0.048889  0.066580 -0.040830 -0.082598  0.074422
# 2018-11-27 -0.025771  0.054603  0.077657 -0.042469 -0.080778  0.084019
# 2018-11-28 -0.003339  0.063175  0.103582 -0.019528 -0.048579  0.093028
# 2018-11-29 -0.005517  0.064444  0.107235 -0.018981 -0.057819  0.094790
# 2018-11-30  0.000544  0.074603  0.129743 -0.009422 -0.048859  0.101841
#
#                  XLE       XLU       XLB       XLC       XLY       XLF
# 2018-11-26 -0.132058  0.084479 -0.078133 -0.121898 -0.066828 -0.029982
# 2018-11-27 -0.134466  0.092648 -0.089417 -0.119095 -0.064054 -0.029250
# 2018-11-28 -0.119615  0.091851 -0.075398 -0.100681 -0.036411 -0.010603
# 2018-11-29 -0.113861  0.091452 -0.068730 -0.097678 -0.040884 -0.019013
# 2018-11-30 -0.115467  0.107591 -0.066336 -0.099079 -0.033906 -0.013894

# %%
corr_df.iloc[:,:-2].plot(figsize = (20,10))

# %% [markdown]
# ## Earnings

# %%
date_lookup = '2018-11-21'

curr_earnings = date_earnings(date_lookup)
curr_earnings = curr_earnings[curr_earnings['Call Time'].isin(['After Market Close', 'Before Market Open'])]
curr_earnings['EarningsDate'] = date_lookup

# %%
month = 12
year = 2018
days_list = list(range(3, 7))

week_earnings = []

for i in days_list:
    date_lookup = '{0}-{1}-{2}'.format(year,month,'0'+(str(i)))
    curr_earnings = date_earnings(date_lookup)
    curr_earnings = curr_earnings[curr_earnings['Call Time'].isin(['After Market Close', 'Before Market Open'])]
    curr_earnings['EarningsDate'] = date_lookup
    week_earnings.append(curr_earnings)
    
curr_earnings = pd.concat(week_earnings,axis = 0)

focus_names = []
max_spread = 1

for ticker in curr_earnings.index:
    try:
        curr_options = all_options(ticker, 100, 1)
    except:
        curr_options = []
    
    if len(curr_options) == 0:
        continue
    elif (curr_options['Ask'] - curr_options['Bid']).mean() <= max_spread:
        focus_names.append(ticker)
    else:
        continue
        
curr_earnings = curr_earnings[curr_earnings.index.isin(focus_names)]

# %%
acs = curr_earnings[curr_earnings['Call Time'] == 'After Market Close']
bcs = curr_earnings[curr_earnings['Call Time'] == 'Before Market Open']
curr_earnings
# Out:
#                 Call Time EPS Estimate  \
# ASNA   After Market Close         0.04
# COUP   After Market Close        -0.03
# FNSR   Before Market Open         0.22
# HOME   After Market Close         0.15
# TOL    After Market Close         1.83
# HPE    After Market Close         0.43
# DG     Before Market Open         1.26
# CONN   Before Market Open         0.58
# DCI    Before Market Open         0.57
# MRVL   After Market Close         0.32
# MOV    Before Market Open         1.12
# GWRE   After Market Close          0.2
# MDB    After Market Close         -0.4
# KLXI   Before Market Open         1.15
# AEO    Before Market Open         0.48
# LULU   After Market Close         0.69
# GIII   Before Market Open         1.81
# HRB    After Market Close        -0.93
# FIVE   After Market Close         0.19
# CIEN   Before Market Open         0.48
# SCWX   Before Market Open        -0.05
# GEF    After Market Close         1.19
# IMKTA  Before Market Open            -
# VRNT   After Market Close         0.71
# KFY    After Market Close          0.8
# MOMO   Before Market Open         0.53
# SNPS   After Market Close         0.78
# SAIC   After Market Close         1.17
# AOBC   After Market Close         0.14
# AVGO   After Market Close         5.55
# MIK    Before Market Open         0.44
# PDCO   Before Market Open         0.37
# PLCE   Before Market Open         3.07
# KR     Before Market Open         0.43
# DOCU   After Market Close        -0.02
# DOMO   After Market Close        -1.38
# GCO    Before Market Open         0.86
# THO    Before Market Open         1.75
# ZUMZ   After Market Close         0.49
#
#                                           Name EarningsDate
# ASNA                   Ascena Retail Group Inc   2018-12-03
# COUP                        Coupa Software Inc   2018-12-03
# FNSR                              Finisar Corp   2018-12-03
# HOME                         At Home Group Inc   2018-12-04
# TOL                          Toll Brothers Inc   2018-12-04
# HPE              Hewlett Packard Enterprise Co   2018-12-04
# DG                         Dollar General Corp   2018-12-04
# CONN                                Conn's Inc   2018-12-04
# DCI                      Donaldson Company Inc   2018-12-04
# MRVL              Marvell Technology Group Ltd   2018-12-04
# MOV                           Movado Group Inc   2018-12-04
# GWRE                    Guidewire Software Inc   2018-12-04
# MDB                                MongoDB Inc   2018-12-04
# KLXI                                   KLX Inc   2018-12-04
# AEO              American Eagle Outfitters Inc   2018-12-05
# LULU                   Lululemon Athletica Inc   2018-12-05
# GIII                   G-III Apparel Group Ltd   2018-12-05
# HRB                        H &amp; R Block Inc   2018-12-05
# FIVE                            Five Below Inc   2018-12-05
# CIEN                                Ciena Corp   2018-12-05
# SCWX                          Secureworks Corp   2018-12-05
# GEF                                  Greif Inc   2018-12-05
# IMKTA                       Ingles Markets Inc   2018-12-05
# VRNT                        Verint Systems Inc   2018-12-05
# KFY                   Korn/Ferry International   2018-12-05
# MOMO                                  Momo Inc   2018-12-05
# SNPS                              Synopsys Inc   2018-12-05
# SAIC   Science Applications International Corp   2018-12-06
# AOBC              American Outdoor Brands Corp   2018-12-06
# AVGO                              Broadcom Inc   2018-12-06
# MIK                     Michaels Companies Inc   2018-12-06
# PDCO                   Patterson Companies Inc   2018-12-06
# PLCE                       Childrens Place Inc   2018-12-06
# KR                                   Kroger Co   2018-12-06
# DOCU                              DocuSign Inc   2018-12-06
# DOMO                                  Domo Inc   2018-12-06
# GCO                                Genesco Inc   2018-12-06
# THO                        Thor Industries Inc   2018-12-06
# ZUMZ                                Zumiez Inc   2018-12-06

# %%
acs
# Out:
#                Call Time EPS Estimate  \
# ASNA  After Market Close         0.04
# COUP  After Market Close        -0.03
# HOME  After Market Close         0.15
# TOL   After Market Close         1.83
# HPE   After Market Close         0.43
# MRVL  After Market Close         0.32
# GWRE  After Market Close          0.2
# MDB   After Market Close         -0.4
# LULU  After Market Close         0.69
# HRB   After Market Close        -0.93
# FIVE  After Market Close         0.19
# GEF   After Market Close         1.19
# VRNT  After Market Close         0.71
# KFY   After Market Close          0.8
# SNPS  After Market Close         0.78
# SAIC  After Market Close         1.17
# AOBC  After Market Close         0.14
# AVGO  After Market Close         5.55
# DOCU  After Market Close        -0.02
# DOMO  After Market Close        -1.38
# ZUMZ  After Market Close         0.49
#
#                                          Name EarningsDate
# ASNA                  Ascena Retail Group Inc   2018-12-03
# COUP                       Coupa Software Inc   2018-12-03
# HOME                        At Home Group Inc   2018-12-04
# TOL                         Toll Brothers Inc   2018-12-04
# HPE             Hewlett Packard Enterprise Co   2018-12-04
# MRVL             Marvell Technology Group Ltd   2018-12-04
# GWRE                   Guidewire Software Inc   2018-12-04
# MDB                               MongoDB Inc   2018-12-04
# LULU                  Lululemon Athletica Inc   2018-12-05
# HRB                       H &amp; R Block Inc   2018-12-05
# FIVE                           Five Below Inc   2018-12-05
# GEF                                 Greif Inc   2018-12-05
# VRNT                       Verint Systems Inc   2018-12-05
# KFY                  Korn/Ferry International   2018-12-05
# SNPS                             Synopsys Inc   2018-12-05
# SAIC  Science Applications International Corp   2018-12-06
# AOBC             American Outdoor Brands Corp   2018-12-06
# AVGO                             Broadcom Inc   2018-12-06
# DOCU                             DocuSign Inc   2018-12-06
# DOMO                                 Domo Inc   2018-12-06
# ZUMZ                               Zumiez Inc   2018-12-06

# %%
bcs
# Out:
#                 Call Time EPS Estimate                           Name  \
# FNSR   Before Market Open         0.22                   Finisar Corp
# DG     Before Market Open         1.26            Dollar General Corp
# CONN   Before Market Open         0.58                     Conn's Inc
# DCI    Before Market Open         0.57          Donaldson Company Inc
# MOV    Before Market Open         1.12               Movado Group Inc
# KLXI   Before Market Open         1.15                        KLX Inc
# AEO    Before Market Open         0.48  American Eagle Outfitters Inc
# GIII   Before Market Open         1.81        G-III Apparel Group Ltd
# CIEN   Before Market Open         0.48                     Ciena Corp
# SCWX   Before Market Open        -0.05               Secureworks Corp
# IMKTA  Before Market Open            -             Ingles Markets Inc
# MOMO   Before Market Open         0.53                       Momo Inc
# MIK    Before Market Open         0.44         Michaels Companies Inc
# PDCO   Before Market Open         0.37        Patterson Companies Inc
# PLCE   Before Market Open         3.07            Childrens Place Inc
# KR     Before Market Open         0.43                      Kroger Co
# GCO    Before Market Open         0.86                    Genesco Inc
# THO    Before Market Open         1.75            Thor Industries Inc
#
#       EarningsDate
# FNSR    2018-12-03
# DG      2018-12-04
# CONN    2018-12-04
# DCI     2018-12-04
# MOV     2018-12-04
# KLXI    2018-12-04
# AEO     2018-12-05
# GIII    2018-12-05
# CIEN    2018-12-05
# SCWX    2018-12-05
# IMKTA   2018-12-05
# MOMO    2018-12-05
# MIK     2018-12-06
# PDCO    2018-12-06
# PLCE    2018-12-06
# KR      2018-12-06
# GCO     2018-12-06
# THO     2018-12-06

# %%
start_time = time.time()

start_date = dt.datetime(2018,1,1)

earnings_data = lookup_earnings(focus_names, start_date)

print("--- %s seconds ---" % (time.time() - start_time))
# Out:
# 2.33% Completed
# 4.65% Completed
# 6.98% Completed
# 9.30% Completed
# 11.63% Completed
# No revenues for AGX
# 13.95% Completed
# 16.28% Completed
# No revenues for AZO
# 18.60% Completed
# No revenues for TOL
# 20.93% Completed
# No revenues for HPE
# 23.26% Completed
# No revenues for DG
# 25.58% Completed
# 27.91% Completed
# No revenues for DCI
# 30.23% Completed
# 32.56% Completed
# 34.88% Completed
# No revenues for MOV
# 37.21% Completed
# 39.53% Completed
# No revenues for RH
# 41.86% Completed
# No revenues for AEO
# 44.19% Completed
# 46.51% Completed
# 48.84% Completed
# No revenues for HRB
# 51.16% Completed
# 53.49% Completed
# 55.81% Completed
# 58.14% Completed
# No revenues for GEF
# 60.47% Completed
# 62.79% Completed
# No revenues for KFY
# 65.12% Completed
# No insiders_txns for MOMO
# 67.44% Completed
# 69.77% Completed
# 72.09% Completed
# 74.42% Completed
# 76.74% Completed
# 79.07% Completed
# 81.40% Completed
# No revenues for KR
# 83.72% Completed
# No growth_summary for DOCU
# No revenues for MEI
# 86.05% Completed
# 88.37% Completed
# --- 336.6530888080597 seconds ---

# %%
#################### Preliminary Name Selection ###################################
summary_df = earnings_data[1]
summary_df = summary_df[summary_df['Market Cap(Mil.)'] > 500].sort_values('Market Cap(Mil.)')

eps_df = earnings_data[0]
eps_df = eps_df[eps_df.Underlying.isin(summary_df.index)]
eps_df['NegativeSurprise'] = eps_df['surprisePercent'] < 0 
eps_df['PositiveSurprise'] = eps_df['surprisePercent'] > 0
eps_df['returnDifferentFromEPS'] = eps_df['surprisePercent']*eps_df['Stock_closeToOpen'] < 0
eps_df['LargeMoves'] = abs(eps_df['Stock_closeToOpen']) > 0.02

eps_corr = eps_df[['Underlying','NegativeSurprise',
                   'PositiveSurprise',
                   'returnDifferentFromEPS']].groupby('Underlying').sum()
eps_corr['surpriseReturnCorrelation'] = np.nan
corrs = []
for ticker in eps_corr.index:
    curr_corr = eps_df[eps_df['Underlying'] == ticker]
    corrs.append(curr_corr[['surprisePercent','Stock_closeToOpen']].corr().iloc[0,1])
eps_corr['surpriseReturnCorrelation'] = corrs
eps_corr['LargeMoves'] = eps_df[['Underlying','LargeMoves']].groupby('Underlying').sum()

selected_names = eps_corr[eps_corr['LargeMoves'] > 2].index.tolist()

#################### Filtering on Preliminary Name Selection ###################################
summary_df = summary_df[summary_df.index.isin(selected_names)]

eps_df = eps_df[eps_df.Underlying.isin(summary_df.index)]
eps_corr = eps_corr[eps_corr.index.isin(summary_df.index)]

scores_df = earnings_data[2]
scores_df = scores_df[scores_df.index.isin(summary_df.index)]
scores_df['TotalScore'] = scores_df.mean(axis = 1)
scores_df = scores_df.sort_values('TotalScore')

analyst_df = earnings_data[3]
analyst_df = analyst_df[analyst_df.index.isin(summary_df.index)]

valuations_df = earnings_data[4]
valuations_df = valuations_df[valuations_df.Underlying.isin(summary_df.index)]

growthrate_df = earnings_data[5]
growthrate_df = growthrate_df[growthrate_df.Underlying.isin(summary_df.index)]

profitability_df = earnings_data[6]
profitability_df = profitability_df[profitability_df.Underlying.isin(summary_df.index)]

finstrength_df = earnings_data[7]
finstrength_df = finstrength_df[finstrength_df.Underlying.isin(summary_df.index)]

perf_df = earnings_data[8]
perf_df = perf_df[perf_df.Underlying.isin(summary_df.index)]

rev_revisions_df = earnings_data[9]
rev_revisions_df = rev_revisions_df[rev_revisions_df.Underlying.isin(summary_df.index)]

earnings_revisions_df = earnings_data[10]
earnings_revisions_df = earnings_revisions_df[earnings_revisions_df.Underlying.isin(summary_df.index)]

insider_trades = earnings_data[11]
insider_trades = insider_trades[insider_trades.Underlying.isin(summary_df.index)]
insider_trades['Trading Date'] = pd.to_datetime(insider_trades['Trading Date'])
def aggregate_txns_date(trade_date):
    
    trade_month = trade_date.month
    trade_year = trade_date.year
    if trade_month <= 3:
        return dt.datetime(trade_year,3,31).date()
    elif trade_month <= 6:
        return dt.datetime(trade_year,6,30).date()
    elif trade_month <= 9:
        return dt.datetime(trade_year,9,30).date()
    else:
        return dt.datetime(trade_year,12,31).date()
    
insider_trades['Trading Date'] = insider_trades['Trading Date'].apply(aggregate_txns_date)

growth_sums = earnings_data[12]
growth_sums = growth_sums[growth_sums.Underlying.isin(summary_df.index)]

# %%
selected_names = scores_df.sort_values(['ValuationScore','TotalScore']).index.tolist()

options_dict = {}

for name in selected_names:
    
    try:
        curr_options = all_options(name,100,1,moneyness=0.1)
        if len(curr_options) > 0 and (curr_options['Ask'] - curr_options['Bid']).mean() < 1:
            options_dict[name] = curr_options
    except:
        None
        
selected_names = list(options_dict.keys())

# %%
vols_list = []

for selected_name in selected_names:
    curr_vol = historical_data(selected_name, dt.datetime(2018,1,1))[['daily_ann','intra_ann','ovrnt_ann']].tail(1)
    curr_vol.index = [selected_name]
    
    aq = alphaquery(selected_name)
    
    curr_iv = aq.vol_df.loc[['Implied Volatility (Calls)', 'Implied Volatility (Puts)', 
                             'Put-Call Implied Volatility Ratio',
                             'Implied Volatility Skew'],['20-Day']].T
    curr_iv.index = [selected_name]
    vols_list.append(curr_vol.join(curr_iv))
    
hv_df = pd.concat(vols_list,axis = 0)

# %%
insider_agg_lst = []


for selected_name in selected_names:
    curr_insider_agg = insider_trades[insider_trades.Underlying == selected_name].groupby(['Type']).agg({'Shares Traded': 'sum'}).T
    curr_insider_agg.index = [selected_name]
    insider_agg_lst.append(curr_insider_agg)
    
insider_agg = pd.concat(insider_agg_lst,axis = 0)
insider_agg['BuyToSell'] = insider_agg['Buy']/insider_agg['Sell']


further_reduce = hv_df[(hv_df['intra_ann'] > hv_df['Implied Volatility (Calls)']) &
                       (hv_df['intra_ann'] > hv_df['Implied Volatility (Puts)'])].dropna().sort_values('intra_ann').join(insider_agg,
                                                                                                        how = 'inner')
selected_names = further_reduce.index.tolist()
curr_shares_out = summary_df[summary_df.index.isin(selected_names)][['Shares Outstanding(Mil.)']]*1000000
further_reduce.join(curr_earnings[['Call Time','EarningsDate']], how = 'left').sort_values(['EarningsDate','Call Time'],ascending = True)#.join(summary_df[summary_df.columns.tolist()[5:]], how = 'inner')
# Out:
#       daily_ann  intra_ann  ovrnt_ann  Implied Volatility (Calls)  \
# ASNA   0.694662   1.278460   0.205046                      1.0613
# FNSR   0.627679   0.723482   0.705651                      0.3048
# TOL    0.347798   0.571811   0.211038                      0.4979
# GWRE   0.488048   0.826325   0.219853                      0.4467
# VRNT   0.363101   0.629050   0.135765                      0.4354
# SNPS   0.368596   0.641045   0.144000                      0.3642
# LULU   0.427369   0.683233   0.295626                      0.6376
# CIEN   0.396946   0.533489   0.242499                      0.5036
# MOMO   0.568907   1.009919   0.421346                      0.8168
# GIII   0.572663   1.023722   0.218447                      0.8420
# SAIC   0.281388   0.567509   0.123060                      0.4647
# ULTA   0.283785   0.632778   0.215602                      0.4197
# PLCE   0.490269   0.694831   0.423102                      0.4663
# PDCO   0.415379   0.707282   0.147347                      0.5365
#
#       Implied Volatility (Puts)  Put-Call Implied Volatility Ratio  \
# ASNA                     1.0644                             1.0029
# FNSR                     0.2999                             0.9839
# TOL                      0.4983                             1.0008
# GWRE                     0.4291                             0.9606
# VRNT                     0.4283                             0.9837
# SNPS                     0.3724                             1.0225
# LULU                     0.6338                             0.9940
# CIEN                     0.4991                             0.9911
# MOMO                     0.7960                             0.9745
# GIII                     0.8498                             1.0093
# SAIC                     0.4572                             0.9839
# ULTA                     0.4192                             0.9988
# PLCE                     0.5031                             1.0789
# PDCO                     0.5372                             1.0013
#
#       Implied Volatility Skew        Buy      Gift        Sell  BuyToSell  \
# ASNA                   0.0833  2017090.0       NaN    226205.0   8.917088
# FNSR                   0.1059   939015.0       NaN   1565851.0   0.599683
# TOL                    0.0496  1854140.0  252767.0   1856303.0   0.998835
# GWRE                   0.0779   609600.0       NaN   1248096.0   0.488424
# VRNT                   0.0604   641436.0       NaN    651476.0   0.984589
# SNPS                   0.0368   343210.0  239740.0    418740.0   0.819626
# LULU                   0.0633    77432.0       NaN  40096480.0   0.001931
# CIEN                   0.0609    92730.0       NaN   1564890.0   0.059257
# MOMO                   0.0399        NaN       NaN         NaN        NaN
# GIII                   0.0733   595076.0       NaN   3643504.0   0.163325
# SAIC                   0.1037   798885.0  178848.0    747882.0   1.068197
# ULTA                   0.0443    50000.0   45090.0    704540.0   0.070968
# PLCE                   0.0267   139175.0       NaN   1560905.0   0.089163
# PDCO                   0.0390   840804.0       NaN      9468.0  88.804816
#
#                Call Time EarningsDate
# ASNA  After Market Close   2018-12-03
# FNSR  Before Market Open   2018-12-03
# TOL   After Market Close   2018-12-04
# GWRE  After Market Close   2018-12-04
# VRNT  After Market Close   2018-12-05
# SNPS  After Market Close   2018-12-05
# LULU  After Market Close   2018-12-05
# CIEN  Before Market Open   2018-12-05
# MOMO  Before Market Open   2018-12-05
# GIII  Before Market Open   2018-12-05
# SAIC  After Market Close   2018-12-06
# ULTA  After Market Close   2018-12-06
# PLCE  Before Market Open   2018-12-06
# PDCO  Before Market Open   2018-12-06

# %%
shorts =  further_reduce.index.tolist()#['ASNA','DG','CONN', 'MOV', 'COUP'] #

longs = []

print(scores_df[scores_df.index.isin(shorts + longs)])
print(eps_df[eps_df.Underlying.isin(shorts + longs)][['EarningsDate',
                                                      'surprisePercent',
                                                      'Underlying',
                                                      'Quarter',
                                                      'Stock_closeToOpen']].set_index('Underlying'))
print(analyst_df[analyst_df.index.isin(shorts + longs)].sort_values('Current'))


summary_df[summary_df.index.isin(shorts + longs)].T
# Out:
#       FinStrengthScore  GrowthRateScore  PerfRankScore  ProfitScore  \
# PDCO               0.0            14.29          58.28         15.0
# SAIC               0.0            28.57          80.40          0.0
# ASNA               0.0            21.43          41.52         20.0
# SNPS              30.0            35.71          78.38         20.0
# VRNT               0.0            57.14          78.18         25.0
# ULTA              60.0            71.43          58.89         50.0
# TOL               10.0            71.43          65.35         50.0
# GWRE              40.0            57.14          78.38         10.0
# CIEN              40.0            50.00          80.20         50.0
# MOMO              60.0            42.86          78.28         35.0
# PLCE              60.0            28.57          81.11         20.0
# GIII              30.0            64.29          77.37         15.0
# FNSR              50.0            57.14          68.28         45.0
# LULU              80.0            57.14          83.43         65.0
#
#       ReturnScore  ValuationScore  TotalScore
# PDCO          0.0           75.00   27.095000
# SAIC         20.0           37.50   27.745000
# ASNA         40.0           43.75   27.783333
# SNPS         20.0           25.00   34.848333
# VRNT         50.0           18.75   38.178333
# ULTA          0.0           18.75   43.178333
# TOL           0.0           68.75   44.255000
# GWRE         60.0           25.00   45.086667
# CIEN         20.0           31.25   45.241667
# MOMO         40.0           31.25   47.898333
# PLCE         40.0           62.50   48.696667
# GIII         40.0           81.25   51.318333
# FNSR         20.0           68.75   51.528333
# LULU         40.0           31.25   59.470000
#            EarningsDate  surprisePercent    Quarter  Stock_closeToOpen
# Underlying
# ASNA         2017-06-08            0.000 2017-10-31           0.027473
# ASNA         2017-12-04           -0.333 2018-01-31          -0.195402
# ASNA         2018-03-05            0.111 2018-04-30          -0.132231
# ASNA         2018-06-04            2.500 2018-07-31          -0.071038
# FNSR         2017-06-15           -0.233 2017-10-31           0.082293
# FNSR         2017-12-07           -0.130 2018-01-31          -0.026593
# FNSR         2018-03-08           -0.583 2018-04-30          -0.111771
# FNSR         2018-06-14            0.500 2018-07-31          -0.016384
# TOL          2017-12-05           -0.017 2017-10-31          -0.091986
# TOL          2018-02-27            0.339 2018-01-31           0.019987
# TOL          2018-05-22           -0.053 2018-04-30          -0.040110
# TOL          2018-08-21            0.223 2018-07-31           0.100490
# GWRE         2017-06-01            0.571 2017-10-31          -0.051143
# GWRE         2017-11-29            0.737 2018-01-31          -0.015722
# GWRE         2018-03-06            6.000 2018-04-30           0.031679
# GWRE         2018-06-05            0.080 2018-07-31          -0.023637
# LULU         2017-12-06            0.077 2017-10-31           0.084097
# LULU         2018-03-27            0.047 2018-01-31           0.070385
# LULU         2018-05-31            0.196 2018-04-30           0.084722
# LULU         2018-08-30            0.449 2018-07-31           0.118978
# GIII         2017-06-06            0.084 2017-10-31           0.287079
# GIII         2017-12-05            0.529 2018-01-31           0.100199
# GIII         2018-03-22            5.400 2018-04-30          -0.066915
# GIII         2018-06-05            6.333 2018-07-31           0.166045
# CIEN         2017-12-07           -0.080 2017-10-31           0.027397
# CIEN         2018-03-06            0.154 2018-01-31           0.057363
# CIEN         2018-05-31           -0.233 2018-04-30           0.018288
# CIEN         2018-08-30            0.333 2018-07-31           0.107287
# VRNT         2017-06-07            0.138 2017-10-31           0.021378
# VRNT         2017-12-06            0.050 2018-01-31          -0.055229
# VRNT         2018-03-28            0.104 2018-04-30           0.132353
# VRNT         2018-06-07            0.226 2018-07-31          -0.002270
# MOMO         2017-11-28            0.184 2017-09-30          -0.111974
# MOMO         2018-03-07            0.152 2017-12-31           0.114218
# MOMO         2018-05-29            0.380 2018-03-31           0.099872
# MOMO         2018-08-22            0.082 2018-06-30           0.058286
# SNPS         2017-11-29            0.211 2017-10-31           0.091391
# SNPS         2018-02-21            0.100 2018-01-31           0.030409
# SNPS         2018-05-23            0.000 2018-04-30          -0.024687
# SNPS         2018-08-22            0.033 2018-07-31           0.041196
# SAIC         2017-06-12            0.126 2017-10-31          -0.102775
# SAIC         2017-12-07            0.506 2018-01-31           0.106987
# SAIC         2018-03-29            0.097 2018-04-30           0.047769
# SAIC         2018-06-12            0.141 2018-07-31          -0.012262
# ULTA         2017-11-30            0.018 2017-10-31          -0.061522
# ULTA         2018-03-15           -0.011 2018-01-31           0.020423
# ULTA         2018-05-31            0.089 2018-04-30          -0.044227
# ULTA         2018-08-30            0.021 2018-07-31           0.011456
# PDCO         2017-11-21           -0.056 2017-10-31          -0.043653
# PDCO         2018-03-01           -0.173 2018-01-31          -0.199810
# PDCO         2018-06-21            0.000 2018-04-30           0.071904
# PDCO         2018-08-31           -0.235 2018-07-31           0.007539
# PLCE         2017-11-15            0.045 2017-10-31           0.053995
# PLCE         2018-03-20            0.012 2018-01-31          -0.093199
# PLCE         2018-05-17           -0.154 2018-04-30          -0.039855
# PLCE         2018-08-23            0.186 2018-07-31           0.006909
#            1-5LinearScale  1MonthAgo  2MonthAgo  3MonthAgo  Current
# Underlying
# MOMO          Mean Rating       1.57       1.57       1.57     1.55
# PLCE          Mean Rating       1.75       1.88       1.88     1.57
# VRNT          Mean Rating       1.67       1.80       1.67     1.67
# SNPS          Mean Rating       1.88       2.00       2.00     1.78
# ULTA          Mean Rating       2.07       2.00       2.00     1.92
# CIEN          Mean Rating       2.00       1.95       1.76     2.05
# GIII          Mean Rating       2.10       2.20       2.20     2.10
# LULU          Mean Rating       2.12       2.24       2.25     2.12
# GWRE          Mean Rating       2.18       2.00       1.91     2.18
# SAIC          Mean Rating       2.38       2.38       2.44     2.38
# TOL           Mean Rating       2.59       2.39       2.39     2.59
# FNSR          Mean Rating       2.43       2.38       2.21     2.62
# PDCO          Mean Rating       3.06       3.05       3.05     3.06
# ASNA          Mean Rating       3.40       3.40       3.40     3.40
#                             ASNA     GIII     PLCE     PDCO     FNSR     VRNT  \
# Beta                        1.70     0.25     0.30     0.97     1.16     1.11
# Dividend                     NaN      NaN     0.40     0.26      NaN      NaN
# EPS (TTM) Industry           NaN      NaN      NaN      NaN      NaN      NaN
# EPS (TTM) Sector             NaN      NaN      NaN      NaN      NaN      NaN
# EPS (TTM) Stock            -0.45     0.70     6.97     0.96     2.13     0.76
# High52Week                  5.28    51.20   161.65    38.52    25.41    52.45
# LastPrice                   3.12    44.12   129.64    25.26    23.47    45.49
# Low52Week                   1.79    30.10   112.55    20.22    14.25    37.10
# Market Cap(Mil.)          613.86  1393.02  2020.65  2486.84  2544.25  2838.96
# P/E (TTM) Industry         30.76    26.13    34.92    30.69    15.09    22.12
# P/E (TTM) Sector           17.65    19.17    19.17    30.88  1223.65     9.66
# P/E (TTM) Stock              NaN    41.00    16.43    27.30    10.49    57.79
# ROE Industry               17.01    11.93    12.11    15.64     5.77    15.96
# ROE Sector                 14.51    12.67    12.67    15.29    14.15    17.89
# ROE Stock                 -10.92     3.28    26.30     6.30    17.49     4.41
# ROI Industry               12.32     9.20     8.61    12.93     4.27    13.96
# ROI Sector                 12.65    10.48    10.48    13.80    14.01    16.43
# ROI Stock                  -3.15     2.42    22.44     3.59    12.96     2.60
# Shares Outstanding(Mil.)  197.38    48.76    17.64    95.06   113.89    64.91
# Yield (%)                    NaN      NaN     1.40     3.98      NaN      NaN
#
#                              SAIC     CIEN      TOL     MOMO     GWRE  \
# Beta                         1.61     1.65     1.16     1.92     1.29
# Dividend                     0.31      NaN     0.11      NaN      NaN
# EPS (TTM) Industry            NaN      NaN      NaN      NaN      NaN
# EPS (TTM) Sector              NaN      NaN      NaN      NaN      NaN
# EPS (TTM) Stock              3.59     0.92     3.75     2.03     0.14
# High52Week                  92.15    35.04    52.73    54.24   107.73
# LastPrice                   69.26    33.03    32.97    31.35    92.41
# Low52Week                   66.34    19.99    28.68    22.49    70.10
# Market Cap(Mil.)          3000.46  3169.11  4876.27  6075.34  7053.32
# P/E (TTM) Industry          22.43    15.09    10.22    39.50    39.50
# P/E (TTM) Sector          1223.65  1223.65    17.65     9.66     9.66
# P/E (TTM) Stock             19.31    24.08     8.82    14.63   606.04
# ROE Industry                14.10     5.77    14.29  -122.57  -122.57
# ROE Sector                  14.15    14.15    14.51    17.89    17.89
# ROE Stock                   47.38    16.63    13.09    38.15     0.80
# ROI Industry                11.97     4.27     9.65  -123.14  -123.14
# ROI Sector                  14.01    14.01    12.65    16.43    16.43
# ROI Stock                   11.76     6.89     6.78    32.40     0.69
# Shares Outstanding(Mil.)    43.24   142.69   147.36   102.24    81.01
# Yield (%)                    1.79      NaN     1.33      NaN      NaN
#
#                              LULU      SNPS      ULTA
# Beta                         0.15      0.98      0.55
# Dividend                      NaN       NaN       NaN
# EPS (TTM) Industry            NaN       NaN       NaN
# EPS (TTM) Sector              NaN       NaN       NaN
# EPS (TTM) Stock              2.07      2.13      7.52
# High52Week                 164.79    103.40    322.49
# LastPrice                  138.48     91.94    309.59
# Low52Week                   65.30     80.13    191.70
# Market Cap(Mil.)          8298.92  12392.43  13509.21
# P/E (TTM) Industry          26.13     34.44     33.86
# P/E (TTM) Sector            19.17   1223.65     19.17
# P/E (TTM) Stock             29.55     38.75     29.26
# ROE Industry                11.93     15.39     14.96
# ROE Sector                  12.67     14.15     12.67
# ROE Stock                   22.27     10.07     31.06
# ROI Industry                 9.20     14.13     10.91
# ROI Sector                  10.48     14.01     10.48
# ROI Stock                   21.22      8.95     23.83
# Shares Outstanding(Mil.)   135.38    150.25     61.43
# Yield (%)                     NaN       NaN       NaN

# %%
# Writing to Excel
os.chdir('C:\\Users\\Fang\\Desktop\\Python Trading\\Trading\\Data\\Historical Queries\\Earnings')
datenow = dt.datetime.today().strftime('%Y-%m-%d')
writer = pd.ExcelWriter('earnings-{}.xlsx'.format(datenow), engine='xlsxwriter')

# Write each dataframe to a different worksheet.
further_reduce.join(summary_df[summary_df.columns.tolist()[5:]], 
                    how = 'inner').join(curr_earnings).to_excel(writer, sheet_name='Summary')

eps_df[eps_df.Underlying.isin(shorts + longs)][['EarningsDate',
                                                      'surprisePercent',
                                                      'Underlying',
                                                      'Quarter',
                                                      'Stock_closeToOpen']].set_index('Underlying').to_excel(writer, sheet_name='EarningsHist')



selected_names = shorts + longs#

direction_points = pd.DataFrame(columns = ['PointsLong','PointsShort','ShortToLongRatio'])

for selected_name in selected_names:
    print(selected_name)
    points_short = 0
    points_long = 0
    
    for i, df in enumerate(earnings_data):
        
        try:
            if i == 2 or i == 3 or i == 1:
                None #print(df[df.index == selected_name])
            elif i == 11:
                #print(df[df.Underlying == selected_name][df.columns.tolist()[1:-1]])
                insider_trades[insider_trades.Underlying == selected_name].groupby(['Trading Date','Title',
                                                                                          'Type']).agg({'Underlying':'count',
                                                                                                        'Shares Traded': 'sum'}).to_excel(writer, sheet_name='{} Txns'.format(selected_name))
                print(insider_trades[insider_trades.Underlying == selected_name].groupby(['Trading Date','Title',
                                                                                          'Type']).agg({'Underlying':'count',
                                                                                                        'Shares Traded': 'sum'}))
            else:
                curr_info = df[df.Underlying == selected_name]
                
                if i == 5 and len(curr_info) != 0: # Growth Summaries (Sales)
                    
                    for info_idx in curr_info.index:
                        if curr_info.loc[info_idx,'Company'] > curr_info.loc[info_idx,'industry'] and curr_info.loc[info_idx,'Company'] > curr_info.loc[info_idx,'sector']:
                            points_long += 1
                        if curr_info.loc[info_idx,'Company'] < curr_info.loc[info_idx,'industry'] and curr_info.loc[info_idx,'Company'] < curr_info.loc[info_idx,'sector']:
                            points_short += 1
                                            
                    # Sales - 5 Yr. Growth Rate
                    if curr_info.loc[1,'Company'] > curr_info.loc[2,'Company']:
                        points_long += 1
                    if curr_info.loc[1,'Company'] < curr_info.loc[2,'Company']:
                        points_short += 1
                        
                    # EPS - 5 Yr. Growth Rate
                    if curr_info.loc[4,'Company'] > curr_info.loc[5,'Company']:
                        points_long += 1
                    if curr_info.loc[4,'Company'] < curr_info.loc[5,'Company']:
                        points_short += 1
                        
                    # Capital Spending - 5 Yr. Growth Rate
                    if curr_info.loc[6,'Company'] > 0:
                        points_long += 1
                    if curr_info.loc[6,'Company'] < 0:
                        points_long += 1
                        
                if i == 6 and len(curr_info) != 0: # Profitability Summmaries
                    
                    for info_idx in curr_info.index:
                        if curr_info.loc[info_idx,'Company'] > curr_info.loc[info_idx,'industry'] and curr_info.loc[info_idx,'Company'] > curr_info.loc[info_idx,'sector']:
                            points_long += 1
                        if curr_info.loc[info_idx,'Company'] < curr_info.loc[info_idx,'industry'] and curr_info.loc[info_idx,'Company'] < curr_info.loc[info_idx,'sector']:
                            points_short += 1
                            
                    # Gross Margin - 5 Yr. Avg. 
                    if curr_info.loc[0,'Company'] > curr_info.loc[1,'Company']:
                        points_long += 1
                    if curr_info.loc[0,'Company'] < curr_info.loc[1,'Company']:
                        points_short += 1
                        
                    # EBITD - 5 Yr. Avg 
                    if curr_info.loc[2,'Company'] > curr_info.loc[3,'Company']:
                        points_long += 1
                    if curr_info.loc[2,'Company'] < curr_info.loc[3,'Company']:
                        points_short += 1
                        
                    # Operating Margin - 5 Yr. Avg. 
                    if curr_info.loc[4,'Company'] > curr_info.loc[5,'Company']:
                        points_long += 1
                    if curr_info.loc[4,'Company'] < curr_info.loc[5,'Company']:
                        points_short += 1
                        
                    # Pre-Tax Margin - 5 Yr. Avg.
                    if curr_info.loc[6,'Company'] > curr_info.loc[7,'Company']:
                        points_long += 1
                    if curr_info.loc[6,'Company'] < curr_info.loc[7,'Company']:
                        points_short += 1
                        
                    # Net Profit Margin - 5 Yr. Avg. 
                    if curr_info.loc[8,'Company'] > curr_info.loc[9,'Company']:
                        points_long += 1
                    if curr_info.loc[8,'Company'] < curr_info.loc[9,'Company']:
                        points_short += 1
                        
                if i == 12 and len(curr_info) != 0:
                    for info_idx in curr_info.index:
                        if curr_info.loc[info_idx,'1 Year'] > curr_info.loc[info_idx,'3 Year'] and curr_info.loc[info_idx,'1 Year'] > curr_info.loc[info_idx,'5 Year']:
                            points_long += 1
                        if curr_info.loc[info_idx,'1 Year'] < curr_info.loc[info_idx,'3 Year'] and curr_info.loc[info_idx,'1 Year'] < curr_info.loc[info_idx,'5 Year']:
                            points_short += 1
                    
                print(curr_info)
            print('\n')
        except:
            continue
    try:
        direction_points.loc[selected_name,:] = [points_long, points_short, points_short/points_long]
        print('Points for short: {0} and Points for long: {1}'.format(points_short, points_long))
        print('Ratio of Short to Long {}'.format(points_short/points_long))
    except:
        continue
        
# Close the Pandas Excel writer and output the Excel file.
writer.save()
os.chdir(main_dir)
writer.save()
# Out:
# CIEN
#   epsActual epsDifference epsEstimate  surprisePercent Underlying    Quarter  \
# 0      0.46         -0.04         0.5           -0.080       CIEN 2017-10-31
# 1      0.15          0.02        0.13            0.154       CIEN 2018-01-31
# 2      0.23         -0.07         0.3           -0.233       CIEN 2018-04-30
# 3      0.48          0.12        0.36            0.333       CIEN 2018-07-31
#
#    Stock_closeToOpen EarningsDate
# 0           0.027397   2017-12-07
# 1           0.057363   2018-03-06
# 2           0.018288   2018-05-31
# 3           0.107287   2018-08-30
#
#
#
#
#
#
#
#
#    Company                         Field  industry   sector Underlying
# 0    24.08               P/E Ratio (TTM)     15.09  1223.65       CIEN
# 1   248.51        P/E High - Last 5 Yrs.     49.60    23.15       CIEN
# 2    37.74         P/E Low - Last 5 Yrs.     13.97     9.16       CIEN
# 3     1.65                          Beta      1.05     1.30       CIEN
# 4     1.14          Price to Sales (TTM)      1.51     2.67       CIEN
# 5     3.36           Price to Book (MRQ)      2.30     2.36       CIEN
# 6     5.56  Price to Tangible Book (MRQ)      3.54     3.63       CIEN
# 7    11.75      Price to Cash Flow (TTM)     16.41    13.97       CIEN
#
#
#    Company                                 Field  industry  sector Underlying
# 0     8.67         Sales (MRQ) vs Qtr. 1 Yr. Ago      3.74   19.80       CIEN
# 1     7.65          Sales (TTM) vs TTM 1 Yr. Ago      2.05    5.62       CIEN
# 2     8.34             Sales - 5 Yr. Growth Rate      5.31    4.94       CIEN
# 3    71.87           EPS (MRQ) vs Qtr. 1 Yr. Ago    335.05  113.41       CIEN
# 4   558.16            EPS (TTM) vs TTM 1 Yr. Ago       NaN     NaN       CIEN
# 5      NaN               EPS - 5 Yr. Growth Rate      7.63   11.10       CIEN
# 6    15.40  Capital Spending - 5 Yr. Growth Rate      8.14    2.99       CIEN
#
#
#    Company                           Field  industry  sector Underlying
# 0    44.66              Gross Margin (TTM)     33.51   40.94       CIEN
# 1    42.44       Gross Margin - 5 Yr. Avg.     34.13   37.27       CIEN
# 2    13.04              EBITD Margin (TTM)       NaN     NaN       CIEN
# 3     8.27               EBITD - 5 Yr. Avg    -12.83   22.12       CIEN
# 4     7.78          Operating Margin (TTM)      6.45   15.94       CIEN
# 5     1.71   Operating Margin - 5 Yr. Avg.    -17.98   12.97       CIEN
# 6     5.65            Pre-Tax Margin (TTM)      6.19   16.95       CIEN
# 7    -1.17     Pre-Tax Margin - 5 Yr. Avg.    -18.72   13.97       CIEN
# 8     4.99         Net Profit Margin (TTM)      4.37   12.52       CIEN
# 9    -1.65  Net Profit Margin - 5 Yr. Avg.    -20.75   10.62       CIEN
#
#
#    Company                       Field  industry  sector Underlying
# 0     2.50           Quick Ratio (MRQ)      1.95    1.83       CIEN
# 1     2.92         Current Ratio (MRQ)      2.41    2.27       CIEN
# 2   106.73     LT Debt to Equity (MRQ)     27.06    8.54       CIEN
# 3   107.55  Total Debt to Equity (MRQ)     46.94   16.07       CIEN
# 4     1.89     Interest Coverage (TTM)     17.09   16.60       CIEN
#
#
#    IndustryRank  PercentActual  Percentvs.S&P500   Period  RankInIndustry  \
# 0          85.0           2.26             -1.27   4 Week            99.0
# 1          44.0         -13.17            -17.40  13 Week            99.0
# 2          61.0           1.14             -6.55  26 Week            99.0
# 3          53.0          -2.03            -16.96  52 Week            99.0
# 4          56.0          -9.01            -20.09      YTD            99.0
#
#   Underlying
# 0       CIEN
# 1       CIEN
# 2       CIEN
# 3       CIEN
# 4       CIEN
#
#
#    Down Last4Weeks  Down LastWeek      NumberOfRevisions  Up Last4Weeks  \
# 0              0.0            0.0  Quarter Ending Oct-18            1.0
# 1              1.0            1.0  Quarter Ending Jan-19            0.0
# 2              0.0            0.0     Year Ending Oct-18            1.0
# 3              0.0            0.0     Year Ending Oct-19            0.0
#
#    Up LastWeek Underlying
# 0          1.0       CIEN
# 1          0.0       CIEN
# 2          1.0       CIEN
# 3          0.0       CIEN
#
#
#    Down Last4Weeks  Down LastWeek      NumberOfRevisions  Up Last4Weeks  \
# 0              0.0            0.0  Quarter Ending Oct-18            0.0
# 1              0.0            0.0  Quarter Ending Jan-19            0.0
# 2              0.0            0.0     Year Ending Oct-18            0.0
# 3              0.0            0.0     Year Ending Oct-19            0.0
#
#    Up LastWeek Underlying
# 0          0.0       CIEN
# 1          0.0       CIEN
# 2          0.0       CIEN
# 3          0.0       CIEN
#
#
#                                             Underlying  Shares Traded
# Trading Date Title                    Type
# 2018-12-31   Chief Executive Officer  Sell         390       936000.0
#              Chief Financial Officer  Sell          90       178890.0
#              Chief Technology Officer Sell          60       150000.0
#              Director                 Buy           30        92730.0
#              General Counsel          Sell          60       120000.0
#              Officer                  Sell         120       180000.0
#
#
#    1 Year  3 Year  5 Year        Field Underlying
# 0    6.33    7.69    8.34      Sales %       CIEN
# 1  428.61     NaN     NaN  EPS (TTM) %       CIEN
# 2     NaN     NaN     NaN   Dividend %       CIEN
#
#
# Points for short: 4 and Points for long: 11
# Ratio of Short to Long 0.36363636363636365
# SAIC
#   epsActual epsDifference epsEstimate  surprisePercent Underlying    Quarter  \
# 0      0.98          0.11        0.87            0.126       SAIC 2017-10-31
# 1      1.16          0.39        0.77            0.506       SAIC 2018-01-31
# 2      1.13           0.1        1.03            0.097       SAIC 2018-04-30
# 3      1.13          0.14        0.99            0.141       SAIC 2018-07-31
#
#    Stock_closeToOpen EarningsDate
# 0          -0.102775   2017-06-12
# 1           0.106987   2017-12-07
# 2           0.047769   2018-03-29
# 3          -0.012262   2018-06-12
#
#
#
#
#
#
#
#
#    Company                         Field  industry  sector Underlying
# 0    17.13               P/E Ratio (TTM)     22.12    9.66       SAIC
# 1    26.54        P/E High - Last 5 Yrs.     35.62   21.86       SAIC
# 2    16.28         P/E Low - Last 5 Yrs.     17.05    9.61       SAIC
# 3     1.50                          Beta      0.87    1.11       SAIC
# 4     0.64          Price to Sales (TTM)    534.69  123.63       SAIC
# 5     8.06           Price to Book (MRQ)      4.39    1.74       SAIC
# 6      NaN  Price to Tangible Book (MRQ)      5.48    2.58       SAIC
# 7    13.23      Price to Cash Flow (TTM)     17.03   12.46       SAIC
#
#
#    Company                                 Field  industry  sector Underlying
# 0     3.43         Sales (MRQ) vs Qtr. 1 Yr. Ago      9.40    7.68       SAIC
# 1     5.80          Sales (TTM) vs TTM 1 Yr. Ago      8.01   12.35       SAIC
# 2    -1.41             Sales - 5 Yr. Growth Rate      7.66    5.49       SAIC
# 3    40.84           EPS (MRQ) vs Qtr. 1 Yr. Ago     13.19   19.71       SAIC
# 4    15.30            EPS (TTM) vs TTM 1 Yr. Ago       NaN     NaN       SAIC
# 5    -0.42               EPS - 5 Yr. Growth Rate      8.14   16.52       SAIC
# 6    25.74  Capital Spending - 5 Yr. Growth Rate      3.57   11.85       SAIC
#
#
#    Company                           Field  industry  sector Underlying
# 0     9.40              Gross Margin (TTM)     32.18   43.56       SAIC
# 1     9.09       Gross Margin - 5 Yr. Avg.     29.14   38.87       SAIC
# 2     6.88              EBITD Margin (TTM)       NaN     NaN       SAIC
# 3     6.89               EBITD - 5 Yr. Avg     12.86   23.49       SAIC
# 4     6.00          Operating Margin (TTM)     12.15   22.41       SAIC
# 5     5.51   Operating Margin - 5 Yr. Avg.      8.94   14.45       SAIC
# 6     5.08            Pre-Tax Margin (TTM)     13.79   23.98       SAIC
# 7     4.75     Pre-Tax Margin - 5 Yr. Avg.     12.64   15.67       SAIC
# 8     3.84         Net Profit Margin (TTM)     10.01   17.48       SAIC
# 9     3.19  Net Profit Margin - 5 Yr. Avg.      8.78   11.83       SAIC
#
#
#    Company                       Field  industry  sector Underlying
# 0     1.25           Quick Ratio (MRQ)      2.58    1.87       SAIC
# 1     1.40         Current Ratio (MRQ)      2.82    2.31       SAIC
# 2   261.31     LT Debt to Equity (MRQ)     13.85    7.63       SAIC
# 3   274.66  Total Debt to Equity (MRQ)     19.70   16.72       SAIC
# 4     5.30     Interest Coverage (TTM)     27.00   10.74       SAIC
#
#
#    IndustryRank  PercentActual  Percentvs.S&P500   Period  RankInIndustry  \
# 0          24.0           1.88              1.90   4 Week            99.0
# 1          33.0         -24.87            -18.84  13 Week            96.0
# 2          78.0         -18.82            -18.59  26 Week            99.0
# 3          87.0          -3.33             -6.24  52 Week            99.0
# 4          82.0         -10.15            -10.43      YTD            99.0
#
#   Underlying
# 0       SAIC
# 1       SAIC
# 2       SAIC
# 3       SAIC
# 4       SAIC
#
#
#    Down Last4Weeks  Down LastWeek      NumberOfRevisions  Up Last4Weeks  \
# 0              NaN            NaN  Quarter Ending Jan-18            NaN
# 1              0.0            0.0  Quarter Ending Apr-19            0.0
# 2              NaN            NaN     Year Ending Jan-18            NaN
# 3              1.0            0.0     Year Ending Jan-19            0.0
# 4              1.0            0.0     Year Ending Jan-20            0.0
#
#    Up LastWeek Underlying
# 0          NaN       SAIC
# 1          0.0       SAIC
# 2          NaN       SAIC
# 3          0.0       SAIC
# 4          0.0       SAIC
#
#
#    Down Last4Weeks  Down LastWeek      NumberOfRevisions  Up Last4Weeks  \
# 0              NaN            NaN  Quarter Ending Jan-18            NaN
# 1              0.0            0.0  Quarter Ending Apr-19            0.0
# 2              NaN            NaN     Year Ending Jan-18            NaN
# 3              1.0            0.0     Year Ending Jan-19            0.0
# 4              1.0            0.0     Year Ending Jan-20            0.0
#
#    Up LastWeek Underlying
# 0          NaN       SAIC
# 1          0.0       SAIC
# 2          NaN       SAIC
# 3          0.0       SAIC
# 4          0.0       SAIC
#
#
#                                            Underlying  Shares Traded
# Trading Date Title                   Type
# 2018-06-30   Chief Executive Officer Buy            9       675000.0
#                                      Gift           9         5490.0
#                                      Sell          27       675000.0
#              Chief Operating Officer Sell           9         1377.0
#              Director                Sell           9         2565.0
# 2018-09-30   Chief Executive Officer Buy           18          180.0
#              Director                Buy           36        81603.0
#                                      Gift          18       173358.0
#                                      Sell          18        53595.0
#              Officer                 Buy            9           45.0
# 2018-12-31   Chief Executive Officer Buy           18          216.0
#              Director                Buy           27        41787.0
#                                      Sell           9        15345.0
#              Officer                 Buy            9           54.0
#
#
#    1 Year  3 Year  5 Year        Field Underlying
# 0    0.27    4.66   -1.41      Sales %       SAIC
# 1   16.85    7.79   -0.42  EPS (TTM) %       SAIC
# 2    0.00    3.45     NaN   Dividend %       SAIC
#
#
# Points for short: 14 and Points for long: 10
# Ratio of Short to Long 1.4
# TOL
#   epsActual epsDifference epsEstimate  surprisePercent Underlying    Quarter  \
# 0      1.17         -0.02        1.19           -0.017        TOL 2017-10-31
# 1      0.83          0.21        0.62            0.339        TOL 2018-01-31
# 2      0.72         -0.04        0.76           -0.053        TOL 2018-04-30
# 3      1.26          0.23        1.03            0.223        TOL 2018-07-31
#
#    Stock_closeToOpen EarningsDate
# 0          -0.091986   2017-12-05
# 1           0.019987   2018-02-27
# 2          -0.040110   2018-05-22
# 3           0.100490   2018-08-21
#
#
#
#
#
#
#
#
#    Company                         Field  industry  sector Underlying
# 0     8.82               P/E Ratio (TTM)     10.22   17.65        TOL
# 1    33.98        P/E High - Last 5 Yrs.     18.97   33.14        TOL
# 2    12.59         P/E Low - Last 5 Yrs.     10.44   13.68        TOL
# 3     1.16                          Beta      0.95    1.37        TOL
# 4     0.73          Price to Sales (TTM)      0.77  136.78        TOL
# 5     1.08           Price to Book (MRQ)      2.60    2.59        TOL
# 6     1.08  Price to Tangible Book (MRQ)      1.45    2.84        TOL
# 7     7.88      Price to Cash Flow (TTM)      7.49   10.49        TOL
#
#
#    Company                                 Field  industry  sector Underlying
# 0    27.31         Sales (MRQ) vs Qtr. 1 Yr. Ago      4.29   12.89        TOL
# 1    19.02          Sales (TTM) vs TTM 1 Yr. Ago      6.69   11.83        TOL
# 2    25.30             Sales - 5 Yr. Growth Rate      8.51    3.66        TOL
# 3    41.57           EPS (MRQ) vs Qtr. 1 Yr. Ago     12.09   39.45        TOL
# 4    39.95            EPS (TTM) vs TTM 1 Yr. Ago       NaN     NaN        TOL
# 5     2.04               EPS - 5 Yr. Growth Rate     23.61    2.39        TOL
# 6    19.35  Capital Spending - 5 Yr. Growth Rate     15.49    2.63        TOL
#
#
#    Company                           Field  industry  sector Underlying
# 0    20.81              Gross Margin (TTM)     22.83   23.88        TOL
# 1    20.93       Gross Margin - 5 Yr. Avg.     22.21   23.11        TOL
# 2    11.28              EBITD Margin (TTM)       NaN     NaN        TOL
# 3    10.58               EBITD - 5 Yr. Avg      9.80   13.93        TOL
# 4    10.90          Operating Margin (TTM)      8.69  -12.77        TOL
# 5    10.09   Operating Margin - 5 Yr. Avg.      7.42    9.35        TOL
# 6    12.50            Pre-Tax Margin (TTM)      9.30   13.75        TOL
# 7    12.47     Pre-Tax Margin - 5 Yr. Avg.      7.91   12.18        TOL
# 8     8.83         Net Profit Margin (TTM)      6.61   13.96        TOL
# 9     8.24  Net Profit Margin - 5 Yr. Avg.      5.36    9.60        TOL
#
#
#    Company                       Field  industry  sector Underlying
# 0      NaN           Quick Ratio (MRQ)      0.78    1.21        TOL
# 1      NaN         Current Ratio (MRQ)      1.74    1.53        TOL
# 2    80.32     LT Debt to Equity (MRQ)     29.64   52.44        TOL
# 3    80.32  Total Debt to Equity (MRQ)     44.33   82.64        TOL
# 4      NaN     Interest Coverage (TTM)     11.71    3.98        TOL
#
#
#    IndustryRank  PercentActual  Percentvs.S&P500   Period  RankInIndustry  \
# 0          50.0          -0.33             -0.31   4 Week            99.0
# 1          50.0         -10.86             -3.70  13 Week            99.0
# 2          26.0         -19.15            -18.92  26 Week            99.0
# 3          16.0         -31.32            -33.39  52 Week            95.0
# 4          14.0         -31.09            -31.31      YTD            99.0
#
#   Underlying
# 0        TOL
# 1        TOL
# 2        TOL
# 3        TOL
# 4        TOL
#
#
#    Down Last4Weeks  Down LastWeek      NumberOfRevisions  Up Last4Weeks  \
# 0              0.0            0.0  Quarter Ending Oct-18            0.0
# 1              1.0            0.0  Quarter Ending Jan-19            0.0
# 2              0.0            0.0     Year Ending Oct-18            0.0
# 3              1.0            0.0     Year Ending Oct-19            0.0
#
#    Up LastWeek Underlying
# 0          0.0        TOL
# 1          0.0        TOL
# 2          0.0        TOL
# 3          0.0        TOL
#
#
#    Down Last4Weeks  Down LastWeek      NumberOfRevisions  Up Last4Weeks  \
# 0              1.0            0.0  Quarter Ending Oct-18            0.0
# 1              1.0            0.0  Quarter Ending Jan-19            0.0
# 2              1.0            0.0     Year Ending Oct-18            0.0
# 3              1.0            0.0     Year Ending Oct-19            0.0
#
#    Up LastWeek Underlying
# 0          0.0        TOL
# 1          0.0        TOL
# 2          0.0        TOL
# 3          0.0        TOL
#                                            Underlying  Shares Traded
# Trading Date Title                   Type
# 2016-12-31   Chief Executive Officer Buy            1       104797.0
#                                      Sell           1        46454.0
#              Chief Financial Officer Buy            1        26199.0
#                                      Sell           1        10926.0
#              Director                Buy            2        32000.0
#                                      Gift           3          779.0
#                                      Sell           2        31472.0
#              Officer                 Buy            1         5986.0
#                                      Gift           1         2000.0
#                                      Sell           1         5986.0
#              Officer and Director    Buy            4       690079.0
#                                      Gift           3       147380.0
#                                      Sell           4       612094.0
#              President               Buy            1        31439.0
#                                      Sell           1        13624.0
# 2017-03-31   Chief Executive Officer Buy            2        16250.0
#                                      Sell           2        16250.0
#              Director                Buy            8        36401.0
#                                      Sell           2        24500.0
#              Officer                 Buy            4         5646.0
#                                      Sell           5         6834.0
#              Officer and Director    Buy            1        24474.0
#                                      Sell           2       275000.0
#              President               Buy            1        20000.0
#                                      Sell           2        27836.0
# 2017-06-30   Chief Executive Officer Sell           3        15845.0
#              Chief Financial Officer Buy            2         4000.0
#                                      Sell           2         4000.0
#              Director                Buy            5        85000.0
#                                      Gift           2         1477.0
# ...                                               ...            ...
# 2017-12-31   Director                Sell           2        36250.0
#              Officer                 Gift           1         3070.0
#              Officer and Director    Buy            1       133736.0
#                                      Gift           2        38900.0
#                                      Sell           1        58497.0
#              President               Buy            2        50015.0
#                                      Sell           4        41666.0
# 2018-03-31   Chief Executive Officer Buy            1        10000.0
#                                      Sell           2        30000.0
#              Chief Financial Officer Buy            2        12000.0
#                                      Sell           3        12000.0
#              Director                Buy            7        27769.0
#                                      Sell           3        61000.0
#              Officer                 Buy            1         4500.0
#                                      Sell           1         4500.0
#              Officer and Director    Gift           1        51550.0
# 2018-06-30   Director                Gift           1          606.0
#              Officer and Director    Gift           2         4617.0
# 2018-09-30   Director                Buy            2        32000.0
#                                      Gift           1           82.0
#                                      Sell           2        32000.0
# 2018-12-31   Chief Executive Officer Buy            1        22437.0
#                                      Sell           1         9229.0
#              Chief Financial Officer Buy            1         5561.0
#                                      Sell           1         2288.0
#              Director                Buy            1            9.0
#                                      Gift           1           95.0
#              Officer and Director    Buy            1        12767.0
#              President               Buy            1         6762.0
#                                      Sell           1         2457.0
#
# [79 rows x 2 columns]
#
#
#    1 Year  3 Year  5 Year        Field Underlying
# 0   12.49   14.13   25.30      Sales %        TOL
# 1   45.32   19.85    2.04  EPS (TTM) %        TOL
# 2     NaN     NaN     NaN   Dividend %        TOL
#
#
# Points for short: 6 and Points for long: 15
# Ratio of Short to Long 0.4
# VRNT
#   epsActual epsDifference epsEstimate  surprisePercent Underlying    Quarter  \
# 0      0.66          0.08        0.58            0.138       VRNT 2017-10-31
# 1      1.05          0.05           1            0.050       VRNT 2018-01-31
# 2      0.53          0.05        0.48            0.104       VRNT 2018-04-30
# 3      0.76          0.14        0.62            0.226       VRNT 2018-07-31
#
#    Stock_closeToOpen EarningsDate
# 0           0.021378   2017-06-07
# 1          -0.055229   2017-12-06
# 2           0.132353   2018-03-28
# 3          -0.002270   2018-06-07
#
#
#
#
#
#
#
#
#    Company                         Field  industry  sector Underlying
# 0    57.79               P/E Ratio (TTM)     22.12    9.66       VRNT
# 1   876.92        P/E High - Last 5 Yrs.     35.62   21.86       VRNT
# 2    45.69         P/E Low - Last 5 Yrs.     17.05    9.61       VRNT
# 3     1.11                          Beta      0.87    1.11       VRNT
# 4     2.38          Price to Sales (TTM)    534.69  123.63       VRNT
# 5     2.41           Price to Book (MRQ)      4.39    1.74       VRNT
# 6      NaN  Price to Tangible Book (MRQ)      5.48    2.58       VRNT
# 7    19.19      Price to Cash Flow (TTM)     17.03   12.46       VRNT
#
#
#    Company                                 Field  industry  sector Underlying
# 0    11.48         Sales (MRQ) vs Qtr. 1 Yr. Ago      9.40    7.68       VRNT
# 1     9.58          Sales (TTM) vs TTM 1 Yr. Ago      8.01   12.35       VRNT
# 2     6.22             Sales - 5 Yr. Growth Rate      7.66    5.49       VRNT
# 3   428.20           EPS (MRQ) vs Qtr. 1 Yr. Ago     13.19   19.71       VRNT
# 4   280.50            EPS (TTM) vs TTM 1 Yr. Ago       NaN     NaN       VRNT
# 5   -45.11               EPS - 5 Yr. Growth Rate      8.14   16.52       VRNT
# 6    14.13  Capital Spending - 5 Yr. Growth Rate      3.57   11.85       VRNT
#
#
#    Company                           Field  industry  sector Underlying
# 0    62.12              Gross Margin (TTM)     32.18   43.56       VRNT
# 1    62.34       Gross Margin - 5 Yr. Avg.     29.14   38.87       VRNT
# 2    15.07              EBITD Margin (TTM)       NaN     NaN       VRNT
# 3    15.59               EBITD - 5 Yr. Avg     12.86   23.49       VRNT
# 4     7.60          Operating Margin (TTM)     12.15   22.41       VRNT
# 5     5.55   Operating Margin - 5 Yr. Avg.      8.94   14.45       VRNT
# 6     4.89            Pre-Tax Margin (TTM)     13.79   23.98       VRNT
# 7     1.93     Pre-Tax Margin - 5 Yr. Avg.     12.64   15.67       VRNT
# 8     4.41         Net Profit Margin (TTM)     10.01   17.48       VRNT
# 9     1.82  Net Profit Margin - 5 Yr. Avg.      8.78   11.83       VRNT
#
#
#    Company                       Field  industry  sector Underlying
# 0     1.53           Quick Ratio (MRQ)      2.58    1.87       VRNT
# 1     1.57         Current Ratio (MRQ)      2.82    2.31       VRNT
# 2    65.67     LT Debt to Equity (MRQ)     13.85    7.63       VRNT
# 3    65.67  Total Debt to Equity (MRQ)     19.70   16.72       VRNT
# 4     0.56     Interest Coverage (TTM)     27.00   10.74       VRNT
#
#
#    IndustryRank  PercentActual  Percentvs.S&P500   Period  RankInIndustry  \
# 0          24.0          -1.73             -1.71   4 Week            80.0
# 1          33.0         -11.10             -3.96  13 Week            93.0
# 2          78.0           4.14              4.44  26 Week            99.0
# 3          87.0           1.48             -1.57  52 Week            99.0
# 4          82.0           4.52              4.18      YTD            99.0
#
#   Underlying
# 0       VRNT
# 1       VRNT
# 2       VRNT
# 3       VRNT
# 4       VRNT
#
#
#    Down Last4Weeks  Down LastWeek      NumberOfRevisions  Up Last4Weeks  \
# 0              NaN            NaN  Quarter Ending Jan-18            NaN
# 1              0.0            0.0  Quarter Ending Apr-19            0.0
# 2              NaN            NaN     Year Ending Jan-18            NaN
# 3              0.0            0.0     Year Ending Jan-19            0.0
# 4              0.0            0.0     Year Ending Jan-20            0.0
#
#    Up LastWeek Underlying
# 0          NaN       VRNT
# 1          0.0       VRNT
# 2          NaN       VRNT
# 3          0.0       VRNT
# 4          0.0       VRNT
#
#
#    Down Last4Weeks  Down LastWeek      NumberOfRevisions  Up Last4Weeks  \
# 0              NaN            NaN  Quarter Ending Jan-18            NaN
# 1              0.0            0.0  Quarter Ending Apr-19            0.0
# 2              NaN            NaN     Year Ending Jan-18            NaN
# 3              0.0            0.0     Year Ending Jan-19            0.0
# 4              0.0            0.0     Year Ending Jan-20            0.0
#
#    Up LastWeek Underlying
# 0          NaN       VRNT
# 1          0.0       VRNT
# 2          NaN       VRNT
# 3          0.0       VRNT
# 4          0.0       VRNT
#
#
#                                            Underlying  Shares Traded
# Trading Date Title                   Type
# 2018-06-30   Chief Executive Officer Buy            4       268800.0
#              Chief Financial Officer Buy            4        60000.0
#              Director                Buy           20        95460.0
#              Officer                 Buy            8       140000.0
# 2018-09-30   Chief Executive Officer Buy            4        49112.0
#                                      Sell           4       245192.0
#              Chief Financial Officer Buy            4        11596.0
#                                      Sell           8        46040.0
#              Director                Sell          12        45708.0
#              Officer                 Buy            8        16468.0
#                                      Sell          24       314536.0
#
#
#    1 Year  3 Year  5 Year        Field Underlying
# 0    6.88    0.20    6.22      Sales %       VRNT
# 1  110.14  -54.96  -45.11  EPS (TTM) %       VRNT
# 2     NaN     NaN     NaN   Dividend %       VRNT
#
#
# Points for short: 9 and Points for long: 13
# Ratio of Short to Long 0.6923076923076923
# ULTA
#   epsActual epsDifference epsEstimate  surprisePercent Underlying    Quarter  \
# 0       1.7          0.03        1.67            0.018       ULTA 2017-10-31
# 1      2.75         -0.03        2.78           -0.011       ULTA 2018-01-31
# 2       2.7          0.22        2.48            0.089       ULTA 2018-04-30
# 3      2.46          0.05        2.41            0.021       ULTA 2018-07-31
#
#    Stock_closeToOpen EarningsDate
# 0          -0.061522   2017-11-30
# 1           0.020423   2018-03-15
# 2          -0.044227   2018-05-31
# 3           0.011456   2018-08-30
#
#
#
#
#
#
#
#
#    Company                         Field  industry  sector Underlying
# 0    29.26               P/E Ratio (TTM)     33.86   19.17       ULTA
# 1    41.63        P/E High - Last 5 Yrs.    111.24   33.06       ULTA
# 2    27.24         P/E Low - Last 5 Yrs.     18.38   12.82       ULTA
# 3     0.55                          Beta      0.50    1.26       ULTA
# 4     2.54          Price to Sales (TTM)      2.02    1.91       ULTA
# 5     8.29           Price to Book (MRQ)      4.31    2.29       ULTA
# 6     8.26  Price to Tangible Book (MRQ)      7.88    2.88       ULTA
# 7    19.07      Price to Cash Flow (TTM)     15.64   13.97       ULTA
#
#
#    Company                                 Field  industry  sector Underlying
# 0    20.64         Sales (MRQ) vs Qtr. 1 Yr. Ago      6.91    7.01       ULTA
# 1    23.01          Sales (TTM) vs TTM 1 Yr. Ago      6.15    4.50       ULTA
# 2    22.27             Sales - 5 Yr. Growth Rate     14.41    4.13       ULTA
# 3    27.76           EPS (MRQ) vs Qtr. 1 Yr. Ago     64.22   41.83       ULTA
# 4    32.36            EPS (TTM) vs TTM 1 Yr. Ago       NaN     NaN       ULTA
# 5    27.98               EPS - 5 Yr. Growth Rate     11.00    2.01       ULTA
# 6    23.78  Capital Spending - 5 Yr. Growth Rate     10.14    1.76       ULTA
#
#
#    Company                           Field  industry  sector Underlying
# 0    36.06              Gross Margin (TTM)     51.28   23.66       ULTA
# 1    35.44       Gross Margin - 5 Yr. Avg.     55.28   22.90       ULTA
# 2    18.25              EBITD Margin (TTM)       NaN     NaN       ULTA
# 3    17.03               EBITD - 5 Yr. Avg     12.72   34.72       ULTA
# 4    13.77          Operating Margin (TTM)      3.99   13.61       ULTA
# 5    12.89   Operating Margin - 5 Yr. Avg.      8.09   38.29       ULTA
# 6    13.79            Pre-Tax Margin (TTM)      3.66   15.98       ULTA
# 7    12.90     Pre-Tax Margin - 5 Yr. Avg.      7.72   40.80       ULTA
# 8     8.84         Net Profit Margin (TTM)      0.65   13.48       ULTA
# 9     8.06  Net Profit Margin - 5 Yr. Avg.      4.43   37.59       ULTA
#
#
#    Company                       Field  industry  sector Underlying
# 0     0.79           Quick Ratio (MRQ)      1.04    1.19       ULTA
# 1     2.79         Current Ratio (MRQ)      1.84    1.45       ULTA
# 2     0.00     LT Debt to Equity (MRQ)     29.52   35.37       ULTA
# 3     0.00  Total Debt to Equity (MRQ)     52.62   70.08       ULTA
# 4      NaN     Interest Coverage (TTM)     31.88    6.28       ULTA
#
#
#    IndustryRank  PercentActual  Percentvs.S&P500   Period  RankInIndustry  \
# 0          37.0          -3.11             -6.46   4 Week            75.0
# 1          54.0         -20.60            -24.47  13 Week            67.0
# 2          39.0         -22.70            -28.58  26 Week            64.0
# 3          33.0          -8.97            -22.84  52 Week            99.0
# 4          23.0         -13.74            -24.25      YTD            92.0
#
#   Underlying
# 0       ULTA
# 1       ULTA
# 2       ULTA
# 3       ULTA
# 4       ULTA
#
#
#    Down Last4Weeks  Down LastWeek      NumberOfRevisions  Up Last4Weeks  \
# 0              NaN            NaN  Quarter Ending Jan-18            NaN
# 1              8.0            0.0  Quarter Ending Apr-19            2.0
# 2              NaN            NaN     Year Ending Jan-18            NaN
# 3              7.0            0.0     Year Ending Jan-19           15.0
# 4             21.0            1.0     Year Ending Jan-20            1.0
#
#    Up LastWeek Underlying
# 0          NaN       ULTA
# 1          0.0       ULTA
# 2          NaN       ULTA
# 3          1.0       ULTA
# 4          0.0       ULTA
#
#
#    Down Last4Weeks  Down LastWeek      NumberOfRevisions  Up Last4Weeks  \
# 0              NaN            NaN  Quarter Ending Jan-18            NaN
# 1              4.0            0.0  Quarter Ending Apr-19            8.0
# 2              NaN            NaN     Year Ending Jan-18            NaN
# 3              6.0            1.0     Year Ending Jan-19            5.0
# 4              8.0            0.0     Year Ending Jan-20            8.0
#
#    Up LastWeek Underlying
# 0          NaN       ULTA
# 1          0.0       ULTA
# 2          NaN       ULTA
# 3          0.0       ULTA
# 4          2.0       ULTA
#
#
#                                            Underlying  Shares Traded
# Trading Date Title                   Type
# 2018-06-30   Chief Executive Officer Sell           5        12480.0
#              Director                Gift          10        40000.0
#                                      Sell          35       322000.0
#              Officer                 Buy           10        40000.0
# 2018-09-30   Director                Buy            5        10000.0
#                                      Gift          10         5090.0
#                                      Sell          45       369615.0
#              General Counsel         Sell           5          445.0
#
#
#    1 Year  3 Year  5 Year        Field Underlying
# 0   23.72   22.05   22.27      Sales %       ULTA
# 1   30.95   27.48   27.98  EPS (TTM) %       ULTA
# 2     NaN     NaN     NaN   Dividend %       ULTA
#
#
# Points for short: 1 and Points for long: 16
# Ratio of Short to Long 0.0625
# SNPS
#   epsActual epsDifference epsEstimate  surprisePercent Underlying    Quarter  \
# 0      0.69          0.12        0.57            0.211       SNPS 2017-10-31
# 1       1.1           0.1           1            0.100       SNPS 2018-01-31
# 2      1.08             0        1.08            0.000       SNPS 2018-04-30
# 3      0.95          0.03        0.92            0.033       SNPS 2018-07-31
#
#    Stock_closeToOpen EarningsDate
# 0           0.091391   2017-11-29
# 1           0.030409   2018-02-21
# 2          -0.024687   2018-05-23
# 3           0.041196   2018-08-22
#
#
#
#
#
#
#
#
#    Company                         Field  industry  sector Underlying
# 0    74.79               P/E Ratio (TTM)     39.50    9.66       SNPS
# 1    98.12        P/E High - Last 5 Yrs.     61.96   21.86       SNPS
# 2    23.02         P/E Low - Last 5 Yrs.     24.81    9.61       SNPS
# 3     1.29                          Beta      0.80    1.11       SNPS
# 4     4.27          Price to Sales (TTM)   7458.41  123.63       SNPS
# 5     4.09           Price to Book (MRQ)      6.50    1.74       SNPS
# 6      NaN  Price to Tangible Book (MRQ)     32.88    2.58       SNPS
# 7    34.67      Price to Cash Flow (TTM)     33.47   12.46       SNPS
#
#
#    Company                                 Field  industry  sector Underlying
# 0    12.13         Sales (MRQ) vs Qtr. 1 Yr. Ago     12.03    7.68       SNPS
# 1    13.55          Sales (TTM) vs TTM 1 Yr. Ago      8.90   12.35       SNPS
# 2     9.19             Sales - 5 Yr. Growth Rate     13.22    5.49       SNPS
# 3   -31.06           EPS (MRQ) vs Qtr. 1 Yr. Ago     16.80   19.71       SNPS
# 4   -45.38            EPS (TTM) vs TTM 1 Yr. Ago       NaN     NaN       SNPS
# 5    -6.19               EPS - 5 Yr. Growth Rate     10.44   16.52       SNPS
# 6   -20.19  Capital Spending - 5 Yr. Growth Rate     11.02   11.85       SNPS
#
#
#    Company                           Field  industry  sector Underlying
# 0    76.44              Gross Margin (TTM)     57.45   43.56       SNPS
# 1    76.98       Gross Margin - 5 Yr. Avg.     59.88   38.87       SNPS
# 2    19.63              EBITD Margin (TTM)       NaN     NaN       SNPS
# 3    21.75               EBITD - 5 Yr. Avg     25.20   23.49       SNPS
# 4    12.92          Operating Margin (TTM)     13.53   22.41       SNPS
# 5    12.50   Operating Margin - 5 Yr. Avg.     18.94   14.45       SNPS
# 6    13.60            Pre-Tax Margin (TTM)     14.39   23.98       SNPS
# 7    13.52     Pre-Tax Margin - 5 Yr. Avg.     19.43   15.67       SNPS
# 8     5.86         Net Profit Margin (TTM)      9.11   17.48       SNPS
# 9     9.96  Net Profit Margin - 5 Yr. Avg.     13.36   11.83       SNPS
#
#
#    Company                       Field  industry  sector Underlying
# 0      NaN           Quick Ratio (MRQ)      1.94    1.87       SNPS
# 1     0.70         Current Ratio (MRQ)      3.08    2.31       SNPS
# 2     3.92     LT Debt to Equity (MRQ)     24.89    7.63       SNPS
# 3    19.68  Total Debt to Equity (MRQ)     29.59   16.72       SNPS
# 4      NaN     Interest Coverage (TTM)     10.87   10.74       SNPS
#
#
#    IndustryRank  PercentActual  Percentvs.S&P500   Period  RankInIndustry  \
# 0          27.0          -0.97             -0.95   4 Week            99.0
# 1          27.0         -14.63             -7.77  13 Week            99.0
# 2          79.0          -0.93             -0.65  26 Week            99.0
# 3          72.0          -2.54             -5.48  52 Week            99.0
# 4          76.0           2.02              1.69      YTD            99.0
#
#   Underlying
# 0       SNPS
# 1       SNPS
# 2       SNPS
# 3       SNPS
# 4       SNPS
#
#
#    Down Last4Weeks  Down LastWeek      NumberOfRevisions  Up Last4Weeks  \
# 0              0.0            0.0  Quarter Ending Oct-18            0.0
# 1              0.0            0.0  Quarter Ending Jan-19            0.0
# 2              0.0            0.0     Year Ending Oct-18            0.0
# 3              0.0            0.0     Year Ending Oct-19            0.0
#
#    Up LastWeek Underlying
# 0          0.0       SNPS
# 1          0.0       SNPS
# 2          0.0       SNPS
# 3          0.0       SNPS
#
#
#    Down Last4Weeks  Down LastWeek      NumberOfRevisions  Up Last4Weeks  \
# 0              0.0            0.0  Quarter Ending Oct-18            0.0
# 1              0.0            0.0  Quarter Ending Jan-19            0.0
# 2              0.0            0.0     Year Ending Oct-18            0.0
# 3              0.0            0.0     Year Ending Oct-19            0.0
#
#    Up LastWeek Underlying
# 0          0.0       SNPS
# 1          0.0       SNPS
# 2          0.0       SNPS
# 3          0.0       SNPS
#
#
#                                            Underlying  Shares Traded
# Trading Date Title                   Type
# 2018-06-30   Chief Financial Officer Buy           20        23190.0
#                                      Sell          20         8020.0
#              General Counsel         Sell          10        69890.0
#              Officer                 Buy           20         9660.0
#                                      Sell          20         3310.0
# 2018-09-30   Chief Executive Officer Buy           20         2180.0
#                                      Gift          10       200000.0
#                                      Sell          10        36090.0
#              Chief Financial Officer Buy           10         1090.0
#              Director                Gift          10        39740.0
#              General Counsel         Buy           30       101490.0
#                                      Sell          20       100000.0
#              Officer                 Buy           30       205600.0
#                                      Sell          20       201430.0
#
#
#    1 Year  3 Year  5 Year        Field Underlying
# 0   12.48    9.82    9.19      Sales %       SNPS
# 1  -48.87  -18.74   -6.19  EPS (TTM) %       SNPS
# 2     NaN     NaN     NaN   Dividend %       SNPS
#
#
# Points for short: 15 and Points for long: 9
# Ratio of Short to Long 1.6666666666666667
# LULU
#   epsActual epsDifference epsEstimate  surprisePercent Underlying    Quarter  \
# 0      0.56          0.04        0.52            0.077       LULU 2017-10-31
# 1      1.33          0.06        1.27            0.047       LULU 2018-01-31
# 2      0.55          0.09        0.46            0.196       LULU 2018-04-30
# 3      0.71          0.22        0.49            0.449       LULU 2018-07-31
#
#    Stock_closeToOpen EarningsDate
# 0           0.084097   2017-12-06
# 1           0.070385   2018-03-27
# 2           0.084722   2018-05-31
# 3           0.118978   2018-08-30
#
#
#
#
#
#
#
#
#    Company                         Field  industry  sector Underlying
# 0    29.55               P/E Ratio (TTM)     26.13   19.17       LULU
# 1    39.99        P/E High - Last 5 Yrs.     65.86   33.06       LULU
# 2    23.87         P/E Low - Last 5 Yrs.     19.48   12.82       LULU
# 3     0.15                          Beta      0.94    1.26       LULU
# 4     3.41          Price to Sales (TTM)      2.78    1.91       LULU
# 5     6.37           Price to Book (MRQ)      2.83    2.29       LULU
# 6     6.04  Price to Tangible Book (MRQ)     27.32    2.88       LULU
# 7    21.61      Price to Cash Flow (TTM)     22.22   13.97       LULU
#
#
#    Company                                 Field  industry  sector Underlying
# 0    12.93         Sales (MRQ) vs Qtr. 1 Yr. Ago     13.25    7.01       LULU
# 1    11.02          Sales (TTM) vs TTM 1 Yr. Ago      3.77    4.50       LULU
# 2    18.56             Sales - 5 Yr. Growth Rate     11.47    4.13       LULU
# 3    -8.55           EPS (MRQ) vs Qtr. 1 Yr. Ago     29.88   41.83       LULU
# 4     6.41            EPS (TTM) vs TTM 1 Yr. Ago       NaN     NaN       LULU
# 5    11.77               EPS - 5 Yr. Growth Rate      8.47    2.01       LULU
# 6     4.10  Capital Spending - 5 Yr. Growth Rate     11.38    1.76       LULU
#
#
#    Company                           Field  industry  sector Underlying
# 0    51.76              Gross Margin (TTM)     38.60   23.66       LULU
# 1    51.44       Gross Margin - 5 Yr. Avg.     41.76   22.90       LULU
# 2    21.30              EBITD Margin (TTM)       NaN     NaN       LULU
# 3    24.54               EBITD - 5 Yr. Avg     13.84   34.72       LULU
# 4    16.58          Operating Margin (TTM)      8.58   13.61       LULU
# 5    21.11   Operating Margin - 5 Yr. Avg.     11.06   38.29       LULU
# 6    16.71            Pre-Tax Margin (TTM)      9.08   15.98       LULU
# 7    21.31     Pre-Tax Margin - 5 Yr. Avg.     11.21   40.80       LULU
# 8    11.68         Net Profit Margin (TTM)      6.63   13.48       LULU
# 9    14.84  Net Profit Margin - 5 Yr. Avg.      8.20   37.59       LULU
#
#
#    Company                       Field  industry  sector Underlying
# 0     3.81           Quick Ratio (MRQ)      1.12    1.19       LULU
# 1     5.22         Current Ratio (MRQ)      1.90    1.45       LULU
# 2     0.00     LT Debt to Equity (MRQ)     11.56   35.37       LULU
# 3     0.00  Total Debt to Equity (MRQ)     20.85   70.08       LULU
# 4      NaN     Interest Coverage (TTM)     15.80    6.28       LULU
#
#
#    IndustryRank  PercentActual  Percentvs.S&P500   Period  RankInIndustry  \
# 0          43.0          -1.67             -5.06   4 Week            99.0
# 1          79.0           5.04             -0.08  13 Week            99.0
# 2          69.0          21.07             11.87  26 Week            99.0
# 3          70.0           4.75            -11.22  52 Week            99.0
# 4          83.0          -5.68            -17.17      YTD            86.0
#
#   Underlying
# 0       LULU
# 1       LULU
# 2       LULU
# 3       LULU
# 4       LULU
#
#
#    Down Last4Weeks  Down LastWeek      NumberOfRevisions  Up Last4Weeks  \
# 0              NaN            NaN  Quarter Ending Jan-18            NaN
# 1              0.0            0.0  Quarter Ending Apr-19            0.0
# 2              NaN            NaN     Year Ending Jan-18            NaN
# 3              1.0            1.0     Year Ending Jan-19            3.0
# 4              0.0            0.0     Year Ending Jan-20            4.0
#
#    Up LastWeek Underlying
# 0          NaN       LULU
# 1          0.0       LULU
# 2          NaN       LULU
# 3          0.0       LULU
# 4          1.0       LULU
#
#
#    Down Last4Weeks  Down LastWeek      NumberOfRevisions  Up Last4Weeks  \
# 0              NaN            NaN  Quarter Ending Jan-18            NaN
# 1              0.0            0.0  Quarter Ending Apr-19            1.0
# 2              NaN            NaN     Year Ending Jan-18            NaN
# 3              0.0            0.0     Year Ending Jan-20            5.0
#
#    Up LastWeek Underlying
# 0          NaN       LULU
# 1          0.0       LULU
# 2          NaN       LULU
# 3          1.0       LULU
#
#
#                                                            Underlying  \
# Trading Date Title                                   Type
# 2018-03-31   Chief Operating Officer                 Buy            4
#              Officer                                 Buy            8
# 2018-06-30   Beneficial Owner of More than 10% Class Sell           4
#              Chief Financial Officer                 Buy            8
#              Chief Operating Officer                 Buy            4
#                                                      Sell          12
#              Director                                Buy           24
#                                                      Sell           8
#              Officer                                 Buy            4
#                                                      Sell          16
# 2018-09-30   Director                                Buy            4
#              Officer                                 Buy            4
#
#                                                            Shares Traded
# Trading Date Title                                   Type
# 2018-03-31   Chief Operating Officer                 Buy          9308.0
#              Officer                                 Buy         12096.0
# 2018-06-30   Beneficial Owner of More than 10% Class Sell     40000000.0
#              Chief Financial Officer                 Buy          5696.0
#              Chief Operating Officer                 Buy         15400.0
#                                                      Sell        13364.0
#              Director                                Buy         24168.0
#                                                      Sell        76916.0
#              Officer                                 Buy          4884.0
#                                                      Sell         6200.0
# 2018-09-30   Director                                Buy          4856.0
#              Officer                                 Buy          1024.0
#
#
#    1 Year  3 Year  5 Year        Field Underlying
# 0   13.78   13.79   18.56      Sales %       LULU
# 1   16.78    4.90   11.77  EPS (TTM) %       LULU
# 2     NaN     NaN     NaN   Dividend %       LULU
#
#
# Points for short: 8 and Points for long: 10
# Ratio of Short to Long 0.8
# PLCE
#   epsActual epsDifference epsEstimate  surprisePercent Underlying    Quarter  \
# 0      2.58          0.11        2.47            0.045       PLCE 2017-10-31
# 1      2.52          0.03        2.49            0.012       PLCE 2018-01-31
# 2      1.87         -0.34        2.21           -0.154       PLCE 2018-04-30
# 3       0.7          0.11        0.59            0.186       PLCE 2018-07-31
#
#    Stock_closeToOpen EarningsDate
# 0           0.053995   2017-11-15
# 1          -0.093199   2018-03-20
# 2          -0.039855   2018-05-17
# 3           0.006909   2018-08-23
#
#
#
#
#
#
#
#
#    Company                         Field  industry  sector Underlying
# 0    18.46               P/E Ratio (TTM)     30.76   17.65       PLCE
# 1    23.28        P/E High - Last 5 Yrs.    106.01   33.14       PLCE
# 2    17.56         P/E Low - Last 5 Yrs.     26.74   13.68       PLCE
# 3     0.25                          Beta      1.18    1.37       PLCE
# 4     1.10          Price to Sales (TTM)      2.00  136.78       PLCE
# 5     6.65           Price to Book (MRQ)      9.60    2.59       PLCE
# 6     6.63  Price to Tangible Book (MRQ)      5.44    2.84       PLCE
# 7    10.96      Price to Cash Flow (TTM)     20.48   10.49       PLCE
#
#
#    Company                                 Field  industry  sector Underlying
# 0    20.11         Sales (MRQ) vs Qtr. 1 Yr. Ago     13.22   12.89       PLCE
# 1     7.77          Sales (TTM) vs TTM 1 Yr. Ago     15.01   11.83       PLCE
# 2     0.66             Sales - 5 Yr. Growth Rate     13.90    3.66       PLCE
# 3   -43.03           EPS (MRQ) vs Qtr. 1 Yr. Ago    488.29   39.45       PLCE
# 4     1.51            EPS (TTM) vs TTM 1 Yr. Ago       NaN     NaN       PLCE
# 5    23.61               EPS - 5 Yr. Growth Rate      2.88    2.39       PLCE
# 6    -8.24  Capital Spending - 5 Yr. Growth Rate      7.63    2.63       PLCE
#
#
#    Company                           Field  industry  sector Underlying
# ...
# 2          79.0          -7.27             -7.01  26 Week            99.0
# 3          72.0           6.70              3.49  52 Week            99.0
# 4          76.0          17.25             16.88      YTD            99.0
#
#   Underlying
# 0       GWRE
# 1       GWRE
# 2       GWRE
# 3       GWRE
# 4       GWRE
#
#
#    Down Last4Weeks  Down LastWeek      NumberOfRevisions  Up Last4Weeks  \
# 0              NaN            NaN  Quarter Ending Jul-18            NaN
# 1              0.0            0.0  Quarter Ending Oct-19            0.0
# 2              NaN            NaN     Year Ending Jul-18            NaN
# 3              0.0            0.0     Year Ending Jul-19            0.0
# 4              0.0            0.0     Year Ending Jul-20            0.0
#
#    Up LastWeek Underlying
# 0          NaN       GWRE
# 1          0.0       GWRE
# 2          NaN       GWRE
# 3          0.0       GWRE
# 4          0.0       GWRE
#
#
#    Down Last4Weeks  Down LastWeek      NumberOfRevisions  Up Last4Weeks  \
# 0              NaN            NaN  Quarter Ending Jul-18            NaN
# 1              0.0            0.0  Quarter Ending Oct-19            0.0
# 2              NaN            NaN     Year Ending Jul-18            NaN
# 3              0.0            0.0     Year Ending Jul-19            0.0
# 4              0.0            0.0     Year Ending Jul-20            0.0
#
#    Up LastWeek Underlying
# 0          NaN       GWRE
# 1          0.0       GWRE
# 2          NaN       GWRE
# 3          0.0       GWRE
# 4          0.0       GWRE
#
#
#                                            Underlying  Shares Traded
# Trading Date Title                   Type
# 2018-09-30   Chief Executive Officer Buy           24       120000.0
#                                      Sell         120       499728.0
#              Chief Operating Officer Sell          24        68712.0
#              General Counsel         Sell          24        64008.0
#              Officer                 Sell          48       116448.0
# 2018-12-31   Chief Executive Officer Buy           24       480000.0
#                                      Sell         192       480000.0
#              Director                Buy           48         9600.0
#                                      Sell          96        19200.0
#
#
#    1 Year  3 Year  5 Year        Field Underlying
# 0   28.54   20.21   17.07      Sales %       GWRE
# 1  -57.88   -4.60  -21.59  EPS (TTM) %       GWRE
# 2     NaN     NaN     NaN   Dividend %       GWRE
#
#
# Points for short: 16 and Points for long: 7
# Ratio of Short to Long 2.2857142857142856
# MOMO
#   epsActual epsDifference epsEstimate  surprisePercent Underlying    Quarter  \
# 0      0.45          0.07        0.38            0.184       MOMO 2017-09-30
# 1      0.53          0.07        0.46            0.152       MOMO 2017-12-31
# 2      0.69          0.19         0.5            0.380       MOMO 2018-03-31
# 3      0.66          0.05        0.61            0.082       MOMO 2018-06-30
#
#    Stock_closeToOpen EarningsDate
# 0          -0.111974   2017-11-28
# 1           0.114218   2018-03-07
# 2           0.099872   2018-05-29
# 3           0.058286   2018-08-22
#
#
#
#
#
#
#
#
# Empty DataFrame
# Columns: [Company, Field, industry, sector, Underlying]
# Index: []
#
#
# Empty DataFrame
# Columns: [Company, Field, industry, sector, Underlying]
# Index: []
#
#
# Empty DataFrame
# Columns: [Company, Field, industry, sector, Underlying]
# Index: []
#
#
# Empty DataFrame
# Columns: [Company, Field, industry, sector, Underlying]
# Index: []
#
#
# Empty DataFrame
# Columns: [IndustryRank, PercentActual, Percentvs.S&P500, Period, RankInIndustry, Underlying]
# Index: []
#
#
# Empty DataFrame
# Columns: [Down Last4Weeks, Down LastWeek, NumberOfRevisions, Up Last4Weeks, Up LastWeek, Underlying]
# Index: []
#
#
# Empty DataFrame
# Columns: [Down Last4Weeks, Down LastWeek, NumberOfRevisions, Up Last4Weeks, Up LastWeek, Underlying]
# Index: []
#
#
# Empty DataFrame
# Columns: [1 Year, 3 Year, 5 Year, Field, Underlying]
# Index: []
#
#
# GIII
#   epsActual epsDifference epsEstimate  surprisePercent Underlying    Quarter  \
# 0      1.67          0.13        1.54            0.084       GIII 2017-10-31
# 1      0.26          0.09        0.17            0.529       GIII 2018-01-31
# 2      0.22          0.27       -0.05            5.400       GIII 2018-04-30
# 3      0.22          0.19        0.03            6.333       GIII 2018-07-31
#
#    Stock_closeToOpen EarningsDate
# 0           0.287079   2017-06-06
# 1           0.100199   2017-12-05
# 2          -0.066915   2018-03-22
# 3           0.166045   2018-06-05
#
#
#
#
#
#
#
#
#    Company                         Field  industry  sector Underlying
# 0    17.53               P/E Ratio (TTM)     40.11   17.65       GIII
# 1    26.61        P/E High - Last 5 Yrs.     51.74   33.14       GIII
# 2    18.87         P/E Low - Last 5 Yrs.     23.32   13.68       GIII
# 3     0.35                          Beta      0.80    1.37       GIII
# 4     0.63          Price to Sales (TTM)      6.48  136.78       GIII
# 5     1.74           Price to Book (MRQ)      8.78    2.59       GIII
# 6     5.55  Price to Tangible Book (MRQ)      9.95    2.84       GIII
# 7    13.04      Price to Cash Flow (TTM)     34.44   10.49       GIII
#
#
#    Company                                 Field  industry  sector Underlying
# 0    16.11         Sales (MRQ) vs Qtr. 1 Yr. Ago     19.37   12.89       GIII
# 1    16.54          Sales (TTM) vs TTM 1 Yr. Ago      7.48   11.83       GIII
# 2    14.93             Sales - 5 Yr. Growth Rate     10.07    3.66       GIII
# 3   213.59           EPS (MRQ) vs Qtr. 1 Yr. Ago     42.47   39.45       GIII
# 4   214.37            EPS (TTM) vs TTM 1 Yr. Ago       NaN     NaN       GIII
# 5     0.02               EPS - 5 Yr. Growth Rate      9.37    2.39       GIII
# 6    24.33  Capital Spending - 5 Yr. Growth Rate     13.53    2.63       GIII
#
#
#    Company                           Field  industry  sector Underlying
# 0    37.50              Gross Margin (TTM)     43.33   23.88       GIII
# 1    35.85       Gross Margin - 5 Yr. Avg.     39.59   23.11       GIII
# 2     8.51              EBITD Margin (TTM)       NaN     NaN       GIII
# 3     7.82               EBITD - 5 Yr. Avg     12.88   13.93       GIII
# 4     7.03          Operating Margin (TTM)      9.66  -12.77       GIII
# 5     6.40   Operating Margin - 5 Yr. Avg.     10.41    9.35       GIII
# 6     5.57            Pre-Tax Margin (TTM)     12.42   13.75       GIII
# 7     5.78     Pre-Tax Margin - 5 Yr. Avg.     10.66   12.18       GIII
# 8     3.65         Net Profit Margin (TTM)      9.18   13.96       GIII
# 9     3.71  Net Profit Margin - 5 Yr. Avg.      7.71    9.60       GIII
#
#
#    Company                       Field  industry  sector Underlying
# 0     0.99           Quick Ratio (MRQ)      1.36    1.21       GIII
# 1     2.12         Current Ratio (MRQ)      4.82    1.53       GIII
# 2    45.46     LT Debt to Equity (MRQ)     11.12   52.44       GIII
# 3    45.46  Total Debt to Equity (MRQ)     39.89   82.64       GIII
# 4     2.83     Interest Coverage (TTM)     36.47    3.98       GIII
#
#
#    IndustryRank  PercentActual  Percentvs.S&P500   Period  RankInIndustry  \
# 0          50.0          -3.61             -3.60   4 Week            74.0
# 1          53.0         -15.49             -8.71  13 Week            82.0
# 2          66.0          -2.98             -2.70  26 Week            99.0
# 3          72.0          40.92             36.67  52 Week            99.0
# 4          72.0           4.09              3.76      YTD            99.0
#
#   Underlying
# 0       GIII
# 1       GIII
# 2       GIII
# 3       GIII
# 4       GIII
#
#
#    Down Last4Weeks  Down LastWeek      NumberOfRevisions  Up Last4Weeks  \
# 0              NaN            NaN  Quarter Ending Jan-18            NaN
# 1              0.0            0.0  Quarter Ending Apr-19            0.0
# 2              NaN            NaN     Year Ending Jan-18            NaN
# 3              0.0            0.0     Year Ending Jan-19            0.0
# 4              0.0            0.0     Year Ending Jan-20            0.0
#
#    Up LastWeek Underlying
# 0          NaN       GIII
# 1          0.0       GIII
# 2          NaN       GIII
# 3          0.0       GIII
# 4          0.0       GIII
#
#
#    Down Last4Weeks  Down LastWeek      NumberOfRevisions  Up Last4Weeks  \
# 0              NaN            NaN  Quarter Ending Jan-18            NaN
# 1              0.0            0.0  Quarter Ending Apr-19            0.0
# 2              NaN            NaN     Year Ending Jan-18            NaN
# 3              0.0            0.0     Year Ending Jan-19            1.0
# 4              0.0            0.0     Year Ending Jan-20            0.0
#
#    Up LastWeek Underlying
# 0          NaN       GIII
# 1          0.0       GIII
# 2          NaN       GIII
# 3          0.0       GIII
# 4          0.0       GIII
#
#
#                                            Underlying  Shares Traded
# Trading Date Title                   Type
# 2018-06-30   Chief Executive Officer Buy            4       528488.0
#                                      Sell          16      3080000.0
#              Director                Buy           28        66588.0
#                                      Sell          12        69648.0
#              Officer and Director    Sell           4        80000.0
# 2018-09-30   Director                Sell          12        72452.0
# 2018-12-31   Chief Financial Officer Sell           4        15392.0
#              Chief Operating Officer Sell           8       161076.0
#              Director                Sell           4         2736.0
#              Officer and Director    Sell           4        37276.0
#              President               Sell           4       124924.0
#
#
#    1 Year  3 Year  5 Year        Field Underlying
# 0   17.62    9.86   14.93      Sales %       GIII
# 1   28.07  -17.33    0.02  EPS (TTM) %       GIII
# 2     NaN     NaN     NaN   Dividend %       GIII
#
#
# Points for short: 9 and Points for long: 12
# Ratio of Short to Long 0.75
# ASNA
#   epsActual epsDifference epsEstimate  surprisePercent Underlying    Quarter  \
# 0      0.11             0        0.11            0.000       ASNA 2017-10-31
# 1     -0.12         -0.03       -0.09           -0.333       ASNA 2018-01-31
# 2     -0.08          0.01       -0.09            0.111       ASNA 2018-04-30
# 3      0.07          0.05        0.02            2.500       ASNA 2018-07-31
#
#    Stock_closeToOpen EarningsDate
# 0           0.027473   2017-06-08
# 1          -0.195402   2017-12-04
# 2          -0.132231   2018-03-05
# 3          -0.071038   2018-06-04
#
#
#
#
#
#
#
#
#    Company                         Field  industry  sector Underlying
# 0      NaN               P/E Ratio (TTM)     34.92   19.17       ASNA
# 1    19.57        P/E High - Last 5 Yrs.    108.52   33.06       ASNA
# 2    19.26         P/E Low - Last 5 Yrs.     25.63   12.82       ASNA
# 3     1.92                          Beta      1.56    1.26       ASNA
# 4     0.06          Price to Sales (TTM)      2.33    1.91       ASNA
# 5     0.52           Price to Book (MRQ)      3.94    2.29       ASNA
# 6      NaN  Price to Tangible Book (MRQ)      4.21    2.88       ASNA
# 7      NaN      Price to Cash Flow (TTM)     19.18   13.97       ASNA
#
#
#    Company                                 Field  industry  sector Underlying
# 0    -8.51         Sales (MRQ) vs Qtr. 1 Yr. Ago     11.84    7.01       ASNA
# 1    -4.94          Sales (TTM) vs TTM 1 Yr. Ago      7.96    4.50       ASNA
# 2    14.67             Sales - 5 Yr. Growth Rate     17.85    4.13       ASNA
# 3  -214.02           EPS (MRQ) vs Qtr. 1 Yr. Ago    108.76   41.83       ASNA
# 4 -8266.84            EPS (TTM) vs TTM 1 Yr. Ago       NaN     NaN       ASNA
# 5      NaN               EPS - 5 Yr. Growth Rate     -5.14    2.01       ASNA
# 6    12.39  Capital Spending - 5 Yr. Growth Rate     11.00    1.76       ASNA
#
#
#    Company                           Field  industry  sector Underlying
# 0    58.04              Gross Margin (TTM)     49.37   23.66       ASNA
# 1    56.15       Gross Margin - 5 Yr. Avg.     48.56   22.90       ASNA
# 2     8.10              EBITD Margin (TTM)       NaN     NaN       ASNA
# 3     8.41               EBITD - 5 Yr. Avg     12.17   34.72       ASNA
# 4   -19.76          Operating Margin (TTM)      7.34   13.61       ASNA
# 5    -3.53   Operating Margin - 5 Yr. Avg.      8.56   38.29       ASNA
# 6   -21.27            Pre-Tax Margin (TTM)      6.09   15.98       ASNA
# 7    -4.35     Pre-Tax Margin - 5 Yr. Avg.      7.27   40.80       ASNA
# 8   -16.05         Net Profit Margin (TTM)      3.42   13.48       ASNA
# 9    -3.66  Net Profit Margin - 5 Yr. Avg.      4.57   37.59       ASNA
#
#
#    Company                       Field  industry  sector Underlying
# 0     0.52           Quick Ratio (MRQ)      1.84    1.19       ASNA
# 1     1.20         Current Ratio (MRQ)      2.58    1.45       ASNA
# 2   181.99     LT Debt to Equity (MRQ)     39.09   35.37       ASNA
# 3   187.34  Total Debt to Equity (MRQ)     60.44   70.08       ASNA
# 4     1.79     Interest Coverage (TTM)     22.00    6.28       ASNA
#
#
#    IndustryRank  PercentActual  Percentvs.S&P500   Period  RankInIndustry  \
# 0          84.0          10.61              6.79   4 Week            99.0
# 1          17.0           7.35              2.12  13 Week            99.0
# 2          19.0         -42.97            -47.30  26 Week            13.0
# 3          44.0         -61.78            -67.61  52 Week            14.0
# 4          16.0         -64.62            -68.93      YTD             6.0
#
#   Underlying
# 0       ASNA
# 1       ASNA
# 2       ASNA
# 3       ASNA
# 4       ASNA
#
#
#    Down Last4Weeks  Down LastWeek      NumberOfRevisions  Up Last4Weeks  \
# 0              NaN            NaN  Quarter Ending Jul-18            NaN
# 1              0.0            0.0  Quarter Ending Oct-19            0.0
# 2              NaN            NaN     Year Ending Jul-18            NaN
# 3              0.0            0.0     Year Ending Jul-19            0.0
# 4              0.0            0.0     Year Ending Jul-20            0.0
#
#    Up LastWeek Underlying
# 0          NaN       ASNA
# 1          0.0       ASNA
# 2          NaN       ASNA
# 3          0.0       ASNA
# 4          0.0       ASNA
#
#
#    Down Last4Weeks  Down LastWeek      NumberOfRevisions  Up Last4Weeks  \
# 0              NaN            NaN  Quarter Ending Jul-18            NaN
# 1              0.0            0.0  Quarter Ending Oct-19            0.0
# 2              NaN            NaN     Year Ending Jul-18            NaN
# 3              0.0            0.0     Year Ending Jul-19            0.0
# 4              1.0            0.0     Year Ending Jul-20            0.0
#
#    Up LastWeek Underlying
# 0          NaN       ASNA
# 1          0.0       ASNA
# 2          NaN       ASNA
# 3          0.0       ASNA
# 4          0.0       ASNA
#
#
#                                            Underlying  Shares Traded
# Trading Date Title                   Type
# 2018-09-30   Chief Executive Officer Sell           5        81080.0
#              Chief Financial Officer Buy           10        33635.0
#                                      Sell           5         3150.0
#              Director                Buy           45      1664640.0
#              Officer                 Buy           15        75740.0
#                                      Sell          15        52150.0
#              President               Buy           10       163080.0
#                                      Sell          10        59250.0
# 2018-12-31   Officer                 Buy            5        79995.0
#                                      Sell           5        30575.0
#
#
#     1 Year  3 Year  5 Year        Field Underlying
# 0    -4.94   11.55   14.67      Sales %       ASNA
# 1 -8749.86     NaN     NaN  EPS (TTM) %       ASNA
# 2      NaN     NaN     NaN   Dividend %       ASNA
#
#
# Points for short: 16 and Points for long: 5
# Ratio of Short to Long 3.2

# %%
direction_points.join(curr_earnings[['Call Time',
                                     'EarningsDate']], how = 'left').sort_values(['EarningsDate',
                                                                                  'Call Time'],ascending = True)
# Out:
#      PointsLong PointsShort ShortToLongRatio           Call Time EarningsDate
# ASNA          5          16              3.2  After Market Close   2018-12-03
# FNSR         15           3              0.2  Before Market Open   2018-12-03
# TOL          15           6              0.4  After Market Close   2018-12-04
# GWRE          7          16          2.28571  After Market Close   2018-12-04
# VRNT         13           9         0.692308  After Market Close   2018-12-05
# SNPS          9          15          1.66667  After Market Close   2018-12-05
# LULU         10           8              0.8  After Market Close   2018-12-05
# CIEN         11           4         0.363636  Before Market Open   2018-12-05
# GIII         12           9             0.75  Before Market Open   2018-12-05
# SAIC         10          14              1.4  After Market Close   2018-12-06
# ULTA         16           1           0.0625  After Market Close   2018-12-06
# PLCE         10          10                1  Before Market Open   2018-12-06
# PDCO          1          20               20  Before Market Open   2018-12-06

# %%
test = reuters_query('COUP')

# %%
test.insiders_txns
# Out:
#                       Name  Price  Shares Traded                    Title  \
# 0            Ford (Todd R)  60.95          300.0  Chief Financial Officer
# 1      Bernshteyn (Robert)  59.44          200.0  Chief Executive Officer
# 2      Bernshteyn (Robert)  54.61        11645.0  Chief Executive Officer
# 3            Ford (Todd R)  62.15          300.0  Chief Financial Officer
# 4      Bernshteyn (Robert)  63.32          903.0  Chief Executive Officer
# 5      Bernshteyn (Robert)  62.14         2000.0  Chief Executive Officer
# 6            Ford (Todd R)   5.52        12500.0  Chief Financial Officer
# 7            Ford (Todd R)  59.01          600.0  Chief Financial Officer
# 8            Ford (Todd R)  63.35          200.0  Chief Financial Officer
# 9      Bernshteyn (Robert)  57.65         2100.0  Chief Executive Officer
# 10     Bernshteyn (Robert)  58.87         2810.0  Chief Executive Officer
# 11           Ford (Todd R)  57.78          400.0  Chief Financial Officer
# 12     Bernshteyn (Robert)  55.40        29556.0  Chief Executive Officer
# 13     Bernshteyn (Robert)  60.72         1100.0  Chief Executive Officer
# 14     Bernshteyn (Robert)  56.11        12911.0  Chief Executive Officer
# 15           Ford (Todd R)  55.50         5308.0  Chief Financial Officer
# 16           Ford (Todd R)  56.15         2322.0  Chief Financial Officer
# 17     Bernshteyn (Robert)   2.32        63225.0  Chief Executive Officer
# 18           Ford (Todd R)  54.68         3070.0  Chief Financial Officer
# 19       Winter (Steven M)  65.00         5668.0                  Officer
# 20       Winter (Steven M)  13.04         5668.0                  Officer
# 21       Winter (Steven M)  13.04         5668.0                  Officer
# 22       Winter (Steven M)  61.96         3018.0                  Officer
# 23   Tiscornia (Anthony D)   3.92          521.0                  Officer
# 24   Tiscornia (Anthony D)  63.09          781.0                  Officer
# 25           Ford (Todd R)  60.95          300.0  Chief Financial Officer
# 26     Bernshteyn (Robert)  59.44          200.0  Chief Executive Officer
# 27     Bernshteyn (Robert)  54.61        11645.0  Chief Executive Officer
# 28           Ford (Todd R)  62.15          300.0  Chief Financial Officer
# 29     Bernshteyn (Robert)  63.32          903.0  Chief Executive Officer
# ..                     ...    ...            ...                      ...
# 345      Winter (Steven M)  13.04         5668.0                  Officer
# 346      Winter (Steven M)  13.04         5668.0                  Officer
# 347      Winter (Steven M)  61.96         3018.0                  Officer
# 348  Tiscornia (Anthony D)   3.92          521.0                  Officer
# 349  Tiscornia (Anthony D)  63.09          781.0                  Officer
# 350          Ford (Todd R)  60.95          300.0  Chief Financial Officer
# 351    Bernshteyn (Robert)  59.44          200.0  Chief Executive Officer
# 352    Bernshteyn (Robert)  54.61        11645.0  Chief Executive Officer
# 353          Ford (Todd R)  62.15          300.0  Chief Financial Officer
# 354    Bernshteyn (Robert)  63.32          903.0  Chief Executive Officer
# 355    Bernshteyn (Robert)  62.14         2000.0  Chief Executive Officer
# 356          Ford (Todd R)   5.52        12500.0  Chief Financial Officer
# 357          Ford (Todd R)  59.01          600.0  Chief Financial Officer
# 358          Ford (Todd R)  63.35          200.0  Chief Financial Officer
# 359    Bernshteyn (Robert)  57.65         2100.0  Chief Executive Officer
# 360    Bernshteyn (Robert)  58.87         2810.0  Chief Executive Officer
# 361          Ford (Todd R)  57.78          400.0  Chief Financial Officer
# 362    Bernshteyn (Robert)  55.40        29556.0  Chief Executive Officer
# 363    Bernshteyn (Robert)  60.72         1100.0  Chief Executive Officer
# 364    Bernshteyn (Robert)  56.11        12911.0  Chief Executive Officer
# 365          Ford (Todd R)  55.50         5308.0  Chief Financial Officer
# 366          Ford (Todd R)  56.15         2322.0  Chief Financial Officer
# 367    Bernshteyn (Robert)   2.32        63225.0  Chief Executive Officer
# 368          Ford (Todd R)  54.68         3070.0  Chief Financial Officer
# 369      Winter (Steven M)  65.00         5668.0                  Officer
# 370      Winter (Steven M)  13.04         5668.0                  Officer
# 371      Winter (Steven M)  13.04         5668.0                  Officer
# 372      Winter (Steven M)  61.96         3018.0                  Officer
# 373  Tiscornia (Anthony D)   3.92          521.0                  Officer
# 374  Tiscornia (Anthony D)  63.09          781.0                  Officer
#
#     Trading Date  Type Underlying
# 0     2018-11-18  Sell       COUP
# 1     2018-11-18  Sell       COUP
# 2     2018-11-18  Sell       COUP
# 3     2018-11-18  Sell       COUP
# 4     2018-11-18  Sell       COUP
# 5     2018-11-18  Sell       COUP
# 6     2018-11-18   Buy       COUP
# 7     2018-11-18  Sell       COUP
# 8     2018-11-18  Sell       COUP
# 9     2018-11-18  Sell       COUP
# 10    2018-11-18  Sell       COUP
# 11    2018-11-18  Sell       COUP
# 12    2018-11-18  Sell       COUP
# 13    2018-11-18  Sell       COUP
# 14    2018-11-18  Sell       COUP
# 15    2018-11-18  Sell       COUP
# 16    2018-11-18  Sell       COUP
# 17    2018-11-18   Buy       COUP
# 18    2018-11-18  Sell       COUP
# 19    2018-11-15  Sell       COUP
# 20    2018-11-15   Buy       COUP
# 21    2018-11-11   Buy       COUP
# 22    2018-11-11  Sell       COUP
# 23    2018-11-11   Buy       COUP
# 24    2018-11-11  Sell       COUP
# 25    2018-11-18  Sell       COUP
# 26    2018-11-18  Sell       COUP
# 27    2018-11-18  Sell       COUP
# 28    2018-11-18  Sell       COUP
# 29    2018-11-18  Sell       COUP
# ..           ...   ...        ...
# 345   2018-11-15   Buy       COUP
# 346   2018-11-11   Buy       COUP
# 347   2018-11-11  Sell       COUP
# 348   2018-11-11   Buy       COUP
# 349   2018-11-11  Sell       COUP
# 350   2018-11-18  Sell       COUP
# 351   2018-11-18  Sell       COUP
# 352   2018-11-18  Sell       COUP
# 353   2018-11-18  Sell       COUP
# 354   2018-11-18  Sell       COUP
# 355   2018-11-18  Sell       COUP
# 356   2018-11-18   Buy       COUP
# 357   2018-11-18  Sell       COUP
# 358   2018-11-18  Sell       COUP
# 359   2018-11-18  Sell       COUP
# 360   2018-11-18  Sell       COUP
# 361   2018-11-18  Sell       COUP
# 362   2018-11-18  Sell       COUP
# 363   2018-11-18  Sell       COUP
# 364   2018-11-18  Sell       COUP
# 365   2018-11-18  Sell       COUP
# 366   2018-11-18  Sell       COUP
# 367   2018-11-18   Buy       COUP
# 368   2018-11-18  Sell       COUP
# 369   2018-11-15  Sell       COUP
# 370   2018-11-15   Buy       COUP
# 371   2018-11-11   Buy       COUP
# 372   2018-11-11  Sell       COUP
# 373   2018-11-11   Buy       COUP
# 374   2018-11-11  Sell       COUP
#
# [375 rows x 7 columns]

# %%
# BKE CRM RAVN

# %%
selected_name = 'ASNA'

aq = alphaquery(selected_name)
print(aq.vol_df)


select_trades = insider_trades[insider_trades.Underlying == selected_name].groupby(['Trading Date','Title',
                                                                                    'Type']).agg({'Underlying':'count',
                                                                                                  'Shares Traded': 'sum'}).reset_index()
select_trades['Percent of Float'] = 100*select_trades['Shares Traded']/curr_shares_out.loc[selected_name,'Shares Outstanding(Mil.)']
select_trades.groupby(['Trading Date','Title',
                       'Type']).agg({'Underlying':'count',
                                     'Shares Traded': 'sum',
                                     'Percent of Float': 'sum'})
# Out:
#                                         10-Day  20-Day  30-Day  60-Day  \
# Field
# Historical Volatility (Close-to-Close)  0.5939  0.6282  0.6893  0.7643
# Historical Volatility (Parkinson)       0.6443  0.8068  0.7609  0.7672
# Implied Volatility (Calls)              1.0613  1.0613  0.9931  0.8610
# Implied Volatility (Puts)               1.0644  1.0644  0.9988  0.8830
# Implied Volatility (Mean)               1.0628  1.0628  0.9960  0.8720
# Put-Call Implied Volatility Ratio       1.0029  1.0029  1.0057  1.0256
# Implied Volatility Skew                 0.0833  0.0833  0.0797  0.0628
# Put-Call Ratio (Volume)                 0.7734  0.7734  0.6946  0.5320
# Put-Call Ratio (Open Interest)          3.3550  3.3550  3.0433  2.0393
# Forward Price                           3.1000  3.1000  3.1000  3.1000
# Call Breakeven Price                    3.7300  3.7300  3.7400  3.8800
# Put Breakeven Price                     2.9800  2.9800  2.9500  2.8100
# Option Breakeven Price                  3.0400  3.0400  3.0600  3.2500
#
#                                         90-Day  120-Day  150-Day  180-Day  \
# Field
# Historical Volatility (Close-to-Close)  0.7499   0.6994   0.6686   0.6846
# Historical Volatility (Parkinson)       0.7632   0.7159   0.6940   0.7069
# Implied Volatility (Calls)              0.8376   0.8155   0.7948   0.7741
# Implied Volatility (Puts)               0.8884   0.8717   0.8356   0.7995
# Implied Volatility (Mean)               0.8630   0.8436   0.8152   0.7868
# Put-Call Implied Volatility Ratio       1.0606   1.0689   1.0513   1.0328
# Implied Volatility Skew                 0.0366   0.0255   0.0279   0.0302
# Put-Call Ratio (Volume)                 0.4867   0.4414   0.3961   0.3507
# Put-Call Ratio (Open Interest)          0.9470   0.5393   0.7402   0.9411
# Forward Price                           3.1000   3.1100   3.1200   3.1400
# Call Breakeven Price                    4.1800   4.2800   4.2100   4.1400
# Put Breakeven Price                     2.6100   2.4800   2.4300   2.3800
# Option Breakeven Price                  3.6400   3.6900   3.4300   3.1700
#
#                                        Underlying
# Field
# Historical Volatility (Close-to-Close)       ASNA
# Historical Volatility (Parkinson)            ASNA
# Implied Volatility (Calls)                   ASNA
# Implied Volatility (Puts)                    ASNA
# Implied Volatility (Mean)                    ASNA
# Put-Call Implied Volatility Ratio            ASNA
# Implied Volatility Skew                      ASNA
# Put-Call Ratio (Volume)                      ASNA
# Put-Call Ratio (Open Interest)               ASNA
# Forward Price                                ASNA
# Call Breakeven Price                         ASNA
# Put Breakeven Price                          ASNA
# Option Breakeven Price                       ASNA
#                                            Underlying  Shares Traded  \
# Trading Date Title                   Type
# 2018-09-30   Chief Executive Officer Buy            1       258590.0
#              Chief Financial Officer Buy            1        10035.0
#                                      Sell           1        10550.0
#              Director                Buy            1      1664640.0
#              Officer                 Buy            1       173020.0
#                                      Sell           1        23560.0
#              President               Buy            1       163080.0
#                                      Sell           1        59250.0
# 2018-12-31   Officer                 Buy            1        79995.0
#                                      Sell           1        30575.0
#
#                                            Percent of Float
# Trading Date Title                   Type
# 2018-09-30   Chief Executive Officer Buy           0.131011
#              Chief Financial Officer Buy           0.005084
#                                      Sell          0.005345
#              Director                Buy           0.843368
#              Officer                 Buy           0.087658
#                                      Sell          0.011936
#              President               Buy           0.082622
#                                      Sell          0.030018
# 2018-12-31   Officer                 Buy           0.040528
#                                      Sell          0.015490

# %%
further_reduce
# Out:
#       daily_ann  intra_ann  ovrnt_ann  Implied Volatility (Calls)  \
# SAIC   0.293864   0.573031   0.134131                      0.4161
# SNPS   0.334326   0.578436   0.144141                      0.3483
# KR     0.332669   0.588991   0.115852                      0.4399
# VRNT   0.355958   0.617114   0.139365                      0.4268
# PDCO   0.372313   0.692127   0.107568                      0.5080
# LULU   0.420008   0.706739   0.299062                      0.6469
# THO    0.444668   0.709771   0.156784                      0.6512
# FNSR   0.622683   0.721044   0.706454                      0.2756
# PLCE   0.530534   0.800946   0.423058                      0.4877
# TOL    0.452874   0.810301   0.222340                      0.4530
# GWRE   0.494042   0.842905   0.240880                      0.4222
# AOBC   0.409852   0.968303   0.348703                      0.6560
# CONN   0.564493   1.014881   0.209340                      0.8436
# MOMO   0.726729   1.151078   0.475162                      0.8446
# ASNA   0.856926   1.646143   0.212730                      0.9075
#
#       Implied Volatility (Puts)  Put-Call Implied Volatility Ratio  \
# SAIC                     0.4173                             1.0029
# SNPS                     0.3644                             1.0462
# KR                       0.4375                             0.9945
# VRNT                     0.4185                             0.9806
# PDCO                     0.5074                             0.9988
# LULU                     0.6522                             1.0082
# THO                      0.7023                             1.0785
# FNSR                     0.2713                             0.9844
# PLCE                     0.5167                             1.0595
# TOL                      0.4577                             1.0104
# GWRE                     0.4465                             1.0576
# AOBC                     0.6978                             1.0637
# CONN                     0.8642                             1.0244
# MOMO                     0.8482                             1.0043
# ASNA                     1.0739                             1.1834
#
#       Implied Volatility Skew        Buy      Gift        Sell  BuyToSell
# SAIC                   0.0577   798885.0  178848.0    747882.0   1.068197
# SNPS                   0.0432   413100.0  239740.0    348850.0   1.184177
# KR                     0.0601  2088364.0  156149.0   1066845.0   1.957514
# VRNT                   0.0619   641436.0       NaN    651476.0   0.984589
# PDCO                   0.0567   840804.0       NaN      9468.0  88.804816
# LULU                   0.0575    77432.0       NaN  40096480.0   0.001931
# THO                    0.0153   700964.0   16400.0    549127.0   1.276506
# FNSR                   0.1576   939015.0       NaN   1585486.0   0.592257
# PLCE                   0.0336   139175.0       NaN   1526625.0   0.091165
# TOL                    0.0525  2102970.0  252767.0   2104829.0   0.999117
# GWRE                   0.0506   609600.0       NaN   1248096.0   0.488424
# AOBC                   0.0566   508599.0       NaN     80532.0   6.315489
# CONN                   0.0253   405435.0       NaN    200440.0   2.022725
# MOMO                   0.0247        NaN       NaN         NaN        NaN
# ASNA                   0.0230  2209305.0       NaN    123935.0  17.826320

# %%
# Saving Selected Names for Reference

os.chdir('C:\\Users\\Fang\\Desktop\\Python Trading\\Trading\\Data\\Historical Queries\\Earnings')

datenow = dt.datetime.today().strftime('%Y-%m-%d')

scores_df[scores_df.index.isin(longs + shorts)].sort_values(['ValuationScore',
                       'TotalScore']).join(summary_df.join(curr_earnings)).to_csv('earnings-{}.csv'.format(datenow))

os.chdir(main_dir)

# %% [markdown]
# ## Barbell Hedging

# %%
ratios = spx_put_backratios(50, 1, 0.2, 2, 25)

# %%
ratios

# %%
spx_options = all_greeks(all_options('^SPX',50,1,0.2))
spx_options = spx_options[(spx_options['Type'] == 'put') &
                          (spx_options['Strike'] < spx_options['Underlying_Price'])]

# %%
spx_options[(spx_options['DTE'] == 7) &
            (spx_options['Strike'] == 2390.0)]

# %%
import requests as req
from bs4 import BeautifulSoup as soup

# %%
ticker = 'FSNR'
aq_url = 'https://www.alphaquery.com/stock/{}/earnings-history'.format(ticker)
s = req.session()

curr_aq = bs(s.get(aq_url).text, 'lxml')

s.cookies.clear()

# %%
curr_earnings_table = curr_aq.select_one('table')

for row in curr_earnings_table.find_all('tr'):
    print(row)
    break
# Out:
# <tr>
# <th class="text-center">Announcement Date</th>
# <th class="text-center">Fiscal Quarter End</th>
# <th class="text-center">Estimated EPS</th>
# <th class="text-center">Actual EPS</th>
# </tr>
