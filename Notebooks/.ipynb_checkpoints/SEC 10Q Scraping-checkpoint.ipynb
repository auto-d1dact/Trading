# %%
import pandas as pd
import numpy as np
import datetime as dt
from bs4 import BeautifulSoup as bs
import requests
import time

# %%
crawler_url = 'https://www.sec.gov/Archives/edgar/data/1661306/0001661306-18-000051-index.htm'
crawler_docs = bs(requests.get(crawler_url).text,'lxml').select_one('table[class="tableFile"]')
crawler_10q_url = 'https://www.sec.gov' + crawler_docs.find_all('tr')[1].find('a').attrs['href']
curr_10q = bs(requests.get(crawler_10q_url).text, 'lxml')

# %%
tables = curr_10q.find_all('table')

# %%
balancesheet = list(filter(lambda x: "total assets" in x.text.lower() and "total liabilities" in x.text.lower(), tables))[0]

# %%
balancesheet.find_all('tr')
# Out:
# [<tr><td colspan="9"></td></tr>,
#  <tr><td style="width:68%;"></td><td style="width:1%;"></td><td style="width:1%;"></td><td style="width:13%;"></td><td style="width:1%;"></td><td style="width:1%;"></td><td style="width:1%;"></td><td style="width:13%;"></td><td style="width:1%;"></td></tr>,
# ...
